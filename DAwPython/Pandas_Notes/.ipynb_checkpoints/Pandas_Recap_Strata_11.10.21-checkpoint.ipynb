# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.describe().T
# Out:
#           count       mean        std   min      25%      50%   75%       max
# survived  891.0   0.383838   0.486592  0.00   0.0000   0.0000   1.0    1.0000
# pclass    891.0   2.308642   0.836071  1.00   2.0000   3.0000   3.0    3.0000
# age       714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# sibsp     891.0   0.523008   1.102743  0.00   0.0000   0.0000   1.0    8.0000
# parch     891.0   0.381594   0.806057  0.00   0.0000   0.0000   0.0    6.0000
# fare      891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %%
df[~df.sex.str.contains("female")]  # df[df.sex=="male"]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.sex.value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
df["age"][df.sex=="male"]  # df["age"][~df.sex.str.contains("female")]
#df[~df.sex.str.contains("female")]["age"]
# Out:
# 0      22.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
#        ...
# 883    28.0
# 884    25.0
# 886    27.0
# 889    26.0
# 890    32.0
# Name: age, Length: 577, dtype: float64

# %%
df[~df.sex.str.contains("female")]["age"]
# Out:
# 0      22.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
#        ...
# 883    28.0
# 884    25.0
# 886    27.0
# 889    26.0
# 890    32.0
# Name: age, Length: 577, dtype: float64

# %%
df[(df.sex=="male") & (df.age>=18)]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 12          0       3  male  20.0      0      0   8.0500        S   Third
# 13          0       3  male  39.0      1      5  31.2750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#      who  adult_male deck  embark_town alive  alone
# ...

# %%
df.survived[(df.sex=="male") & (df.age>=18)].mean()
# Out:
# 0.17721518987341772

# %%
df.survived[~((df.sex=="male") & (df.age>=18))].mean()
# Out:
# 0.5483870967741935

# %%
df.survived[(df.sex=="female") | (df.age<18)].mean()
# Out:
# 0.6881720430107527

# %%
df.survived[(df.sex!="male") & (df.age<18)].mean()
# Out:
# 0.6909090909090909

# %%
df.groupby("sex")[ ["survived","age"]].mean()
# Out:
#         survived        age
# sex
# female  0.742038  27.915709
# male    0.188908  30.726645

# %%
df.groupby(["sex","pclass"])["survived"].mean()
# Out:
# sex     pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: survived, dtype: float64

# %%
planets = sns.load_dataset("planets")

# %%
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
planets.shape
# Out:
# (1035, 6)

# %%
df = pd.DataFrame({"key":["A","B","C","A","B","C"],
                  "data":range(6)},
                  columns=["key","data"])
df
# Out:
#   key  data
# 0   A     0
# 1   B     1
# 2   C     2
# 3   A     3
# 4   B     4
# 5   C     5

# %%
df.groupby("key").sum()
# Out:
#      data
# key
# A       3
# B       5
# C       7

# %%
df.groupby("key").mean()
# Out:
#      data
# key
# A     1.5
# B     2.5
# C     3.5

# %%
planets.groupby("method").median()
# Out:
#                                number  orbital_period   mass  distance    year
# method
# Astrometry                        1.0      631.180000    NaN    17.875  2011.5
# Eclipse Timing Variations         2.0     4343.500000  5.125   315.360  2010.0
# Imaging                           1.0    27500.000000    NaN    40.395  2009.0
# Microlensing                      1.0     3300.000000    NaN  3840.000  2010.0
# Orbital Brightness Modulation     2.0        0.342887    NaN  1180.000  2011.0
# Pulsar Timing                     3.0       66.541900    NaN  1200.000  1994.0
# Pulsation Timing Variations       1.0     1170.000000    NaN       NaN  2007.0
# Radial Velocity                   1.0      360.200000  1.260    40.445  2009.0
# Transit                           1.0        5.714932  1.470   341.000  2012.0
# Transit Timing Variations         2.0       57.011000    NaN   855.000  2012.5

# %%
planets.groupby("method")["orbital_period"].median()
# Out:
# method
# Astrometry                         631.180000
# Eclipse Timing Variations         4343.500000
# Imaging                          27500.000000
# Microlensing                      3300.000000
# Orbital Brightness Modulation        0.342887
# Pulsar Timing                       66.541900
# Pulsation Timing Variations       1170.000000
# Radial Velocity                    360.200000
# Transit                              5.714932
# Transit Timing Variations           57.011000
# Name: orbital_period, dtype: float64

# %%
rng = np.random.RandomState(0)
df = pd.DataFrame({"key":["A","B","C","A","B","C"],
                  "data1":range(6),
                  "data2":rng.randint(0,10,6)},
                  columns=["key","data1","data2"])
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9

# %%
df.groupby("key")["data1"].median()
# Out:
# key
# A    1.5
# B    2.5
# C    3.5
# Name: data1, dtype: float64

# %%
df.groupby("key")["data1"].min()
# Out:
# key
# A    0
# B    1
# C    2
# Name: data1, dtype: int64

# %%
df.groupby("key").aggregate(["min", np.median, max])
# Out:
#     data1            data2
#       min median max   min median max
# key
# A       0    1.5   3     3    4.0   5
# B       1    2.5   4     0    3.5   7
# C       2    3.5   5     3    6.0   9

# %%
df.groupby("key").aggregate({"data1": min,
                             "data2":max})
# Out:
#      data1  data2
# key
# A        0      5
# B        1      7
# C        2      9

# %%
a = df.groupby("key").std()
a
# Out:
#        data1     data2
# key
# A    2.12132  1.414214
# B    2.12132  4.949747
# C    2.12132  4.242641

# %%
def filter_func(x):
    return x["data2"].std() > 4

# %%
b = df.groupby("key").filter(filter_func)
b
# Out:
#   key  data1  data2
# 1   B      1      0
# 2   C      2      3
# 4   B      4      7
# 5   C      5      9

# %%
display(df,a,b)
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9
#        data1     data2
# key
# A    2.12132  1.414214
# B    2.12132  4.949747
# C    2.12132  4.242641
#   key  data1  data2
# 1   B      1      0
# 2   C      2      3
# 4   B      4      7
# 5   C      5      9

# %%
df.groupby("key").transform(lambda x: x-x.mean())
# Out:
#    data1  data2
# 0   -1.5    1.0
# 1   -1.5   -3.5
# 2   -1.5   -3.0
# 3    1.5   -1.0
# 4    1.5    3.5
# 5    1.5    3.0

# %%
def norm_by_data2(x):
    x["data1"] /= x["data2"].sum()  # x["data1"] =  x["data1"]/x["data2"].sum()
    return x

# %%
df.groupby("key").apply(norm_by_data2)
# Out:
#   key     data1  data2
# 0   A  0.000000      5
# 1   B  0.142857      0
# 2   C  0.166667      3
# 3   A  0.375000      3
# 4   B  0.571429      7
# 5   C  0.416667      9

# %%
L = [0,1,0,1,2,0]
a1 = df.groupby(L).sum()  # L deki listeye göre df 0,2 ve 5 satıra 0, 1 ve 3.satıra 1, 4.satıra 2 indexini vererek bunlara göre grupluyor.
a1
# Out:
#    data1  data2
# 0      7     17
# 1      4      3
# 2      4      7

# %%
display(df, a1)
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9
#    data1  data2
# 0      7     17
# 1      4      3
# 2      4      7

# %%
df2 = df.set_index("key")
df2
# Out:
#      data1  data2
# key
# A        0      5
# B        1      0
# C        2      3
# A        3      3
# B        4      7
# C        5      9

# %%
df2.groupby(str.lower).mean()
# Out:
#    data1  data2
# a    1.5    4.0
# b    2.5    3.5
# c    3.5    6.0

# %%
df1 = pd.DataFrame({"employee":["Bob","Jake","Lisa","Sue"],
                   "group":["Accounting","Engineering","Engineering","HR"]})
df2 = pd.DataFrame({"employee":["Lisa","Bob","Jake","Sue"],
                   "hire_date":(2004,1008,2012,2014)})

# %%
df1
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR

# %%
df2
# Out:
#   employee  hire_date
# 0     Lisa       2004
# 1      Bob       1008
# 2     Jake       2012
# 3      Sue       2014

# %%
df1.merge(df2)
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       1008
# 1     Jake  Engineering       2012
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2014

# %%
df3 = pd.merge(df1,df2)
df3
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       1008
# 1     Jake  Engineering       2012
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2014

# %%
df4 = pd.DataFrame({"group":["Accounting","Engineering","HR"],
                   "superviser":["Carly","Guido","Steve"]})

# %%
df4
# Out:
#          group superviser
# 0   Accounting      Carly
# 1  Engineering      Guido
# 2           HR      Steve

# %%
pd.merge(df3,df4)
# Out:
#   employee        group  hire_date superviser
# 0      Bob   Accounting       1008      Carly
# 1     Jake  Engineering       2012      Guido
# 2     Lisa  Engineering       2004      Guido
# 3      Sue           HR       2014      Steve

# %%
df5 = pd.DataFrame({"group": ["Accounting","Accounting","Engineering","Engineering","HR","HR"],
                   "skills":["math","spreadsheets","coding","linux","spreatsheets","organization"]})

# %%
df5
# Out:
#          group        skills
# 0   Accounting          math
# 1   Accounting  spreadsheets
# 2  Engineering        coding
# 3  Engineering         linux
# 4           HR  spreatsheets
# 5           HR  organization

# %%
df1
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR

# %%
pd.merge(df1,df5)
# Out:
#   employee        group        skills
# 0      Bob   Accounting          math
# 1      Bob   Accounting  spreadsheets
# 2     Jake  Engineering        coding
# 3     Jake  Engineering         linux
# 4     Lisa  Engineering        coding
# 5     Lisa  Engineering         linux
# 6      Sue           HR  spreatsheets
# 7      Sue           HR  organization

# %%
pd.merge(df1, df2, on="employee")
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       1008
# 1     Jake  Engineering       2012
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2014

# %%
df3 = pd.DataFrame({"name":["Bob","Jake","Lisa","Sue"],
                   "salary":[70000,8000,9000,10000]})
df3
# Out:
#    name  salary
# 0   Bob   70000
# 1  Jake    8000
# 2  Lisa    9000
# 3   Sue   10000

# %%
display(df1,df3)
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
#    name  salary
# 0   Bob   70000
# 1  Jake    8000
# 2  Lisa    9000
# 3   Sue   10000

# %%
pd.merge(df1, df3, left_on="employee", right_on="name")
# Out:
#   employee        group  name  salary
# 0      Bob   Accounting   Bob   70000
# 1     Jake  Engineering  Jake    8000
# 2     Lisa  Engineering  Lisa    9000
# 3      Sue           HR   Sue   10000

# %%
pd.merge(df1, df3, left_on="employee", right_on="name").drop("name",axis=1)
# Out:
#   employee        group  salary
# 0      Bob   Accounting   70000
# 1     Jake  Engineering    8000
# 2     Lisa  Engineering    9000
# 3      Sue           HR   10000

# %%
df1a = df1.set_index("employee")
df2a = df2.set_index("employee")

# %%
df1a
# Out:
#                 group
# employee
# Bob        Accounting
# Jake      Engineering
# Lisa      Engineering
# Sue                HR

# %%
df2a
# Out:
#           hire_date
# employee
# Lisa           2004
# Bob            1008
# Jake           2012
# Sue            2014

# %%
pd.merge(df1a, df2a, left_index=True, right_index=True)
# Out:
#                 group  hire_date
# employee
# Bob        Accounting       1008
# Jake      Engineering       2012
# Lisa      Engineering       2004
# Sue                HR       2014

# %%
pd.merge(df1a, df3, left_index=True, right_on="name")
# Out:
#          group  name  salary
# 0   Accounting   Bob   70000
# 1  Engineering  Jake    8000
# 2  Engineering  Lisa    9000
# 3           HR   Sue   10000

# %%
df6 = pd.DataFrame({"name":["Peter","Paul","Mary"],
                   "food":["fish","beans","bread"]},
                  columns=["name","food"])

df7 = pd.DataFrame({"name":["Mary","Joseph"],
                   "drink":["wine","bear"]},
                  columns=["name","drink"])

# %%
df6
# Out:
#     name   food
# 0  Peter   fish
# 1   Paul  beans
# 2   Mary  bread

# %%
df7
# Out:
#      name drink
# 0    Mary  wine
# 1  Joseph  bear

# %%
pd.merge(df6,df7)
# Out:
#    name   food drink
# 0  Mary  bread  wine

# %%
pd.merge(df6,df7, how="inner")
# Out:
#    name   food drink
# 0  Mary  bread  wine

# %%
pd.merge(df6,df7, how="outer")
# Out:
#      name   food drink
# 0   Peter   fish   NaN
# 1    Paul  beans   NaN
# 2    Mary  bread  wine
# 3  Joseph    NaN  bear

# %%
pd.merge(df6,df7, how="left")
# Out:
#     name   food drink
# 0  Peter   fish   NaN
# 1   Paul  beans   NaN
# 2   Mary  bread  wine

# %%
pd.merge(df6,df7, how="right")
# Out:
#      name   food drink
# 0    Mary  bread  wine
# 1  Joseph    NaN  bear

# %%
df8 = pd.DataFrame({"name":["Peter","Paul","Mary","Philip"],
                   "rank":[1,2,3,4]})

df9 = pd.DataFrame({"name":["Peter","Paul","Mary","Sue"],
                   "rank":[3,2,4,2]})

# %%
df8
# Out:
#      name  rank
# 0   Peter     1
# 1    Paul     2
# 2    Mary     3
# 3  Philip     4

# %%
df9
# Out:
#     name  rank
# 0  Peter     3
# 1   Paul     2
# 2   Mary     4
# 3    Sue     2

# %%
pd.merge(df8, df9, on="name")
# Out:
#     name  rank_x  rank_y
# 0  Peter       1       3
# 1   Paul       2       2
# 2   Mary       3       4

# %%
pd.merge(df8, df9, on="name", suffixes = ["_L","_R"])
# Out:
#     name  rank_L  rank_R
# 0  Peter       1       3
# 1   Paul       2       2
# 2   Mary       3       4

# %%
def make_df(cols, ind):
    data = {c:[str(c) + str(i) for i in ind]
           for c in cols}
    return pd.DataFrame(data, ind)

# %%
make_df("ABC",range(3))
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2

# %%
ser1 = pd.Series(["A","B","C"], index=[1,2,3])
ser2 = pd.Series(["D","E","F"], index=[4,5,6])

# %%
ser1
# Out:
# 1    A
# 2    B
# 3    C
# dtype: object

# %%
ser2
# Out:
# 4    D
# 5    E
# 6    F
# dtype: object

# %%
pd.concat([ser1,ser2])
# Out:
# 1    A
# 2    B
# 3    C
# 4    D
# 5    E
# 6    F
# dtype: object

# %%
df1 = make_df("AB",[1,2])

# %%
df1
# Out:
#     A   B
# 1  A1  B1
# 2  A2  B2

# %%
df2 = make_df("AB", [3,4])

# %%
df2
# Out:
#     A   B
# 3  A3  B3
# 4  A4  B4

# %%
pd.concat([df1,df2])
# Out:
#     A   B
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 4  A4  B4

# %%
df3 = make_df("AB", [0,1])
df4 = make_df("CD", [0,1])

# %%
df3
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1

# %%
df4
# Out:
#     C   D
# 0  C0  D0
# 1  C1  D1

# %%
pd.concat([df3, df4], axis=1)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1

# %%
x = make_df("AB", [0,1])
y = make_df("AB", [2,3])

# %%
x
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1

# %%
y
# Out:
#     A   B
# 2  A2  B2
# 3  A3  B3

# %%
pd.concat([x, y])
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
pd.concat([x, y], axis=1)
# Out:
#      A    B    A    B
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2  NaN  NaN   A2   B2
# 3  NaN  NaN   A3   B3

# %%
pd.concat([x, y], verify_integrity=True)
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
pd.concat([x, y], ignore_index=True)
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
pd.concat([x, y], keys=["x","y"])
# Out:
#       A   B
# x 0  A0  B0
#   1  A1  B1
# y 2  A2  B2
#   3  A3  B3

# %%
df5 = make_df("ABC", [0,1])
df6 = make_df("BCD", [3,4])

# %%
df5
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1

# %%
df6
# Out:
#     B   C   D
# 3  B3  C3  D3
# 4  B4  C4  D4

# %%
pd.concat([df5, df6])
# Out:
#      A   B   C    D
# 0   A0  B0  C0  NaN
# 1   A1  B1  C1  NaN
# 3  NaN  B3  C3   D3
# 4  NaN  B4  C4   D4

# %%
pd.concat([df5, df6], join="inner")
# Out:
#     B   C
# 0  B0  C0
# 1  B1  C1
# 3  B3  C3
# 4  B4  C4

# %%
pd.concat([df5, df6], join="outer")
# Out:
#      A   B   C    D
# 0   A0  B0  C0  NaN
# 1   A1  B1  C1  NaN
# 3  NaN  B3  C3   D3
# 4  NaN  B4  C4   D4

# %%
df1.append(df2)
# Out:
#     A   B
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 4  A4  B4

# %%
pd.concat([df1,df2])
# Out:
#     A   B
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 4  A4  B4

# %%
pwd
# Out:
# 'C:\\Users\\HP\\DATA_SCIENCE_COURSE_NOTES\\DAwPython\\Pandas_Notes'

# %%
df = pd.read_csv("C:\\Users\\HP\\DATA_SCIENCE_COURSE_NOTES\\Datalar\\pokemon_data.csv")
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df[['Name', 'Type 1', 'Type 2', 'HP']]
# Out:
#                       Name   Type 1  Type 2  HP
# 0                Bulbasaur    Grass  Poison  45
# 1                  Ivysaur    Grass  Poison  60
# 2                 Venusaur    Grass  Poison  80
# 3    VenusaurMega Venusaur    Grass  Poison  80
# 4               Charmander     Fire     NaN  39
# ..                     ...      ...     ...  ..
# 795                Diancie     Rock   Fairy  50
# 796    DiancieMega Diancie     Rock   Fairy  50
# 797    HoopaHoopa Confined  Psychic   Ghost  80
# 798     HoopaHoopa Unbound  Psychic    Dark  80
# 799              Volcanion     Fire   Water  80
#
# [800 rows x 4 columns]

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.iloc[0:5]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
for index, row in df.iterrows():
    print(index, row["Name"])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
df.loc[df["Type 1"]=="Fire"]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values(["Type 1","HP"], ascending=[1,0])  # Type1 true olarak, HP ise false olarak sıralı getirir.
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # Making changes to the data

# %%
df["Total"] = df["HP"] + df["Attack"] + df["Defense"] + df["Sp. Atk"] + df["Sp. Def"] + df["Speed"]

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
df = df.drop(columns=["Total"])

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df["Total"] = df.iloc[:,4:10].sum(axis=1)

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
df.columns.values
# Out:
# array(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack',
#        'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation',
#        'Legendary'], dtype=object)

# %%
cols = list(df.columns.values)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  Total  HP  \
# 0      1              Bulbasaur    Grass  Poison      False    318  45
# 1      2                Ivysaur    Grass  Poison      False    405  60
# 2      3               Venusaur    Grass  Poison      False    525  80
# 3      3  VenusaurMega Venusaur    Grass  Poison      False    625  80
# 4      4             Charmander     Fire     NaN      False    309  39
# ..   ...                    ...      ...     ...        ...    ...  ..
# 795  719                Diancie     Rock   Fairy       True    600  50
# 796  719    DiancieMega Diancie     Rock   Fairy       True    700  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True    600  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True    680  80
# 799  721              Volcanion     Fire   Water       True    600  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# ...

# %% [markdown]
# # Saving Our Data(Exportin in to desired format)

# %%
df.to_csv("modified.cvs")

# %%
pd.read_csv("modified.cvs").head(5)
# Out:
#    Unnamed: 0  #                   Name Type 1  Type 2  Legendary  Total  HP  \
# 0           0  1              Bulbasaur  Grass  Poison      False    318  45
# 1           1  2                Ivysaur  Grass  Poison      False    405  60
# 2           2  3               Venusaur  Grass  Poison      False    525  80
# 3           3  3  VenusaurMega Venusaur  Grass  Poison      False    625  80
# 4           4  4             Charmander   Fire     NaN      False    309  39
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0      49       49       65       65     45           1
# 1      62       63       80       80     60           1
# 2      82       83      100      100     80           1
# 3     100      123      122      120     80           1
# 4      52       43       60       50     65           1

# %%
df.to_csv("modified.cvs", index=False)

# %%
pd.read_csv("modified.cvs").head(5)
# Out:
#    #                   Name Type 1  Type 2  Legendary  Total  HP  Attack  \
# 0  1              Bulbasaur  Grass  Poison      False    318  45      49
# 1  2                Ivysaur  Grass  Poison      False    405  60      62
# 2  3               Venusaur  Grass  Poison      False    525  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison      False    625  80     100
# 4  4             Charmander   Fire     NaN      False    309  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0       49       65       65     45           1
# 1       63       80       80     60           1
# 2       83      100      100     80           1
# 3      123      122      120     80           1
# 4       43       60       50     65           1

# %%
df.to_excel("modified.xlsx")

# %%
pd.read_excel("modified.xlsx").head()
# Out:
#    Unnamed: 0  #                   Name Type 1  Type 2  Legendary  Total  HP  \
# 0           0  1              Bulbasaur  Grass  Poison      False    318  45
# 1           1  2                Ivysaur  Grass  Poison      False    405  60
# 2           2  3               Venusaur  Grass  Poison      False    525  80
# 3           3  3  VenusaurMega Venusaur  Grass  Poison      False    625  80
# 4           4  4             Charmander   Fire     NaN      False    309  39
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0      49       49       65       65     45           1
# 1      62       63       80       80     60           1
# 2      82       83      100      100     80           1
# 3     100      123      122      120     80           1
# 4      52       43       60       50     65           1

# %%
df.to_excel("modified.xlsx",index=False)

# %%
pd.read_excel("modified.xlsx").head()
# Out:
#    #                   Name Type 1  Type 2  Legendary  Total  HP  Attack  \
# 0  1              Bulbasaur  Grass  Poison      False    318  45      49
# 1  2                Ivysaur  Grass  Poison      False    405  60      62
# 2  3               Venusaur  Grass  Poison      False    525  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison      False    625  80     100
# 4  4             Charmander   Fire     NaN      False    309  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0       49       65       65     45           1
# 1       63       80       80     60           1
# 2       83      100      100     80           1
# 3      123      122      120     80           1
# 4       43       60       50     65           1

# %% [markdown]
# # Filtering Data

# %%
new_df = df.loc[(df["Type 1"]=="Grass") & (df["Type 2"]=="Poison") & (df["HP"]>70)]

# %%
new_df
# Out:
#        #                   Name Type 1  Type 2  Legendary  Total   HP  Attack  \
# 2      3               Venusaur  Grass  Poison      False    525   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False    625   80     100
# 50    45              Vileplume  Grass  Poison      False    490   75      80
# 77    71             Victreebel  Grass  Poison      False    490   80     105
# 652  591              Amoonguss  Grass  Poison      False    464  114      85
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation
# 2         83      100      100     80           1
# 3        123      122      120     80           1
# 50        85      110       90     50           1
# 77        65      100       70     70           1
# 652       70       85       80     30           5

# %%
new_df.to_csv("filtered.csv")

# %%
new_df
# Out:
#        #                   Name Type 1  Type 2  Legendary  Total   HP  Attack  \
# 2      3               Venusaur  Grass  Poison      False    525   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False    625   80     100
# 50    45              Vileplume  Grass  Poison      False    490   75      80
# 77    71             Victreebel  Grass  Poison      False    490   80     105
# 652  591              Amoonguss  Grass  Poison      False    464  114      85
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation
# 2         83      100      100     80           1
# 3        123      122      120     80           1
# 50        85      110       90     50           1
# 77        65      100       70     70           1
# 652       70       85       80     30           5

# %%
new_df.reset_index(drop=True)
# Out:
#      #                   Name Type 1  Type 2  Legendary  Total   HP  Attack  \
# 0    3               Venusaur  Grass  Poison      False    525   80      82
# 1    3  VenusaurMega Venusaur  Grass  Poison      False    625   80     100
# 2   45              Vileplume  Grass  Poison      False    490   75      80
# 3   71             Victreebel  Grass  Poison      False    490   80     105
# 4  591              Amoonguss  Grass  Poison      False    464  114      85
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0       83      100      100     80           1
# 1      123      122      120     80           1
# 2       85      110       90     50           1
# 3       65      100       70     70           1
# 4       70       85       80     30           5

# %%
df.loc[df["Name"].str.contains("Mega")].head()  # name de mega içerenleri getirir.
# Out:
#      #                       Name Type 1  Type 2  Legendary  Total  HP  \
# 3    3      VenusaurMega Venusaur  Grass  Poison      False    625  80
# 7    6  CharizardMega Charizard X   Fire  Dragon      False    634  78
# 8    6  CharizardMega Charizard Y   Fire  Flying      False    634  78
# 12   9    BlastoiseMega Blastoise  Water     NaN      False    630  79
# 19  15      BeedrillMega Beedrill    Bug  Poison      False    495  65
#
#     Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 3      100      123      122      120     80           1
# 7      130      111      130       85    100           1
# 8      104       78      159      115    100           1
# 12     103      120      135      115     78           1
# 19     150       40       15       80    145           1

# %%
df.loc[~df["Name"].str.contains("Mega")].head()  # Name de Mega geçmeyenleri getirir.
# Out:
#    #        Name Type 1  Type 2  Legendary  Total  HP  Attack  Defense  \
# 0  1   Bulbasaur  Grass  Poison      False    318  45      49       49
# 1  2     Ivysaur  Grass  Poison      False    405  60      62       63
# 2  3    Venusaur  Grass  Poison      False    525  80      82       83
# 4  4  Charmander   Fire     NaN      False    309  39      52       43
# 5  5  Charmeleon   Fire     NaN      False    405  58      64       58
#
#    Sp. Atk  Sp. Def  Speed  Generation
# 0       65       65     45           1
# 1       80       80     60           1
# 2      100      100     80           1
# 4       60       50     65           1
# 5       80       65     80           1

# %%
df.loc[df["Type 1"].str.contains("Fire|Grass", regex=True)]   
# type 1 içinde fire veya grass geçenleri getirir. iki value istiyorsak bunun için regex kullanılır.
# Out:
#        #                   Name Type 1  Type 2  Legendary  Total   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison      False    318   45      49
# 1      2                Ivysaur  Grass  Poison      False    405   60      62
# 2      3               Venusaur  Grass  Poison      False    525   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False    625   80     100
# 4      4             Charmander   Fire     NaN      False    309   39      52
# ..   ...                    ...    ...     ...        ...    ...  ...     ...
# 735  667                 Litleo   Fire  Normal      False    369   62      50
# 736  668                 Pyroar   Fire  Normal      False    507   86      68
# 740  672                 Skiddo  Grass     NaN      False    350   66      65
# 741  673                 Gogoat  Grass     NaN      False    531  123     100
# 799  721              Volcanion   Fire   Water       True    600   80     110
#
# ...

# %%
df.loc[df["Type 1"].str.contains("fire|grass" flags= re.I, regex=True)]
# Out:
#   File "<ipython-input-297-ae2b0e821fdd>", line 1
#     df.loc[df["Type 1"].str.contains("fire|grass" flags= re.I, regex=True)]
#                                                   ^
# SyntaxError: invalid syntax

# %%
df.loc[df["Type 1"].str.contains("pi[a-z]*" flags= re.I, regex=True)]  
# pi ile başlayanları getirir. burada flags=re.I ise büyük küçük harf olayını dikkate almaz.
# Out:
#   File "<ipython-input-298-d8c5e480ba00>", line 1
#     df.loc[df["Type 1"].str.contains("pi[a-z]*" flags= re.I, regex=True)]
#                                                 ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  Total  HP  \
# 0      1              Bulbasaur    Grass  Poison      False    318  45
# 1      2                Ivysaur    Grass  Poison      False    405  60
# 2      3               Venusaur    Grass  Poison      False    525  80
# 3      3  VenusaurMega Venusaur    Grass  Poison      False    625  80
# 4      4             Charmander     Fire     NaN      False    309  39
# ..   ...                    ...      ...     ...        ...    ...  ..
# 795  719                Diancie     Rock   Fairy       True    600  50
# 796  719    DiancieMega Diancie     Rock   Fairy       True    700  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True    600  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True    680  80
# 799  721              Volcanion     Fire   Water       True    600  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# ...

# %%
df.loc[df["Type 1"] == "Fire", "Legendary"] = True
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  Total  HP  \
# 0      1              Bulbasaur    Grass  Poison      False    318  45
# 1      2                Ivysaur    Grass  Poison      False    405  60
# 2      3               Venusaur    Grass  Poison      False    525  80
# 3      3  VenusaurMega Venusaur    Grass  Poison      False    625  80
# 4      4             Charmander     Fire     NaN       True    309  39
# ..   ...                    ...      ...     ...        ...    ...  ..
# 795  719                Diancie     Rock   Fairy       True    600  50
# 796  719    DiancieMega Diancie     Rock   Fairy       True    700  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True    600  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True    680  80
# 799  721              Volcanion     Fire   Water       True    600  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# ...

# %% [markdown]
# # Conditional Changes

# %%
df.loc[df["Total"] > 500, ["Generation","Legendary"]] = ["Test 1", "Test 2"]
df
# Out:
#        #                   Name   Type 1  Type 2 Legendary  Total  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison     False    318  45      49
# 1      2                Ivysaur    Grass  Poison     False    405  60      62
# 2      3               Venusaur    Grass  Poison    Test 2    525  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison    Test 2    625  80     100
# 4      4             Charmander     Fire     NaN      True    309  39      52
# ..   ...                    ...      ...     ...       ...    ...  ..     ...
# 795  719                Diancie     Rock   Fairy    Test 2    600  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy    Test 2    700  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost    Test 2    600  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark    Test 2    680  80     160
# 799  721              Volcanion     Fire   Water    Test 2    600  80     110
#
# ...

# %% [markdown]
# # Aggregate Statistics(Groupby)

# %%
df = pd.read_csv("modified.cvs")
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  Total  HP  \
# 0      1              Bulbasaur    Grass  Poison      False    318  45
# 1      2                Ivysaur    Grass  Poison      False    405  60
# 2      3               Venusaur    Grass  Poison      False    525  80
# 3      3  VenusaurMega Venusaur    Grass  Poison      False    625  80
# 4      4             Charmander     Fire     NaN      False    309  39
# ..   ...                    ...      ...     ...        ...    ...  ..
# 795  719                Diancie     Rock   Fairy       True    600  50
# 796  719    DiancieMega Diancie     Rock   Fairy       True    700  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True    600  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True    680  80
# 799  721              Volcanion     Fire   Water       True    600  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# ...

# %%
df.groupby(["Type 1"]).mean().sort_values("Defense", ascending=False)
# Out:
#                    #  Legendary       Total         HP      Attack  \
# Type 1
# Steel     442.851852   0.148148  487.703704  65.222222   92.703704
# Rock      392.727273   0.090909  453.750000  65.363636   92.863636
# Dragon    474.375000   0.375000  550.531250  83.312500  112.125000
# Ground    356.281250   0.125000  437.500000  73.781250   95.750000
# Ghost     486.500000   0.062500  439.562500  64.437500   73.781250
# Water     303.089286   0.035714  430.455357  72.062500   74.151786
# Ice       423.541667   0.083333  433.458333  72.000000   72.750000
# Grass     344.871429   0.042857  421.142857  67.271429   73.214286
# Bug       334.492754   0.000000  378.927536  56.884058   70.971014
# Dark      461.354839   0.064516  445.741935  66.806452   88.387097
# Poison    251.785714   0.000000  399.142857  67.250000   74.678571
# Fire      327.403846   0.096154  458.076923  69.903846   84.769231
# Psychic   380.807018   0.245614  475.947368  70.631579   71.456140
# ...

# %%
df.groupby(["Type 1"]).mean().sort_values("HP", ascending=False)
# Out:
#                    #  Legendary       Total         HP      Attack  \
# Type 1
# Dragon    474.375000   0.375000  550.531250  83.312500  112.125000
# Normal    319.173469   0.020408  401.683673  77.275510   73.469388
# Fairy     449.529412   0.058824  413.176471  74.117647   61.529412
# Ground    356.281250   0.125000  437.500000  73.781250   95.750000
# Water     303.089286   0.035714  430.455357  72.062500   74.151786
# Ice       423.541667   0.083333  433.458333  72.000000   72.750000
# Flying    677.750000   0.500000  485.000000  70.750000   78.750000
# Psychic   380.807018   0.245614  475.947368  70.631579   71.456140
# Fire      327.403846   0.096154  458.076923  69.903846   84.769231
# Fighting  363.851852   0.000000  416.444444  69.851852   96.777778
# Grass     344.871429   0.042857  421.142857  67.271429   73.214286
# Poison    251.785714   0.000000  399.142857  67.250000   74.678571
# Dark      461.354839   0.064516  445.741935  66.806452   88.387097
# ...

# %%
df.groupby(["Type 1"]).sum()
# Out:
#               #  Legendary  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1
# Bug       23080          0  26146  3925    4897     4880     3717     4471
# Dark      14302          2  13818  2071    2740     2177     2314     2155
# Dragon    15180         12  17617  2666    3588     2764     3099     2843
# Electric  15994          4  19510  2631    3040     2917     3961     3243
# Fairy      7642          1   7024  1260    1046     1117     1335     1440
# Fighting   9824          0  11244  1886    2613     1780     1434     1747
# Fire      17025          5  23820  3635    4408     3524     4627     3755
# Flying     2711          2   1940   283     315      265      377      290
# Ghost     15568          2  14066  2062    2361     2598     2539     2447
# Grass     24141          3  29480  4709    5125     4956     5425     4930
# Ground    11401          4  14000  2361    3064     2715     1807     2008
# ...

# %%
df["count"] = 1
df.groupby(["Type 1"]).count()["count"]
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
df.groupby(["Type 1","Type 2"]).count()["count"]
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# # Working with large amounts of dat

# %%
new_df = pd.DataFrame(columns=df.columns)

for df in pd.read_csv("modified.cvs", chunksize=5):
    results = df.groupby(["Type 1"]).count()
    
    new_df = pd.concat([new_df, results])
    
new_df
# Out:
#          # Name Type 1 Type 2 Legendary Total HP Attack Defense Sp. Atk  \
# Fire     1    1    NaN      0         1     1  1      1       1       1
# Grass    4    4    NaN      4         4     4  4      4       4       4
# Fire     4    4    NaN      3         4     4  4      4       4       4
# Water    1    1    NaN      0         1     1  1      1       1       1
# Bug      2    2    NaN      0         2     2  2      2       2       2
# ...     ..  ...    ...    ...       ...   ... ..    ...     ...     ...
# Fairy    1    1    NaN      0         1     1  1      1       1       1
# Flying   2    2    NaN      2         2     2  2      2       2       2
# Fire     1    1    NaN      1         1     1  1      1       1       1
# Psychic  2    2    NaN      2         2     2  2      2       2       2
# Rock     2    2    NaN      2         2     2  2      2       2       2
#
#         Sp. Def Speed Generation
# Fire          1     1          1
# Grass         4     4          4
# ...
