# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %% [markdown]
# read data
#
# if didn't work you can use this parameters: encoding="windows-1252"

# %%
kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill.shape
# Out:
# (2535, 14)

# %%
kill.dropna().shape
# Out:
# (2254, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
kill.groupby(["gender","manner_of_death"])["age"].describe()
# Out:
#                           count       mean        std   min   25%   50%   75%  \
# gender manner_of_death
# F      shot                89.0  36.235955  12.140300  12.0  26.0  36.0  45.0
#        shot and Tasered     5.0  35.600000  13.849188  17.0  30.0  37.0  39.0
# M      shot              2011.0  36.236698  12.926377   6.0  26.0  34.0  45.0
#        shot and Tasered   149.0  36.523490  12.125796  15.0  27.0  35.0  45.0
#
#                           max
# gender manner_of_death
# F      shot              71.0
#        shot and Tasered  55.0
# M      shot              91.0
#        shot and Tasered  76.0

# %%
kill.manner_of_death.unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %%
# a = kill.groupby(["gender","manner_of_death"])["age"].describe()
# a.reset_index()["manner_of_death"].value_counts().index
# Out:
# Index(['shot and Tasered', 'shot'], dtype='object')

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
# with seaborn

sns.boxplot(x = 'gender', y = 'age', hue = 'manner_of_death', data = kill)

plt.show()

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
# with seaborn

#plt.figure(figsize=(10,6))

fig,ax=plt.subplots(figsize=(10,5))

sns.swarmplot(x = 'gender', y = 'age', hue = 'manner_of_death', data = kill)

plt.show()

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252").dropna()

# %%
kill.city.value_counts().head(12)
# Out:
# Los Angeles     35
# Phoenix         28
# Houston         24
# Chicago         22
# Austin          18
# Las Vegas       17
# Columbus        16
# San Antonio     15
# Miami           15
# Indianapolis    14
# St. Louis       14
# Tucson          13
# Name: city, dtype: int64

# %%
# with seaborn barplot

cities = kill.city.value_counts()

fig,ax=plt.subplots(figsize=(8,4))

sns.barplot(x = cities[:12].index, y=cities[:12].values)

plt.title("Most Dangerous Cities", color = 'blue',fontsize=14)

plt.xticks(rotation = 45)

plt.show()

# %%
kill.city.value_counts()[:12]
# Out:
# Los Angeles     35
# Phoenix         28
# Houston         24
# Chicago         22
# Austin          18
# Las Vegas       17
# Columbus        16
# San Antonio     15
# Miami           15
# Indianapolis    14
# St. Louis       14
# Tucson          13
# Name: city, dtype: int64

# %%
# with seaborn countplot

fig,ax=plt.subplots(figsize=(8,4))

sns.countplot(x="city", data=kill,
              order=kill.city.value_counts()[:12].index)

ax.set_title("Most Dangerous Cities", color = 'blue',fontsize=14)

ax.set_xticklabels(kill.city.value_counts()[:12].index,rotation = 45)

plt.show()

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
kill.state.value_counts()[:20]
# Out:
# CA    366
# TX    200
# FL    136
# AZ    105
# OH     70
# NC     66
# OK     65
# CO     63
# GA     61
# MO     58
# IL     56
# TN     56
# WA     51
# LA     47
# PA     45
# AL     45
# VA     43
# NY     43
# WI     42
# NM     41
# Name: state, dtype: int64

# %%
# with seaborn barplot
states = kill.state.value_counts()

fig,ax=plt.subplots(figsize=(8,4))

sns.barplot(x = states[:20].index, y=states[:20].values)

ax.set_title("Most Dangerous States", color = 'blue',fontsize=14)

ax.set_xticklabels(kill.city.value_counts()[:20].index,rotation = 45)

plt.show()

# %%
fig,ax=plt.subplots(figsize=(8,4))

sns.countplot(x="state", data=kill,
              order=kill.state.value_counts()[:20].index)

ax.set_title("Most Dangerous States", color = 'blue',fontsize=14)

ax.set_xticklabels(kill.state.value_counts()[:20].index,rotation = 45)

plt.show()

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
kill.signs_of_mental_illness.value_counts()
# Out:
# False    1681
# True      573
# Name: signs_of_mental_illness, dtype: int64

# %%
# with seaborn

fig,ax=plt.subplots(figsize=(6,3))

sns.countplot(x = "signs_of_mental_illness", data=kill,
              order=kill.signs_of_mental_illness.value_counts().index)

plt.show()

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
kill.threat_level.value_counts()
# Out:
# attack          1462
# other            677
# undetermined     115
# Name: threat_level, dtype: int64

# %%
# with seaborn

fig,ax=plt.subplots(figsize=(6,4))

sns.countplot(x = "threat_level", data=kill,
              order=kill.threat_level.value_counts().index)

plt.show()

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
kill.flee.value_counts()
# Out:
# Not fleeing    1528
# Car             360
# Foot            278
# Other            88
# Name: flee, dtype: int64

# %%
fig,ax=plt.subplots(figsize=(6,4))

sns.countplot(kill.flee)

#sns.countplot(x = "flee", data=kill,
#              order=kill.flee.value_counts().index)

plt.show()

# %%
fig, ax = plt.subplots(ncols=1, nrows=3, figsize = (18,15))

sns.boxplot(x="gender", y="age", data=kill, ax = ax[0])

sns.boxplot(x="gender", y="age",  data=kill, ax = ax[1], hue = "manner_of_death" )

sns.boxplot(x="gender", y="age",  data=kill, ax = ax[2], hue = "manner_of_death" )

plt.show()

# %%
fig=plt.figure(figsize=(10,8))

fig=plt.subplot(2,2,1)
sns.boxplot(x="gender", y="age", hue = "manner_of_death", data=kill)

fig=plt.subplot(2,2,2)
sns.boxplot("gender", "age","manner_of_death", kill)

fig=plt.subplot(2,2,3)
sns.boxplot(kill.gender, kill.age, kill.manner_of_death)

plt.tight_layout();

# %%
fig, ax =plt.subplots(figsize=(8,5))

sns.countplot(x="state", data=kill,
             order=state_freq.index[::-1]   #tersten okutmak için.
             )

ax.set_xticklabels(state_freq.index, rotation = 45)
ax.set_title("Most dangerous states",color = "blue",fontsize=15);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-3dcb7a90ffa0> in <module>
#       2
#       3 sns.countplot(x="state", data=kill,
# ----> 4              order=state_freq.index[::-1]
#       5              )
#       6
#
# NameError: name 'state_freq' is not defined
