# %%
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Covid-19 Dashboard.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 326692 entries, 0 to 326691
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   people_positive_cases_count      326692 non-null  int64
#  1   county_name                      301300 non-null  object
#  2   province_state_name              306544 non-null  object
#  3   report_date                      326692 non-null  object
#  4   continent_name                   325864 non-null  object
#  5   data_source_name                 326692 non-null  object
#  6   people_death_new_count           326692 non-null  int64
#  7   county_fips_number               296056 non-null  float64
#  8   country_alpha_3_code             325864 non-null  object
#  9   country_short_name               326692 non-null  object
#  10  country_alpha_2_code             325772 non-null  object
# ...

# %%
df["report_date"] = pd.to_datetime(df["report_date"], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 326692 entries, 0 to 326691
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   people_positive_cases_count      326692 non-null  int64
#  1   county_name                      301300 non-null  object
#  2   province_state_name              306544 non-null  object
#  3   report_date                      326692 non-null  datetime64[ns]
#  4   continent_name                   325864 non-null  object
#  5   data_source_name                 326692 non-null  object
#  6   people_death_new_count           326692 non-null  int64
#  7   county_fips_number               296056 non-null  float64
#  8   country_alpha_3_code             325864 non-null  object
#  9   country_short_name               326692 non-null  object
#  10  country_alpha_2_code             325772 non-null  object
# ...

# %%
df.head()
# Out:
#    people_positive_cases_count county_name province_state_name report_date  \
# 0                         3149     Fayette             Indiana  2021-08-21
# 1                         3177     Fayette             Indiana  2021-08-23
# 2                         3201     Fayette             Indiana  2021-08-24
# 3                         3246     Fayette             Indiana  2021-08-26
# 4                         3265     Fayette             Indiana  2021-08-27
#
#   continent_name data_source_name  people_death_new_count  county_fips_number  \
# 0        America   New York Times                       0             18041.0
# 1        America   New York Times                       0             18041.0
# 2        America   New York Times                       0             18041.0
# 3        America   New York Times                       0             18041.0
# 4        America   New York Times                       1             18041.0
#
# ...

# %%
df3 = df[df["report_date"]=='2021-06-01'].groupby('country_short_name')[['country_short_name','people_positive_cases_count','people_positive_new_cases_count','people_death_count','people_death_new_count']]

# %%
df3.head()
# Out:
#        country_short_name  people_positive_cases_count  \
# 9           United States                         1983
# 101         United States                        55101
# 193         United States                         1114
# 285         United States                         2087
# 377         United States                          516
# ...                   ...                          ...
# 325435         Tajikistan                        13714
# 325527            Taiwan*                         8842
# 325711   Congo (Kinshasa)                        31651
# 325803            Senegal                        41433
# 325895            Vanuatu                            4
#
#         people_positive_new_cases_count  people_death_count  \
# 9                                     1                  41
# 101                                  55                1039
# 193                                   2                  37
# ...
