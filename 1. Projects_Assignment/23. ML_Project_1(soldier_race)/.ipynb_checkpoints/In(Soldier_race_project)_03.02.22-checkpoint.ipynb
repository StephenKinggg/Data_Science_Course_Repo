# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>

# %% [markdown]
# # WELCOME!

# %% [markdown]
# In this project, you must apply EDA processes for the development of predictive models. Handling outliers, domain knowledge and feature engineering will be challenges.
#
# Also, this project aims to improve your ability to implement algorithms for Multi-Class Classification. Thus, you will have the opportunity to implement many algorithms commonly used for Multi-Class Classification problems.
#
# Before diving into the project, please take a look at the determines and tasks.

# %% [markdown]
# # Determines

# %% [markdown]
# The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#
# The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects.
#
#
# DATA DICT:
# https://data.world/datamil/ansur-ii-data-dictionary/workspace/file?filename=ANSUR+II+Databases+Overview.pdf
#
# ---
#
# To achieve high prediction success, you must understand the data well and develop different approaches that can affect the dependent variable.
#
# Firstly, try to understand the dataset column by column using pandas module. Do research within the scope of domain (body scales, and race characteristics) knowledge on the internet to get to know the data set in the fastest way.
#
# You will implement ***Logistic Regression, Support Vector Machine, XGBoost, Random Forest*** algorithms. Also, evaluate the success of your models with appropriate performance metrics.
#
# At the end of the project, choose the most successful model and try to enhance the scores with ***SMOTE*** make it ready to deploy. Furthermore, use ***SHAP*** to explain how the best model you choose works.

# %% [markdown]
# # Tasks

# %% [markdown]
# #### 1. Exploratory Data Analysis (EDA)
# - Import Libraries, Load Dataset, Exploring Data
#
#     *i. Import Libraries*
#
#     *ii. Ingest Data *
#
#     *iii. Explore Data*
#
#     *iv. Outlier Detection*
#
#     *v.  Drop unnecessary features*
#
# #### 2. Data Preprocessing
# - Scale (if needed)
# - Separete the data frame for evaluation purposes
#
# #### 3. Multi-class Classification
# - Import libraries
# - Implement SVM Classifer
# - Implement Decision Tree Classifier
# - Implement Random Forest Classifer
# - Implement XGBoost Classifer
# - Compare The Models

# %% [markdown]
# # EDA
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %% [markdown]
# ## Import Libraries
# Besides Numpy and Pandas, you need to import the necessary modules for data visualization, data preprocessing, Model building and tuning.
#
# *Note: Check out the course materials.*

# %% [raw]
# 2010-2012 yılında Amerikan ordusunda istihdam edilen askerlerin malzeme ihtiyaçlarını belirlemek maksadıyla etnik özelliklerini belirlemek maksadıyla hazırlanmıştır.
#
# İnsanları rencide etmeden görev yapan tüm unsurları tespit etmeye yarayan bir model oluşturmaktır.

# %%
#!pip install pyforest

# %%
#!pip install cufflinks

# %%
import pyforest
import plotly
import cufflinks as cf
#Enabling the offline mode for interactive plotting locally
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
#To display the plots
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
from sklearn.metrics import make_scorer
from sklearn.metrics import classification_report,confusion_matrix,plot_confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve, auc
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
# ...

# %% [markdown]
# ## Ingest Data from links below and make a dataframe
# - Soldiers Male : https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr
# - Soldiers Female : https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq

# %%
df_male = pd.read_csv('https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr', encoding='latin-1')

# %%
df_female= pd.read_csv('https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq')

# %% [markdown]
# # EDA
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %%
df_male.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# ...

# %%
df_female.head()
# Out:
#    SubjectId  abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# ...

# %%
print(df_male.shape)
print(df_female.shape)
# Out:
# (4082, 108)
# (1986, 108)

# %%
data = pd.concat([df_male,df_female], axis=0, ignore_index=True)
data.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# ...

# %%
data.shape
# Out:
# (6068, 109)

# %%
data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6068 entries, 0 to 6067
# Data columns (total 109 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    subjectid                       float64
#  1    abdominalextensiondepthsitting  int64
#  2    acromialheight                  int64
#  3    acromionradialelength           int64
#  4    anklecircumference              int64
#  5    axillaheight                    int64
#  6    balloffootcircumference         int64
#  7    balloffootlength                int64
#  8    biacromialbreadth               int64
#  9    bicepscircumferenceflexed       int64
#  10   bicristalbreadth                int64
#  11   bideltoidbreadth                int64
#  12   bimalleolarbreadth              int64
#  13   bitragionchinarc                int64
#  14   bitragionsubmandibulararc       int64
#  15   bizygomaticbreadth              int64
#  16   buttockcircumference            int64
# ...

# %%
data.isnull().sum().any()
# Out:
# True

# %%
data.duplicated().sum()
# Out:
# 0

# %%
print(data["DODRace"].value_counts())
data["DODRace"].value_counts().plot(kind="pie", autopct='%1.1f%%',figsize=(10,10));
# Out:
# 1    3792
# 2    1298
# 3     679
# 4     188
# 6      59
# 5      49
# 8       3
# Name: DODRace, dtype: int64

# %% [raw]
# Buradaki featurelar arasından target sütun değerlerini tespit etmek için hangilerinin kullanılıp kullanılamayacağını bakıyoruz. ihtiyaç olmayacakları düşebiliriz. bunları pdf dosyasındaki açıklamalardan inceledik.
#
# aşağıda missing value 1800 den büyük olanları sildik. bunun için böyle bir sınır belirledik. bir datanın 1/3 boş ise onu silebiliriz ve bununla uğraşmak istemeyebiliriz.

# %%
drop_list =[]
for col in data:
  if data[col].isnull().sum()>1800:  
    print(f"{col} = {data[col].isnull().sum()}")
    drop_list.append(col)
    
drop_list
# Out:
# subjectid = 1986
# Ethnicity = 4647
# SubjectId = 4082
# ['subjectid', 'Ethnicity', 'SubjectId']

# %%
data.drop(drop_list, axis=1, inplace=True)

# %%
data.isnull().sum().any()
# Out:
# False

# %%
data.shape
# Out:
# (6068, 106)

# %%
# to find how many unique values object features have
for col in data.select_dtypes("object"):
  print(f"{col} has {data[col].nunique()} unique value")
# Out:
# Gender has 2 unique value
# Date has 253 unique value
# Installation has 12 unique value
# Component has 3 unique value
# Branch has 3 unique value
# PrimaryMOS has 285 unique value
# SubjectsBirthLocation has 152 unique value
# WritingPreference has 3 unique value

# %% [raw]
# BirthLocation çok fazla feature sahip düşülmesi gerekebilir diye düşünebiliriz ancak bu feature Hispanic olanları tespit etmede çok önemli bir yere sahip olduğunu gördüğümüzden dolayı silmedik. amacım white ve black tespit etmek olsaydı bunu silebilirdim ancak hispanic olduğundan etkisini gözönünde bulundurarak silmedim.

# %%
data.DODRace.unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 8], dtype=int64)

# %%
data["DODRace"] = data.DODRace.map({
    1: "White",
    2: "Black",
    3: "Hispanic",
    4: "Asian",
    5: "Native American",
    6: "Pacific Islander",
    8: "Other"
})

# %% [raw]
# component ve branc silecektim ancak bundan önce dağılımın nasıl olduğuna baktım. hispaniclerin bazı unsurlarda fazla olması gibi bir durum söz konusu mu bunu inceledim. dağılımın orantılı olarak gerçekleştiğini gördüm.

# %%
data.groupby(["Component"])["DODRace"].value_counts() #.iplot(kind="barh")
# Out:
# Component            DODRace
# Army National Guard  White               1855
#                      Black                499
#                      Hispanic             253
#                      Asian                 60
#                      Native American       24
#                      Pacific Islander      17
# Army Reserve         White                114
#                      Black                 52
#                      Hispanic              41
#                      Asian                  9
#                      Pacific Islander       3
#                      Native American        1
# Regular Army         White               1823
#                      Black                747
#                      Hispanic             385
#                      Asian                119
#                      Pacific Islander      39
#                      Native American       24
#                      Other                  3
# Name: DODRace, dtype: int64

# %%
data.groupby(["Component", "Branch"])["DODRace"].value_counts() #.iplot(kind="barh")
# Out:
# Component            Branch                  DODRace
# Army National Guard  Combat Arms             White               623
#                                              Black                79
#                                              Hispanic             74
#                                              Asian                18
#                                              Native American       9
#                                              Pacific Islander      4
#                      Combat Service Support  White               917
#                                              Black               312
#                                              Hispanic            142
#                                              Asian                33
#                                              Pacific Islander     11
#                                              Native American      10
#                      Combat Support          White               315
# ...

# %%
drop_list1 = [
    "Date", "Installation", "Component", "Branch", "PrimaryMOS",
    "Weightlbs", "Heightin",   
]

data.drop(drop_list1, axis=1, inplace=True)

# %%
data.columns  # mutlaka bakıyoruz çünkü column isimlerinin önünde ve arkasında bir boşluk var mı diye kontrol ediyoruz.
# Out:
# Index(['abdominalextensiondepthsitting', 'acromialheight', 'acromionradialelength', 'anklecircumference', 'axillaheight', 'balloffootcircumference', 'balloffootlength', 'biacromialbreadth', 'bicepscircumferenceflexed', 'bicristalbreadth', 'bideltoidbreadth', 'bimalleolarbreadth', 'bitragionchinarc', 'bitragionsubmandibulararc', 'bizygomaticbreadth', 'buttockcircumference', 'buttockdepth', 'buttockheight', 'buttockkneelength', 'buttockpopliteallength', 'calfcircumference', 'cervicaleheight', 'chestbreadth', 'chestcircumference', 'chestdepth', 'chestheight', 'crotchheight', 'crotchlengthomphalion', 'crotchlengthposterioromphalion', 'earbreadth', 'earlength', 'earprotrusion', 'elbowrestheight', 'eyeheightsitting', 'footbreadthhorizontal', 'footlength', 'forearmcenterofgriplength', 'forearmcircumferenceflexed', 'forearmforearmbreadth', 'forearmhandlength', 'functionalleglength', 'handbreadth', 'handcircumference', 'handlength', 'headbreadth', 'headcircumference', 'headlength',
# ...

# %%
data.SubjectNumericRace.value_counts()  # çok farklı değerlerin olduğunu gördük askerlerin beyanlarında ve bunuda düştük.
# Out:
# 1        3561
# 2        1026
# 3         541
# 31        160
# 51        126
# 8         116
# 4         109
# 21         60
# 6          59
# 41         46
# 61         35
# 23         34
# 28         26
# 251        20
# 5          18
# 18         18
# 25         14
# 351        10
# 38          9
# 64          8
# 62          8
# 35          8
# 42          7
# 63          7
# 231         6
# 43          5
# 235         4
# 218         3
# 651         2
# 2351        2
# 318         2
# 641         2
# 451         2
# 423         2
# 431         2
# 2518        2
# 48          1
# 631         1
# 4251        1
# 428         1
# 238         1
# 358         1
# 425         1
# 42351       1
# Name: SubjectNumericRace, dtype: int64

# %%
data.drop("SubjectNumericRace", axis=1, inplace=True)

# %%
data.DODRace.value_counts()
# Out:
# White               3792
# Black               1298
# Hispanic             679
# Asian                188
# Pacific Islander      59
# Native American       49
# Other                  3
# Name: DODRace, dtype: int64

# %%
data.DODRace.value_counts()
# Out:
# White               3792
# Black               1298
# Hispanic             679
# Asian                188
# Pacific Islander      59
# Native American       49
# Other                  3
# Name: DODRace, dtype: int64

# %%
data = data[(data["DODRace"] == "White") | (data["DODRace"] == "Black") |
                (data["DODRace"] == "Hispanic")]
data

# value_counts()<500 küçük olanları sildik.
# Out:
#       abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# ...

# %%
data.reset_index(drop=True, inplace=True)  # index yeniden numaralandırdık.

# %%
data
# Out:
#       abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# ...

# %% [raw]
# heatmap bakınca kırmızı olanların birbiri ile corr içinde olduklarını yani multicollinearity olduğunu görebiliyoruz. Ancak bunun tahminlerimize bir etkisi yok sadece feature importance etkisi vardır. SVC den bir feature importance alamıyoruz. Distance based modellerde feature importance alamıyoruz. Treebased olanlar ise multicollinearity ile mücadele edebiliyor zaten.
#
# insan oranının altın oranda yaratıldığı düşünüldüğünde bunun olmasının normal olarak değerlendiriyoruz.

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data.corr(), cmap ="coolwarm")
# Out:
# <AxesSubplot:>

# %% [raw]
# distance tabanlı modellerden biz bir feature importance elde edemiyoruz. modellerimde multicollinearity benim için bir sorun olmadığından dolayı eleme işlemi yapmıyorum.

# %%
df_temp = data.corr()

feature =[]
collinear=[]
for col in df_temp.columns:
    for i in df_temp.index:
        if (df_temp[col][i]> .9 and df_temp[col][i] < 1) or (df_temp[col][i]< -.9 and df_temp[col][i] > -1) :
                feature.append(col)
                collinear.append(i)
                # print(f"multicolinearity alert in between {col} - {i}")

# %%
my_dict = {"feature":feature, "collinear":collinear}
df_col = pd.DataFrame(my_dict)
df_col
# Out:
#                             feature                       collinear
# 0    abdominalextensiondepthsitting              waistcircumference
# 1    abdominalextensiondepthsitting                      waistdepth
# 2                    acromialheight                    axillaheight
# 3                    acromialheight                 cervicaleheight
# 4                    acromialheight                     chestheight
# 5                    acromialheight              iliocristaleheight
# 6                    acromialheight               kneeheightsitting
# 7                    acromialheight                         stature
# 8                    acromialheight             suprasternaleheight
# 9                    acromialheight                  tenthribheight
# 10                   acromialheight            waistheightomphalion
# 11                   acromialheight                     wristheight
# 12            acromionradialelength             shoulderelbowlength
# ...

# %%
df_col.value_counts("feature")
# burada ilk feature 19 tane feature ile multicoll. durumu söz konusu.
# Out:
# feature
# kneeheightsitting                 19
# iliocristaleheight                15
# tenthribheight                    15
# axillaheight                      14
# waistheightomphalion              14
# crotchheight                      14
# cervicaleheight                   14
# kneeheightmidpatella              12
# suprasternaleheight               12
# chestheight                       11
# tibialheight                      11
# acromialheight                    10
# poplitealheight                   10
# span                               9
# trochanterionheight                9
# stature                            9
# lateralfemoralepicondyleheight     7
# buttockheight                      7
# sleeveoutseam                      6
# forearmhandlength                  5
# radialestylionlength               4
# shoulderelbowlength                3
# functionalleglength                3
# waistcircumference                 3
# bideltoidbreadth                   3
# ...

# %% [markdown]
# # DATA Preprocessing
# - In this step we divide our data to X(Features) and y(Target) then ,
# - To train and evaluation purposes we create train and test sets,
# - Lastly, scale our data if features not in same scale. Why?

# %% [raw]
# logreg bir gradientdescent tabanlı, SVM ise bir distance tabanlı modeldir. Burada categorik olanları get dummies ile numerik dönüştürüyorduk.

# %%
X = data.drop("DODRace", axis=1)
X = pd.get_dummies(data=X, drop_first=True)
y = data.DODRace

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101, stratify =y)

# %%
print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (4615, 232)
# Train target shape   :  (4615,)
# Test features shape  :  (1154, 232)
# Test target shape    :  (1154,)

# %% [markdown]
# # Modelling
# - Fit the model with train dataset
# - Get predict from vanilla model on both train and test sets to examine if there is over/underfitting
# - Apply GridseachCV for both hyperparemeter tuning and sanity test of our model.
# - Use hyperparameters that you find from gridsearch and make final prediction and evaluate the result according to chosen metric.

# %% [markdown]
# ## 1. Logistic model

# %% [markdown]
# ### Vanilla Logistic Model

# %% [raw]
# Vanilla Logistic Model, default değerler ile logreg modeli kurmak demektir. ancak burada işi uzatmamak için balanced ile işlemleri yaptık.

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
from sklearn.pipeline import Pipeline
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced', max_iter=10000, random_state=101))]
pipe_log_model = Pipeline(steps=operations)

# %%
pipe_log_model.fit(X_train, y_train)
eval_metric(pipe_log_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[240  13   7]
#  [  5 111  20]
#  [ 25  89 644]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.92      0.91       260
#     Hispanic       0.52      0.82      0.64       136
#        White       0.96      0.85      0.90       758
#
#     accuracy                           0.86      1154
#    macro avg       0.79      0.86      0.81      1154
# weighted avg       0.89      0.86      0.87      1154
#
#
# Train_Set
# [[ 971   38   29]
#  [  21  456   66]
#  [  58  355 2621]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.94      0.93      1038
#     Hispanic       0.54      0.84      0.66       543
#        White       0.97      0.86      0.91      3034
#
#     accuracy                           0.88      4615
#    macro avg       0.81      0.88      0.83      4615
# weighted avg       0.91      0.88      0.89      4615

# %% [raw]
# Black değerlerinin çok iyi scorelar alması demek bunların vücut ölçülerinin diğerleri ile kıyaslandığında ayırtedici olduğunu söyleyebiliriz. Yukarıdaki balanced dengesiz olan classın scorelarını iyileştiriyor.
#
# Benim yoğunlaşacağım scorelar Hispanic scorelar olacaktır. Çünkü scorelara bakınca en düşük scorelar buna ait. balanced vermeden önce bu scorelar daha düşüktü. dengesiz bir durum söz konusu ise burada class_weight hemen balanced yapıp bu sorunu gidermeye çalışıyoruz.
#
# multiclass larda farklı bir sınıfa yoğunlaşmak için make_scorer kullanıyoruz.
#
# amacım hispanic scoreları iyileştirmek.

# %%
scoring = {"f1_Hispanic" : make_scorer(f1_score, average = None, labels =["Hispanic"]),
           "precision_Hispanic" : make_scorer(precision_score, average = None, labels =["Hispanic"]),
           "recall_Hispanic" : make_scorer(recall_score, average = None, labels =["Hispanic"])}

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
model = Pipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.599993
# test_precision_Hispanic    0.492007
# test_recall_Hispanic       0.771481
# dtype: float64

# %% [markdown]
# ### Logistic Model GridsearchCV

# %% [raw]
# gridsearch yaparken sadece bir score verebildiğimden dolayı burada amacım Hispanic recall scorelarını artırmak olduğundan dolayı burada sadece makescorer içine recallscore verdim.
#
# gridsearch de tekrar CV yapmaya gerek yok.

# %%
recall_Hispanic =  make_scorer(recall_score, average=None, labels=["Hispanic"])

# %%
param_grid = {
    "log__C": [0.1, 0.5, 1],
    'log__penalty': ["l1", "l2"],
    'log__solver': ['liblinear', 'lbfgs'],  # küçük datalarda liblinear çok iyi scorelar verebiliyor.
}

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced', max_iter=10000, random_state=101))]
model = Pipeline(steps=operations)

log_model_grid = GridSearchCV(model,
                              param_grid,
                              verbose=3,
                              scoring=recall_Hispanic,
                              n_jobs=-1, 
                              cv=5)

# %%
log_model_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', MinMaxScaler()),
#                                        ('log',
#                                         LogisticRegression(class_weight='balanced',
#                                                            max_iter=10000,
#                                                            random_state=101))]),
#              n_jobs=-1,
#              param_grid={'log__C': [0.1, 0.5, 1], 'log__penalty': ['l1', 'l2'],
#                          'log__solver': ['liblinear', 'lbfgs']},
#              scoring=make_scorer(recall_score, average=None, labels=['Hispanic']),
#              verbose=3)

# %%
log_model_grid.best_params_
# Out:
# {'log__C': 1, 'log__penalty': 'l2', 'log__solver': 'lbfgs'}

# %%
log_model_grid.best_score_
# Out:
# 0.7697757390417942

# %%
eval_metric(log_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[240  13   7]
#  [  5 111  20]
#  [ 25  89 644]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.92      0.91       260
#     Hispanic       0.52      0.82      0.64       136
#        White       0.96      0.85      0.90       758
#
#     accuracy                           0.86      1154
#    macro avg       0.79      0.86      0.81      1154
# weighted avg       0.89      0.86      0.87      1154
#
#
# Train_Set
# [[ 971   38   29]
#  [  21  456   66]
#  [  58  355 2621]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.94      0.93      1038
#     Hispanic       0.54      0.84      0.66       543
#        White       0.97      0.86      0.91      3034
#
#     accuracy                           0.88      4615
#    macro avg       0.81      0.88      0.83      4615
# weighted avg       0.91      0.88      0.89      4615

# %%
from yellowbrick.classifier import PrecisionRecallCurve

operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced', max_iter=10000, random_state=101))]
model = Pipeline(steps=operations)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],  # yukarıdaki sırayla veriyorus.
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
viz.score_  #["Hispanic"]
# Out:
# {'Black': 0.9741700884399221,
#  'Hispanic': 0.7331151215633762,
#  'White': 0.9713910070562224,
#  'micro': 0.9380908672925616}

# %% [raw]
# multiclasslarda aşağıdaki gibi hangi class score alacaksam onu labelse köşeli parentez içinde belirtiyorum. binary deki gibi poslabel yazıp geçemiyoruz. multiclasslarda mutlaka average None yazılması gerekiyor.
#
# mesela black ve hispanic gibi iki classın macro avg scorenu isteseydik bu durumda avarega=macro yazardık aynı durum weighted içinde geçerlidir.
#
# aldığım scoreları sonra karşılaştırmak için aşağıdaki gibi scoreları değişkenlere atadım.
#
# dengesiz bir veri seti ile karşılaşınca bizim yapacağımız ilk iş müşteriden ilave veri istemek olmalıdır. bu olmazse buradaki işlemleri sırasıyla yapacağız.

# %%
y_pred = log_model_grid.predict(X_test)

log_AP = viz.score_["Hispanic"]
log_f1 = f1_score(y_test, y_pred, average=None, labels=["Hispanic"])  # multiclasslarda labels ve average kullanıyoruz.
log_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"]) # iki sınıf yazsaydın average none olmazdı.

# %% [markdown]
# ## Lojistic Regression solver "liblenear" for small dataset

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced', max_iter=10000, random_state=101,
                                                                    solver="liblinear", penalty="l1"))]
pipe_log_model_libl = Pipeline(steps=operations)

# %% [raw]
# solver="liblinear", penalty="l1" küçük data setlerinde çok iyi scorelar verdiğini biliyorum. ancak l1 ile çalışır. l2 riched ile çalışmaz.
#
# tüm classlar için iyi scorelar ve dengeli scorelar verdi. CV ile aşağıda kontrolümü yaptım ve birbirine yakın olduğunu gördüm.

# %%
pipe_log_model_libl.fit(X_train,y_train)
eval_metric(pipe_log_model_libl, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[246   3  11]
#  [  5  96  35]
#  [ 19  33 706]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.95      0.93       260
#     Hispanic       0.73      0.71      0.72       136
#        White       0.94      0.93      0.94       758
#
#     accuracy                           0.91      1154
#    macro avg       0.86      0.86      0.86      1154
# weighted avg       0.91      0.91      0.91      1154
#
#
# Train_Set
# [[ 973   19   46]
#  [  30  385  128]
#  [  44  147 2843]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.94      0.93      1038
#     Hispanic       0.70      0.71      0.70       543
#        White       0.94      0.94      0.94      3034
#
#     accuracy                           0.91      4615
#    macro avg       0.86      0.86      0.86      4615
# weighted avg       0.91      0.91      0.91      4615

# %%
model = Pipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.644959
# test_precision_Hispanic    0.662196
# test_recall_Hispanic       0.631380
# dtype: float64

# %% [markdown]
# ## 2. SVC

# %% [markdown]
# ### Vanilla SVC model

# %% [raw]
# yukarıda logreg için yaptıklarımı VanillaSVC için yapıyorum. default yerine direkt balanced ile başladım.

# %%
operations_svc = [("scaler", MinMaxScaler()), ("svc", SVC(class_weight="balanced", random_state=101))]
pipe_svc_model = Pipeline(steps=operations_svc)

# %%
pipe_svc_model.fit(X_train, y_train)

eval_metric(pipe_svc_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[241  11   8]
#  [  5 111  20]
#  [ 22 107 629]]
#               precision    recall  f1-score   support
#
#        Black       0.90      0.93      0.91       260
#     Hispanic       0.48      0.82      0.61       136
#        White       0.96      0.83      0.89       758
#
#     accuracy                           0.85      1154
#    macro avg       0.78      0.86      0.80      1154
# weighted avg       0.89      0.85      0.86      1154
#
#
# Train_Set
# [[ 959   41   38]
#  [  22  452   69]
#  [  53  422 2559]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.92      0.93      1038
#     Hispanic       0.49      0.83      0.62       543
#        White       0.96      0.84      0.90      3034
#
#     accuracy                           0.86      4615
#    macro avg       0.79      0.87      0.81      4615
# weighted avg       0.90      0.86      0.87      4615

# %%
model = Pipeline(steps=operations_svc)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.571221
# test_precision_Hispanic    0.457893
# test_recall_Hispanic       0.762256
# dtype: float64

# %% [markdown]
# ###  SVC Model GridsearchCV

# %%
param_grid = {
    'svc__C': [1,2,3],
    'svc__gamma': ["scale", "auto", 1, 0.1, 0.01]
}

# %% [raw]
# CV veya Gridsearch score almak için modeli sıfırlamayı unutma.

# %%
operations_svc = [("scaler", MinMaxScaler()), ("svc", SVC(class_weight="balanced", random_state=101))]
model = Pipeline(steps=operations_svc)

svm_model_grid = GridSearchCV(model,
                              param_grid,
                              verbose=3,
                              scoring=recall_Hispanic,
                              n_jobs=-1)

# %%
svm_model_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# GridSearchCV(estimator=Pipeline(steps=[('scaler', MinMaxScaler()),
#                                        ('svc',
#                                         SVC(class_weight='balanced',
#                                             random_state=101))]),
#              n_jobs=-1,
#              param_grid={'svc__C': [1, 2, 3],
#                          'svc__gamma': ['scale', 'auto', 1, 0.1, 0.01]},
#              scoring=make_scorer(recall_score, average=None, labels=['Hispanic']),
#              verbose=3)

# %%
svm_model_grid.best_params_
# Out:
# {'svc__C': 2, 'svc__gamma': 'scale'}

# %%
svm_model_grid.best_score_
# Out:
# 0.764186204553177

# %%
eval_metric(svm_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[240  10  10]
#  [  5 111  20]
#  [ 22  92 644]]
#               precision    recall  f1-score   support
#
#        Black       0.90      0.92      0.91       260
#     Hispanic       0.52      0.82      0.64       136
#        White       0.96      0.85      0.90       758
#
#     accuracy                           0.86      1154
#    macro avg       0.79      0.86      0.82      1154
# weighted avg       0.89      0.86      0.87      1154
#
#
# Train_Set
# [[ 968   36   34]
#  [  19  462   62]
#  [  55  371 2608]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.93      0.93      1038
#     Hispanic       0.53      0.85      0.65       543
#        White       0.96      0.86      0.91      3034
#
#     accuracy                           0.87      4615
#    macro avg       0.81      0.88      0.83      4615
# weighted avg       0.91      0.87      0.88      4615

# %%
operations_svc = [("scaler", MinMaxScaler()), ("svc", SVC(C=2, class_weight="balanced",random_state=101))]
model = Pipeline(steps=operations_svc)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
y_pred = svm_model_grid.predict(X_test)

svc_AP = viz.score_["Hispanic"]
svc_f1 = f1_score(y_test, y_pred, average=None, labels=["Hispanic"])
svc_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# ## 3. RF

# %% [raw]
# artık treebased modellere geçtik. Bunlarda getdummies yerine encoder kullanacağız. LabelEncoder veya OrdinalEncoder kullanacağız.

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
X2 = data.drop("DODRace",axis=1)
y = data.DODRace

# %%
cat = X2.select_dtypes("object").columns
cat
# Out:
# Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object')

# %%
enc = OrdinalEncoder()
X2[cat] = enc.fit_transform(X2[cat])
X2.head()
# Out:
#    abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# ...

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y, test_size=0.2, random_state=101, stratify =y)

# %%
print("Train features shape : ", X_train2.shape)
print("Train target shape   : ", y_train2.shape)
print("Test features shape  : ", X_test2.shape)
print("Test target shape    : ", y_test2.shape)
# Out:
# Train features shape :  (4615, 97)
# Train target shape   :  (4615,)
# Test features shape  :  (1154, 97)
# Test target shape    :  (1154,)

# %% [markdown]
# ### Vanilla RF Model

# %% [raw]
# default değerler yerine balanced kullandık çünkü değerler bu olmadan kötü çıkıyor. scoreların kötü çıktığını görüyoruz. Bundan dolayı hyperparameter ile oynayacağız.

# %%
rf_model = RandomForestClassifier(class_weight="balanced", random_state=101)

# %%
rf_model.fit(X_train2, y_train2)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=101)

# %%
eval_metric(rf_model, X_train2, y_train2, X_test2, y_test2)
# Out:
# Test_Set
# [[191   0  69]
#  [  9   5 122]
#  [ 12   1 745]]
#               precision    recall  f1-score   support
#
#        Black       0.90      0.73      0.81       260
#     Hispanic       0.83      0.04      0.07       136
#        White       0.80      0.98      0.88       758
#
#     accuracy                           0.82      1154
#    macro avg       0.84      0.58      0.59      1154
# weighted avg       0.82      0.82      0.77      1154
#
#
# Train_Set
# [[1038    0    0]
#  [   0  542    1]
#  [   0    0 3034]]
#               precision    recall  f1-score   support
#
#        Black       1.00      1.00      1.00      1038
#     Hispanic       1.00      1.00      1.00       543
#        White       1.00      1.00      1.00      3034
#
#     accuracy                           1.00      4615
#    macro avg       1.00      1.00      1.00      4615
# weighted avg       1.00      1.00      1.00      4615

# %%
model = RandomForestClassifier(class_weight="balanced", random_state=101)

scores = cross_validate(model, X_train2, y_train2, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.076156
# test_precision_Hispanic    0.853333
# test_recall_Hispanic       0.040606
# dtype: float64

# %% [markdown]
# ### RF Model GridsearchCV

# %%
param_grid = {'n_estimators':[400,500],
             'max_depth':[10,12,14,16]} #'min_samples_split':[18,20,22], 'max_features': ['auto', None, 15, 20]

# %% [raw]
# max_depth overfitting çözemedi. Bu durumda minsamplesplit kullanmam gerekecek.
#
# overfitting engellemek için önce test seti değerlerini train seti kendine çekmeye çalışır ancak bu olmayınca kendi yaklaşmaya başlar.
#
# RF scorelarının çok kötü olduğunu gördüm. gridsearch ile de scoreların iyileşmediğini gördüm.
#
# modelimin score kötü yani 0.5 altında. Bu modelimin bundan daha kötü yani yazı tura atmaktan daha kötü olduğunu söyleyebeliriz.

# %%
rf_model = RandomForestClassifier(class_weight="balanced", random_state=101)
rf_grid_model = GridSearchCV(rf_model,
                             param_grid,
                             verbose=3,
                             scoring=recall_Hispanic,
                             n_jobs=-1)

# %%
rf_grid_model.fit(X_train2,y_train2)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# GridSearchCV(estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=101),
#              n_jobs=-1,
#              param_grid={'max_depth': [10, 12, 14, 16],
#                          'n_estimators': [400, 500]},
#              scoring=make_scorer(recall_score, average=None, labels=['Hispanic']),
#              verbose=3)

# %%
rf_grid_model.best_params_
# Out:
# {'max_depth': 10, 'n_estimators': 400}

# %%
rf_grid_model.best_score_
# Out:
# 0.22099898063200815

# %%
eval_metric(rf_grid_model, X_train2, y_train2, X_test2, y_test2)
# Out:
# Test_Set
# [[210   2  48]
#  [ 14  31  91]
#  [ 21  28 709]]
#               precision    recall  f1-score   support
#
#        Black       0.86      0.81      0.83       260
#     Hispanic       0.51      0.23      0.31       136
#        White       0.84      0.94      0.88       758
#
#     accuracy                           0.82      1154
#    macro avg       0.73      0.66      0.68      1154
# weighted avg       0.80      0.82      0.80      1154
#
#
# Train_Set
# [[1023    1   14]
#  [   0  529   14]
#  [   3   21 3010]]
#               precision    recall  f1-score   support
#
#        Black       1.00      0.99      0.99      1038
#     Hispanic       0.96      0.97      0.97       543
#        White       0.99      0.99      0.99      3034
#
#     accuracy                           0.99      4615
#    macro avg       0.98      0.98      0.98      4615
# weighted avg       0.99      0.99      0.99      4615

# %%
model = RandomForestClassifier(class_weight="balanced", random_state=101, max_depth=10, n_estimators = 500)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train2, y_train2)
viz.score(X_test2, y_test2)
viz.show();

# %%
y_pred = rf_grid_model.predict(X_test2)

rf_AP = viz.score_["Hispanic"]
rf_f1 = f1_score(y_test2, y_pred, average=None, labels=["Hispanic"])
rf_recall = recall_score(y_test2, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# ## 4. XGBoost

# %% [markdown]
# ### Vanilla XGBoost Model

# %% [raw]
# eğer modelimizde dengesizliği ortadan kaldıracak bir hyperparametre yoksa multiclasslarda bir dengesizlik varsa bunu class_weight ile çözebiliriz.
#
# eğer binary olsaydı bunu XGB parametrelerinden scaleposweight ile çözmeye çalışabilirdik. multiclasslarda bir işe yaramıyor.

# %%
xgb_model = XGBClassifier(random_state=101)

# %%
from sklearn.utils import class_weight
classes_weights = class_weight.compute_sample_weight(class_weight='balanced', y=y_train2)
classes_weights
# Out:
# array([2.8330264 , 0.50703142, 0.50703142, ..., 0.50703142, 1.4820167 ,
#        0.50703142])

# %% [raw]
# bu işlem sonucunda classları value_counts değerlerine göre ağırlıklandırıyor. Modelin kendisinde böyle ağırlıklandırmak için bir parametre yoksa bu şekilde cözebiliriz. model içine fit işlemi yaparken direkt olarak sampleweighte classesweights verdik.

# %%
xgb_model.fit(X_train2, y_train2, sample_weight=classes_weights)
# weight parameter in XGBoost is per instance not per class. Therefore, we need to assign the weight of each class to its instances, which is the same thing.
# Out:
# [15:45:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=4,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=101, reg_alpha=0, reg_lambda=1,
#               scale_pos_weight=None, subsample=1, tree_method='exact',
# ...

# %%
eval_metric(xgb_model, X_train2, y_train2, X_test2, y_test2)
# Out:
# Test_Set
# [[233   2  25]
#  [ 12  60  64]
#  [ 19  19 720]]
#               precision    recall  f1-score   support
#
#        Black       0.88      0.90      0.89       260
#     Hispanic       0.74      0.44      0.55       136
#        White       0.89      0.95      0.92       758
#
#     accuracy                           0.88      1154
#    macro avg       0.84      0.76      0.79      1154
# weighted avg       0.87      0.88      0.87      1154
#
#
# Train_Set
# [[1038    0    0]
#  [   0  543    0]
#  [   0    0 3034]]
#               precision    recall  f1-score   support
#
#        Black       1.00      1.00      1.00      1038
#     Hispanic       1.00      1.00      1.00       543
#        White       1.00      1.00      1.00      3034
#
#     accuracy                           1.00      4615
#    macro avg       1.00      1.00      1.00      4615
# weighted avg       1.00      1.00      1.00      4615

# %%
model = XGBClassifier(random_state=101)

scores = cross_validate(model, X_train2, y_train2, scoring = scoring, cv = 10, fit_params={"sample_weight":classes_weights})
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# [15:42:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:42:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:42:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %% [markdown]
# ### XGBoost Model GridsearchCV

# %%
comp = pd.DataFrame(classes_weights)

comp["label"]= y_train2.reset_index(drop=True)  # modeldeki indeks numaralırını sıfırladı.
comp.groupby("label")[0].value_counts()
# Out:
# label     0
# Black     1.482017    1038
# Hispanic  2.833026     543
# White     0.507031    3034
# Name: 0, dtype: int64

# %%
y_train2.reset_index(drop=True)
# Out:
# 0       Hispanic
# 1          White
# 2          White
# 3          White
# 4          Black
#           ...
# 4610    Hispanic
# 4611       White
# 4612       White
# 4613       Black
# 4614       White
# Name: DODRace, Length: 4615, dtype: object

# %%
comp.groupby("label")[0].value_counts()
# Out:
# label     0
# Black     1.482017    1038
# Hispanic  2.833026     543
# White     0.507031    3034
# Name: 0, dtype: int64

# %%
param_grid = {"n_estimators":[100, 300],
              'max_depth':[3,5,6],
              "learning_rate": [0.1, 0.3],
              "subsample":[0.5, 1],
              "colsample_bytree":[0.5, 1]}

# %%
xgb_model = XGBClassifier(random_state=101)
xgb_grid_model = GridSearchCV(xgb_model, 
                              param_grid, 
                              scoring=recall_Hispanic, 
                              n_jobs = -1, 
                              verbose = 2).fit(X_train2, y_train2, sample_weight=classes_weights)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits

# %%
xgb_grid_model.best_params_

# %%
xgb_grid_model.best_score_

# %%
eval_metric(xgb_grid_model, X_train2, y_train2, X_test2, y_test2)

# %%
model = XGBClassifier(random_state=101, colsample_bytree=0.5, subsample=0.5)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1",
    sample_weight=classes_weights
)
viz.fit(X_train2, y_train2)
viz.score(X_test2, y_test2)
viz.show();

# %%
y_pred = xgb_grid_model.predict(X_test2)

xgb_AP = viz.score_["Hispanic"]
xgb_f1 = f1_score(y_test2, y_pred, average=None, labels=["Hispanic"])
xgb_recall = recall_score(y_test2, y_pred, average=None, labels=["Hispanic"])

# %% [raw]
# advanced modellerden aldığımız scoreların kötü olduğunu gördük. Demek ki her data seti için iyi scorelar vermeyebiliyor.

# %% [markdown]
# ## Comparing Models

# %% [raw]
# f1 score her zaman bir array döndürdügünden dolayı bunu [] ile belirtmek gerekir.

# %%
compare = pd.DataFrame({"Model": ["Logistic Regression", "SVM",  "Random Forest", "XGBoost"],
                        "F1": [log_f1[0], svc_f1[0], rf_f1[0], xgb_f1[0]],
                        "Recall": [log_recall[0], svc_recall[0], rf_recall[0], xgb_recall[0]],
                        "AP": [log_AP, svc_AP, rf_AP, xgb_AP]})

def labels(ax):
    for p in ax.patches:
        width = p.get_width()                        # get bar length
        ax.text(width,                               # set the text at 1 unit right of the bar
                p.get_y() + p.get_height() / 2,      # get Y coordinate + X coordinate / 2
                '{:1.3f}'.format(width),             # set variable to display, 2 decimals
                ha = 'left',                         # horizontal alignment
                va = 'center')                       # vertical alignment
    
plt.figure(figsize=(14,10))
plt.subplot(311)
compare = compare.sort_values(by="F1", ascending=False)
ax=sns.barplot(x="F1", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(312)
compare = compare.sort_values(by="Recall", ascending=False)
ax=sns.barplot(x="Recall", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(313)
compare = compare.sort_values(by="AP", ascending=False)
ax=sns.barplot(x="AP", y="Model", data=compare, palette="Blues_d")
labels(ax)
plt.show()

# %% [raw]
# Karşılaştırma sonucunda advanced modellerin düşük çıktığını görüyoruz. SVC scoreları daha iyi çıksa bile hem maliyet hem de feature importance yapamadığımdan dolayı çok tercih etmiyoruz. Bu sebeple LogisticRegresyonu seçtik. lagisticregresyon içindeki Lasso ve Riched gibi parametreler ile oynayarak feature importance yapabiliyoruz.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Before the Deployment
# - Choose the model that works best based on your chosen metric
# - For final step, fit the best model with whole dataset to get better performance.
# - And your model ready to deploy, dump your model and scaler.

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
final_model = Pipeline(steps=operations)

# %%
final_model.fit(X, y)

# %%
X.describe()

# %% [raw]
# datamdaki tüm featureların mean alıp tek bir değermiş gibi olsa nasıl bir score döndürür bunu görmek istedim.

# %%
mean_human = X.describe().loc["mean"]
mean_human

# %%
final_model.predict(X.loc[[201]]) 

# modeli 2 boyutlu yani ne ile train edildiyse o boyutta istediğinden dolayı iki boyutlu aldık.

# %%
y[201]

# %%
final_model.predict([mean_human])

# %% [markdown]
# - Evaluation metrics
# https://towardsdatascience.com/comprehensive-guide-on-multiclass-classification-metrics-af94cfb83fbd

# %% [raw]
# bizim aldığımız degerler ile gerçek değerler arasındaki corr olarak tarif edilir.
# Dengesiz data setlerinde hangi score daha doğru olduğunu bulmak için matthews_corrcoef, cohen_kappa_score diye iki tane yeni score üretmişler. Bu tür data setlerinde bunlarada bakmak gerekir.

# %%
from sklearn.metrics import matthews_corrcoef

y_pred = final_model.predict(X_test)

matthews_corrcoef(y_test, y_pred)

# %%
from sklearn.metrics import cohen_kappa_score

cohen_kappa_score(y_test, y_pred)

# %% [markdown]
# ---
# ---

# %% [markdown]
# # SMOTE
# https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

# %% [markdown]
# ##  Smote implement

# %%
#!pip install imblearn

# %% [raw]
# smote, datalarımız bir grift yapı oluşturmuş ise çok iyi sonuçlar vermez.
#
# smote oversampling ile çalıştırırsam, data setimdeki dengesiz dataları en büyük class sayısına eşitler.
#
# random undersampling ile çalıştırırsam, data setimdeki dengesiz dataları en küçük class sayısına eşitler.
#
# ancak ben ne az ne de çok olan ile eşitlemek istemiyorum.
#
# yukarıdaki işlemler aslında sentetik veri oluşturma işlemleridir. yaklaşımın nasıl olmasını görmek anlamında bunu değerlendirmek gerekir. datanın doğasını bozmamak gerekir. bu yapıyı bozmadan ufak dokunuşlar ile daha iyi scorelar almayı amaçlıyoruz.
#
# gözlem sayısını artırmak sadece train setine uygulanır. Test setine kesinlikle dokunmuyorum.
#
# default degerler ile kullanırsam bu durumda en fazla veya en az olana yakın biryapı oluşturur. Bunun yerine dengeli bir yapı bulmak için sampling_strategy ile hangi classın ne kadar artırılmasını sampling_strategy={"Hispanic": 1200} veya azaltılmasını sampling_strategy={"White": 2500} istiyorsam bunu yazıyorum.
#
# black dokunmamızın sebebi hispaniç ile white arasında bir griftlik söz konusu.

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as imbpipeline

# %%
over = SMOTE(sampling_strategy={"Hispanic": 1200})
under = RandomUnderSampler(sampling_strategy={"White": 2500})

# %%
X_resampled_over, y_resampled_over = over.fit_resample(X_train, y_train)

# %%
y_resampled_over.value_counts()

# %%
X_resampled_under, y_resampled_under = under.fit_resample(X_train, y_train)

# %%
y_resampled_under.value_counts()

# %% [raw]
# Buradaki pipeline bildiğimiz sklearn pipeline değil. Buradaki imblearn library pipelinedır.
#
# normal pipeline fit, transform ve predict işlemlerini kabul ediyor. buradaki fit_resample kabul etmediğinden dolayı burada imblearn library pipeline kullandık.
#
# Aslında hepsini azaltıp score alsak iyi scorelar alırız. bu istediğimiz bir durum değil. bundan dolayı dengeyi yakalamaya çalışıyoruz.

# %% [raw]
# eğer veri kaliteli, gerçekçi ise ölçmek istediğini yansıtıyorsa  örnek arttırmak sorun olmayabilir ve daha doğru sonuçlara ulaşabilirsiniz. Ancak veri kalitesi düşükse , örneklemi iyi temsil etmiyorsa örneklem arttırmak sonuçlar için sıkıntılı olabilir diye bir değerlendirme yapabiliriz.(alıntı)

# %%
# we are configuring our pipeline steps
steps = [('o', over), ('u', under)]

# create a pipeline that will automatically apply over and under
# sampling in order to steps that we created.
pipeline = imbpipeline(steps=steps)

# we will create new data over X_train and y_train.
# We simply delete some of our samples if its race "white" and we add synthetic samples to "hispanics".
X_resampled, y_resampled = pipeline.fit_resample(X_train, y_train)

# %%
y_resampled.value_counts()

# %%
y_train.value_counts()

# %% [markdown]
# ## Logistic Regression Over/Under Sampling

# %% [raw]
# ## what does the smote pipeline do?
#
# smote_pipeline.fit(X_train, y_train) --> over.fit_resample(X_train) --> under.fit_resample(X_train_over)
#
#                                      --> scaler.fit_transform(X_train_over_under), log_model.fit(X_train_over_under_scaled, y_train)
#
#
# for predict, over and under sumpling algortims do nothing.
#
# smote_pipeline.predict(X_test)       --> scaler.transform(X_test) --> log_model.predict(X_test_scaled)

# %%
operations = [('o', over), ('u', under), ("scaler", MinMaxScaler()), 
              ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]

# %%
smote_pipeline = imbpipeline(steps=operations)

# %%
smote_pipeline.fit(X_train, y_train)

# %%
eval_metric(smote_pipeline, X_train, y_train, X_test, y_test)

# %%
model = smote_pipeline = imbpipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]

# %% [raw]
# birbirine grift olan yapılarda smoote pek bir fayda sağlamaz. ancak ayrılmış bir yapı söz konusu ise daha iyi scorelar alabiliriz. Bakıldığında burada smoote scorelarını düşük geldiğini görüyoruz.

# %% [markdown]
# #  SHAP

# %% [markdown]
# https://towardsdatascience.com/shap-explain-any-machine-learning-model-in-python-24207127cad7

# %%
# !pip install shap

# %% [raw]
# SHAP pipeline işlemini kabul etmiyor. feature importance yapacağımdan dolayı burada penalty="l1", solver='saga' seçtim. Çünkü Lasso ile feature selection yapabiliyorum.
#
# hangi class için scoreları iyileştirmek istiyorsam onu veriyorum.
#
# logistic ve treebased modeller için kullanıyorum. ilave olarak SVM feature importance vermesede shape ile kullanarak feature importance yapabiliyorum.

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model_shap = LogisticRegression(class_weight='balanced',max_iter=10000, random_state=101, penalty="l1", solver='saga')
model_shap.fit(X_train_scaled, y_train)

# %%
eval_metric(model_shap, X_train_scaled, y_train, X_test_scaled, y_test)

# %% [raw]
# !!! önemli:
#
# shape bir modeli verirken üzerinde çalıştığım class için en iyi scoreları veren modele seçmem gerekir. Yukarıda RF ve XGBOOST scoreları çok kötü geldiğinden dolayı bunları buraya vermem mümkün olamaz.
#
# Shape bir gözlemi tahmin ederken hangi featuren daha büyük etkisi var bunu gösteriyor.
#
# aşağıdaki indekse ait gözlemi tahmin eden feature ların etkisine bakıyorum.

# %%
import shap
explainer = shap.Explainer(model_shap, X_train_scaled)
start_index = 203
end_index = 204
shap_values = explainer.shap_values(X_test_scaled[start_index:end_index])

# %%
shap_values

# %%
shap_values[0][0] # white classını seçerken ki featurelerin etkisini görüyoruz.
shap_values[1][0] # hispanic classını seçerken ki featurelerin etkisini görüyoruz.
shap_values[2][0] # black classını seçerken ki featurelerin etkisini görüyoruz.

# %%
shap_values[0].shape

# %%
# %% >> Visualize local predictions
shap.initjs()
# Force plot
prediction = model_shap.predict(X_test_scaled[start_index:end_index])[0]
print(f"The log_model predicted: {prediction}")
shap.force_plot(explainer.expected_value[1],
                shap_values[1],
                X_test_scaled[start_index:end_index], # for values
                feature_names= X.columns)

# %% [raw]
# aşağıdaki değer, modelimin hispanicler için - 0.81 ile başlayacağı anlamına gelir. kırmızıların hispanicleri doğru olarak teşhis etmek için katkısı daha fazladır. mavi olanların ise daha azdır.
#
# aşağıda en düşük değer hispanic sınıfına ait olduğundan dolayı bu gözlemin hispanic sınıfına atandığını yani bu sınıfı seçtiğini görüyoruz.

# %%
explainer.expected_value[1]

# %%
X_test_scaled[203]

# %%
shap.force_plot(explainer.expected_value[0],
                shap_values[0],
                X_test_scaled[start_index:end_index], # for values
                feature_names= X.columns)

# %%
shap.force_plot(explainer.expected_value[2],
                shap_values[2],
                X_test_scaled[start_index:end_index], # for values
                feature_names= X.columns)

# %% [markdown]
# ## Shap values for all data

# %%
explainer = shap.Explainer(model_shap, X_train_scaled)

shap_values = explainer.shap_values(X_test_scaled)

# %%
shap.summary_plot(shap_values, X_train_scaled, max_display=300,feature_names = X.columns)

# %% [raw]
# !!! çok önemli:
#
# bütün gözlemlerim için featureların ne kadar etkisi var önemli olan kısım budur. burada görüldüğü gibi bütün data yani X_test için bunu yapıyorum.
#
# baktığımda en kuvvetli featureler içerisinde hispaniçleri tahmin etmede hiçbirinin bir katkısı olmadığını görüyoruz. hispanicleri tespit etmeye katkısı olan featurelardan önemli olanları aşağıda belirttik.

# %%
hispanic = ["SubjectsBirthLocation",  'handlength',  'forearmcircumferenceflexed', "headlength", 'bitragionsubmandibulararc',
            'footbreadthhorizontal',  'bimalleolarbreadth', 'poplitealheight', 'waistdepth', 'WritingPreference', 'tragiontopofhead',
            'bideltoidbreadth', 'neckcircumferencebase', 'biacromialbreadth','buttockheight', 'buttockkneelength', 'earlength', 
            'axillaheight', "Age"]

# %%
#list(X.columns)

# %%
X3 = data[hispanic]
X3 = pd.get_dummies(data=X3, drop_first=True)
y = data.DODRace

# %%
X3.shape

# %%
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, y, test_size=0.2, random_state=101, stratify =y)

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101,
                                                                    penalty="l1", solver='saga'))]
pipe_shap_model = Pipeline(steps=operations)

# %%
pipe_shap_model.fit(X_train3, y_train3)

# %%
eval_metric(pipe_shap_model, X_train3, y_train3, X_test3, y_test3)

# %% [raw]
# scorelarıma baktığımda black ve white kötüleşti ancak hispanicleri ayırmada daha iyi scorelar aldığımız görüyoruz.
#
# burada önemli husus shape verdiğimiz penalty mutlaka l1 olacaktır.

# %%
model = Pipeline(steps=operations)

scores = cross_validate(model, X_train3, y_train3, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]

# %%
from yellowbrick.classifier import PrecisionRecallCurve
model = Pipeline(steps=operations)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train3, y_train3)
viz.score(X_test3, y_test3)
viz.show();

# %% [markdown]
# ## SMOTE for X3 dataset

# %% [raw]
# yukarıda iyileştirdiğim score birde smote uygulayıp sonuç almak istedim ancak smote scorelarımı düşürdüğünü gördüm.

# %%
operations = [('o', over), ('u', under), ("scaler", MinMaxScaler()), 
              ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]

# %%
smote_pipeline_2 = imbpipeline(steps=operations)

# %%
smote_pipeline_2.fit(X_train3, y_train3)

# %%
eval_metric(smote_pipeline_2, X_train3, y_train3, X_test3, y_test3)

# %%
model = imbpipeline(steps=operations)

scores = cross_validate(model, X_train3, y_train3, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]

# %% [markdown]
# ## Find the best threshold for multiclassification

# %% [raw]
# multiclass için benim için hangi class önemli ise bunu 1 diğerlerini 0 yapıp bu şekilde de modelden score alıyorum.
#
# hispaniclere 1, diğerlerine 0 diyerek yeni bir veri seti oluşturduk.

# %%
y2 = y.map({"Hispanic":1, "White":0, "Black":0})

# %%
y2

# %%
X_train4, X_test4, y_train4, y_test4 = train_test_split(X3, y2, test_size=0.2, random_state=101, stratify =y2)

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
pipe_shap_model2 = Pipeline(steps=operations)

# %%
pipe_shap_model2.fit(X_train4, y_train4)

# %%
eval_metric(pipe_shap_model2, X_train4, y_train4, X_test4, y_test4)

# %%
from sklearn.metrics import plot_roc_curve, plot_precision_recall_curve, roc_auc_score, auc, roc_curve, average_precision_score, precision_recall_curve

operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(max_iter=10000,random_state=101))]
log_basic_model = Pipeline(steps=operations)

log_basic_model.fit(X_train4, y_train4)
plot_precision_recall_curve(log_basic_model, X_train4, y_train4);

# %%
y_pred_proba = log_basic_model.predict_proba(X_train4)
average_precision_score(y_train4, y_pred_proba[:,1])

# %%
precisions, recalls, thresholds = precision_recall_curve(y_train4, y_pred_proba[:,1])

# %%
optimal_idx = np.argmax((2 * precisions * recalls) / (precisions + recalls))
optimal_threshold = thresholds[optimal_idx]
optimal_threshold

# %%
y_pred2 = pd.Series(pipe_shap_model2.predict_proba(X_test4)[:,1]).apply(lambda x : 1 if x >= optimal_threshold else 0)

# dengeli score aldığımız modelimize uyguladık.

# %% [raw]
# aldığımız scorelara göre, aşağıdaki gibi scorelar ile müşteriye gidip onun için hangisinin daha önemli olduğunu soruyoruz. mesela burada

# %% [markdown]
# ![image.png](attachment:fd92abf4-479e-42fb-bdb5-b2e5fff32b98.png)

# %%
print(confusion_matrix(y_test4,y_pred2))
print(classification_report(y_test4,y_pred2))

# %%
y_train_pred2 = pd.Series(pipe_shap_model2.predict_proba(X_train4)[:,1]).apply(lambda x : 1 if x >= optimal_threshold else 0)
print(confusion_matrix(y_train4, y_train_pred2))
print(classification_report(y_train4, y_train_pred2))

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score

def CV(n, est, X, y, optimal_threshold):
    skf = StratifiedKFold(n_splits = n, shuffle = True, random_state = 42)
    acc_scores = []
    pre_scores = []
    rec_scores = []
    f1_scores  = []
    
    X = X.reset_index(drop=True)
    y = y.reset_index(drop=True)
    
    for train_index, test_index in skf.split(X, y):
        
        X_train = X.loc[train_index]
        y_train = y.loc[train_index]
        X_test = X.loc[test_index]
        y_test = y.loc[test_index]
        
        
        est = est
        est.fit(X_train, y_train)
        y_pred = est.predict(X_test)
        y_pred_proba = est.predict_proba(X_test)
             
        y_pred2 = pd.Series(y_pred_proba[:,1]).apply(lambda x : 1 if x >= optimal_threshold else 0)
        
        acc_scores.append(accuracy_score(y_test, y_pred2))
        pre_scores.append(precision_score(y_test, y_pred2, pos_label=1))
        rec_scores.append(recall_score(y_test, y_pred2, pos_label=1))
        f1_scores.append(f1_score(y_test, y_pred2, pos_label=1))
    
    print(f'Accuracy {np.mean(acc_scores)*100:>10,.2f}%  std {np.std(acc_scores)*100:.2f}%')
    print(f'Precision-1 {np.mean(pre_scores)*100:>7,.2f}%  std {np.std(pre_scores)*100:.2f}%')
    print(f'Recall-1 {np.mean(rec_scores)*100:>10,.2f}%  std {np.std(rec_scores)*100:.2f}%')
    print(f'F1_score-1 {np.mean(f1_scores)*100:>8,.2f}%  std {np.std(f1_scores)*100:.2f}%')

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
model = Pipeline(steps=operations)
CV(10, model, X_train4, y_train4, optimal_threshold)

# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
