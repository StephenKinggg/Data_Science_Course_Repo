# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Data Analysis Project***". This is the capstone project of ***Data Analysis*** Module. **Auto Scout** data which using for this project, scraped from the on-line car trading company in 2019, contains many features of 9 different car models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using many Python libraries such as Numpy, Pandas, Matplotlib, Seaborn, Scipy you will analyze clean dataset.
#
# The project consists of 3 parts:
# * First part is related with 'data cleaning'. It deals with Incorrect Headers, Incorrect Format, Anomalies, Dropping useless columns.
# * Second part is related with 'filling data'. It deals with Missing Values. Categorical to numeric transformation is done.
# * Third part is related with 'handling outliers of data' via Visualisation libraries. Some insights are extracted.

# %% [markdown]
# # PART- 1 `( Data Cleaning )`

# %% [markdown]
# https://www.youtube.com/watch?v=aBygOp17doQ
#
# https://www.youtube.com/watch?v=FVECTpahzCQ
#
# https://blog.softhints.com/pandas-typeerror-unhashable-type-list-dict/

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re

# %%
import pandas as pd
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 60)
pd.set_option('display.width', 5)
pd.set_option('display.max_colwidth', 30)

# %% [markdown]
# typ : {'frame', 'series'}, default 'frame'
#     The type of object to recover.
#
# dtype : bool or dict, default None
#     If True, infer dtypes; if a dict of column to dtype, then use those;
#     if False, then don't infer dtypes at all, applies only to the data.

# %%
df = pd.read_json('scout_car.json', lines=True, orient='records', convert_axes=True, dtype=True,convert_dates=True)
df
# Out:
#                                  url  \
# 0      https://www.autoscout24.co...
# 1      https://www.autoscout24.co...
# 2      https://www.autoscout24.co...
# 3      https://www.autoscout24.co...
# 4      https://www.autoscout24.co...
# ...                              ...
# 15914  https://www.autoscout24.co...
# 15915  https://www.autoscout24.co...
# 15916  https://www.autoscout24.co...
# 15917  https://www.autoscout24.co...
# 15918  https://www.autoscout24.co...
#
#            make_model  \
# 0             Audi A1
# 1             Audi A1
# 2             Audi A1
# 3             Audi A1
# 4             Audi A1
# ...               ...
# 15914  Renault Espace
# 15915  Renault Espace
# 15916  Renault Espace
# 15917  Renault Espace
# 15918  Renault Espace
#
#                    short_description  \
# 0      Sportback 1.4 TDI S-tronic...
# 1                     1.8 TFSI sport
# 2      Sportback 1.6 TDI S tronic...
# 3            1.4 TDi Design S tronic
# ...

# %%
spec_chars = ["!",'"',"#","%","&","'","(",")"," ",
              "*","+",",","-","/",":",";","<",
              "=",">","?","@","[","\\","]","^",
              "`","{","|","}","~","–","\n","."]

for char in spec_chars:
    df.columns = df.columns.str.replace(char, '_')
# Out:
# <ipython-input-164-8f1b537feb51>:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace(char, '_')

# %%
df.columns = df.columns.str.lower()

# %%
df.rename(columns={"_comfort___convenience_":"comfort_convenience","_entertainment___media_":"entertainment_media","_extras_":"extras","_safety___security_":"safety_security","nr__of_doors":"nr_of_doors","nr__of_seats":"nr_of_seats"}, inplace=True)

# %%
df.columns
# Out:
# Index(['url',
#        'make_model',
#        'short_description',
#        'body_type',
#        'price',
#        'vat',
#        'km',
#        'registration',
#        'prev_owner',
#        'kw',
#        'hp',
#        'type',
#        'previous_owners',
#        'next_inspection',
#        'inspection_new',
#        'warranty',
#        'full_service',
#        'non_smoking_vehicle',
#        'null',
#        'make',
#        'model',
#        'offer_number',
#        'first_registration',
#        'body_color',
#        'paint_type',
#        'body_color_original',
#        'upholstery',
#        'body',
#        'nr_of_doors',
#        'nr_of_seats',
#        'model_code',
#        'gearing_type',
#        'displacement',
#        'cylinders',
#        'weight',
#        'drive_chain',
#        'fuel',
#        'consumption',
#        'co2_emission',
#        'emission_class',
#        'comfort_convenience',
#        'entertainment_media',
#        'extras',
# ...

# %% [markdown]
# df.rename(columns=lambda x: re.sub('(\s|/)','_', x), inplace=True).str.lower()
#
# df.columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kw                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  type                           15917 non-null  object
# ...

# %%
df.shape
# Out:
# (15919, 54)

# %%
df['make_model'].value_counts()
# Out:
# Audi A3           3097
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2526
# Opel Corsa        2219
# Renault Clio      1839
# Renault Espace     991
# Renault Duster      34
# Audi A2              1
# Name: make_model, dtype: int64

# %%
df['mark'] = df['make_model'].astype('str').str.split(' ', expand=True)[0]

# %%
df.mark.value_counts()
# Out:
# Opel       7343
# Audi       5712
# Renault    2864
# Name: mark, dtype: int64

# %%
df['model'] = df['make_model'].astype('str').str.split(' ', expand=True)[1]

# %%
df.model.value_counts()
# Out:
# A3          3097
# A1          2614
# Insignia    2598
# Astra       2526
# Corsa       2219
# Clio        1839
# Espace       991
# Duster        34
# A2             1
# Name: model, dtype: int64

# %%
df['short_description'].value_counts().head(50)
# Out:
# SPB 1.6 TDI 116 CV S tronic Sport                    64
# 1.4 66kW (90CV) Selective                            40
# MOVE KLIMA CD USB ALLWETTER BLUETOOTH                38
# SPB 30 TFSI S tronic Admired                         35
# SPB 30 TDI S tronic Business                         35
# Sporter 1.5 dCi 90CV Zen , NAVI - AZIENDALE          32
# dCi 75 Business Energy eco2 Euro6 55 kW (75 C        31
# dCi 160CV EDC Energy Intens                          30
# 1.2 5 porte b-Color                                  30
# 1.2 5 porte Advance                                  28
# SPB 1.6 TDI 116 CV Sport                             28
# R.S. TROPHY ENERGY TCe 220 EDC                       28
# RS Sport 1.6 TCE220 Aut.*NAVI*SPORT-FWK*LED          27
# 1.4 TFSI Design*PDC*Sport-S*LM-Felgen*SHZ*           27
# K 1.4 SIDI Turbo Innovation Aut. *NAVI*              27
# 1.2 TCE ENERGY INTENS Aut. *Navi*LED*                27
# 1.6 TCE ENERGY INTENS *Navi*LED*Cam*Pano*            27
# ...

# %%
df['short_description'].str.extract("(\d\d\d\d|\d.\d|\d)").value_counts()
# Out:
# 1.6     3693
# 1.4     2312
# 3       1348
# 1.0     1174
# 1.2      880
#         ...
# 169        1
# 1739       1
# 2.8        1
# 2000       1
# 9890       1
# Length: 100, dtype: int64

# %%
df['short_description'].str.extract("([A-Z][A-Z][A-Z])").value_counts()
# Out:
# TFS    2196
# CDT    2163
# TDI    1574
# SPB    1162
# EDC     842
#        ...
# ITA       1
# ILU       1
# IIN       1
# IDO       1
# ZER       1
# Length: 261, dtype: int64

# %%
df['body_type'].value_counts().head(30)
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
df['price'].isna().value_counts()
# Out:
# False    15919
# Name: price, dtype: int64

# %%
df['price'].value_counts().head(20)
# Out:
# 14990    154
# 15990    151
# 10990    139
# 15900    106
# 17990    102
# 9900      98
# 20900     93
# 22900     92
# 13990     92
# 21900     91
# 19900     89
# 14900     88
# 16990     86
# 17900     86
# 18900     86
# 16900     84
# 18990     81
# 8490      78
# 12990     77
# 21500     75
# Name: price, dtype: int64

# %%
df['vat'].value_counts().head(20)  # get_dummy ile kategorik sayısala çevirelim.
# Out:
# VAT deductible      10980
# Price negotiable      426
# Name: vat, dtype: int64

# %%
df['km'].value_counts().head(20)
# Out:
# 10 km        1045
# - km         1024
# 1 km          367
# 5 km          170
# 50 km         148
# 100 km        139
# 15 km         109
# 5,000 km      104
# 20 km          61
# 3,000 km       58
# 12 km          56
# 8,000 km       49
# 45,000 km      48
# 30,000 km      47
# 10,000 km      47
# 25,000 km      47
# 18,000 km      46
# 1,000 km       46
# 35,000 km      44
# 19,000 km      44
# Name: km, dtype: int64

# %%
df['km'].str.replace(r'\D+', '', regex=True).replace({'':0}).astype('int').value_counts().head(20)

# df["km"].replace(to_replace=r"\d+", value=r" ", regex=True) sadece km kalsın istersek
# Out:
# 10       1045
# 0        1043
# 1         367
# 5         170
# 50        148
# 100       139
# 15        109
# 5000      104
# 20         61
# 3000       58
# 12         56
# 8000       49
# 45000      48
# 30000      47
# 25000      47
# 10000      47
# 18000      46
# 1000       46
# 35000      44
# 19000      44
# Name: km, dtype: int64

# %%
df['registration'].value_counts().head(10)
# Out:
# -/-        1597
# 03/2018     695
# 02/2019     585
# 05/2018     572
# 03/2019     543
# 04/2018     541
# 01/2019     541
# 02/2018     539
# 03/2016     536
# 04/2016     532
# Name: registration, dtype: int64

# %%
# df["registration"] = pd.to_datetime(df["registration"], errors='coerce')

# %%
# df["registration"].value_counts().head(10)

# %%
df['registration'].str.extract('(\d{2}).(\d{4})')[1].isna().value_counts()
# Out:
# False    14322
# True      1597
# Name: 1, dtype: int64

# %%
df['prev_owner'].value_counts().head(100)  # None dolduralacak.
# Out:
# 1 previous owner     8294
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# Name: prev_owner, dtype: int64

# %%
df['prev_owner'].str.replace(r'\D+', '', regex=True).replace({'':0}).astype('str').value_counts().head(20)

# None değerlerden dolayı astype("int") girersek hata veriyor.
# Out:
# 1       8294
# None    6828
# 2        778
# 3         17
# 4          2
# Name: prev_owner, dtype: int64

# %%
df['kW'].value_counts().head(100)   # silinecek.
# Out:
# Series([], Name: kW, dtype: int64)

# %%
df['hp'].value_counts().head(100)
# Out:
# 85 kW     2542
# 66 kW     2122
# 81 kW     1402
# 100 kW    1308
# 110 kW    1112
#           ...
# 163 kW       1
# 239 kW       1
# 44 kW        1
# 133 kW       1
# 75 kW        1
# Name: hp, Length: 81, dtype: int64

# %%
df['hp'].str.replace(r'\D+', '', regex=True).replace({'':0}).astype('int').value_counts().head(60)
# Out:
# False    15919
# Name: hp, dtype: int64

# %%
df = pd.read_json('scout_car.json', lines=True, orient='records', convert_axes=True, dtype=True,convert_dates=True)
df.head(3)
# Out:
#                              url  \
# 0  https://www.autoscout24.co...
# 1  https://www.autoscout24.co...
# 2  https://www.autoscout24.co...
#
#   make_model  \
# 0    Audi A1
# 1    Audi A1
# 2    Audi A1
#
#                short_description  \
# 0  Sportback 1.4 TDI S-tronic...
# 1                 1.8 TFSI sport
# 2  Sportback 1.6 TDI S tronic...
#
#   body_type  \
# 0    Sedans
# 1    Sedans
# 2    Sedans
#
#    price  \
# 0  15770
# 1  14500
# 2  14640
#
#                 vat  \
# 0    VAT deductible
# 1  Price negotiable
# 2    VAT deductible
#
#           km  \
# 0  56,013 km
# 1  80,000 km
# 2  83,450 km
#
#   registration  \
# 0      01/2016
# 1      03/2017
# 2      02/2016
#
#           prev_owner  \
# 0  2 previous owners
# 1               None
# 2   1 previous owner
#
#    kW  \
# 0 NaN
# 1 NaN
# 2 NaN
#
#        hp  \
# 0   66 kW
# 1  141 kW
# 2   85 kW
#
#                             Type  \
# 0  [, Used, , Diesel (Particu...
# 1           [, Used, , Gasoline]
# ...

# %%
df['type'].value_counts().head(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [, Used, , Diesel (Particulate Filter)]                                                                                  3475
# [, Used, , Diesel]                                                                                                       2516
# [, Used, , Gasoline]                                                                                                     2367
# ...

# %%
df['type'] = df['type'].astype('str').str.split(', ,', expand=True)

# %%
df['type'].value_counts().head(10)
# Out:
# ['', 'Used', '', 'Diesel (Particulate Filter)']              3475
# ['', 'Used', '', 'Diesel']                                   2516
# ['', 'Used', '', 'Gasoline']                                 2367
# ['', 'Used', '', 'Super 95']                                 1818
# ['', 'Pre-registered', '', 'Super 95']                        500
# ['', 'New', '', 'Super 95']                                   497
# ['', "Employee's car", '', 'Diesel (Particulate Filter)']     343
# ['', 'New', '', 'Gasoline']                                   340
# ['', 'Used', '', 'Super 95 / Regular/Benzine 91']             324
# ['', "Employee's car", '', 'Super 95']                        264
# Name: type, dtype: int64

# %%
# [df['type'][i][0] for i in range(len(df['type']))]
# Out:
# ['[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
# ...

# %%
df["vehicle_type"] = df['type'].str.split(',', expand=True)[1]

# %%
df["vehicle_type"].str.replace(r'\W+', ' ', regex=True).replace({'':0}).isna().value_counts().head(20)
# Out:
# False    15917
# True         2
# Name: vehicle_type, dtype: int64

# %%
df["previous_owners"].value_counts().head(100)
# Out:
# \n1\n    8294
# \n2\n     778
# \n0\n     188
# \n3\n      17
# \n4\n       2
# Name: previous_owners, dtype: int64

# %%
df["previous_owners"] = [item[0] if type(item)==list else item for item in df["previous_owners"]]

df["previous_owners"].value_counts().head(100)
# Out:
# \n1\n    8294
# \n2\n     778
# \n0\n     188
# \n3\n      17
# \n4\n       2
# Name: previous_owners, dtype: int64

# %%
df["previous_owners"].str.extract('(\d)').value_counts()    # prev_owner ile aynı buradaki list işlemi var.
# Out:
# 1    8294
# 2     778
# 0     188
# 3      17
# 4       2
# dtype: int64

# %%
df['next_inspection'].value_counts().head(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# \n04/2022\n                               62
# \n03/2021\n                               38
# \n03/2022\n                               36
# \n06/2021\n                               34
# \n01/2022\n                               32
#                                           ..
# [\n03/2021\n, \n120 g CO2/km (comb)\n]     6
# \n09/2020\n                                6
# [\n03/2022\n, \n108 g CO2/km (comb)\n]     6
# ...

# %%
#print("EmailMatches:", len(re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Za-z]{2,3}", email)))

# %%
df['next_inspection'] = [item[0] if type(item)==list else item for item in df['next_inspection']]

df['next_inspection']
# Out:
# 0        \n06/2021\n
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#             ...
# 15914            NaN
# 15915    \n01/2022\n
# 15916            NaN
# 15917            NaN
# 15918            NaN
# Name: next_inspection, Length: 15919, dtype: object

# %%
df['next_inspection'].str.extract('(\d{2})/(\d{4})').isna().value_counts() #3535 tane eksik var. Doldurulması gerekir.
# Out:
# 0      1
# True   True     12384
# False  False     3535
# dtype: int64

# %%
df = pd.read_json('scout_car.json', lines=True, orient='records', convert_axes=True, dtype=True,convert_dates=True)
df.head(3)
# Out:
#                              url  \
# 0  https://www.autoscout24.co...
# 1  https://www.autoscout24.co...
# 2  https://www.autoscout24.co...
#
#   make_model  \
# 0    Audi A1
# 1    Audi A1
# 2    Audi A1
#
#                short_description  \
# 0  Sportback 1.4 TDI S-tronic...
# 1                 1.8 TFSI sport
# 2  Sportback 1.6 TDI S tronic...
#
#   body_type  \
# 0    Sedans
# 1    Sedans
# 2    Sedans
#
#    price  \
# 0  15770
# 1  14500
# 2  14640
#
#                 vat  \
# 0    VAT deductible
# 1  Price negotiable
# 2    VAT deductible
#
#           km  \
# 0  56,013 km
# 1  80,000 km
# 2  83,450 km
#
#   registration  \
# 0      01/2016
# 1      03/2017
# 2      02/2016
#
#           prev_owner  \
# 0  2 previous owners
# 1               None
# 2   1 previous owner
#
#    kW  \
# 0 NaN
# 1 NaN
# 2 NaN
#
#        hp  \
# 0   66 kW
# 1  141 kW
# 2   85 kW
#
#                             Type  \
# 0  [, Used, , Diesel (Particu...
# 1           [, Used, , Gasoline]
# ...

# %%
df['inspection_new'].value_counts().head(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nYes\n, \nEuro 6\n]                                                                          523
# \nYes\n                                                                                        362
# [\nYes\n, \n102 g CO2/km (comb)\n]                                                             174
# [\nYes\n, \n4 (Green)\n]                                                                       166
# ...

# %%
df['inspection_new'] = [item[0] if type(item)==list else item for item in df['inspection_new']]

df['inspection_new'].value_counts().head(100)
# Out:
# \nYes\n    3932
# Name: inspection_new, dtype: int64

# %%
df['inspection_new'].str.extract('(\w)').isna().value_counts()   #3932 tane eksik
# Out:
# True     11987
# False     3932
# dtype: int64

# %%
df['warranty'].value_counts().head(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, \n, \nEuro 6\n]                        1868
# \n12 months\n                               1177
# \n                                           979
# \n24 months\n                                566
# [\n, \n, \n4 (Green)\n]                      517
#                                             ...
# [\n, \n, \n115 g CO2/km (comb)\n]             14
# [\n24 months\n, \n97 g CO2/km (comb)\n]       14
# ...

# %%
df['warranty'] = [item[0] if type(item)==list else item for item in df['warranty']]

df['warranty'].head(20)
# Out:
# 0                \n
# 1               NaN
# 2                \n
# 3               NaN
# 4                \n
# 5               NaN
# 6               NaN
# 7                \n
# 8     \n12 months\n
# 9      \n3 months\n
# 10              NaN
# 11               \n
# 12               \n
# 13    \n12 months\n
# 14              NaN
# 15    \n12 months\n
# 16              NaN
# 17              NaN
# 18     \n6 months\n
# 19               \n
# Name: warranty, dtype: object

# %%
df['warranty'].str.extract('(\d{1,2}).(\w+)').isna().value_counts().head(100)    #.isna().value_counts()
# Out:
# 0      1
# True   True     11066
# False  False     4853
# dtype: int64

# %%
df['full_service'].value_counts().head(100)   # düşülecek.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, \n, \n4 (Green)\n]                                                                       2235
# [\n, \n, \nEuro 6\n]                                                                          2097
# [\n, \n]                                                                                      1702
# [\n, \n, \nEuro 6d-TEMP\n]                                                                     399
# ...

# %%
df['full_service']= [item[0] if type(item)==list else item for item in df['full_service']]

df['full_service'].value_counts()      # buradan consumption değerleri alınabilir.
# Out:
# \n    8215
# Name: full_service, dtype: int64

# %%
df['non_smoking_vehicle'].value_counts().head(100)   # düşülecek.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, \n]                             3647
# [\n, \n, \n4 (Green)\n]              1240
# [\n, \n, \nEuro 6\n]                 1127
# [\n, \n, \nEuro 6d-TEMP\n]            345
# \n                                     70
#                                      ...
# [\n, \n, \n154 g CO2/km (comb)\n]       1
# [\n, \n, \n144 g CO2/km (comb)\n]       1
# [\n, \n, \n189 g CO2/km (comb)\n]       1
# ...

# %%
df['non_smoking_vehicle']= [item[0] if type(item)==list else item for item in df['non_smoking_vehicle']]

df['non_smoking_vehicle'].value_counts()

#df['non_smoking_vehicle'].str.extract('(^\d{1,3})')   # buradan consumption değerleri alınabilir.
# Out:
# \n    7177
# Name: non_smoking_vehicle, dtype: int64

# %%
df['null'].value_counts().head(100)  # düşülecek.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# []    15919
# Name: null, dtype: int64

# %%
df['Make'].value_counts().head(100)   # düşülecek
# Out:
# \nOpel\n       7343
# \nAudi\n       5712
# \nRenault\n    2864
# Name: Make, dtype: int64

# %%
df['Make']= df['Make'].str.replace('\n', '')

# %%
df['Make'].value_counts().head(100)
# Out:
# Opel       7343
# Audi       5712
# Renault    2864
# Name: Make, dtype: int64

# %%
df['Model'].value_counts().head(100)    # düşülecek
# Out:
# A3          3097
# A1          2614
# Insignia    2598
# Astra       2526
# Corsa       2219
# Clio        1839
# Espace       991
# Duster        34
# A2             1
# Name: Model, dtype: int64

# %%
df['offer_number'].value_counts().head(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nTP62881\n]    27
# [\nJV03654\n]    27
# [\nXT61649\n]    27
# [\nAK13780\n]    27
# [\nXJ38068\n]    27
#                  ..
# [\n2689896\n]     4
# [\n2740823\n]     4
# [\n4834343\n]     4
# [\n4922457\n]     4
# [\n4834287\n]     4
# Name: offer_number, Length: 100, dtype: int64

# %%
df['offer_number']= [item[0] if type(item)==list else item for item in df['offer_number']]

df['offer_number'].value_counts()
# Out:
# \nTP62881\n     27
# \nXJ38068\n     27
# \nAK13780\n     27
# \nJV03654\n     27
# \nXT61649\n     27
#                 ..
# \nVO809335\n     1
# \n55629\n        1
# \n2875621\n      1
# \nG5548\n        1
# \n13120\n        1
# Name: offer_number, Length: 11440, dtype: int64

# %%
df['offer_number'].str.extract('(\S+)') #.value_counts().head(100)
# Out:
#                     0
# 0           LR-062483
# 1                 NaN
# 2            AM-95365
# 3                 NaN
# 4               C1626
# ...               ...
# 15914        10988301
# 15915     507370_3223
# 15916        Espace16
# 15917         2691331
# 15918  Re_30000008029
#
# [15919 rows x 1 columns]

# %%
df = pd.read_json('scout_car.json', lines=True, orient='records', convert_axes=True, dtype=True,convert_dates=True)
df.head()
# Out:
#                              url  \
# 0  https://www.autoscout24.co...
# 1  https://www.autoscout24.co...
# 2  https://www.autoscout24.co...
# 3  https://www.autoscout24.co...
# 4  https://www.autoscout24.co...
#
#   make_model  \
# 0    Audi A1
# 1    Audi A1
# 2    Audi A1
# 3    Audi A1
# 4    Audi A1
#
#                short_description  \
# 0  Sportback 1.4 TDI S-tronic...
# 1                 1.8 TFSI sport
# 2  Sportback 1.6 TDI S tronic...
# 3        1.4 TDi Design S tronic
# 4  Sportback 1.4 TDI S-Tronic...
#
#   body_type  \
# 0    Sedans
# 1    Sedans
# 2    Sedans
# 3    Sedans
# 4    Sedans
#
#    price  \
# 0  15770
# 1  14500
# 2  14640
# 3  14500
# 4  16790
#
#                 vat  \
# 0    VAT deductible
# 1  Price negotiable
# 2    VAT deductible
# 3              None
# 4              None
#
#           km  \
# 0  56,013 km
# 1  80,000 km
# 2  83,450 km
# 3  73,000 km
# 4  16,200 km
#
#   registration  \
# 0      01/2016
# 1      03/2017
# 2      02/2016
# ...

# %%
df['First Registration'].value_counts().head(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, 2018, \n]    4522
# [\n, 2016, \n]    3674
# [\n, 2017, \n]    3273
# [\n, 2019, \n]    2853
# Name: First Registration, dtype: int64

# %%
df['First Registration']= [",".join(item) if type(item)==list else item for item in df['First Registration']]

df['First Registration'].str.extract("(\d+)").isna().value_counts()
# Out:
# False    14322
# True      1597
# dtype: int64

# %%
df['Body Color'].value_counts().head(1000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, Black, \n]     3745
# [\n, Grey, \n]      3505
# [\n, White, \n]     3406
# [\n, Silver, \n]    1647
# [\n, Blue, \n]      1431
# [\n, Red, \n]        957
# [\n, Brown, \n]      289
# [\n, Green, \n]      154
# [\n, Beige, \n]      108
# [\n, Yellow, \n]      51
# [\n, Violet, \n]      18
# [\n, Bronze, \n]       6
# [\n, Orange, \n]       3
# [\n, Gold, \n]         2
# Name: Body Color, dtype: int64

# %%
df['Body Color']= [",".join(item) if type(item)==list else item for item in df['Body Color']]

df['Body Color'].str.extract("(\w+)").isna().value_counts()
# Out:
# False    15322
# True       597
# dtype: int64

# %%
df['Paint Type'].value_counts().head(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nMetallic\n]       9794
# [\nUni/basic\n]       347
# [\nPerl effect\n]       6
# Name: Paint Type, dtype: int64

# %%
df['Paint Type']= [",".join(item) if type(item)==list else item for item in df['Paint Type']]

df['Paint Type'].str.extract("(\w+.\w+)").isna().value_counts()
# Out:
# False    10147
# True      5772
# dtype: int64

# %%
df['Body Color Original'].isna().value_counts()
# Out:
# False    12160
# True      3759
# Name: Body Color Original, dtype: int64

# %%
df['Body Color Original']= [item[0] if type(item)==list else item for item in df['Body Color Original']]

df['Body Color Original'].str.extract("(\w+.\w+)").value_counts()
# Out:
# Onyx Schwarz              389
# Bianco                    282
# Argon Silber              273
# Quarz Grau                266
# Mythosschwarz Metallic    256
#                          ...
# Darmoon Blue                1
# Mitos                       1
# Shiny Grey                  1
# Darkmoon Blau               1
# DIAMANTBLAU                 1
# Length: 1415, dtype: int64

# %%
df['Upholstery'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nCloth, Black\n]           5821
# [\nPart leather, Black\n]    1121
# [\nCloth\n]                  1005
# [\nCloth, Grey\n]             891
# [\nCloth, Other\n]            639
# [\nFull leather, Black\n]     575
# [\nBlack\n]                   491
# [\nGrey\n]                    273
# [\nOther, Other\n]            182
# [\nPart leather\n]            140
# Name: Upholstery, dtype: int64

# %%
df['Upholstery']= [",".join(item) if type(item)==list else item for item in df['Upholstery']]

df['Upholstery'].str.extract("(\w+..\w+)").isna().value_counts()
# Out:
# False    12199
# True      3720
# dtype: int64

# %%
df['Body'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, Sedans, \n]           7903
# [\n, Station wagon, \n]    3553
# [\n, Compact, \n]          3153
# [\n, Van, \n]               783
# [\n, Other, \n]             290
# [\n, Transporter, \n]        88
# [\n, Off-Road, \n]           56
# [\n, Coupe, \n]              25
# [\n, Convertible, \n]         8
# Name: Body, dtype: int64

# %%
df['Body']= [",".join(item) if type(item)==list else item for item in df['Body']]

df['Body'].str.extract("(\w+.\w+)").value_counts()
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# dtype: int64

# %%
df['Nr. of Doors'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n5\n]    11575
# [\n4\n]     3079
# [\n3\n]      832
# [\n2\n]      219
# [\n7\n]        1
# [\n1\n]        1
# Name: Nr. of Doors, dtype: int64

# %%
df['Nr. of Doors']= [item[0] if type(item)==list else item for item in df['Nr. of Doors']]

df['Nr. of Doors'].str.extract("(\w+)").isna().value_counts()
# Out:
# False    15707
# True       212
# dtype: int64

# %%
df['Nr. of Seats'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n5\n]    13336
# [\n4\n]     1125
# [\n7\n]      362
# [\n2\n]      116
# [\n6\n]        2
# [\n3\n]        1
# Name: Nr. of Seats, dtype: int64

# %%
df['Nr. of Seats']= [item[0] if type(item)==list else item for item in df['Nr. of Seats']]

df['Nr. of Seats'].str.extract("(\w+)").isna().value_counts()
# Out:
# False    14942
# True       977
# dtype: int64

# %%
df['Model Code'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n0035/BCB\n]    268
# [\n0588/BNO\n]    245
# [\n0588/BDB\n]    206
# [\n0588/BHX\n]    188
# [\n1844/ADJ\n]    175
# [\n0588/BDF\n]    175
# [\n0588/BCV\n]    139
# [\n3333/BAJ\n]    122
# [\n3333/BEF\n]    118
# [\n0588/AYB\n]    117
# Name: Model Code, dtype: int64

# %%
df['Model Code']= [item[0] if type(item)==list else item for item in df['Model Code']]

df['Model Code'].str.extract("(\S+)").isna().value_counts()
# Out:
# True     10941
# False     4978
# dtype: int64

# %%
df['Gearing Type'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, Manual, \n]            8153
# [\n, Automatic, \n]         7297
# [\n, Semi-automatic, \n]     469
# Name: Gearing Type, dtype: int64

# %%
df['Gearing Type']= [",".join(item) if type(item)==list else item for item in df['Gearing Type']]

df['Gearing Type'].str.extract("(\w+.\w+)").isna().value_counts()
# Out:
# False    15919
# dtype: int64

# %%
df['Displacement'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n1,598 cc\n]    4761
# [\n999 cc\n]      2438
# [\n1,398 cc\n]    1314
# [\n1,399 cc\n]     749
# [\n1,229 cc\n]     677
# [\n1,956 cc\n]     670
# [\n1,461 cc\n]     595
# [\n1,490 cc\n]     559
# [\n1,422 cc\n]     467
# [\n1,197 cc\n]     353
# Name: Displacement, dtype: int64

# %%
df['Displacement']= [",".join(item) if type(item)==list else item for item in df['Displacement']]

df['Displacement'].str.extract("(\d+.\d+)").value_counts()
# Out:
# 1,598    4761
# 999      2438
# 1,398    1314
# 1,399     749
# 1,229     677
#          ...
# 1,333       1
# 1,696       1
# 1,686       1
# 1,350       1
# 1,533       1
# Length: 74, dtype: int64

# %%
df['Cylinders'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n4\n]    8105
# [\n3\n]    2104
# [\n5\n]      22
# [\n6\n]       3
# [\n2\n]       2
# [\n8\n]       2
# [\n1\n]       1
# Name: Cylinders, dtype: int64

# %%
df['Cylinders']= [item[0] if type(item)==list else item for item in df['Cylinders']]

df['Cylinders'].str.extract("(\d+)").value_counts()
# Out:
# 4    8105
# 3    2104
# 5      22
# 6       3
# 2       2
# 8       2
# 1       1
# dtype: int64

# %%
df['Weight'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n1,163 kg\n]    574
# [\n1,360 kg\n]    356
# [\n1,165 kg\n]    301
# [\n1,335 kg\n]    242
# [\n1,135 kg\n]    213
# [\n1,199 kg\n]    205
# [\n1,734 kg\n]    170
# [\n1,180 kg\n]    168
# [\n1,503 kg\n]    165
# [\n1,350 kg\n]    155
# Name: Weight, dtype: int64

# %%
df['Weight']= [item[0] if type(item)==list else item for item in df['Weight']]

df['Weight'].str.extract("(\d+.\d+)").isna().value_counts()
# Out:
# False    8943
# True     6976
# dtype: int64

# %%
df['Drive chain'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nfront\n]    8886
# [\n4WD\n]       171
# [\nrear\n]        4
# Name: Drive chain, dtype: int64

# %%
df['Drive chain']= [item[0] if type(item)==list else item for item in df['Drive chain']]

df['Drive chain'].str.extract("(\S+)").value_counts()
# Out:
# front    8886
# 4WD       171
# rear        4
# dtype: int64

# %%
df = pd.read_json('scout_car.json', lines=True, orient='records', convert_axes=True, dtype=True,convert_dates=True)
df.head(2)
# Out:
#                              url  \
# 0  https://www.autoscout24.co...
# 1  https://www.autoscout24.co...
#
#   make_model  \
# 0    Audi A1
# 1    Audi A1
#
#                short_description  \
# 0  Sportback 1.4 TDI S-tronic...
# 1                 1.8 TFSI sport
#
#   body_type  \
# 0    Sedans
# 1    Sedans
#
#    price  \
# 0  15770
# 1  14500
#
#                 vat  \
# 0    VAT deductible
# 1  Price negotiable
#
#           km  \
# 0  56,013 km
# 1  80,000 km
#
#   registration  \
# 0      01/2016
# 1      03/2017
#
#           prev_owner  \
# 0  2 previous owners
# 1               None
#
#    kW  \
# 0 NaN
# 1 NaN
#
#        hp  \
# 0   66 kW
# 1  141 kW
#
#                             Type  \
# 0  [, Used, , Diesel (Particu...
# 1           [, Used, , Gasoline]
#
#   Previous Owners  \
# 0           \n2\n
# 1             NaN
#
#                  Next Inspection  \
# 0  [\n06/2021\n, \n99 g CO2/k...
# 1                            NaN
#
#           Inspection new  \
# ...

# %%
df["Fuel"].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, Diesel (Particulate Filter), \n]                4315
# [\n, Super 95, \n]                                   3338
# [\n, Gasoline, \n]                                   3175
# [\n, Diesel, \n]                                     2984
# [\n, Super 95 / Regular/Benzine 91, \n]               424
# [\n, Regular/Benzine 91, \n]                          354
# [\n, Super E10 95, \n]                                331
# ...

# %%
df['Fuel']= [",".join(item) if type(item)==list else item for item in df['Fuel']]

df['Fuel']=df['Fuel'].str.replace(r'[\s,\s]', ' ', regex=True).replace({'':0}, inplace=False)

# %%
df['Fuel'].value_counts().head(10)
# Out:
#   Diesel (Particulate Filter)                  4315
#   Super 95                                     3338
#   Gasoline                                     3175
#   Diesel                                       2984
#   Super 95 / Regular/Benzine 91                 424
#   Regular/Benzine 91                            354
#   Super E10 95                                  331
#   Super 95 (Particulate Filter)                 268
#   Super 95 / Super E10 95                       131
#   Regular/Benzine 91 (Particulate Filter)       100
# Name: Fuel, dtype: int64

# %%
benzine = ["Gasoline","Super 95","Regular", "Super E10 95","Super Plus 98","Super Plus E10 98","Others"]

lpg = ["LPG","Liquid petroleum gas","CNG","Biogas","Domestic gas H"]


def fueltype(x):
    if x in benzine:
        return "Benzine"
    elif x in lpg:
        return "LPG/CNG"
    else :
        return x

df["Fuel"] = df["Fuel"].apply(fueltype)

df["Fuel"]
# Out:
# 0          Diesel (Particulate Filt...
# 1                           Gasoline
# 2          Diesel (Particulate Filt...
# 3          Diesel (Particulate Filt...
# 4          Diesel (Particulate Filt...
#                      ...
# 15914      Diesel (Particulate Filt...
# 15915      Super 95 / Super Plus 98...
# 15916                         Diesel
# 15917                         Diesel
# 15918                       Super 95
# Name: Fuel, Length: 15919, dtype: object

# %%
df['Consumption'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [[3.9 l/100 km (comb)], [4.1 l/100 km (city)], [3.7 l/100 km (country)]]    304
# [[4.2 l/100 km (comb)], [5 l/100 km (city)], [3.7 l/100 km (country)]]      276
# [[5.4 l/100 km (comb)], [6.8 l/100 km (city)], [4.5 l/100 km (country)]]    257
# [[3.8 l/100 km (comb)], [4.3 l/100 km (city)], [3.5 l/100 km (country)]]    253
# [[4.7 l/100 km (comb)], [5.1 l/100 km (city)], [4.4 l/100 km (country)]]    244
# ...

# %%
df['CO2 Emission'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n120 g CO2/km (comb)\n]    740
# [[], [], []]                 628
# [\n99 g CO2/km (comb)\n]     545
# [\n97 g CO2/km (comb)\n]     537
# [\n104 g CO2/km (comb)\n]    501
# [\n102 g CO2/km (comb)\n]    477
# [\n103 g CO2/km (comb)\n]    445
# [\n114 g CO2/km (comb)\n]    382
# [\n124 g CO2/km (comb)\n]    372
# [\n108 g CO2/km (comb)\n]    362
# Name: CO2 Emission, dtype: int64

# %%
df['Emission Class'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nEuro 6\n]          10139
# [\nEuro 6d-TEMP\n]     1845
# [[], [], []]            607
# [\nEuro 6c\n]           127
# [\nEuro 5\n]             78
# [\nEuro 6d\n]            62
# [\nEuro 4\n]             40
# Name: Emission Class, dtype: int64

# %%
df['\nComfort & Convenience\n'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [Air conditioning, Electrical side mirrors, Hill Holder, Power windows]                                                                                                                                                                                                                                                                                                 216
# ...

# %%
df['\nEntertainment & Media\n'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [Bluetooth, Hands-free equipment, On-board computer, Radio, USB]                    1282
# [Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, USB]                982
# [Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, USB]     783
# [On-board computer, Radio]                                                           487
# ...

# %%
df['\nExtras\n'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [Alloy wheels]                                       3245
# [Alloy wheels, Touch screen]                          697
# [Alloy wheels, Voice Control]                         577
# [Alloy wheels, Touch screen, Voice Control]           541
# [Alloy wheels, Roof rack]                             385
# [Alloy wheels, Sport seats]                           380
# [Roof rack]                                           337
# ...

# %%
df['\nSafety & Security\n'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [ABS, Central door lock, Daytime running lights, Driver-side airbag, Electronic stability control, Fog lights, Immobilizer, Isofix, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control]                                538
# ...

# %%
df['description'].value_counts().head(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ...

# %%
df['Emission Label'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n4 (Green)\n]         3553
# [\n1 (No sticker)\n]     381
# [[], [], []]              40
# [\n5 (Blue)\n]             8
# [\n3 (Yellow)\n]           2
# [\n2 (Red)\n]              1
# Name: Emission Label, dtype: int64

# %%
df['Gears'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n6\n]     5822
# [\n5\n]     3239
# [\n7\n]     1908
# [\n8\n]      224
# [\n9\n]        6
# [\n4\n]        2
# [\n3\n]        2
# [\n1\n]        2
# [\n50\n]       1
# [\n2\n]        1
# Name: Gears, dtype: int64

# %%
df['Country version'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nGermany\n]           4502
# [\nItaly\n]             1038
# [\nEuropean Union\n]     507
# [\nNetherlands\n]        464
# [\nSpain\n]              325
# [\nBelgium\n]            314
# [\nAustria\n]            208
# [\nCzech Republic\n]      52
# [\nPoland\n]              49
# [\nFrance\n]              38
# Name: Country version, dtype: int64

# %%
df['Electricity consumption'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n0 kWh/100 km (comb)\n]    137
# Name: Electricity consumption, dtype: int64

# %%
df['Last Service Date'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n02/2019\n, \nEuro 6\n]                 23
# [\n05/2019\n, \nEuro 6\n]                 16
# [\n01/2018\n, \n118 g CO2/km (comb)\n]    15
# [\n03/2019\n, \nEuro 6\n]                 15
# [\n04/2019\n, \nEuro 6\n]                 13
# [\n06/2019\n, \nEuro 6\n]                 13
# [\n01/2019\n, \nEuro 6\n]                 12
# [\n12/2018\n, \nEuro 6\n]                 11
# [\n10/2018\n, \nEuro 6\n]                 10
# ...

# %%
df['Other Fuel Types'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [[], [], []]    880
# Name: Other Fuel Types, dtype: int64

# %%
df['Availability'].value_counts().head(10)
# Out:
# \nin 90 days from ordering\n     196
# \nin 120 days from ordering\n    182
# \nin 1 day from ordering\n        51
# \nin 3 days from ordering\n       35
# \nin 5 days from ordering\n       35
# \nin 180 days from ordering\n     24
# \nin 14 days from ordering\n      24
# \nin 7 days from ordering\n       20
# \nin 150 days from ordering\n     18
# \nin 2 days from ordering\n       16
# Name: Availability, dtype: int64

# %%
df['Last Timing Belt Service Date'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n04/2016\n]                2
# [\n01/2019\n]                1
# [\n01/1970\n]                1
# [\n05/2019\n]                1
# [\n06/2017\n]                1
# [\n04/2019\n]                1
# [\n01/1900\n]                1
# [\n02/2018\n]                1
# [\n05/2018\n, \nEuro 6\n]    1
# [\n01/2018\n]                1
# Name: Last Timing Belt Service Date, dtype: int64

# %%
df['Available from'].value_counts().head(10)
# Out:
# \n31/08/19\n    98
# \n30/07/19\n    25
# \n15/08/19\n    24
# \n16/09/19\n    14
# \n29/06/19\n    12
# \n01/07/19\n    11
# \n28/06/19\n    10
# \n19/08/19\n     7
# \n10/09/19\n     6
# \n10/11/19\n     5
# Name: Available from, dtype: int64

# %%
df.columns
# Out:
# Index(['url',
#        'make_model',
#        'short_description',
#        'body_type',
#        'price',
#        'vat',
#        'km',
#        'registration',
#        'prev_owner',
#        'kW',
#        'hp',
#        'Type',
#        'Previous Owners',
#        'Next Inspection',
#        'Inspection new',
#        'Warranty',
#        'Full Service',
#        'Non-smoking Vehicle',
#        'null',
#        'Make',
#        'Model',
#        'Offer Number',
#        'First Registration',
#        'Body Color',
#        'Paint Type',
#        'Body Color Original',
#        'Upholstery',
#        'Body',
#        'Nr. of Doors',
#        'Nr. of Seats',
#        'Model Code',
#        'Gearing Type',
#        'Displacement',
#        'Cylinders',
#        'Weight',
#        'Drive chain',
#        'Fuel',
#        'Consumption',
#        'CO2 Emission',
#        'Emission Class',
#        '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n',
# ...

# %%
spec_chars = ["!",'"',"#","%","&","'","(",")"," ",
              "*","+",",","-","/",":",";","<",
              "=",">","?","@","[","\\","]","^",
              "`","{","|","}","~","–","\n"]

for char in spec_chars:
    df.columns = df.columns.str.replace(char, '_')

#df.columns = df.columns.str.split().str.join(" ")
# Out:
# <ipython-input-101-8744ff9a5916>:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace(char, '_')

# %% [markdown]
# ## 2. yöntem column isimlerini değiştirirken:
#
# df.rename(columns=lambda x: re.sub('(\s|/)','_', x), inplace=True)
#
# df = df.clean_names().head()
#
# df.keys()

# %%
df.columns
# Out:
# Index(['url',
#        'make_model',
#        'short_description',
#        'body_type',
#        'price',
#        'vat',
#        'km',
#        'registration',
#        'prev_owner',
#        'kW',
#        'hp',
#        'Type',
#        'Previous_Owners',
#        'Next_Inspection',
#        'Inspection_new',
#        'Warranty',
#        'Full_Service',
#        'Non_smoking_Vehicle',
#        'null',
#        'Make',
#        'Model',
#        'Offer_Number',
#        'First_Registration',
#        'Body_Color',
#        'Paint_Type',
#        'Body_Color_Original',
#        'Upholstery',
#        'Body',
#        'Nr._of_Doors',
#        'Nr._of_Seats',
#        'Model_Code',
#        'Gearing_Type',
#        'Displacement',
#        'Cylinders',
#        'Weight',
#        'Drive_chain',
#        'Fuel',
#        'Consumption',
#        'CO2_Emission',
#        'Emission_Class',
#        '_Comfort___Convenience_',
#        '_Entertainment___Media_',
#        '_Extras_',
# ...

# %%
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['url',
#        'make_model',
#        'short_description',
#        'body_type',
#        'price',
#        'vat',
#        'km',
#        'registration',
#        'prev_owner',
#        'kw',
#        'hp',
#        'type',
#        'previous_owners',
#        'next_inspection',
#        'inspection_new',
#        'warranty',
#        'full_service',
#        'non_smoking_vehicle',
#        'null',
#        'make',
#        'model',
#        'offer_number',
#        'first_registration',
#        'body_color',
#        'paint_type',
#        'body_color_original',
#        'upholstery',
#        'body',
#        'nr._of_doors',
#        'nr._of_seats',
#        'model_code',
#        'gearing_type',
#        'displacement',
#        'cylinders',
#        'weight',
#        'drive_chain',
#        'fuel',
#        'consumption',
#        'co2_emission',
#        'emission_class',
#        '_comfort___convenience_',
#        '_entertainment___media_',
#        '_extras_',
# ...

# %%
df.rename(columns={"_comfort___convenience_":"comfort_convenience","_entertainment___media_":"entertainment_media","_extras_":"extras","_safety___security_":"safety_security"}, inplace=True)

# %%
df.columns
# Out:
# Index(['url',
#        'make_model',
#        'short_description',
#        'body_type',
#        'price',
#        'vat',
#        'km',
#        'registration',
#        'prev_owner',
#        'kw',
#        'hp',
#        'type',
#        'previous_owners',
#        'next_inspection',
#        'inspection_new',
#        'warranty',
#        'full_service',
#        'non_smoking_vehicle',
#        'null',
#        'make',
#        'model',
#        'offer_number',
#        'first_registration',
#        'body_color',
#        'paint_type',
#        'body_color_original',
#        'upholstery',
#        'body',
#        'nr._of_doors',
#        'nr._of_seats',
#        'model_code',
#        'gearing_type',
#        'displacement',
#        'cylinders',
#        'weight',
#        'drive_chain',
#        'fuel',
#        'consumption',
#        'co2_emission',
#        'emission_class',
#        'comfort_convenience',
#        'entertainment_media',
#        'extras',
# ...

# %%
#missing data

total = df.isnull().sum().sort_values(ascending=False)

percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)

missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

missing_data.head(50)
# Out:
#                                Total  \
# kw                             15919
# last_timing_belt_service_date  15903
# electricity_consumption        15782
# available_from                 15647
# last_service_date              15353
# availability                   15284
# other_fuel_types               15039
# next_inspection                12384
# inspection_new                 11987
# emission_label                 11934
# model_code                     10941
# non_smoking_vehicle             8742
# country_version                 8333
# full_service                    7704
# weight                          6974
# drive_chain                     6858
# prev_owner                      6828
# previous_owners                 6640
# paint_type                      5772
# cylinders                       5680
# warranty                        5420
# gears                           4712
# vat                             4513
# body_color_original             3759
# ...

# %%
df['Inspection new'] = df['Inspection new'].astype('str').str.split(',', expand=True)

# %%
df['Inspection new'].apply(tuple).value_counts()
# Out:
# (n, a, n)                            11987
# ([, ', \, n, Y, e, s, \, n, ')        3490
# (\n, Y, e, s, \n)                      362
# ([, ', \, n, Y, e, s, \, n, ', ])       80
# Name: Inspection new, dtype: int64

# %%
dct = []

for i in df.loc[:, 'kW']:
    if str(i) == 'nan':
        dct.append(['Nothing_kW'])
    else:
        dct.append([i])
dct[:2]
# Out:
# [['Nothing_kW'], ['Nothing_kW']]

# %% [markdown]
# ## Import Libraries and Data

# %%
df_dummied.to_csv("final_scout_dummy.csv", index=False)

# %%
df.to_csv("final_scout_not_dummy.csv", index=False)
