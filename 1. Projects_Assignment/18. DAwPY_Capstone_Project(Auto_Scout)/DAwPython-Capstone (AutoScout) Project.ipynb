# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Data Analysis Project***". This is the capstone project of ***Data Analysis*** Module. **Auto Scout** data which using for this project, scraped from the on-line car trading company in 2019, contains many features of 9 different car models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using many Python libraries such as Numpy, Pandas, Matplotlib, Seaborn, Scipy you will analyze clean dataset.
#
# The project consists of 3 parts:
# * First part is related with 'data cleaning'. It deals with Incorrect Headers, Incorrect Format, Anomalies, Dropping useless columns.
# * Second part is related with 'filling data'. It deals with Missing Values. Categorical to numeric transformation is done.
# * Third part is related with 'handling outliers of data' via Visualisation libraries. Some insights are extracted.

# %% [markdown]
# # PART- 1 `( Data Cleaning )`

# %% [markdown]
# https://www.youtube.com/watch?v=aBygOp17doQ
#
# https://www.youtube.com/watch?v=FVECTpahzCQ
#
# https://blog.softhints.com/pandas-typeerror-unhashable-type-list-dict/

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re

# %%
import pandas as pd
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 60)
pd.set_option('display.width', 5)
pd.set_option('display.max_colwidth', 30)

# %% [markdown]
# typ : {'frame', 'series'}, default 'frame'
#     The type of object to recover.
#
# dtype : bool or dict, default None
#     If True, infer dtypes; if a dict of column to dtype, then use those;
#     if False, then don't infer dtypes at all, applies only to the data.

# %%
df = pd.read_json('scout_car.json', lines=True, orient='records', convert_axes=True, dtype=True,convert_dates=True)
df
# Out:
#                                  url  \
# 0      https://www.autoscout24.co...
# 1      https://www.autoscout24.co...
# 2      https://www.autoscout24.co...
# 3      https://www.autoscout24.co...
# 4      https://www.autoscout24.co...
# ...                              ...
# 15914  https://www.autoscout24.co...
# 15915  https://www.autoscout24.co...
# 15916  https://www.autoscout24.co...
# 15917  https://www.autoscout24.co...
# 15918  https://www.autoscout24.co...
#
#            make_model  \
# 0             Audi A1
# 1             Audi A1
# 2             Audi A1
# 3             Audi A1
# 4             Audi A1
# ...               ...
# 15914  Renault Espace
# 15915  Renault Espace
# 15916  Renault Espace
# 15917  Renault Espace
# 15918  Renault Espace
#
#                    short_description  \
# 0      Sportback 1.4 TDI S-tronic...
# 1                     1.8 TFSI sport
# 2      Sportback 1.6 TDI S tronic...
# 3            1.4 TDi Design S tronic
# ...

# %%
spec_chars = ["!",'"',"#","%","&","'","(",")"," ",
              "*","+",",","-","/",":",";","<",
              "=",">","?","@","[","\\","]","^",
              "`","{","|","}","~","–","\n","."]

for char in spec_chars:
    df.columns = df.columns.str.replace(char, '_')
# Out:
# <ipython-input-164-8f1b537feb51>:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace(char, '_')

# %%
df.columns = df.columns.str.lower()

# %%
df.rename(columns={"_comfort___convenience_":"comfort_convenience","_entertainment___media_":"entertainment_media","_extras_":"extras","_safety___security_":"safety_security","nr__of_doors":"nr_of_doors","nr__of_seats":"nr_of_seats"}, inplace=True)

# %%
df.columns
# Out:
# Index(['url',
#        'make_model',
#        'short_description',
#        'body_type',
#        'price',
#        'vat',
#        'km',
#        'registration',
#        'prev_owner',
#        'kw',
#        'hp',
#        'type',
#        'previous_owners',
#        'next_inspection',
#        'inspection_new',
#        'warranty',
#        'full_service',
#        'non_smoking_vehicle',
#        'null',
#        'make',
#        'model',
#        'offer_number',
#        'first_registration',
#        'body_color',
#        'paint_type',
#        'body_color_original',
#        'upholstery',
#        'body',
#        'nr_of_doors',
#        'nr_of_seats',
#        'model_code',
#        'gearing_type',
#        'displacement',
#        'cylinders',
#        'weight',
#        'drive_chain',
#        'fuel',
#        'consumption',
#        'co2_emission',
#        'emission_class',
#        'comfort_convenience',
#        'entertainment_media',
#        'extras',
# ...

# %% [markdown]
# df.rename(columns=lambda x: re.sub('(\s|/)','_', x), inplace=True).str.lower()
#
# df.columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kw                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  type                           15917 non-null  object
# ...

# %%
df.shape
# Out:
# (15919, 54)

# %%
df['make_model'].value_counts()   # tam veri. make ve model sütunları silinecek.
# Out:
# Audi A3           3097
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2526
# Opel Corsa        2219
# Renault Clio      1839
# Renault Espace     991
# Renault Duster      34
# Audi A2              1
# Name: make_model, dtype: int64

# %%
# df['mark'] = df['make_model'].astype('str').str.split(' ', expand=True)[0]

# %%
# df.mark.value_counts()
# Out:
# Opel       7343
# Audi       5712
# Renault    2864
# Name: mark, dtype: int64

# %%
# df['model'] = df['make_model'].astype('str').str.split(' ', expand=True)[1]

# %%
# df.model.value_counts()
# Out:
# A3          3097
# A1          2614
# Insignia    2598
# Astra       2526
# Corsa       2219
# Clio        1839
# Espace       991
# Duster        34
# A2             1
# Name: model, dtype: int64

# %%
df['short_description'].value_counts(dropna=False).head(50)   # 46 tane eksik veri var. Hacmi aldık buradan.
# Out:
# SPB 1.6 TDI 116 CV S tronic Sport                    64
# NaN                                                  46
# 1.4 66kW (90CV) Selective                            40
# MOVE KLIMA CD USB ALLWETTER BLUETOOTH                38
# SPB 30 TDI S tronic Business                         35
# SPB 30 TFSI S tronic Admired                         35
# Sporter 1.5 dCi 90CV Zen , NAVI - AZIENDALE          32
# dCi 75 Business Energy eco2 Euro6 55 kW (75 C        31
# dCi 160CV EDC Energy Intens                          30
# 1.2 5 porte b-Color                                  30
# SPB 1.6 TDI 116 CV Sport                             28
# R.S. TROPHY ENERGY TCe 220 EDC                       28
# 1.2 5 porte Advance                                  28
# 1.6 TDI Sport DSG *SHZ*Xenon*Navi*Bose*PDC*          27
# 1.4 TDI Design DKG*Navi*PDC*Alu*SHZ*                 27
# 1.6 TCE ENERGY INTENS *Navi*LED*Cam*Pano*            27
# 1.2 LIMITED *Navi*Temp*R&Go*Garantie*                27
# ...

# %%
df['engine'] = df['short_description'].str.extract("(\d\d\d\d|\d.\d|\d)")  #.value_counts()

# %%
df['engine']
# Out:
# 0        1.4
# 1        1.8
# 2        1.6
# 3        1.4
# 4        1.4
#         ...
# 15914    200
# 15915    225
# 15916    200
# 15917    200
# 15918    225
# Name: engine, Length: 15919, dtype: object

# %%
df['short_description'].str.extract("([A-Z][A-Z][A-Z])").value_counts()
# Out:
# TFS    2196
# CDT    2163
# TDI    1574
# SPB    1162
# EDC     842
#        ...
# ITA       1
# ILU       1
# IIN       1
# IDO       1
# ZER       1
# Length: 261, dtype: int64

# %%
df['short_description'].apply(pd.Series)
# Out:
#                                    0
# 0      Sportback 1.4 TDI S-tronic...
# 1                     1.8 TFSI sport
# 2      Sportback 1.6 TDI S tronic...
# 3            1.4 TDi Design S tronic
# 4      Sportback 1.4 TDI S-Tronic...
# ...                              ...
# 15914  Blue dCi 200CV EDC Executi...
# 15915  TCe 225 EDC GPF LIM Deluxe...
# 15916  Blue dCi 200 EDC Initiale ...
# 15917  Blue dCi 200CV EDC Busines...
# 15918  INITIALE PARIS TCe 225 EDC...
#
# [15919 rows x 1 columns]

# %%
df['body_type'].value_counts(dropna=False).head(30)   # 60 eksik var. Bunlara other yazılabilir.
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# NaN                60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
df['price'].isna().value_counts()
# Out:
# False    15919
# Name: price, dtype: int64

# %%
df['price'].value_counts().head(20)
# Out:
# 14990    154
# 15990    151
# 10990    139
# 15900    106
# 17990    102
# 9900      98
# 20900     93
# 22900     92
# 13990     92
# 21900     91
# 19900     89
# 14900     88
# 16990     86
# 17900     86
# 18900     86
# 16900     84
# 18990     81
# 8490      78
# 12990     77
# 21500     75
# Name: price, dtype: int64

# %%
df['vat'].value_counts(dropna=False).head(20)  # get_dummy ile kategorik sayısala çevirelim. 4513 eksik veri var.
# Out:
# VAT deductible      10980
# NaN                  4513
# Price negotiable      426
# Name: vat, dtype: int64

# %%
df['km'].value_counts(dropna=False).head(20)  # - olan yerine  yazdık. 1024 tane veri.
# Out:
# 10 km        1045
# - km         1024
# 1 km          367
# 5 km          170
# 50 km         148
# 100 km        139
# 15 km         109
# 5,000 km      104
# 20 km          61
# 3,000 km       58
# 12 km          56
# 8,000 km       49
# 45,000 km      48
# 10,000 km      47
# 25,000 km      47
# 30,000 km      47
# 1,000 km       46
# 18,000 km      46
# 19,000 km      44
# 35,000 km      44
# Name: km, dtype: int64

# %%
df['km'].str.replace(r'\D+', '', regex=True).replace({'':0}).astype('int').value_counts().head(20)

# df["km"].replace(to_replace=r"\d+", value=r" ", regex=True) sadece km kalsın istersek
# Out:
# 10       1045
# 0        1043
# 1         367
# 5         170
# 50        148
# 100       139
# 15        109
# 5000      104
# 20         61
# 3000       58
# 12         56
# 8000       49
# 45000      48
# 30000      47
# 25000      47
# 10000      47
# 18000      46
# 1000       46
# 35000      44
# 19000      44
# Name: km, dtype: int64

# %%
df['km'] = df['km'].str.replace(r'\D+', '', regex=True).replace({'':0}).astype('int')

# %%
df['km']
# Out:
# 0        56013
# 1        80000
# 2        83450
# 3        73000
# 4        16200
#          ...
# 15914        0
# 15915     9900
# 15916       15
# 15917       10
# 15918        0
# Name: km, Length: 15919, dtype: int32

# %%
df['registration'].value_counts(dropna=False).head(10)  # 1597 eksik var. Buradan yıl alındı. Bundan age hesaplanacak.
# Out:
# -/-        1597
# 03/2018     695
# 02/2019     585
# 05/2018     572
# 03/2019     543
# 04/2018     541
# 01/2019     541
# 02/2018     539
# 03/2016     536
# 04/2016     532
# Name: registration, dtype: int64

# %%
df['registration'].str.extract('(\d{4})')  #.isna().value_counts()  #(\d{2}).
# Out:
#           0
# 0      2016
# 1      2017
# 2      2016
# 3      2016
# 4      2016
# ...     ...
# 15914   NaN
# 15915  2019
# 15916  2019
# 15917  2019
# 15918  2019
#
# [15919 rows x 1 columns]

# %%
df['registration'] = df['registration'].str.extract('(\d{4})')

df['registration'].value_counts()
# Out:
# 2018    4522
# 2016    3674
# 2017    3273
# 2019    2853
# Name: registration, dtype: int64

# %%
df["age"] = 2019- df['registration'].astype("int")   # nan lar silinmeli.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-748-ea604274c846> in <module>
# ----> 1 df["age"] = 2019- df['registration'].astype("int")   # nan lar silinmeli.
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...

# %%
df['prev_owner'].value_counts(dropna=False).head(100)  # 6828 eksik var. None dolduralacak.
# Out:
# 1 previous owner     8294
# NaN                  6828
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# Name: prev_owner, dtype: int64

# %%
df['prev_owner'].str.replace(r'\D+', '', regex=True).replace({'':0}).astype('str').value_counts(dropna=False).head(20)

# None değerlerden dolayı astype("int") girersek hata veriyor.
# Out:
# 1       8294
# None    6828
# 2        778
# 3         17
# 4          2
# Name: prev_owner, dtype: int64

# %%
df['prev_owner'] = df['prev_owner'].str.replace(r'\D+', '', regex=True).replace({'':0}).astype('str')

# %%
df['prev_owner']
# Out:
# 0           2
# 1        None
# 2           1
# 3           1
# 4           1
#          ...
# 15914    None
# 15915       1
# 15916       1
# 15917    None
# 15918       1
# Name: prev_owner, Length: 15919, dtype: object

# %%
df['kW'].value_counts().head(100)   # silinecek.
# Out:
# Series([], Name: kW, dtype: int64)

# %%
df['hp'].value_counts(dropna=False).head(100)  # tam veriler.
# Out:
# 85 kW     2542
# 66 kW     2122
# 81 kW     1402
# 100 kW    1308
# 110 kW    1112
#           ...
# 239 kW       1
# 44 kW        1
# 9 kW         1
# 132 kW       1
# 115 kW       1
# Name: hp, Length: 81, dtype: int64

# %%
df['hp'].str.replace(r'\D+', '', regex=True).replace({'':0}).astype('int').value_counts().head(60)
# Out:
# 85     2542
# 66     2122
# 81     1402
# 100    1308
# 110    1112
#        ...
# 93        3
# 40        2
# 53        2
# 228       2
# 140       2
# Name: hp, Length: 60, dtype: int64

# %%
df['hp'] = df['hp'].str.replace(r'\D+', '', regex=True).replace({'':0}).astype('int')

df['hp']
# Out:
# 0         66
# 1        141
# 2         85
# 3         66
# 4         66
#         ...
# 15914    147
# 15915    165
# 15916    146
# 15917    147
# 15918    165
# Name: hp, Length: 15919, dtype: int32

# %%
df = pd.read_json('scout_car.json', lines=True, orient='records', convert_axes=True, dtype=True,convert_dates=True)
df.head(3)
# Out:
#                              url  \
# 0  https://www.autoscout24.co...
# 1  https://www.autoscout24.co...
# 2  https://www.autoscout24.co...
#
#   make_model  \
# 0    Audi A1
# 1    Audi A1
# 2    Audi A1
#
#                short_description  \
# 0  Sportback 1.4 TDI S-tronic...
# 1                 1.8 TFSI sport
# 2  Sportback 1.6 TDI S tronic...
#
#   body_type  \
# 0    Sedans
# 1    Sedans
# 2    Sedans
#
#    price  \
# 0  15770
# 1  14500
# 2  14640
#
#                 vat  \
# 0    VAT deductible
# 1  Price negotiable
# 2    VAT deductible
#
#           km  \
# 0  56,013 km
# 1  80,000 km
# 2  83,450 km
#
#   registration  \
# 0      01/2016
# 1      03/2017
# 2      02/2016
#
#           prev_owner  \
# 0  2 previous owners
# 1               None
# 2   1 previous owner
#
#    kW  \
# 0 NaN
# 1 NaN
# 2 NaN
#
#        hp  \
# 0   66 kW
# 1  141 kW
# 2   85 kW
#
#                             Type  \
# 0  [, Used, , Diesel (Particu...
# 1           [, Used, , Gasoline]
# ...

# %%
df['Type'].value_counts().head(100)   # 2 tane eksik veri var.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [, Used, , Diesel (Particulate Filter)]                                                                                  3475
# [, Used, , Diesel]                                                                                                       2516
# [, Used, , Gasoline]                                                                                                     2367
# ...

# %%
# df['Type'] = df['Type'].astype('str').str.split(', ,', expand=True)

# %%
# df['Type'].value_counts().head(10)
# Out:
# ['', 'Used', '', 'Diesel (Particulate Filter)']              3475
# ['', 'Used', '', 'Diesel']                                   2516
# ['', 'Used', '', 'Gasoline']                                 2367
# ['', 'Used', '', 'Super 95']                                 1818
# ['', 'Pre-registered', '', 'Super 95']                        500
# ['', 'New', '', 'Super 95']                                   497
# ['', "Employee's car", '', 'Diesel (Particulate Filter)']     343
# ['', 'New', '', 'Gasoline']                                   340
# ['', 'Used', '', 'Super 95 / Regular/Benzine 91']             324
# ['', "Employee's car", '', 'Super 95']                        264
# Name: Type, dtype: int64

# %%
# [df['type'][i][0] for i in range(len(df['type']))]
# Out:
# ['[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
#  '[',
# ...

# %%
# df["vehicle_type"] = df['Type'].str.split(',', expand=True)[1]

# %%
# df["vehicle_type"].str.replace(r'\W+', ' ', regex=True).replace({'':0}).value_counts(dropna=False).head(30)
# Out:
#  Used               11096
#  New                 1650
#  Pre registered      1364
#  Employee s car      1011
#  Demonstration        796
# NaN                     2
# Name: vehicle_type, dtype: int64

# %%
df['Type'].apply(pd.Series)
# Out:
#       0   \
# 0
# 1
# 2
# 3
# 4
# ...   ..
# 15914
# 15915
# 15916
# 15917
# 15918
#
#                     1  \
# 0                Used
# 1                Used
# 2                Used
# 3                Used
# 4                Used
# ...               ...
# 15914             New
# 15915            Used
# 15916  Pre-registered
# 15917  Pre-registered
# 15918   Demonstration
#
#       2   \
# 0
# 1
# 2
# 3
# 4
# ...   ..
# 15914
# 15915
# 15916
# 15917
# 15918
#
#                                    3
# 0        Diesel (Particulate Filter)
# 1                           Gasoline
# 2        Diesel (Particulate Filter)
# 3        Diesel (Particulate Filter)
# 4        Diesel (Particulate Filter)
# ...                              ...
# 15914    Diesel (Particulate Filter)
# 15915  Super 95 / Super Plus 98 (...
# 15916                         Diesel
# 15917                         Diesel
# 15918                       Super 95
#
# [15919 rows x 4 columns]

# %%
df['Type']= df['Type'].apply(pd.Series)[1]

# %%
df['Type']
# Out:
# 0                  Used
# 1                  Used
# 2                  Used
# 3                  Used
# 4                  Used
#               ...
# 15914               New
# 15915              Used
# 15916    Pre-registered
# 15917    Pre-registered
# 15918     Demonstration
# Name: Type, Length: 15919, dtype: object

# %%
# df['Type'].value_counts()
# Out:
# Used              11096
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# Name: Type, dtype: int64

# %%
# df["Used"] = np.where(df['Type'].str.contains("Used"), 1, 0)  

# df["Used"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 15914    0
# 15915    1
# 15916    0
# 15917    0
# 15918    0
# Name: Used, Length: 15919, dtype: int32

# %%
# df["New"] = np.where(df['Type'].str.contains("New"), 1, 0)  

# df["New"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15914    1
# 15915    0
# 15916    0
# 15917    0
# 15918    0
# Name: New, Length: 15919, dtype: int32

# %%
# df["Pre-registered"] = np.where(df['Type'].str.contains("Pre-registered"), 1, 0)  

# df["Pre-registered"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15914    0
# 15915    0
# 15916    1
# 15917    1
# 15918    0
# Name: Pre-registered, Length: 15919, dtype: int32

# %%
# df["Employee's car"] = np.where(df['Type'].str.contains("Employee's car"), 1, 0)  

# df["Employee's car"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15914    0
# 15915    0
# 15916    0
# 15917    0
# 15918    0
# Name: Employee's car, Length: 15919, dtype: int32

# %%
# df["Demonstration"] = np.where(df['Type'].str.contains("Demonstration"), 1, 0)  

# df["Demonstration"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15914    0
# 15915    0
# 15916    0
# 15917    0
# 15918    1
# Name: Demonstration, Length: 15919, dtype: int32

# %%
df["Previous Owners"].value_counts(dropna=False).head(100)   # 6640 eksik. Burada 0 olanlar var. yukarıdaki prev_owner göre daha düşük. Karşılaştıralım.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# \n1\n                                                                                        8101
# NaN                                                                                          6640
# \n2\n                                                                                         766
# \n0\n                                                                                         163
# ...

# %%
df["Previous Owners"] = [item[0] if type(item)==list else item for item in df["Previous Owners"]]

df["Previous Owners"].value_counts().head(100)
# Out:
# \n1\n    8294
# \n2\n     778
# \n0\n     188
# \n3\n      17
# \n4\n       2
# Name: Previous Owners, dtype: int64

# %%
df["Previous Owners"].str.extract('(\d)').value_counts()    # prev_owner ile aynı buradaki list işlemi var.
# Out:
# 1    8294
# 2     778
# 0     188
# 3      17
# 4       2
# dtype: int64

# %%
df["Previous Owners"] = df["Previous Owners"].str.extract('(\d)')

# %%
df["Previous Owners"]
# Out:
# 0          2
# 1        NaN
# 2          1
# 3          1
# 4          1
#         ...
# 15914    NaN
# 15915    NaN
# 15916    NaN
# 15917    NaN
# 15918      1
# Name: Previous Owners, Length: 15919, dtype: object

# %%
df["Previous Owners"].apply(pd.Series)
# Out:
#            0  \
# 0      \n2\n
# 1        NaN
# 2      \n1\n
# 3      \n1\n
# 4      \n1\n
# ...      ...
# 15914    NaN
# 15915  \n1\n
# 15916  \n1\n
# 15917    NaN
# 15918  \n1\n
#
#                              1  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 15914                      NaN
# 15915                       \n
# 15916  \n139 g CO2/km (comb)\n
# 15917                      NaN
# 15918                      NaN
#
#                          2  \
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 15914                  NaN
# 15915  7.4 l/100 km (comb)
# 15916                  NaN
# 15917                  NaN
# 15918                  NaN
#
#          3  \
# 0      NaN
# 1      NaN
# 2      NaN
# ...

# %%
df['Next Inspection'].value_counts().head(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# \n04/2022\n                               62
# \n03/2021\n                               38
# \n03/2022\n                               36
# \n06/2021\n                               34
# \n01/2022\n                               32
#                                           ..
# [\n06/2021\n, \n128 g CO2/km (comb)\n]     6
# \n08/2020\n                                6
# [\n04/2021\n, \n102 g CO2/km (comb)\n]     6
# ...

# %%
#print("EmailMatches:", len(re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Za-z]{2,3}", email)))

# %%
df['Next Inspection'] = [item[0] if type(item)==list else item for item in df['Next Inspection']]

df['Next Inspection']
# Out:
# 0        \n06/2021\n
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#             ...
# 15914            NaN
# 15915    \n01/2022\n
# 15916            NaN
# 15917            NaN
# 15918            NaN
# Name: next_inspection, Length: 15919, dtype: object

# %%
# df['Next Inspection'].str.extract('(\d{2})/(\d{4})').isna().value_counts()  #12384 tane eksik var. Doldurulması gerekir.

# alttaki inspection new ile karşılaştırılabilir.
# Out:
# 0      1
# True   True     12384
# False  False     3535
# dtype: int64

# %%
df['Next Inspection'] = df['Next Inspection'].str.extract('(\d{4})')

# %%
df['Next Inspection'].value_counts()
# Out:
# 2022    205
# 2021    200
# 2020    137
# 2019    102
# 2023     42
# 2018     12
# 2017      6
# 2016      3
# 2024      1
# 1999      1
# 1955      1
# Name: Next Inspection, dtype: int64

# %%
df['Next Inspection'].apply(pd.Series)
# Out:
#                  0  \
# 0      \n06/2021\n
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 15914          NaN
# 15915  \n01/2022\n
# 15916          NaN
# 15917          NaN
# 15918          NaN
#
#                              1  \
# 0       \n99 g CO2/km (comb)\n
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 15914                      NaN
# 15915  \n168 g CO2/km (comb)\n
# 15916                      NaN
# 15917                      NaN
# 15918                      NaN
#
#          2  \
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 15914  NaN
# 15915  NaN
# 15916  NaN
# 15917  NaN
# 15918  NaN
#
#          3  \
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 15914  NaN
# 15915  NaN
# 15916  NaN
# 15917  NaN
# 15918  NaN
#
#          4  \
# ...

# %%
df['Next_Inspection'] = df['Next Inspection'].apply(pd.Series)[0].str.extract('(\d{4})')

# %%
df['Next_Inspection']
# Out:
# 0        2021
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 15914     NaN
# 15915    2022
# 15916     NaN
# 15917     NaN
# 15918     NaN
# Name: Next_Inspection, Length: 15919, dtype: object

# %%
df = pd.read_json('scout_car.json', lines=True, orient='records', convert_axes=True, dtype=True,convert_dates=True)
df.head(3)
# Out:
#                              url  \
# 0  https://www.autoscout24.co...
# 1  https://www.autoscout24.co...
# 2  https://www.autoscout24.co...
#
#   make_model  \
# 0    Audi A1
# 1    Audi A1
# 2    Audi A1
#
#                short_description  \
# 0  Sportback 1.4 TDI S-tronic...
# 1                 1.8 TFSI sport
# 2  Sportback 1.6 TDI S tronic...
#
#   body_type  \
# 0    Sedans
# 1    Sedans
# 2    Sedans
#
#    price  \
# 0  15770
# 1  14500
# 2  14640
#
#                 vat  \
# 0    VAT deductible
# 1  Price negotiable
# 2    VAT deductible
#
#           km  \
# 0  56,013 km
# 1  80,000 km
# 2  83,450 km
#
#   registration  \
# 0      01/2016
# 1      03/2017
# 2      02/2016
#
#           prev_owner  \
# 0  2 previous owners
# 1               None
# 2   1 previous owner
#
#    kW  \
# 0 NaN
# 1 NaN
# 2 NaN
#
#        hp  \
# 0   66 kW
# 1  141 kW
# 2   85 kW
#
#                             Type  \
# 0  [, Used, , Diesel (Particu...
# 1           [, Used, , Gasoline]
# ...

# %%
df['Inspection new'].value_counts(dropna=False).head(100)  #11987 eksik var. Bu değerler No ile doldurulabilir.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# NaN                                                                                            11987
# [\nYes\n, \nEuro 6\n]                                                                            523
# \nYes\n                                                                                          362
# [\nYes\n, \n102 g CO2/km (comb)\n]                                                               174
# ...

# %%
df['Inspection new'] = [item[0] if type(item)==list else item for item in df['Inspection new']]

df['Inspection new'].value_counts().head(100)
# Out:
# \nYes\n    3932
# Name: Inspection new, dtype: int64

# %%
df['Inspection new'] = df['Inspection new'].str.extract('(\w+)')   #.value_counts()

# %%
df['Inspection new']
# Out:
# 0        Yes
# 1        NaN
# 2        NaN
# 3        NaN
# 4        Yes
#         ...
# 15914    NaN
# 15915    NaN
# 15916    Yes
# 15917    NaN
# 15918    Yes
# Name: Inspection new, Length: 15919, dtype: object

# %%
df['Inspection new'].apply(pd.Series)
# Out:
#              0  \
# 0      \nYes\n
# 1          NaN
# 2          NaN
# 3          NaN
# 4      \nYes\n
# ...        ...
# 15914      NaN
# 15915      NaN
# 15916  \nYes\n
# 15917      NaN
# 15918  \nYes\n
#
#                              1  \
# 0                   \nEuro 6\n
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4      \n109 g CO2/km (comb)\n
# ...                        ...
# 15914                      NaN
# 15915                      NaN
# 15916         \nEuro 6d-TEMP\n
# 15917                      NaN
# 15918  \n153 g CO2/km (comb)\n
#
#          2  \
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 15914  NaN
# 15915  NaN
# 15916  NaN
# 15917  NaN
# 15918  NaN
#
#          3  \
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 15914  NaN
# 15915  NaN
# 15916  NaN
# 15917  NaN
# 15918  NaN
#
#          4  \
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# ...

# %%
df['Inspectionnew'] = df['Inspection new'].apply(pd.Series)[0].str.extract('(\w+)')

# %%
df['Inspectionnew']
# Out:
# 0        Yes
# 1        NaN
# 2        NaN
# 3        NaN
# 4        Yes
#         ...
# 15914    NaN
# 15915    NaN
# 15916    Yes
# 15917    NaN
# 15918    Yes
# Name: Inspectionnew, Length: 15919, dtype: object

# %%
df['Warranty'] #.value_counts(dropna=False)  # garanti sürelerini ay olarak aldık. 5645+5420 eksik değer var. Boş olanlar 0 olarak doldurulabilir.
# Out:
# 0              [\n, \n, \n4 (Green)\n]
# 1                                  NaN
# 2        [\n, \n, \n99 g CO2/km (co...
# 3                                  NaN
# 4                 [\n, \n, \nEuro 6\n]
#                      ...
# 15914                    \n24 months\n
# 15915             [\n, \n, \nEuro 6\n]
# 15916          [\n, \n, \n4 (Green)\n]
# 15917                               \n
# 15918                              NaN
# Name: Warranty, Length: 15919, dtype: object

# %%
df['Warranty'] = [item[0] if type(item)==list else item for item in df['Warranty']]

df['Warranty']
# Out:
# 0                   \n
# 1                  NaN
# 2                   \n
# 3                  NaN
# 4                   \n
#              ...
# 15914    \n24 months\n
# 15915               \n
# 15916               \n
# 15917               \n
# 15918              NaN
# Name: Warranty, Length: 15919, dtype: object

# %%
df['Warranty'] = df['Warranty'].str.extract('(\d{1,3})') #.value_counts().head(100)    #.isna().value_counts() #.(\w+)

# %%
df['Warranty'].value_counts()
# Out:
# 12    2594
# 24    1118
# 60     401
# 36     279
# 48     149
# 6      125
# 72      59
# 3       33
# 23      11
# 18      10
# 20       7
# 25       6
# 2        5
# 26       4
# 50       4
# 16       4
# 4        3
# 13       3
# 19       3
# 1        3
# 34       3
# 46       2
# 21       2
# 22       2
# 45       2
# 28       2
# 11       2
# 14       2
# 9        2
# 17       2
# 65       1
# 10       1
# 15       1
# 56       1
# 49       1
# 7        1
# 40       1
# 33       1
# 47       1
# 8        1
# 30       1
# Name: Warranty, dtype: int64

# %%
df['Warranty'].apply(pd.Series)
# Out:
#                    0  \
# 0                 \n
# 1                NaN
# 2                 \n
# 3                NaN
# 4                 \n
# ...              ...
# 15914  \n24 months\n
# 15915             \n
# 15916             \n
# 15917             \n
# 15918            NaN
#
#          1  \
# 0       \n
# 1      NaN
# 2       \n
# 3      NaN
# 4       \n
# ...    ...
# 15914  NaN
# 15915   \n
# 15916   \n
# 15917  NaN
# 15918  NaN
#
#                             2  \
# 0               \n4 (Green)\n
# 1                         NaN
# 2      \n99 g CO2/km (comb)\n
# 3                         NaN
# 4                  \nEuro 6\n
# ...                       ...
# 15914                     NaN
# 15915              \nEuro 6\n
# 15916           \n4 (Green)\n
# 15917                     NaN
# 15918                     NaN
#
#          3  \
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 15914  NaN
# 15915  NaN
# 15916  NaN
# 15917  NaN
# 15918  NaN
#
# ...

# %%
df['Warranty'] = df['Warranty'].apply(pd.Series)[0].str.extract('(\d{1,3})')

# %%
df['Warranty']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 15914     24
# 15915    NaN
# 15916    NaN
# 15917    NaN
# 15918    NaN
# Name: Warranty, Length: 15919, dtype: object

# %%
df.head(3)
# Out:
#                              url  \
# 0  https://www.autoscout24.co...
# 1  https://www.autoscout24.co...
# 2  https://www.autoscout24.co...
#
#   make_model  \
# 0    Audi A1
# 1    Audi A1
# 2    Audi A1
#
#                short_description  \
# 0  Sportback 1.4 TDI S-tronic...
# 1                 1.8 TFSI sport
# 2  Sportback 1.6 TDI S tronic...
#
#   body_type  \
# 0    Sedans
# 1    Sedans
# 2    Sedans
#
#    price  \
# 0  15770
# 1  14500
# 2  14640
#
#                 vat  \
# 0    VAT deductible
# 1  Price negotiable
# 2    VAT deductible
#
#       km  \
# 0  56013
# 1  80000
# 2  83450
#
#   registration  \
# 0         2016
# 1         2017
# 2         2016
#
#   prev_owner  \
# 0          2
# 1       None
# 2          1
#
#    kW  \
# 0 NaN
# 1 NaN
# 2 NaN
#
#     hp  \
# 0   66
# 1  141
# 2   85
#
#    Type  \
# 0  Used
# 1  Used
# 2  Used
#
#   Previous Owners  \
# 0               2
# 1             NaN
# 2               1
#
#                  Next Inspection  \
# ...

# %%
df = pd.read_json('scout_car.json', lines=True, orient='records', convert_axes=True, dtype=True,convert_dates=True)

# %%
df['Full Service'].value_counts().head(100)   # düşülecek.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, \n, \n4 (Green)\n]                                                                       2235
# [\n, \n, \nEuro 6\n]                                                                          2097
# [\n, \n]                                                                                      1702
# [\n, \n, \nEuro 6d-TEMP\n]                                                                     399
# ...

# %%
df['Full Service']= [item[0] if type(item)==list else item for item in df['Full Service']]

df['Full Service'].str.split("\n,")

#df['Full Service'].str.extract("(\s+)").value_counts()

    # buradan consumption değerleri alınabilir.
# Out:
# 0        [\n]
# 1         NaN
# 2         NaN
# 3        [\n]
# 4        [\n]
#          ...
# 15914     NaN
# 15915     NaN
# 15916    [\n]
# 15917     NaN
# 15918     NaN
# Name: Full Service, Length: 15919, dtype: object

# %%
df['Full Service'].apply(pd.Series)
# Out:
#          0  \
# 0       \n
# 1      NaN
# 2      NaN
# 3       \n
# 4       \n
# ...    ...
# 15914  NaN
# 15915  NaN
# 15916   \n
# 15917  NaN
# 15918  NaN
#
#          1  \
# 0       \n
# 1      NaN
# 2      NaN
# 3       \n
# 4       \n
# ...    ...
# 15914  NaN
# 15915  NaN
# 15916   \n
# 15917  NaN
# 15918  NaN
#
#                             2  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3      \n99 g CO2/km (comb)\n
# 4               \n4 (Green)\n
# ...                       ...
# 15914                     NaN
# 15915                     NaN
# 15916                     NaN
# 15917                     NaN
# 15918                     NaN
#
#          3  \
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 15914  NaN
# 15915  NaN
# 15916  NaN
# 15917  NaN
# 15918  NaN
#
#          4  \
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 15914  NaN
# 15915  NaN
# ...

# %%
df['Full Service'].apply(pd.Series)[2].value_counts()  #2 ve 3 te değerler var.
# Out:
# \n4 (Green)\n                 2235
# \nEuro 6\n                    2097
# \nEuro 6d-TEMP\n               399
# \n120 g CO2/km (comb)\n        105
# \n126 g CO2/km (comb)\n         84
#                               ...
# \nEuro 4\n                       1
# \n80 g CO2/km (comb)\n           1
# \n87 g CO2/km (comb)\n           1
# \n253 g CO2/km (comb)\n          1
# \n13,983 g CO2/km (comb)\n       1
# Name: 2, Length: 93, dtype: int64

# %%
df['Full Service Consumption'] = df['Full Service'].apply(pd.Series)[3].str.extract("(\d\d|\d.\d|\d)")

# %%
df['Full Service'].apply(pd.Series)[2].value_counts()
# Out:
# \n4 (Green)\n              2235
# \nEuro 6\n                 2097
# \nEuro 6d-TEMP\n            399
# \n120 g CO2/km (comb)\n     105
# \n126 g CO2/km (comb)\n      84
#                            ...
# \n164 g CO2/km (comb)\n       1
# \n87 g CO2/km (comb)\n        1
# \n84 g CO2/km (comb)\n        1
# \nEuro 4\n                    1
# \n197 g CO2/km (comb)\n       1
# Name: 2, Length: 93, dtype: int64

# %%
df['CO2 Emission Full Serv'] = df['Full Service'].apply(pd.Series)[2].str.extract("(\d{2,3})")

# %%
df['CO2 Emission Full Serv'].value_counts()
# Out:
# 120    105
# 126     84
# 104     77
# 97      76
# 124     61
#       ...
# 80       1
# 253      1
# 164      1
# 13       1
# 156      1
# Name: CO2 Emission Full Serv, Length: 83, dtype: int64

# %%
df["Full Service Emission Label"] = np.where(df['Full Service'].str.contains("Euro"), 1, 0)  

df["Full Service Emission Label"].value_counts()
# Out:
# 1    15636
# 0      283
# Name: Full Service Emission Label, dtype: int64

# %%
df['Full Service'].apply(pd.Series)[2].str.contains("Euro")  # df['Emission Class Full Serv']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3        False
# 4        False
#          ...
# 15914      NaN
# 15915      NaN
# 15916      NaN
# 15917      NaN
# 15918      NaN
# Name: 2, Length: 15919, dtype: object

# %%
df['Emission Class Full Serv'].value_counts()
# Out:
# 4 (Green)              2235
# Euro 6                 2097
# Euro 6d-TEMP            399
# 120 g CO2/km (comb)     105
# 126 g CO2/km (comb)      84
#                        ...
# 253 g CO2/km (comb)       1
# 164 g CO2/km (comb)       1
# 156 g CO2/km (comb)       1
# 197 g CO2/km (comb)       1
# 159 g CO2/km (comb)       1
# Name: Emission Class Full Serv, Length: 92, dtype: int64

# %%
df['Full Service'].apply(pd.Series)[2].str.contains("Green|Red|Blue|Yellow|No Sticker")  #df['Emission Label']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3        False
# 4         True
#          ...
# 15914      NaN
# 15915      NaN
# 15916      NaN
# 15917      NaN
# 15918      NaN
# Name: 2, Length: 15919, dtype: object

# %% [markdown]
# data = [['Green', 'Rectangle\r\nTriangle\r\nOctangle', 10], ['Blue', 'Rectangle\r\nTriangle', 15]]
# df = pd.DataFrame(data, columns = ['Color', 'Shape', 'Price'])
# new_df = pd.DataFrame(columns = ['Color', 'Shape', 'Price'])
#
# for index, row in df.iterrows():
#     split = row['Shape'].split('\r\n')
#     for shape in split:
#         new_df = new_df.append(pd.DataFrame({'Color':[row['Color']], 'Shape':[shape], 'Price':[row['Price']]}))
#
# new_df = new_df.reset_index(drop=True)
# print(new_df)

# %%
df = pd.read_json('scout_car.json', lines=True, orient='records', convert_axes=True, dtype=True,convert_dates=True)

# %%
df['Non-smoking Vehicle'].value_counts().head(100)   # düşülecek.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, \n]                             3647
# [\n, \n, \n4 (Green)\n]              1240
# [\n, \n, \nEuro 6\n]                 1127
# [\n, \n, \nEuro 6d-TEMP\n]            345
# \n                                     70
#                                      ...
# [\n, \n, \n150 g CO2/km (comb)\n]       1
# [\n, \n, \n91 g CO2/km (comb)\n]        1
# [\n, \n, \n101 g CO2/km (comb)\n]       1
# ...

# %%
df['Non-smoking Vehicle']= [item[0] if type(item)==list else item for item in df['Non-smoking Vehicle']]

df['Non-smoking Vehicle'].value_counts()

#df['non_smoking_vehicle'].str.extract('(^\d{1,3})')   # buradan consumption değerleri alınabilir.
# Out:
# \n    7177
# Name: non_smoking_vehicle, dtype: int64

# %%
df["Non-smoking Vehicle"].apply(pd.Series)[0].value_counts()
# Out:
# \n    7177
# Name: 0, dtype: int64

# %%
df["Non-smoking Vehicle"].apply(pd.Series)[3].value_counts()
# Out:
# 5.2 l/100 km (comb)    6
# 6.5 l/100 km (comb)    2
# 6.1 l/100 km (comb)    2
# 6.2 l/100 km (comb)    1
# 6.3 l/100 km (comb)    1
# 5.6 l/100 km (comb)    1
# 1.6 l/100 km (comb)    1
# 6.4 l/100 km (comb)    1
# 5.7 l/100 km (comb)    1
# Name: 3, dtype: int64

# %%
df["Non-smoking Vehicle Consumption"] = df["Non-smoking Vehicle"].apply(pd.Series)[3].str.extract("(\d\d|\d.\d|\d)")

# %%
df["Non-smoking Vehicle"].apply(pd.Series)[2].str.contains("Euro")
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3         True
# 4          NaN
#          ...
# 15914      NaN
# 15915    False
# 15916      NaN
# 15917      NaN
# 15918      NaN
# Name: 2, Length: 15919, dtype: object

# %%
df["Non-smoking Vehicle"].apply(pd.Series)[2].str.contains("Green|Red|Blue|Yellow|No Sticker")
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3        False
# 4          NaN
#          ...
# 15914      NaN
# 15915     True
# 15916      NaN
# 15917      NaN
# 15918      NaN
# Name: 2, Length: 15919, dtype: object

# %%
df['null'].value_counts().head(100)  # düşülecek.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# []    15919
# Name: null, dtype: int64

# %%
df['Make'].value_counts().head(100)   # düşülecek
# Out:
# \nOpel\n       7343
# \nAudi\n       5712
# \nRenault\n    2864
# Name: Make, dtype: int64

# %%
df['Make']= df['Make'].str.replace('\n', '')

# %%
df['Make'].value_counts().head(100)
# Out:
# Opel       7343
# Audi       5712
# Renault    2864
# Name: Make, dtype: int64

# %%
df['Model'].value_counts().head(100)    # düşülecek
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, A3, \n]          3097
# [\n, A1, \n]          2614
# [\n, Insignia, \n]    2598
# [\n, Astra, \n]       2526
# [\n, Corsa, \n]       2219
# [\n, Clio, \n]        1839
# [\n, Espace, \n]       991
# [\n, Duster, \n]        34
# [\n, A2, \n]             1
# Name: Model, dtype: int64

# %%
df['offer_number'].value_counts().head(100)   #silinecek.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'offer_number'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-a980041a4281> in <module>
# ...

# %%
df['offer_number']= [item[0] if type(item)==list else item for item in df['offer_number']]

df['offer_number'].value_counts()
# Out:
# \nTP62881\n     27
# \nXJ38068\n     27
# \nAK13780\n     27
# \nJV03654\n     27
# \nXT61649\n     27
#                 ..
# \nVO809335\n     1
# \n55629\n        1
# \n2875621\n      1
# \nG5548\n        1
# \n13120\n        1
# Name: offer_number, Length: 11440, dtype: int64

# %%
df['offer_number'].str.extract('(\S+)') #.value_counts().head(100)
# Out:
#                     0
# 0           LR-062483
# 1                 NaN
# 2            AM-95365
# 3                 NaN
# 4               C1626
# ...               ...
# 15914        10988301
# 15915     507370_3223
# 15916        Espace16
# 15917         2691331
# 15918  Re_30000008029
#
# [15919 rows x 1 columns]

# %%
df = pd.read_json('scout_car.json', lines=True, orient='records', convert_axes=True, dtype=True,convert_dates=True)
df.head()
# Out:
#                              url  \
# 0  https://www.autoscout24.co...
# 1  https://www.autoscout24.co...
# 2  https://www.autoscout24.co...
# 3  https://www.autoscout24.co...
# 4  https://www.autoscout24.co...
#
#   make_model  \
# 0    Audi A1
# 1    Audi A1
# 2    Audi A1
# 3    Audi A1
# 4    Audi A1
#
#                short_description  \
# 0  Sportback 1.4 TDI S-tronic...
# 1                 1.8 TFSI sport
# 2  Sportback 1.6 TDI S tronic...
# 3        1.4 TDi Design S tronic
# 4  Sportback 1.4 TDI S-Tronic...
#
#   body_type  \
# 0    Sedans
# 1    Sedans
# 2    Sedans
# 3    Sedans
# 4    Sedans
#
#    price  \
# 0  15770
# 1  14500
# 2  14640
# 3  14500
# 4  16790
#
#                 vat  \
# 0    VAT deductible
# 1  Price negotiable
# 2    VAT deductible
# 3              None
# 4              None
#
#           km  \
# 0  56,013 km
# 1  80,000 km
# 2  83,450 km
# 3  73,000 km
# 4  16,200 km
#
#   registration  \
# 0      01/2016
# 1      03/2017
# 2      02/2016
# ...

# %%
df['First Registration'].value_counts().head(100)  # yukarıdaki registration ile karşılaştırıp biri düşülecek.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, 2018, \n]    4522
# [\n, 2016, \n]    3674
# [\n, 2017, \n]    3273
# [\n, 2019, \n]    2853
# Name: First Registration, dtype: int64

# %%
df['First Registration']= [",".join(item) if type(item)==list else item for item in df['First Registration']]

df['First_Registration'] = df['First Registration'].str.extract("(\d+)")  #.isna().value_counts()

# buradan age hesaplayacağız.

# %%
df['First Registration'] = df['First Registration'].str.extract("(\d+)")

# %%
df['Body Color'].value_counts().head(1000)   # 3 grup yapılabilir.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, Black, \n]     3745
# [\n, Grey, \n]      3505
# [\n, White, \n]     3406
# [\n, Silver, \n]    1647
# [\n, Blue, \n]      1431
# [\n, Red, \n]        957
# [\n, Brown, \n]      289
# [\n, Green, \n]      154
# [\n, Beige, \n]      108
# [\n, Yellow, \n]      51
# [\n, Violet, \n]      18
# [\n, Bronze, \n]       6
# [\n, Orange, \n]       3
# [\n, Gold, \n]         2
# Name: Body Color, dtype: int64

# %%
df['Body Color']= [",".join(item) if type(item)==list else item for item in df['Body Color']]

df['Body Color'].str.extract("(\w+)").isna().value_counts()
# Out:
# False    15322
# True       597
# dtype: int64

# %%
df['Body_Color'] = df['Body Color'].str.extract("(\w+)")

# %%
df['Paint Type'].value_counts().head(100)  # düşülebilir.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nMetallic\n]       9794
# [\nUni/basic\n]       347
# [\nPerl effect\n]       6
# Name: Paint Type, dtype: int64

# %%
df['Paint Type']= [",".join(item) if type(item)==list else item for item in df['Paint Type']]

df['Paint Type'].str.extract("(\w+.\w+)").isna().value_counts()
# Out:
# False    10147
# True      5772
# dtype: int64

# %%
df['Paint_Type'] = df['Paint Type'].str.extract("(\w+.\w+)")

# %%
df['Body Color Original'].isna().value_counts()  # ikiye bölünebilir orjinal ve değil diye.
# Out:
# False    12160
# True      3759
# Name: Body Color Original, dtype: int64

# %%
df['Body Color Original']= [item[0] if type(item)==list else item for item in df['Body Color Original']]

df['Body Color Original'].str.extract("(\w+.\w+)").value_counts()
# Out:
# Onyx Schwarz              389
# Bianco                    282
# Argon Silber              273
# Quarz Grau                266
# Mythosschwarz Metallic    256
#                          ...
# Darmoon Blue                1
# Mitos                       1
# Shiny Grey                  1
# Darkmoon Blau               1
# DIAMANTBLAU                 1
# Length: 1415, dtype: int64

# %%
df['Body_Color_Original'] = df['Body Color Original'].str.extract("(\w+.\w+)")

# %%
df['Upholstery'].value_counts().head(10)  #ikiye ayrılabilir cloth ve full leather diye
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nCloth, Black\n]           5821
# [\nPart leather, Black\n]    1121
# [\nCloth\n]                  1005
# [\nCloth, Grey\n]             891
# [\nCloth, Other\n]            639
# [\nFull leather, Black\n]     575
# [\nBlack\n]                   491
# [\nGrey\n]                    273
# [\nOther, Other\n]            182
# [\nPart leather\n]            140
# Name: Upholstery, dtype: int64

# %%
df['Upholstery']= [",".join(item) if type(item)==list else item for item in df['Upholstery']]

df['Upholstery'].str.extract("(\w+..\w+)").isna().value_counts()
# Out:
# False    12199
# True      3720
# dtype: int64

# %%
df['Upholstery_type'] = df.Upholstery.apply(pd.Series)[0].str.split(",", n = 1, expand = True)[0].str.extract("(\w+..\w+)")

# %%
df['Upholstery_type']
# Out:
# 0               Cloth
# 1               Cloth
# 2               Cloth
# 3                 NaN
# 4               Cloth
#              ...
# 15914             NaN
# 15915           Cloth
# 15916    Full leather
# 15917    Part leather
# 15918    Full leather
# Name: Upholstery_type, Length: 15919, dtype: object

# %%
df['Upholstery_color'] = df.Upholstery.apply(pd.Series)[0].str.split(",", n = 1, expand = True)[1].str.extract("(\w+..\w+)")

# %%
df['Upholstery_color']
# Out:
# 0        Black
# 1         Grey
# 2        Black
# 3          NaN
# 4        Black
#          ...
# 15914      NaN
# 15915      NaN
# 15916    Black
# 15917      NaN
# 15918    Brown
# Name: Upholstery_color, Length: 15919, dtype: object

# %%
df.head(3)
# Out:
#                              url  \
# 0  https://www.autoscout24.co...
# 1  https://www.autoscout24.co...
# 2  https://www.autoscout24.co...
#
#   make_model  \
# 0    Audi A1
# 1    Audi A1
# 2    Audi A1
#
#                short_description  \
# 0  Sportback 1.4 TDI S-tronic...
# 1                 1.8 TFSI sport
# 2  Sportback 1.6 TDI S tronic...
#
#   body_type  \
# 0    Sedans
# 1    Sedans
# 2    Sedans
#
#    price  \
# 0  15770
# 1  14500
# 2  14640
#
#                 vat  \
# 0    VAT deductible
# 1  Price negotiable
# 2    VAT deductible
#
#       km  \
# 0  56013
# 1  80000
# 2  83450
#
#   registration  \
# 0         2016
# 1         2017
# 2         2016
#
#   prev_owner  \
# 0          2
# 1       None
# 2          1
#
#    kW  \
# 0 NaN
# 1 NaN
# 2 NaN
#
#     hp  \
# 0   66
# 1  141
# 2   85
#
#    Type  \
# 0  Used
# 1  Used
# 2  Used
#
#   Previous Owners  \
# 0               2
# 1             NaN
# 2               1
#
#                  Next Inspection  \
# ...

# %%
df['Body'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, Sedans, \n]           7903
# [\n, Station wagon, \n]    3553
# [\n, Compact, \n]          3153
# [\n, Van, \n]               783
# [\n, Other, \n]             290
# [\n, Transporter, \n]        88
# [\n, Off-Road, \n]           56
# [\n, Coupe, \n]              25
# [\n, Convertible, \n]         8
# Name: Body, dtype: int64

# %%
df['Body']= [",".join(item) if type(item)==list else item for item in df['Body']]

df['Body'].str.extract("(\w+.\w+)").value_counts()
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# dtype: int64

# %%
df['Body'] = df['Body'].str.extract("(\w+.\w+)")

# %%
df['Nr. of Doors'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n5\n]    11575
# [\n4\n]     3079
# [\n3\n]      832
# [\n2\n]      219
# [\n7\n]        1
# [\n1\n]        1
# Name: Nr. of Doors, dtype: int64

# %%
df['Nr. of Doors']= [item[0] if type(item)==list else item for item in df['Nr. of Doors']]

df['Nr. of Doors'].str.extract("(\w+)").isna().value_counts()
# Out:
# False    15707
# True       212
# dtype: int64

# %%
df['Nr_of_Doors'] = df['Nr. of Doors'].str.extract("(\w+)")

# %%
df['Nr. of Seats'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n5\n]    13336
# [\n4\n]     1125
# [\n7\n]      362
# [\n2\n]      116
# [\n6\n]        2
# [\n3\n]        1
# Name: Nr. of Seats, dtype: int64

# %%
df['Nr. of Seats']= [item[0] if type(item)==list else item for item in df['Nr. of Seats']]

df['Nr. of Seats'].str.extract("(\w+)").isna().value_counts()
# Out:
# False    14942
# True       977
# dtype: int64

# %%
df['Nr_of_Seats'] = df['Nr. of Seats'].str.extract("(\w+)")

# %%
df['Model Code'].value_counts().head(10)  #silinebilir. belki eksikler bundan tamalanabilir.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n0035/BCB\n]    268
# [\n0588/BNO\n]    245
# [\n0588/BDB\n]    206
# [\n0588/BHX\n]    188
# [\n1844/ADJ\n]    175
# [\n0588/BDF\n]    175
# [\n0588/BCV\n]    139
# [\n3333/BAJ\n]    122
# [\n3333/BEF\n]    118
# [\n0588/AYB\n]    117
# Name: Model Code, dtype: int64

# %%
df['Model Code']= [item[0] if type(item)==list else item for item in df['Model Code']]

df['Model Code'].str.extract("(\S+)").isna().value_counts()
# Out:
# True     10941
# False     4978
# dtype: int64

# %%
df['Model_Code'] = df['Model Code'].str.extract("(\S+)")

# %%
df['Gearing Type'].value_counts().head(10)   # aşağıdaki gears ile karşılaştırıp birini elemek lazım.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, Manual, \n]            8153
# [\n, Automatic, \n]         7297
# [\n, Semi-automatic, \n]     469
# Name: Gearing Type, dtype: int64

# %%
df['Gearing Type']= [",".join(item) if type(item)==list else item for item in df['Gearing Type']]

df['Gearing_Type'] = df['Gearing Type'].str.extract("(\w+.\w+)")  #.isna().value_counts()

# %%
df['Gearing Type'] = df['Gearing Type'].apply(pd.Series)[1]

# %%
df['Displacement'].value_counts().head(10)     # cc bunu engine ile karşılaştırmak lazım
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n1,598 cc\n]    4761
# [\n999 cc\n]      2438
# [\n1,398 cc\n]    1314
# [\n1,399 cc\n]     749
# [\n1,229 cc\n]     677
# [\n1,956 cc\n]     670
# [\n1,461 cc\n]     595
# [\n1,490 cc\n]     559
# [\n1,422 cc\n]     467
# [\n1,197 cc\n]     353
# Name: Displacement, dtype: int64

# %%
df['Displacement']= [",".join(item) if type(item)==list else item for item in df['Displacement']]

df['Displacement'].str.extract("(\d+.\d+)").value_counts()
# Out:
# 1,598    4761
# 999      2438
# 1,398    1314
# 1,399     749
# 1,229     677
#          ...
# 1,333       1
# 1,696       1
# 1,686       1
# 1,350       1
# 1,533       1
# Length: 74, dtype: int64

# %%
df['Displacement'] = df['Displacement'].apply(pd.Series)[0].str.extract("(\d+.\d+)")

# %%
df['Displacement'].value_counts()
# Out:
# 1,598     4761
# 999       2438
# 1,398     1314
# 1,399      749
# 1,229      677
#           ...
# 16,000       1
# 140          1
# 1,800        1
# 15,898       1
# 1,100        1
# Name: Displacement, Length: 74, dtype: int64

# %%
df['Cylinders'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n4\n]    8105
# [\n3\n]    2104
# [\n5\n]      22
# [\n6\n]       3
# [\n2\n]       2
# [\n8\n]       2
# [\n1\n]       1
# Name: Cylinders, dtype: int64

# %%
df['Cylinders']= [item[0] if type(item)==list else item for item in df['Cylinders']]

df['Cylinders'].str.extract("(\d+)").value_counts()
# Out:
# 4    8105
# 3    2104
# 5      22
# 6       3
# 2       2
# 8       2
# 1       1
# dtype: int64

# %%
df['Cylinders'] = df['Cylinders'].str.extract("(\d+)")

# %%
df['Cylinders']
# Out:
# 0          3
# 1          4
# 2        NaN
# 3          3
# 4          3
#         ...
# 15914      4
# 15915      4
# 15916      4
# 15917      4
# 15918      4
# Name: Cylinders, Length: 15919, dtype: object

# %%
df['Weight'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n1,163 kg\n]    574
# [\n1,360 kg\n]    356
# [\n1,165 kg\n]    301
# [\n1,335 kg\n]    242
# [\n1,135 kg\n]    213
# [\n1,199 kg\n]    205
# [\n1,734 kg\n]    170
# [\n1,180 kg\n]    168
# [\n1,503 kg\n]    165
# [\n1,350 kg\n]    155
# Name: Weight, dtype: int64

# %%
df['Weight']= [item[0] if type(item)==list else item for item in df['Weight']]

df['Weight'].str.extract("(\d+.\d+)").isna().value_counts()
# Out:
# False    8943
# True     6976
# dtype: int64

# %%
df['Weight'] = df['Weight'].str.extract("(\d+.\d+)")

# %%
df['Weight'] = df['Weight'].apply(pd.Series)[0].str.extract("(\d+.\d+)")

# %%
df['Drive chain'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nfront\n]    8886
# [\n4WD\n]       171
# [\nrear\n]        4
# Name: Drive chain, dtype: int64

# %%
df['Drive chain']= [item[0] if type(item)==list else item for item in df['Drive chain']]

df['Drive chain'].str.extract("(\S+)").value_counts()
# Out:
# front    8886
# 4WD       171
# rear        4
# dtype: int64

# %%
df['Drive_chain'] = df['Drive chain'].str.extract("(\S+)")

# %%
df = pd.read_json('scout_car.json', lines=True, orient='records', convert_axes=True, dtype=True,convert_dates=True)
df.head(2)
# Out:
#                              url  \
# 0  https://www.autoscout24.co...
# 1  https://www.autoscout24.co...
#
#   make_model  \
# 0    Audi A1
# 1    Audi A1
#
#                short_description  \
# 0  Sportback 1.4 TDI S-tronic...
# 1                 1.8 TFSI sport
#
#   body_type  \
# 0    Sedans
# 1    Sedans
#
#    price  \
# 0  15770
# 1  14500
#
#                 vat  \
# 0    VAT deductible
# 1  Price negotiable
#
#           km  \
# 0  56,013 km
# 1  80,000 km
#
#   registration  \
# 0      01/2016
# 1      03/2017
#
#           prev_owner  \
# 0  2 previous owners
# 1               None
#
#    kW  \
# 0 NaN
# 1 NaN
#
#        hp  \
# 0   66 kW
# 1  141 kW
#
#                             Type  \
# 0  [, Used, , Diesel (Particu...
# 1           [, Used, , Gasoline]
#
#   Previous Owners  \
# 0           \n2\n
# 1             NaN
#
#                  Next Inspection  \
# 0  [\n06/2021\n, \n99 g CO2/k...
# 1                            NaN
#
#           Inspection new  \
# ...

# %%
df["Fuel"].value_counts().head(10)   # bunu 2 gruba ayıracağız.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, Diesel (Particulate Filter), \n]                4315
# [\n, Super 95, \n]                                   3338
# [\n, Gasoline, \n]                                   3175
# [\n, Diesel, \n]                                     2984
# [\n, Super 95 / Regular/Benzine 91, \n]               424
# [\n, Regular/Benzine 91, \n]                          354
# [\n, Super E10 95, \n]                                331
# ...

# %%
df['Fuel']= [",".join(item) if type(item)==list else item for item in df['Fuel']]

df['Fuel']=df['Fuel'].str.replace(r'[\s,\s./]', ' ', regex=True).replace({'':0}, inplace=False)

# %%
df['Fuel'] #.value_counts().head(20)
# Out:
#   Diesel (Particulate Filter)                                                                                    4315
#   Super 95                                                                                                       3338
#   Gasoline                                                                                                       3175
#   Diesel                                                                                                         2984
#   Super 95   Regular Benzine 91                                                                                   424
#   Regular Benzine 91                                                                                              354
#   Super E10 95                                                                                                    331
#   Super 95 (Particulate Filter)                                                                                   268
# ...

# %%
# df['Fuel'].apply(pd.Series)[0]
# Out:
# 0          Diesel (Particulate Filt...
# 1                           Gasoline
# 2          Diesel (Particulate Filt...
# 3          Diesel (Particulate Filt...
# 4          Diesel (Particulate Filt...
#                      ...
# 15914      Diesel (Particulate Filt...
# 15915      Super 95   Super Plus 98...
# 15916                         Diesel
# 15917                         Diesel
# 15918                       Super 95
# Name: 0, Length: 15919, dtype: object

# %%
benzine = ["Gasoline","Super 95","Regular", "Super E10 95","Super Plus 98","Super Plus E10 98","Others"]

lpg = ["LPG","Liquid petroleum gas","CNG","Biogas","Domestic gas H"]


def fueltype(x):
    if x in benzine:
        return "Benzine"
    elif x in lpg:
        return "LPG/CNG"
    else :
        return x

df["Fuel"] = df["Fuel"].apply(fueltype)

df["Fuel"]
# Out:
# 0          Diesel (Particulate Filt...
# 1                           Gasoline
# 2          Diesel (Particulate Filt...
# 3          Diesel (Particulate Filt...
# 4          Diesel (Particulate Filt...
#                      ...
# 15914      Diesel (Particulate Filt...
# 15915      Super 95   Super Plus 98...
# 15916                         Diesel
# 15917                         Diesel
# 15918                       Super 95
# Name: Fuel, Length: 15919, dtype: object

# %%
df['Consumption'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [[3.9 l/100 km (comb)], [4.1 l/100 km (city)], [3.7 l/100 km (country)]]    304
# [[4.2 l/100 km (comb)], [5 l/100 km (city)], [3.7 l/100 km (country)]]      276
# [[5.4 l/100 km (comb)], [6.8 l/100 km (city)], [4.5 l/100 km (country)]]    257
# [[3.8 l/100 km (comb)], [4.3 l/100 km (city)], [3.5 l/100 km (country)]]    253
# [[4.7 l/100 km (comb)], [5.1 l/100 km (city)], [4.4 l/100 km (country)]]    244
# ...

# %%
df['Consumption'].apply(pd.Series)  #[0].isna().value_counts()
# Out:
#                            0  \
# 0      [3.8 l/100 km (comb)]
# 1      [5.6 l/100 km (comb)]
# 2      [3.8 l/100 km (comb)]
# 3      [3.8 l/100 km (comb)]
# 4      [4.1 l/100 km (comb)]
# ...                      ...
# 15914  [5.3 l/100 km (comb)]
# 15915                     \n
# 15916  [5.3 l/100 km (comb)]
# 15917  [5.3 l/100 km (comb)]
# 15918  [6.8 l/100 km (comb)]
#
#                            1  \
# 0      [4.3 l/100 km (city)]
# 1      [7.1 l/100 km (city)]
# 2      [4.4 l/100 km (city)]
# 3      [4.3 l/100 km (city)]
# 4      [4.6 l/100 km (city)]
# ...                      ...
# 15914  [6.2 l/100 km (city)]
# 15915    7.4 l/100 km (comb)
# 15916  [6.2 l/100 km (city)]
# 15917  [6.2 l/100 km (city)]
# 15918  [8.7 l/100 km (city)]
#
#                               2  \
# 0      [3.5 l/100 km (country)]
# 1      [4.7 l/100 km (country)]
# 2      [3.4 l/100 km (country)]
# 3      [3.5 l/100 km (country)]
# 4      [3.8 l/100 km (country)]
# ...                         ...
# ...

# %%
df['Concomb'] = df['Consumption'].apply(pd.Series)[0].apply(pd.Series)

# %%
df['Concity'] = df['Consumption'].apply(pd.Series)[1].apply(pd.Series)

# %%
df['Concountry'] = df['Consumption'].apply(pd.Series)[2].apply(pd.Series)

# %%
df['Conn'] = df['Consumption'].apply(pd.Series)[3].apply(pd.Series)

# %%
df['Connn'] = df['Consumption'].apply(pd.Series)[5].apply(pd.Series)

# %%
df1 = pd.concat([df['Concomb'],df['Concity'],df['Concountry'],df['Conn'],df['Connn']], axis=1)

# %%
df1
# Out:
#                    Concomb  \
# 0      3.8 l/100 km (comb)
# 1      5.6 l/100 km (comb)
# 2      3.8 l/100 km (comb)
# 3      3.8 l/100 km (comb)
# 4      4.1 l/100 km (comb)
# ...                    ...
# 15914  5.3 l/100 km (comb)
# 15915                   \n
# 15916  5.3 l/100 km (comb)
# 15917  5.3 l/100 km (comb)
# 15918  6.8 l/100 km (comb)
#
#                    Concity  \
# 0      4.3 l/100 km (city)
# 1      7.1 l/100 km (city)
# 2      4.4 l/100 km (city)
# 3      4.3 l/100 km (city)
# 4      4.6 l/100 km (city)
# ...                    ...
# 15914  6.2 l/100 km (city)
# 15915  7.4 l/100 km (comb)
# 15916  6.2 l/100 km (city)
# 15917  6.2 l/100 km (city)
# 15918  8.7 l/100 km (city)
#
#                    Concountry  \
# 0      3.5 l/100 km (country)
# 1      4.7 l/100 km (country)
# 2      3.4 l/100 km (country)
# 3      3.5 l/100 km (country)
# 4      3.8 l/100 km (country)
# ...                       ...
# 15914  4.7 l/100 km (country)
# 15915                      \n
# ...

# %%
df2 = df1.copy() #.astype("str")

# %%
df2 = df2.replace("\n", np.nan)

df2
# Out:
#                    Concomb  \
# 0      3.8 l/100 km (comb)
# 1      5.6 l/100 km (comb)
# 2      3.8 l/100 km (comb)
# 3      3.8 l/100 km (comb)
# 4      4.1 l/100 km (comb)
# ...                    ...
# 15914  5.3 l/100 km (comb)
# 15915                  NaN
# 15916  5.3 l/100 km (comb)
# 15917  5.3 l/100 km (comb)
# 15918  6.8 l/100 km (comb)
#
#                    Concity  \
# 0      4.3 l/100 km (city)
# 1      7.1 l/100 km (city)
# 2      4.4 l/100 km (city)
# 3      4.3 l/100 km (city)
# 4      4.6 l/100 km (city)
# ...                    ...
# 15914  6.2 l/100 km (city)
# 15915  7.4 l/100 km (comb)
# 15916  6.2 l/100 km (city)
# 15917  6.2 l/100 km (city)
# 15918  8.7 l/100 km (city)
#
#                    Concountry  \
# 0      3.5 l/100 km (country)
# 1      4.7 l/100 km (country)
# 2      3.4 l/100 km (country)
# 3      3.5 l/100 km (country)
# 4      3.8 l/100 km (country)
# ...                       ...
# 15914  4.7 l/100 km (country)
# 15915                     NaN
# ...

# %%
df2["Concomb"]
# Out:
# 0        3.8 l/100 km (comb)
# 1        5.6 l/100 km (comb)
# 2        3.8 l/100 km (comb)
# 3        3.8 l/100 km (comb)
# 4        4.1 l/100 km (comb)
#                 ...
# 15914    5.3 l/100 km (comb)
# 15915                    NaN
# 15916    5.3 l/100 km (comb)
# 15917    5.3 l/100 km (comb)
# 15918    6.8 l/100 km (comb)
# Name: Concomb, Length: 15919, dtype: object

# %%
df2.Concomb.fillna(df2.Concity, inplace=True)

df2.Concomb
# Out:
# 0        3.8 l/100 km (comb)
# 1        5.6 l/100 km (comb)
# 2        3.8 l/100 km (comb)
# 3        3.8 l/100 km (comb)
# 4        4.1 l/100 km (comb)
#                 ...
# 15914    5.3 l/100 km (comb)
# 15915    7.4 l/100 km (comb)
# 15916    5.3 l/100 km (comb)
# 15917    5.3 l/100 km (comb)
# 15918    6.8 l/100 km (comb)
# Name: Concomb, Length: 15919, dtype: object

# %%
df2.Concountry.fillna(df2.Connn, inplace=True)

df2.Concountry
# Out:
# 0        3.5 l/100 km (country)
# 1        4.7 l/100 km (country)
# 2        3.4 l/100 km (country)
# 3        3.5 l/100 km (country)
# 4        3.8 l/100 km (country)
#                   ...
# 15914    4.7 l/100 km (country)
# 15915    6.3 l/100 km (country)
# 15916    4.7 l/100 km (country)
# 15917    4.7 l/100 km (country)
# 15918    5.7 l/100 km (country)
# Name: Concountry, Length: 15919, dtype: object

# %%
df2["Concity"] = np.where(df2.Concity.str.contains("comb"), df.Conn, df2.Concity)  

df2["Concity"]
# Out:
# 0        4.3 l/100 km (city)
# 1        7.1 l/100 km (city)
# 2        4.4 l/100 km (city)
# 3        4.3 l/100 km (city)
# 4        4.6 l/100 km (city)
#                 ...
# 15914    6.2 l/100 km (city)
# 15915    9.2 l/100 km (city)
# 15916    6.2 l/100 km (city)
# 15917    6.2 l/100 km (city)
# 15918    8.7 l/100 km (city)
# Name: Concity, Length: 15919, dtype: object

# %%
df2
# Out:
#                    Concomb  \
# 0      3.8 l/100 km (comb)
# 1      5.6 l/100 km (comb)
# 2      3.8 l/100 km (comb)
# 3      3.8 l/100 km (comb)
# 4      4.1 l/100 km (comb)
# ...                    ...
# 15914  5.3 l/100 km (comb)
# 15915  7.4 l/100 km (comb)
# 15916  5.3 l/100 km (comb)
# 15917  5.3 l/100 km (comb)
# 15918  6.8 l/100 km (comb)
#
#                    Concity  \
# 0      4.3 l/100 km (city)
# 1      7.1 l/100 km (city)
# 2      4.4 l/100 km (city)
# 3      4.3 l/100 km (city)
# 4      4.6 l/100 km (city)
# ...                    ...
# 15914  6.2 l/100 km (city)
# 15915  9.2 l/100 km (city)
# 15916  6.2 l/100 km (city)
# 15917  6.2 l/100 km (city)
# 15918  8.7 l/100 km (city)
#
#                    Concountry  \
# 0      3.5 l/100 km (country)
# 1      4.7 l/100 km (country)
# 2      3.4 l/100 km (country)
# 3      3.5 l/100 km (country)
# 4      3.8 l/100 km (country)
# ...                       ...
# 15914  4.7 l/100 km (country)
# 15915  6.3 l/100 km (country)
# ...

# %%
df2.drop(columns=["Conn","Connn"], axis = 0, inplace=True)

# %%
df2.Concomb = df2.Concomb.str.extract("(\d\d|\d.\d|\d)")

# %%
df2.Concity = df2.Concity.str.extract("(\d\d|\d.\d|\d)")

# %%
df2.Concountry = df2.Concountry.str.extract("(\d\d|\d.\d|\d)")

# %%
df2
# Out:
#       Concomb  \
# 0         3.8
# 1         5.6
# 2         3.8
# 3         3.8
# 4         4.1
# ...       ...
# 15914     5.3
# 15915     7.4
# 15916     5.3
# 15917     5.3
# 15918     6.8
#
#       Concity  \
# 0         4.3
# 1         7.1
# 2         4.4
# 3         4.3
# 4         4.6
# ...       ...
# 15914     6.2
# 15915     9.2
# 15916     6.2
# 15917     6.2
# 15918     8.7
#
#       Concountry
# 0            3.5
# 1            4.7
# 2            3.4
# 3            3.5
# 4            3.8
# ...          ...
# 15914        4.7
# 15915        6.3
# 15916        4.7
# 15917        4.7
# 15918        5.7
#
# [15919 rows x 3 columns]

# %%
df[["Cons_comb", "Cons_city", "Cons_country"]] = df2[["Concomb","Concity", "Concountry"]]

# %%
df.head(3)
# Out:
#                              url  \
# 0  https://www.autoscout24.co...
# 1  https://www.autoscout24.co...
# 2  https://www.autoscout24.co...
#
#   make_model  \
# 0    Audi A1
# 1    Audi A1
# 2    Audi A1
#
#                short_description  \
# 0  Sportback 1.4 TDI S-tronic...
# 1                 1.8 TFSI sport
# 2  Sportback 1.6 TDI S tronic...
#
#   body_type  \
# 0    Sedans
# 1    Sedans
# 2    Sedans
#
#    price  \
# 0  15770
# 1  14500
# 2  14640
#
#                 vat  \
# 0    VAT deductible
# 1  Price negotiable
# 2    VAT deductible
#
#       km  \
# 0  56013
# 1  80000
# 2  83450
#
#   registration  \
# 0         2016
# 1         2017
# 2         2016
#
#   prev_owner  \
# 0          2
# 1       None
# 2          1
#
#    kW  \
# 0 NaN
# 1 NaN
# 2 NaN
#
#     hp  \
# 0   66
# 1  141
# 2   85
#
#    Type  \
# 0  Used
# 1  Used
# 2  Used
#
#   Previous Owners  \
# 0               2
# 1             NaN
# 2               1
#
#                  Next Inspection  \
# ...

# %%
df.Temp_Rating.fillna(df.Farheit, inplace=True)
del df['Farheit']
df.columns = 'File heat Observations'.split()

# %%
# df2.loc[df2["Consumption comb"]=="\n"]["Consumption comb"] = df2.loc[df2["Consumption comb"]=="\n"]["Consumption city"]

# %%
df.drop(['education-num'], axis=1, inplace=True)

# %%
df[(df["hours-per-week"] == 99)].sample(10)

# %%
df.relationship.replace(["Not-in-family","Other-relative"],"Unmarried",inplace=True)

# %%
data.ingredients.apply(pd.Series) \
    .merge(data, right_index = True, left_index = True) \
    .drop(["ingredients"], axis = 1) \
    .melt(id_vars = ['cuisine', 'id'], value_name = "ingredient") \
    .drop("variable", axis = 1) \
    .dropna()

# %% [markdown]
# data = [['Green', 'Rectangle\r\nTriangle\r\nOctangle', 10], ['Blue', 'Rectangle\r\nTriangle', 15]]
# df = pd.DataFrame(data, columns = ['Color', 'Shape', 'Price'])
# new_df = pd.DataFrame(columns = ['Color', 'Shape', 'Price'])
#
# for index, row in df.iterrows():
#     split = row['Shape'].split('\r\n')
#     for shape in split:
#         new_df = new_df.append(pd.DataFrame({'Color':[row['Color']], 'Shape':[shape], 'Price':[row['Price']]}))
#
# new_df = new_df.reset_index(drop=True)
# print(new_df)

# %%
df = df.apply(lambda x: x.str.strip() if isinstance(x, str) else x).replace('', np.nan)

# %%
df['CO2 Emission'].value_counts().head(100)   # kalabilir
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n120 g CO2/km (comb)\n]    740
# [[], [], []]                 628
# [\n99 g CO2/km (comb)\n]     545
# [\n97 g CO2/km (comb)\n]     537
# [\n104 g CO2/km (comb)\n]    501
#                             ...
# [\n0 g CO2/km (comb)\n]        2
# [\n191 g CO2/km (comb)\n]      2
# [\n167 g CO2/km (comb)\n]      2
# [\n84 g CO2/km (comb)\n]       2
# [\n162 g CO2/km (comb)\n]      2
# ...

# %%
df['CO2 Emission']= [item[0] if type(item)==list else item for item in df['CO2 Emission']]

df['CO2 Emission'].str.extract("(\d+)").value_counts().head(20)
# Out:
# 120    740
# 99     545
# 97     537
# 104    501
# 102    477
# 103    445
# 114    382
# 124    372
# 107    362
# 108    362
# 119    361
# 106    349
# 128    329
# 126    282
# 85     275
# 118    270
# 110    266
# 127    257
# 117    254
# 111    237
# dtype: int64

# %%
df['CO2_Emission'] = df['CO2 Emission'].str.extract("(\d+)")

# %%
df['CO2 Emission'].apply(pd.Series)[0].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# \n120 g CO2/km (comb)\n       740
# []                            628
# \n99 g CO2/km (comb)\n        545
# \n97 g CO2/km (comb)\n        537
# \n104 g CO2/km (comb)\n       501
#                              ...
# \n12,324 g CO2/km (comb)\n      1
# \n51 g CO2/km (comb)\n          1
# \n184 g CO2/km (comb)\n         1
# \n181 g CO2/km (comb)\n         1
# \n171 g CO2/km (comb)\n         1
# ...

# %%
df = pd.read_json('scout_car.json', lines=True, orient='records', convert_axes=True, dtype=True,convert_dates=True)

# %%
df['Emission Class'].value_counts().head(50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nEuro 6\n]          10139
# [\nEuro 6d-TEMP\n]     1845
# [[], [], []]            607
# [\nEuro 6c\n]           127
# [\nEuro 5\n]             78
# [\nEuro 6d\n]            62
# [\nEuro 4\n]             40
# Name: Emission Class, dtype: int64

# %%
df['Emission Class']= [item[0] if type(item)==list else item for item in df['Emission Class']]

df['Emission Class'].str.extract("(\w.+)").value_counts().head()
# Out:
# Euro 6          10139
# Euro 6d-TEMP     1845
# Euro 6c           127
# Euro 5             78
# Euro 6d            62
# dtype: int64

# %%
df['Emission_Class'] = df['Emission Class'].str.extract("(\w.+)")

# %%
df['\nComfort & Convenience\n']
# Out:
# 0        Air conditioning,Armrest,A...
# 1        Air conditioning,Automatic...
# 2        Air conditioning,Cruise co...
# 3        Air suspension,Armrest,Aux...
# 4        Air conditioning,Armrest,A...
#                      ...
# 15914    Air conditioning,Automatic...
# 15915    Air conditioning,Automatic...
# 15916    Air conditioning,Armrest,A...
# 15917    Air conditioning,Automatic...
# 15918    Air conditioning,Automatic...
# Name: \nComfort & Convenience\n, Length: 15919, dtype: object

# %%
df['\nComfort & Convenience\n'].value_counts(dropna=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# NaN                                                                                                                                                                                                                                                                                                                                                                     920
# ...

# %%
df['\nComfort & Convenience\n']= [",".join(item) if type(item)==list else item for item in df['\nComfort & Convenience\n']]

df['Comfort'] = df['\nComfort & Convenience\n'].str.extract("(\w.+)")  #.isna().value_counts().head()

# %%
dfair = df['\nComfort & Convenience\n'].apply(pd.Series)

# %%
dfair
# Out:
#                      0   \
# 0      Air conditioning
# 1      Air conditioning
# 2      Air conditioning
# 3        Air suspension
# 4      Air conditioning
# ...                 ...
# 15914  Air conditioning
# 15915  Air conditioning
# 15916  Air conditioning
# 15917  Air conditioning
# 15918  Air conditioning
#
#                               1   \
# 0                        Armrest
# 1      Automatic climate control
# 2                 Cruise control
# 3                        Armrest
# 4                        Armrest
# ...                          ...
# 15914  Automatic climate control
# 15915  Automatic climate control
# 15916                    Armrest
# 15917  Automatic climate control
# 15918  Automatic climate control
#
#                               2   \
# 0      Automatic climate control
# 1                    Hill Holder
# 2        Electrical side mirrors
# 3              Auxiliary heating
# 4      Automatic climate control
# ...                          ...
# ...

# %%
dfair[0].value_counts()
# Out:
# Air conditioning                  14315
# Cruise control                      343
# Armrest                              98
# Electrical side mirrors              89
# Navigation system                    46
# Multi-function steering wheel        24
# Power windows                        23
# Leather steering wheel               15
# Sunroof                               8
# Park Distance Control                 8
# Hill Holder                           8
# Electrically heated windshield        5
# Light sensor                          4
# Air suspension                        3
# Electrically adjustable seats         3
# Auxiliary heating                     2
# Heated steering wheel                 2
# Panorama roof                         1
# Rain sensor                           1
# Heads-up display                      1
# Name: 0, dtype: int64

# %%
dfair[1].value_counts()
# Out:
# Armrest                               7074
# Automatic climate control             2931
# Cruise control                        2447
# Electrical side mirrors               1319
# Power windows                          343
# Multi-function steering wheel          154
# Leather steering wheel                  91
# Seat ventilation                        90
# Hill Holder                             78
# Air suspension                          59
# Navigation system                       37
# Park Distance Control                   36
# Electrically adjustable seats           26
# Electrically heated windshield          26
# Light sensor                            16
# Lumbar support                          13
# Start-stop system                       11
# Auxiliary heating                       11
# Keyless central door lock               10
# Panorama roof                            7
# Rain sensor                              6
# Split rear seats                         5
# ...

# %%
dfair[2].value_counts()
# Out:
# Automatic climate control              5768
# Cruise control                         3298
# Electrical side mirrors                2143
# Hill Holder                             788
# Power windows                           504
# Multi-function steering wheel           363
# Electrically heated windshield          314
# Leather steering wheel                  307
# Electrically adjustable seats           149
# Light sensor                            137
# Navigation system                       134
# Split rear seats                        128
# Seat ventilation                         90
# Park Distance Control                    66
# Auxiliary heating                        57
# Armrest                                  53
# Start-stop system                        40
# Heated steering wheel                    35
# Keyless central door lock                33
# Parking assist system sensors rear       13
# Lumbar support                           13
# ...

# %%
dfair[3].value_counts()
# Out:
# Cruise control                         4597
# Electrical side mirrors                3209
# Multi-function steering wheel           970
# Hill Holder                             901
# Leather steering wheel                  735
# Power windows                           685
# Electrically adjustable seats           595
# Heated steering wheel                   360
# Navigation system                       337
# Light sensor                            282
# Park Distance Control                   246
# Auxiliary heating                       187
# Electrically heated windshield          179
# Split rear seats                        158
# Keyless central door lock               135
# Start-stop system                       111
# Automatic climate control                48
# Parking assist system sensors rear       32
# Lumbar support                           32
# Heads-up display                         25
# Rain sensor                              24
# ...

# %%
dfair[4].value_counts()
# Out:
# Electrical side mirrors                3732
# Leather steering wheel                 1485
# Hill Holder                            1328
# Electrically adjustable seats          1012
# Multi-function steering wheel           887
# Power windows                           819
# Heated steering wheel                   726
# Light sensor                            649
# Park Distance Control                   526
# Navigation system                       437
# Keyless central door lock               355
# Electrically heated windshield          229
# Start-stop system                       196
# Cruise control                          189
# Parking assist system sensors rear      122
# Electric tailgate                       112
# Heads-up display                         82
# Lumbar support                           56
# Rain sensor                              55
# Split rear seats                         50
# Parking assist system camera             45
# ...

# %%
dfair[5].value_counts()
# Out:
# Leather steering wheel                 2215
# Hill Holder                            1656
# Multi-function steering wheel          1257
# Electrical side mirrors                1146
# Light sensor                           1042
# Heated steering wheel                   922
# Power windows                           793
# Park Distance Control                   587
# Navigation system                       564
# Keyless central door lock               500
# Electric tailgate                       344
# Parking assist system sensors rear      271
# Start-stop system                       261
# Electrically heated windshield          161
# Heads-up display                        151
# Rain sensor                             126
# Lumbar support                          104
# Split rear seats                         81
# Electrically adjustable seats            76
# Parking assist system sensors front      76
# Seat heating                             49
# ...

# %%
dfair[6].value_counts()
# Out:
# Leather steering wheel                 1961
# Light sensor                           1593
# Multi-function steering wheel          1398
# Hill Holder                            1042
# Park Distance Control                   901
# Power windows                           787
# Navigation system                       721
# Heated steering wheel                   511
# Keyless central door lock               415
# Parking assist system sensors rear      399
# Electric tailgate                       380
# Lumbar support                          315
# Start-stop system                       304
# Electrical side mirrors                 219
# Parking assist system sensors front     161
# Rain sensor                             150
# Heads-up display                        131
# Split rear seats                        103
# Seat heating                             66
# Parking assist system camera             64
# Tinted windows                           42
# ...

# %%
df["Air_conditioning"] = np.where(df['Comfort'].str.contains("Air conditioning"), 1, 0)  

df["Air_conditioning"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    1
# Name: Air_conditioning, Length: 15919, dtype: int32

# %%
df.head(3)
# Out:
#                              url  \
# 0  https://www.autoscout24.co...
# 1  https://www.autoscout24.co...
# 2  https://www.autoscout24.co...
#
#   make_model  \
# 0    Audi A1
# 1    Audi A1
# 2    Audi A1
#
#                short_description  \
# 0  Sportback 1.4 TDI S-tronic...
# 1                 1.8 TFSI sport
# 2  Sportback 1.6 TDI S tronic...
#
#   body_type  \
# 0    Sedans
# 1    Sedans
# 2    Sedans
#
#    price  \
# 0  15770
# 1  14500
# 2  14640
#
#                 vat  \
# 0    VAT deductible
# 1  Price negotiable
# 2    VAT deductible
#
#       km  \
# 0  56013
# 1  80000
# 2  83450
#
#   registration  \
# 0         2016
# 1         2017
# 2         2016
#
#   prev_owner  \
# 0          2
# 1       None
# 2          1
#
#    kW  \
# 0 NaN
# 1 NaN
# 2 NaN
#
#     hp  \
# 0   66
# 1  141
# 2   85
#
#    Type  \
# 0  Used
# 1  Used
# 2  Used
#
#   Previous Owners  \
# 0               2
# 1             NaN
# 2               1
#
#                  Next Inspection  \
# ...

# %%
df["Cruise_control"] = np.where(df['Comfort'].str.contains("Cruise control"), 1, 0)  

df["Cruise_control"]
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    1
# Name: Cruise_control, Length: 15919, dtype: int32

# %%
df["Automatic_climate_control"] = np.where(df['Comfort'].str.contains("Automatic climate control"), 1, 0)  

df["Automatic_climate_control"]
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    1
# Name: Automatic_climate_control, Length: 15919, dtype: int32

# %%
df["Armrest"] = np.where(df['Comfort'].str.contains("Armrest"), 1, 0)  

df["Armrest"]
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 15914    0
# 15915    0
# 15916    1
# 15917    0
# 15918    0
# Name: Armrest, Length: 15919, dtype: int32

# %%
df["Electrical_side_mirrors"] = np.where(df['Comfort'].str.contains("Electrical side mirrors"), 1, 0)  

df["Electrical_side_mirrors"]
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    1
# Name: Electrical_side_mirrors, Length: 15919, dtype: int32

# %%
df["Navigation_system"] = np.where(df['Comfort'].str.contains("Navigation system"), 1, 0)  

df["Navigation_system"]
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    0
# 15918    1
# Name: Navigation_system, Length: 15919, dtype: int32

# %%
df["Multifunction_steering_wheel"] = np.where(df['Comfort'].str.contains("Multi-function steering wheel"), 1, 0)  

df["Multifunction_steering_wheel"]
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    0
# 15916    1
# 15917    0
# 15918    0
# Name: Multifunction_steering_wheel, Length: 15919, dtype: int32

# %%
df["Power_windows"] = np.where(df['Comfort'].str.contains("Power windows"), 1, 0)  

df["Power_windows"]
# Out:
# 1    14834
# 0     1085
# Name: Power_windows, dtype: int64

# %%
df["Sunroof"] = np.where(df['Comfort'].str.contains("Sunroof"), 1, 0)  

df["Sunroof"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15914    0
# 15915    1
# 15916    1
# 15917    0
# 15918    0
# Name: Sunroof, Length: 15919, dtype: int32

# %%
df["Leather_steering_wheel "] = np.where(df['Comfort'].str.contains("Leather steering wheel"), 1, 0)  

df["Leather_steering_wheel "]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    1
# Name: Leather_steering_wheel , Length: 15919, dtype: int32

# %%
df["Park_Distance_Control"] = np.where(df['Comfort'].str.contains("Park Distance Control"), 1, 0)  

df["Park_Distance_Control"]
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    0
# Name: Park_Distance_Control, Length: 15919, dtype: int32

# %%
df["Hill_Holder"] = np.where(df['Comfort'].str.contains("Hill Holder"), 1, 0)  

df["Hill_Holder"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    0
# 15917    0
# 15918    1
# Name: Hill_Holder, Length: 15919, dtype: int32

# %%
Air suspension                        3

Auxiliary heating                     2
Heated steering wheel                 2
Panorama roof                         1
Rain sensor                           1
Heads-up display

# %%
df["Light_sensor"] = np.where(df['Comfort'].str.contains("Light sensor"), 1, 0)  

df["Light_sensor"]
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    0
# Name: Light_sensor, Length: 15919, dtype: int32

# %%
df["Electrically_heated_windshield"] = np.where(df['Comfort'].str.contains("Electrically heated windshield"), 1, 0)  

df["Electrically_heated_windshield"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15914    0
# 15915    1
# 15916    1
# 15917    0
# 15918    0
# Name: Electrically_heated_windshield, Length: 15919, dtype: int32

# %%
df["Electrically_adjustable_seats"] = np.where(df['Comfort'].str.contains("Electrically adjustable seats"), 1, 0)  

df["Electrically_adjustable_seats"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15914    1
# 15915    0
# 15916    0
# 15917    1
# 15918    1
# Name: Electrically_adjustable_seats, Length: 15919, dtype: int32

# %%
df["Electrical_side_mirrors"] = np.where(df['Comfort'].str.contains("Electrical side mirrors"), 1, 0)  

df["Electrical_side_mirrors"]
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    1
# Name: Electrical_side_mirrors, Length: 15919, dtype: int32

# %%
df["Seat_ventilation"] = np.where(df['Comfort'].str.contains("Seat ventilation"), 1, 0)  

df["Seat_ventilation"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15914    0
# 15915    0
# 15916    1
# 15917    0
# 15918    0
# Name: Seat_ventilation, Length: 15919, dtype: int32

# %%
df["Light_sensor"] = np.where(df['Comfort'].str.contains("Light sensor"), 1, 0)  

df["Light_sensor"]
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    0
# Name: Light_sensor, Length: 15919, dtype: int32

# %%
df["Rain_sensor"] = np.where(df['Comfort'].str.contains("Rain sensor"), 1, 0)  

df["Rain_sensor"]
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    0
# 15918    0
# Name: Rain_sensor, Length: 15919, dtype: int32

# %%
df["Split_rear_seats"] = np.where(df['Comfort'].str.contains("Split rear seats"), 1, 0)  

df["Split_rear_seats"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 15914    1
# 15915    0
# 15916    0
# 15917    0
# 15918    0
# Name: Split_rear_seats, Length: 15919, dtype: int32

# %%
df["Electric_tailgate"] = np.where(df['Comfort'].str.contains("Electric tailgate"), 1, 0)  

df["Electric_tailgate"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15914    0
# 15915    1
# 15916    1
# 15917    0
# 15918    1
# Name: Electric_tailgate, Length: 15919, dtype: int32

# %%
df["Keyless_central_door_lock"] = np.where(df['Comfort'].str.contains("Keyless central door lock"), 1, 0)  

df["Keyless_central_door_lock"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15914    1
# 15915    1
# 15916    0
# 15917    0
# 15918    0
# Name: Keyless_central_door_lock, Length: 15919, dtype: int32

# %%
df["Parking_assist_system_sensors_front"] = np.where(df['Comfort'].str.contains("Parking assist system sensors front"), 1, 0)  

df["Parking_assist_system_sensors_front"]
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    0
# 15918    0
# Name: Parking_assist_system_sensors_front, Length: 15919, dtype: int32

# %%
Lumbar support                          13
Start-stop system                       11
Auxiliary heating                       11
Keyless central door lock               10
Panorama roof                            7

Split rear seats                         5
Electric tailgate                        3
Sunroof                                  3
Heads-up display                         2
Heated steering wheel                    2
Leather seats                            2
Parking assist system sensors rear       1
Massage seats                            1
Tinted windows                           1
Seat heating                             1

# %%
Split rear seats                        128
Seat ventilation                         90
Park Distance Control                    66
Auxiliary heating                        57
Armrest                                  53
Start-stop system                        40
Heated steering wheel                    35
Keyless central door lock                33
Parking assist system sensors rear       13
Lumbar support                           13
Rain sensor                              12
Electric tailgate                        11
Parking assist system camera             11
Panorama roof                             9
Seat heating                              7
Heads-up display                          5
Parking assist system sensors front       4
Tinted windows                            3
Sunroof                                   2
Leather seats                             1

# %%
df['\nEntertainment & Media\n'].value_counts(dropna=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# NaN                                                                                 1374
# [Bluetooth, Hands-free equipment, On-board computer, Radio, USB]                    1282
# [Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, USB]                982
# [Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, USB]     783
# ...

# %%
df['\nEntertainment & Media\n']= [",".join(item) if type(item)==list else item for item in df['\nEntertainment & Media\n']]

df["Entertainment"] = df['\nEntertainment & Media\n'].str.extract("(\w.+)")

# %%
dfent = df['\nEntertainment & Media\n'].apply(pd.Series)

dfent.head(5)
# Out:
#            0  \
# 0  Bluetooth
# 1  Bluetooth
# 2        MP3
# 3  Bluetooth
# 4  Bluetooth
#
#                       1  \
# 0  Hands-free equipment
# 1  Hands-free equipment
# 2     On-board computer
# 3             CD player
# 4             CD player
#
#                       2  \
# 0     On-board computer
# 1     On-board computer
# 2                   NaN
# 3  Hands-free equipment
# 4  Hands-free equipment
#
#        3  \
# 0  Radio
# 1  Radio
# 2    NaN
# 3    MP3
# 4    MP3
#
#                    4  \
# 0                NaN
# 1       Sound system
# 2                NaN
# 3  On-board computer
# 4  On-board computer
#
#        5  \
# 0    NaN
# 1    NaN
# 2    NaN
# 3  Radio
# 4  Radio
#
#               6  \
# 0           NaN
# 1           NaN
# 2           NaN
# 3  Sound system
# 4           USB
#
#      7  \
# 0  NaN
# 1  NaN
# 2  NaN
# 3  USB
# 4  NaN
#
#      8  \
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
#      9
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
df["Bluetooth"] = np.where(df["Entertainment"].str.contains("Bluetooth"), 1, 0)  

df["Bluetooth"]
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    0
# Name: Bluetooth, Length: 15919, dtype: int32

# %%
df["Handsfree_equipment"] = np.where(df["Entertainment"].str.contains("Hands-free equipment"), 1, 0)  

df["Handsfree_equipment"]
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    0
# 15918    0
# Name: Handsfree_equipment, Length: 15919, dtype: int32

# %%
df["Onboard_computer"] = np.where(df["Entertainment"].str.contains("On-board computer"), 1, 0)  

df["Onboard_computer"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    0
# 15916    1
# 15917    0
# 15918    0
# Name: Onboard_computer, Length: 15919, dtype: int32

# %%
df["Radio"] = np.where(df["Entertainment"].str.contains("Radio"), 1, 0)  

df["Radio"]
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    0
# Name: Radio, Length: 15919, dtype: int32

# %%
df["CD_player"] = np.where(df["Entertainment"].str.contains("CD player"), 1, 0)  

df["CD_player"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 15914    0
# 15915    0
# 15916    0
# 15917    0
# 15918    0
# Name: CD_player, Length: 15919, dtype: int32

# %%
df["Television"] = np.where(df["Entertainment"].str.contains("Television"), 1, 0)  

df["Television"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15914    0
# 15915    0
# 15916    0
# 15917    0
# 15918    0
# Name: Television, Length: 15919, dtype: int32

# %%
df["Digital_radio"] = np.where(df["Entertainment"].str.contains("Digital radio"), 1, 0)  

df["Digital_radio"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15914    1
# 15915    1
# 15916    0
# 15917    1
# 15918    0
# Name: Digital_radio, Length: 15919, dtype: int32

# %%
df["MP3"] = np.where(df["Entertainment"].str.contains("MP3"), 1, 0)  

df["MP3"]
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 15914    0
# 15915    0
# 15916    0
# 15917    0
# 15918    0
# Name: MP3, Length: 15919, dtype: int32

# %%
df["Sound_system"] = np.where(df["Entertainment"].str.contains("Sound system"), 1, 0)  

df["Sound_system"]
# Out:
# 0        0
# 1        1
# 2        0
# 3        1
# 4        0
#         ..
# 15914    0
# 15915    0
# 15916    0
# 15917    0
# 15918    0
# Name: Sound_system, Length: 15919, dtype: int32

# %%
df["USB"] = np.where(df["Entertainment"].str.contains("USB"), 1, 0)  

df["USB"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    0
# 15917    1
# 15918    1
# Name: USB, Length: 15919, dtype: int32

# %%
pd.get_dummies(dfent)
# Out:
#        0_Bluetooth  \
# 0                1
# 1                1
# 2                0
# 3                1
# 4                1
# ...            ...
# 15914            1
# 15915            1
# 15916            1
# 15917            1
# 15918            0
#
#        0_CD player  \
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 15914            0
# 15915            0
# 15916            0
# 15917            0
# 15918            0
#
#        0_Digital radio  \
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 15914                0
# 15915                0
# 15916                0
# 15917                0
# 15918                0
#
#        0_Hands-free equipment  \
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# ...

# %%
dfent[0].value_counts()
# Out:
# Bluetooth               11650
# On-board computer        1080
# CD player                 655
# Radio                     533
# Hands-free equipment      248
# Digital radio             164
# MP3                       142
# USB                        46
# Sound system               27
# Name: 0, dtype: int64

# %%
dfent[1].value_counts()
# Out:
# Hands-free equipment    4572
# CD player               4136
# Digital radio           1425
# On-board computer       1392
# Radio                   1065
# MP3                      559
# USB                      156
# Sound system              64
# Name: 1, dtype: int64

# %%
dfent[2].value_counts()
# Out:
# Hands-free equipment    3916
# On-board computer       3120
# MP3                     2347
# Radio                   1480
# Digital radio            640
# USB                      245
# Sound system              67
# Name: 2, dtype: int64

# %%
dfent[3].value_counts()
# Out:
# On-board computer       3579
# Radio                   2945
# MP3                     2380
# USB                      718
# Hands-free equipment     569
# Sound system             200
# Name: 3, dtype: int64

# %%
dfent[4].value_counts()
# Out:
# Radio                3305
# On-board computer    2358
# USB                  2154
# MP3                   425
# Sound system          414
# Television              2
# Name: 4, dtype: int64

# %%
dfent[5].value_counts()
# Out:
# USB                  2358
# Radio                2274
# Sound system          593
# On-board computer     409
# Television              7
# Name: 5, dtype: int64

# %%
dfent[6].value_counts()
# Out:
# USB             1574
# Sound system     670
# Radio            387
# Television        10
# Name: 6, dtype: int64

# %%
dfent[7].value_counts()
# Out:
# USB             716
# Sound system    205
# Television        6
# Name: 7, dtype: int64

# %%
dfent[8].value_counts()
# Out:
# USB           181
# Television     10
# Name: 8, dtype: int64

# %%
dfent[9].value_counts()
# Out:
# USB    10
# Name: 9, dtype: int64

# %%
df['\nExtras\n'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [Alloy wheels]                                       3245
# [Alloy wheels, Touch screen]                          697
# [Alloy wheels, Voice Control]                         577
# [Alloy wheels, Touch screen, Voice Control]           541
# [Alloy wheels, Roof rack]                             385
# [Alloy wheels, Sport seats]                           380
# [Roof rack]                                           337
# ...

# %%
df['\nExtras\n']= [",".join(item) if type(item)==list else item for item in df['\nExtras\n']]

df['Extras'] =  df['\nExtras\n'].str.extract("(\w.+)")    #.isna().value_counts().head()

df['Extras']
# Out:
# 0        Alloy wheels,Catalytic Con...
# 1        Alloy wheels,Sport seats,S...
# 2           Alloy wheels,Voice Control
# 3        Alloy wheels,Sport seats,V...
# 4        Alloy wheels,Sport package...
#                      ...
# 15914        Alloy wheels,Touch screen
# 15915    Alloy wheels,Touch screen,...
# 15916                     Alloy wheels
# 15917        Alloy wheels,Touch screen
# 15918        Alloy wheels,Touch screen
# Name: Extras, Length: 15919, dtype: object

# %%
dfex = df['\nExtras\n'].apply(pd.Series)

# %%
df["Alloy_wheels"] = np.where(df['Extras'].str.contains("Alloy wheels"), 1, 0)  

df["Alloy_wheels"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    1
# Name: Alloy_wheels, Length: 15919, dtype: int32

# %%
df["Touch_screen"] = np.where(df['Extras'].str.contains("Touch screen"), 1, 0)  

df["Touch_screen"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15914    1
# 15915    1
# 15916    0
# 15917    1
# 15918    1
# Name: Touch_screen, Length: 15919, dtype: int32

# %%
df["Voice_Control"] = np.where(df['Extras'].str.contains("Voice Control"), 1, 0)  

df["Voice_Control"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 15914    0
# 15915    1
# 15916    0
# 15917    0
# 15918    0
# Name: Voice_Control, Length: 15919, dtype: int32

# %%
df["Winter_tyres"] = np.where(df['Extras'].str.contains("Winter tyres"), 1, 0)  

df["Winter_tyres"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15914    0
# 15915    0
# 15916    0
# 15917    0
# 15918    0
# Name: Winter_tyres, Length: 15919, dtype: int32

# %%
df["Roof_rack"] = np.where(df['Extras'].str.contains("Roof rack"), 1, 0)  

df["Roof_rack"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15914    0
# 15915    0
# 15916    0
# 15917    0
# 15918    0
# Name: Roof_rack, Length: 15919, dtype: int32

# %%
df["Sport_package"] = np.where(df['Extras'].str.contains("Sport package"), 1, 0)  

df["Sport_package"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 15914    0
# 15915    0
# 15916    0
# 15917    0
# 15918    0
# Name: Sport_package, Length: 15919, dtype: int32

# %%
df["Catalytic_Converter"] = np.where(df['Extras'].str.contains("Catalytic Converter"), 1, 0)  

df["Catalytic_Converter"]
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15914    0
# 15915    0
# 15916    0
# 15917    0
# 15918    0
# Name: Catalytic_Converter, Length: 15919, dtype: int32

# %%
df["Ski_bag"] = np.where(df['Extras'].str.contains("Ski bag"), 1, 0)  

df["Ski_bag"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15914    0
# 15915    0
# 15916    0
# 15917    0
# 15918    0
# Name: Ski_bag, Length: 15919, dtype: int32

# %%
df["Sport_suspension"] = np.where(df['Extras'].str.contains("Sport suspension"), 1, 0)  

df["Sport_suspension"]
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 15914    0
# 15915    0
# 15916    0
# 15917    0
# 15918    0
# Name: Sport_suspension, Length: 15919, dtype: int32

# %%
df["Trailer_hitch"] = np.where(df['Extras'].str.contains("Trailer hitch"), 1, 0)  

df["Trailer_hitch"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15914    0
# 15915    0
# 15916    0
# 15917    0
# 15918    0
# Name: Trailer_hitch, Length: 15919, dtype: int32

# %%
df["Shift_paddles"] = np.where(df['Extras'].str.contains("Shift paddles"), 1, 0)  

df["Shift_paddles"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15914    0
# 15915    0
# 15916    0
# 15917    0
# 15918    0
# Name: Shift_paddles, Length: 15919, dtype: int32

# %%
dfex[0].value_counts(ascending=True)
# Out:
# Alloy wheels,Roof rack,Sport suspension,Touch screen,Trailer hitch,Voice Control       1
# Alloy wheels,Catalytic Converter,Sport package,Trailer hitch                           1
# Alloy wheels,Sport package,Trailer hitch,Winter tyres                                  1
# Roof rack,Sport package,Touch screen,Voice Control                                     1
# Alloy wheels,Shift paddles,Sport package,Sport suspension,Winter tyres                 1
#                                                                                     ...
# Alloy wheels,Roof rack                                                               385
# Alloy wheels,Touch screen,Voice Control                                              541
# Alloy wheels,Voice Control                                                           577
# Alloy wheels,Touch screen                                                            697
# Alloy wheels                                                                        3245
# ...

# %%
df['\nSafety & Security\n'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [ABS, Central door lock, Daytime running lights, Driver-side airbag, Electronic stability control, Fog lights, Immobilizer, Isofix, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control]                                538
# ...

# %%
df['\nSafety & Security\n']= [",".join(item) if type(item)==list else item for item in df['\nSafety & Security\n']]

df['Safety_Security'] = df['\nSafety & Security\n'].str.extract("(\w.+)")  #.isna().value_counts().head()

# %%
df['\nSafety & Security\n'].apply(pd.Series)
# Out:
#                                    0
# 0      ABS,Central door lock,Dayt...
# 1      ABS,Central door lock,Cent...
# 2      ABS,Central door lock,Dayt...
# 3      ABS,Alarm system,Central d...
# 4      ABS,Central door lock,Driv...
# ...                              ...
# 15914  ABS,Central door lock,Cent...
# 15915  ABS,Adaptive Cruise Contro...
# 15916  ABS,Adaptive Cruise Contro...
# 15917  ABS,Blind spot monitor,Dri...
# 15918  ABS,Blind spot monitor,Day...
#
# [15919 rows x 1 columns]

# %%
df["ABS"] = np.where(df['Safety_Security'].str.contains("ABS"), 1, 0)  

df["ABS"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    1
# Name: ABS, Length: 15919, dtype: int32

# %%
df["Central_door_lock"] = np.where(df['Safety_Security'].str.contains("Central door lock"), 1, 0)  

df["Central_door_lock"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    0
# 15918    0
# Name: Central_door_lock, Length: 15919, dtype: int32

# %%
df["Daytime_running_lights"] = np.where(df['Safety_Security'].str.contains("Daytime running lights"), 1, 0)  

df["Daytime_running_lights"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        0
# 4        0
#         ..
# 15914    0
# 15915    1
# 15916    1
# 15917    0
# 15918    1
# Name: Daytime_running_lights, Length: 15919, dtype: int32

# %%
df["Driverside_airbag"] = np.where(df['Safety_Security'].str.contains("Driver-side airbag"), 1, 0)  

df["Driverside_airbag"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    1
# Name: Driverside_airbag, Length: 15919, dtype: int32

# %%
df["Fog_lights"] = np.where(df['Safety_Security'].str.contains("Fog lights"), 1, 0)  

df["Fog_lights"]
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 15914    0
# 15915    0
# 15916    0
# 15917    0
# 15918    0
# Name: Fog_lights, Length: 15919, dtype: int32

# %%
df["Xenon_headlights"] = np.where(df['Safety_Security'].str.contains("Xenon headlights"), 1, 0)  

df["Xenon_headlights"]
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 15914    0
# 15915    0
# 15916    0
# 15917    0
# 15918    0
# Name: Xenon_headlights, Length: 15919, dtype: int32

# %%
df["Immobilizer"] = np.where(df['Safety_Security'].str.contains("Immobilizer"), 1, 0)  

df["Immobilizer"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    0
# 15918    1
# Name: Immobilizer, Length: 15919, dtype: int32

# %%
df["Isofix"] = np.where(df['Safety_Security'].str.contains("Isofix"), 1, 0)  

df["Isofix"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    1
# Name: Isofix, Length: 15919, dtype: int32

# %%
df["Passengerside_airbag"] = np.where(df['Safety_Security'].str.contains("Passenger-side airbag"), 1, 0)  

df["Passengerside_airbag"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    1
# Name: Passengerside_airbag, Length: 15919, dtype: int32

# %%
df["Power_steering"] = np.where(df['Safety_Security'].str.contains("Power steering"), 1, 0)  

df["Power_steering"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    1
# Name: Power_steering, Length: 15919, dtype: int32

# %%
df["Side_airbag"] = np.where(df['Safety_Security'].str.contains("Side airbag"), 1, 0)  

df["Side_airbag"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    1
# Name: Side_airbag, Length: 15919, dtype: int32

# %%
df["Tire_pressure_monitoring_system"] = np.where(df['Safety_Security'].str.contains("Tire pressure monitoring system"), 1, 0)  

df["Tire_pressure_monitoring_system"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    0
# 15917    1
# 15918    1
# Name: Tire_pressure_monitoring_system, Length: 15919, dtype: int32

# %%
df["Traction_control"] = np.where(df['Safety_Security'].str.contains("Traction control"), 1, 0)  

df["Traction_control"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    0
# 15918    0
# Name: Traction_control, Length: 15919, dtype: int32

# %%
myseries.to_frame(name='my_column_name')

# %%
df["Traction control"] = df["Traction control"].to_frame(name="Traction control")

# %%
df.head(3)
# Out:
#                              url  \
# 0  https://www.autoscout24.co...
# 1  https://www.autoscout24.co...
# 2  https://www.autoscout24.co...
#
#   make_model  \
# 0    Audi A1
# 1    Audi A1
# 2    Audi A1
#
#                short_description  \
# 0  Sportback 1.4 TDI S-tronic...
# 1                 1.8 TFSI sport
# 2  Sportback 1.6 TDI S tronic...
#
#   body_type  \
# 0    Sedans
# 1    Sedans
# 2    Sedans
#
#    price  \
# 0  15770
# 1  14500
# 2  14640
#
#                 vat  \
# 0    VAT deductible
# 1  Price negotiable
# 2    VAT deductible
#
#       km  \
# 0  56013
# 1  80000
# 2  83450
#
#   registration  \
# 0         2016
# 1         2017
# 2         2016
#
#   prev_owner  \
# 0          2
# 1       None
# 2          1
#
#    kW  \
# 0 NaN
# 1 NaN
# 2 NaN
#
#     hp  \
# 0   66
# 1  141
# 2   85
#
#    Type  \
# 0  Used
# 1  Used
# 2  Used
#
#   Previous Owners  \
# 0               2
# 1             NaN
# 2               1
#
#                  Next Inspection  \
# ...

# %%
df['description'].value_counts().head(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ...

# %%
df['description']= [",".join(item) if type(item)==list else item for item in df['description']]

df['description'].str.extract("(\w.+)").isna().value_counts().head()

#df['description'].str.replace(r'[\s]', ' ', regex=True).replace({'':0}, inplace=False).isna().value_counts()
# Out:
# False    15248
# True       671
# dtype: int64

# %%
df['description'].apply(pd.Series)
# Out:
#                                  0    \
# 0                                 \n
# 1      \nLangstreckenfahrzeug dah...
# 2                                 \n
# 3                        \nAudi A1:
# 4                                 \n
# ...                              ...
# 15914  \nVettura visionabile nell...
# 15915  \nDach: Panorama-Glas-Schi...
# 15916                             \n
# 15917                \nDEK:[2691331]
# 15918                             \n
#
#                                  1    \
# 0                        Sicherheit:
# 1         Bremsen neu bei 62000 km.
# 2          Fahrzeug-Nummer: AM-95365
# 3                     - 1e eigenaar
# 4              Technik & Sicherheit:
# ...                              ...
# 15914  Prezzo escluse spese immat...
# 15915                            NaN
# 15916                      Getriebe:
# 15917  Renault Espace Blue dCi 20...
# 15918            Sicherheit Airbags:
#
#                                  2    \
# 0
# ...

# %%
df = pd.read_json('scout_car.json', lines=True, orient='records', convert_axes=True, dtype=True,convert_dates=True)

# %%
df['Emission Label'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n4 (Green)\n]         3553
# [\n1 (No sticker)\n]     381
# [[], [], []]              40
# [\n5 (Blue)\n]             8
# [\n3 (Yellow)\n]           2
# [\n2 (Red)\n]              1
# Name: Emission Label, dtype: int64

# %%
df['Emission Label']= [item[0] if type(item)==list else item for item in df['Emission Label']]

df['Emission Label'].str.extract("(\S+)").isna().value_counts().head(10)
# Out:
# True     11974
# False     3945
# dtype: int64

# %%
df['Emission_Label'] = df['Emission Label'].str.extract("(\S+)")

# %%
df['Gears'].value_counts().head(10)   # Bu vites sayısı.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n6\n]     5822
# [\n5\n]     3239
# [\n7\n]     1908
# [\n8\n]      224
# [\n9\n]        6
# [\n4\n]        2
# [\n3\n]        2
# [\n1\n]        2
# [\n50\n]       1
# [\n2\n]        1
# Name: Gears, dtype: int64

# %%
df['Gears']= [item[0] if type(item)==list else item for item in df['Gears']]

df['Gears'] = df['Gears'].str.extract("(\d+)")  #.isna().value_counts().head(10)

# %%
df = pd.read_json('scout_car.json', lines=True, orient='records', convert_axes=True, dtype=True,convert_dates=True)

# %%
df['Country version'].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nGermany\n]           4502
# [\nItaly\n]             1038
# [\nEuropean Union\n]     507
# [\nNetherlands\n]        464
# [\nSpain\n]              325
# [\nBelgium\n]            314
# [\nAustria\n]            208
# [\nCzech Republic\n]      52
# [\nPoland\n]              49
# [\nFrance\n]              38
# Name: Country version, dtype: int64

# %%
df['Country version']= [item[0] if type(item)==list else item for item in df['Country version']]

df['Country'] = df['Country version'].str.extract("(\w+)")  #.isna().value_counts().head(20)

# %%
df['Electricity consumption'].value_counts().head(10)  # silelim.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n0 kWh/100 km (comb)\n]    137
# Name: Electricity consumption, dtype: int64

# %%
df['Last Service Date'].value_counts().head(10)   #silinebilir.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n02/2019\n, \nEuro 6\n]                 23
# [\n05/2019\n, \nEuro 6\n]                 16
# [\n03/2019\n, \nEuro 6\n]                 15
# [\n01/2018\n, \n118 g CO2/km (comb)\n]    15
# [\n06/2019\n, \nEuro 6\n]                 13
# [\n04/2019\n, \nEuro 6\n]                 13
# [\n01/2019\n, \nEuro 6\n]                 12
# [\n12/2018\n, \nEuro 6\n]                 11
# [\n10/2018\n, \nEuro 6\n]                 10
# ...

# %%
df['Last Service Date'].apply(pd.Series)[1].isna().value_counts()
# Out:
# True     15440
# False      479
# Name: 1, dtype: int64

# %%
df['Last Service Date']= [",".join(item) if type(item)==list else item for item in df['Last Service Date']]

df['Last Service Date'].str.extract('(\d{2}/\d{4})').value_counts()
# Out:
# 05/2019    61
# 02/2019    55
# 01/2019    51
# 06/2019    49
# 04/2019    48
# 03/2019    47
# 12/2018    32
# 10/2018    24
# 07/2018    21
# 06/2018    21
# 05/2018    21
# 01/2018    20
# 09/2018    17
# 11/2018    17
# 04/2018    16
# 08/2018    13
# 03/2018     9
# 06/2017     7
# 02/2018     5
# 01/2017     3
# 05/2017     3
# 12/2017     3
# 02/2017     3
# 10/2017     3
# 11/2017     2
# 06/2016     2
# 04/2016     2
# 07/2017     2
# 09/2017     1
# 08/2019     1
# 09/2019     1
# 07/2019     1
# 10/2019     1
# 04/2017     1
# 11/2019     1
# 05/2016     1
# 03/2016     1
# dtype: int64

# %%
df = pd.read_json('scout_car.json', lines=True, orient='records', convert_axes=True, dtype=True,convert_dates=True)
df.head()

# %%
df['Other Fuel Types'].value_counts().head(10)  #silelim
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [[], [], []]    880
# Name: Other Fuel Types, dtype: int64

# %%
df['Availability'].value_counts().head(10)   #silinebilir.
# Out:
# \nin 90 days from ordering\n     196
# \nin 120 days from ordering\n    182
# \nin 1 day from ordering\n        51
# \nin 5 days from ordering\n       35
# \nin 3 days from ordering\n       35
# \nin 14 days from ordering\n      24
# \nin 180 days from ordering\n     24
# \nin 7 days from ordering\n       20
# \nin 150 days from ordering\n     18
# \nin 2 days from ordering\n       16
# Name: Availability, dtype: int64

# %%
df['Availability'] = df['Availability'].str.extract('(\d{1,3})')   #.isna().value_counts()

# %%
df['Last Timing Belt Service Date'].value_counts().head(10)   #silelim.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n04/2016\n]                2
# [\n01/2019\n]                1
# [\n01/1970\n]                1
# [\n05/2019\n]                1
# [\n06/2017\n]                1
# [\n04/2019\n]                1
# [\n01/1900\n]                1
# [\n02/2018\n]                1
# [\n05/2018\n, \nEuro 6\n]    1
# [\n01/2018\n]                1
# Name: Last Timing Belt Service Date, dtype: int64

# %%
df['Last Timing Belt Service Date']= [item[0] if type(item)==list else item for item in df['Last Timing Belt Service Date']]

df['Last Timing Belt Service Date'] = df['Last Timing Belt Service Date'].str.extract('(\d{2}/\d{4})')  #.isna().value_counts()

# %%
df['Available from'].value_counts().head(10)  #silinebilir.
# Out:
# \n31/08/19\n    98
# \n30/07/19\n    25
# \n15/08/19\n    24
# \n16/09/19\n    14
# \n29/06/19\n    12
# \n01/07/19\n    11
# \n28/06/19\n    10
# \n19/08/19\n     7
# \n10/09/19\n     6
# \n10/11/19\n     5
# Name: Available from, dtype: int64

# %%
df['Available from'] = df['Available from'].str.extract('(\d{2}/\d{2}/\d{2})')   #.isna().value_counts().head(10)

# %%
df.columns
# Out:
# Index(['url',
#        'make_model',
#        'short_description',
#        'body_type',
#        'price',
#        'vat',
#        'km',
#        'registration',
#        'prev_owner',
#        'kW',
#        ...
#        'Xenon_headlights',
#        'Immobilizer',
#        'Isofix',
#        'Passengerside_airbag',
#        'Power_steering',
#        'Side_airbag',
#        'Tire_pressure_monitoring_system',
#        'Traction_control',
#        'Emission_Label',
#        'Country'],
#       dtype='object', length=139)

# %%
df.drop(columns=["url","short_description","vat","Full Service","kW", "Non-smoking Vehicle","null","Make","Model","Offer Number","First Registration","Model Code","Drive chain", "Electricity consumption", "Emission Label", "\nComfort & Convenience\n","\nEntertainment & Media\n","\nExtras\n",
       "\nSafety & Security\n","description","Electricity consumption","Last Service Date","Other Fuel Types","Availability","Last Timing Belt Service Date","Available from","Safety_Security"], axis=0, inplace=True)

# %%
df.to_csv("final_scout_not_dummy.csv", index=False)

# %%
df.columns
# Out:
# Index(['url',
#        'make_model',
#        'short_description',
#        'body_type',
#        'price',
#        'vat',
#        'km',
#        'registration',
#        'prev_owner',
#        'kW',
#        'hp',
#        'Type',
#        'Previous Owners',
#        'Next Inspection',
#        'Inspection new',
#        'Warranty',
#        'Full Service',
#        'Non-smoking Vehicle',
#        'null',
#        'Make',
#        'Model',
#        'Offer Number',
#        'First Registration',
#        'Body Color',
#        'Paint Type',
#        'Body Color Original',
#        'Upholstery',
#        'Body',
#        'Nr. of Doors',
#        'Nr. of Seats',
#        'Model Code',
#        'Gearing Type',
#        'Displacement',
#        'Cylinders',
#        'Weight',
#        'Drive chain',
#        'Fuel',
#        'Consumption',
#        'CO2 Emission',
#        'Emission Class',
#        '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n',
# ...

# %%
spec_chars = ["!",'"',"#","%","&","'","(",")"," ",
              "*","+",",","-","/",":",";","<",
              "=",">","?","@","[","\\","]","^",
              "`","{","|","}","~","–","\n"]

for char in spec_chars:
    df.columns = df.columns.str.replace(char, '_')

#df.columns = df.columns.str.split().str.join(" ")
# Out:
# <ipython-input-101-8744ff9a5916>:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace(char, '_')

# %% [markdown]
# ## 2. yöntem column isimlerini değiştirirken:
#
# df.rename(columns=lambda x: re.sub('(\s|/)','_', x), inplace=True)
#
# df = df.clean_names().head()
#
# df.keys()

# %%
df.columns
# Out:
# Index(['url',
#        'make_model',
#        'short_description',
#        'body_type',
#        'price',
#        'vat',
#        'km',
#        'registration',
#        'prev_owner',
#        'kW',
#        'hp',
#        'Type',
#        'Previous_Owners',
#        'Next_Inspection',
#        'Inspection_new',
#        'Warranty',
#        'Full_Service',
#        'Non_smoking_Vehicle',
#        'null',
#        'Make',
#        'Model',
#        'Offer_Number',
#        'First_Registration',
#        'Body_Color',
#        'Paint_Type',
#        'Body_Color_Original',
#        'Upholstery',
#        'Body',
#        'Nr._of_Doors',
#        'Nr._of_Seats',
#        'Model_Code',
#        'Gearing_Type',
#        'Displacement',
#        'Cylinders',
#        'Weight',
#        'Drive_chain',
#        'Fuel',
#        'Consumption',
#        'CO2_Emission',
#        'Emission_Class',
#        '_Comfort___Convenience_',
#        '_Entertainment___Media_',
#        '_Extras_',
# ...

# %%
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['url',
#        'make_model',
#        'short_description',
#        'body_type',
#        'price',
#        'vat',
#        'km',
#        'registration',
#        'prev_owner',
#        'kw',
#        'hp',
#        'type',
#        'previous_owners',
#        'next_inspection',
#        'inspection_new',
#        'warranty',
#        'full_service',
#        'non_smoking_vehicle',
#        'null',
#        'make',
#        'model',
#        'offer_number',
#        'first_registration',
#        'body_color',
#        'paint_type',
#        'body_color_original',
#        'upholstery',
#        'body',
#        'nr._of_doors',
#        'nr._of_seats',
#        'model_code',
#        'gearing_type',
#        'displacement',
#        'cylinders',
#        'weight',
#        'drive_chain',
#        'fuel',
#        'consumption',
#        'co2_emission',
#        'emission_class',
#        '_comfort___convenience_',
#        '_entertainment___media_',
#        '_extras_',
# ...

# %%
df.rename(columns={"_comfort___convenience_":"comfort_convenience","_entertainment___media_":"entertainment_media","_extras_":"extras","_safety___security_":"safety_security"}, inplace=True)

# %%
df.columns
# Out:
# Index(['url',
#        'make_model',
#        'short_description',
#        'body_type',
#        'price',
#        'vat',
#        'km',
#        'registration',
#        'prev_owner',
#        'kw',
#        'hp',
#        'type',
#        'previous_owners',
#        'next_inspection',
#        'inspection_new',
#        'warranty',
#        'full_service',
#        'non_smoking_vehicle',
#        'null',
#        'make',
#        'model',
#        'offer_number',
#        'first_registration',
#        'body_color',
#        'paint_type',
#        'body_color_original',
#        'upholstery',
#        'body',
#        'nr._of_doors',
#        'nr._of_seats',
#        'model_code',
#        'gearing_type',
#        'displacement',
#        'cylinders',
#        'weight',
#        'drive_chain',
#        'fuel',
#        'consumption',
#        'co2_emission',
#        'emission_class',
#        'comfort_convenience',
#        'entertainment_media',
#        'extras',
# ...

# %%
#missing data

total = df.isnull().sum().sort_values(ascending=False)

percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)

missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

missing_data.head(50)
# Out:
#                                Total  \
# kw                             15919
# last_timing_belt_service_date  15903
# electricity_consumption        15782
# available_from                 15647
# last_service_date              15353
# availability                   15284
# other_fuel_types               15039
# next_inspection                12384
# inspection_new                 11987
# emission_label                 11934
# model_code                     10941
# non_smoking_vehicle             8742
# country_version                 8333
# full_service                    7704
# weight                          6974
# drive_chain                     6858
# prev_owner                      6828
# previous_owners                 6640
# paint_type                      5772
# cylinders                       5680
# warranty                        5420
# gears                           4712
# vat                             4513
# body_color_original             3759
# ...

# %%
df['Inspection new'] = df['Inspection new'].astype('str').str.split(',', expand=True)

# %%
df['Inspection new'].apply(tuple).value_counts()
# Out:
# (n, a, n)                            11987
# ([, ', \, n, Y, e, s, \, n, ')        3490
# (\n, Y, e, s, \n)                      362
# ([, ', \, n, Y, e, s, \, n, ', ])       80
# Name: Inspection new, dtype: int64

# %%
dct = []

for i in df.loc[:, 'kW']:
    if str(i) == 'nan':
        dct.append(['Nothing_kW'])
    else:
        dct.append([i])
dct[:2]
# Out:
# [['Nothing_kW'], ['Nothing_kW']]

# %% [markdown]
# ## Import Libraries and Data

# %%
df_dummied.to_csv("final_scout_dummy.csv", index=False)

# %%
df.to_csv("final_scout_not_dummy.csv", index=False)
