# %% [markdown]
# ![image.png](attachment:12f7a627-8e00-4db5-8f82-54b5a0e3ec5a.png)

# %% [raw]
# Veri setini incelediğimizde yaş değişkenine göre satın alma durumunda bir farklılık oluştuğunu görebiliyoruz. Yani yaş etkeninin bu ürünü alıp almama durumunda en önemli bir etken gibi önplana çıkıyor. Ülke ve maaş durumu ise bize ikinci planda satın alma durumuna etki eden hususlar olarak görünüyor.

# %% [markdown]
# ![image.png](attachment:7069ca3d-5b8a-4717-a44d-02983ea31fda.png)

# %%
Yeni bir gözlem geldiğinde önceki değerlere ilişkin oluşturduğumuz modele göre tahminde bulunma işlemidir.

# %% [markdown]
# ![image.png](attachment:eee7f342-c8ff-4c3c-bffa-70b1b12ab9df.png)

# %%
Sahibinden.com tarafından geliştirildi.

# %% [markdown]
# ![image.png](attachment:894935f3-8bff-44f2-822f-e5bfaf15e4cf.png)

# %% [markdown]
# ![image.png](attachment:c5260308-4a22-483c-a371-488f8e6e4d59.png)

# %% [markdown]
# ![image.png](attachment:54e05089-16d4-46c9-a243-e606d3934116.png)

# %% [markdown]
# ![image.png](attachment:7a93da2b-d4ff-4dfc-8cf6-25a64748516b.png)

# %% [markdown]
# ![image.png](attachment:3849f992-515c-49ba-a9d3-731b3599958b.png)

# %% [markdown]
# ![image.png](attachment:fe1bb2e7-8816-49ef-b5f8-431e930bf202.png)

# %% [markdown]
# ![image.png](attachment:e46a2b8c-6420-4401-b5a6-ef34b7a70a15.png)

# %% [markdown]
# ![image.png](attachment:4f61c18a-36f9-48a9-a4cd-75c16a95c04f.png)

# %% [markdown]
# ![image.png](attachment:ae0d4689-a26a-4538-83df-2955ad895300.png)

# %% [markdown]
# ![image.png](attachment:e8cdd061-176e-4646-8972-0c5c74050b52.png)

# %% [markdown]
# ### Terminoloji

# %% [markdown]
# ![image.png](attachment:d3dd06b3-b09f-4781-b201-7828dbe9ac5f.png)

# %% [raw]
# Burada y bağımlı(target variable), x ise bağımsız değişkendir.

# %% [markdown]
# ![image.png](attachment:2da4d56e-8005-44ca-8a8a-0a225cea1bc7.png)

# %%
Burada regresyon varsa y bağımlı değişken süreklidir.

# %% [markdown]
# ![image.png](attachment:529f250c-1575-4411-a4d2-e968b1366dc6.png)

# %% [markdown]
# ![image.png](attachment:0998afcd-7179-49f7-b537-69c6c3a46c72.png)

# %% [markdown]
# ![image.png](attachment:e5f97967-5e1a-4334-8fe4-03ea1181bf5b.png)

# %% [markdown]
# Burada renksiz olanlar y bağımlı değişkeni üzerine etkisi olmayan ve modül dışında tutulacak değişkenlerdir.

# %% [markdown]
# ![image.png](attachment:2020ad2d-41e2-41a6-9d14-d5cd997de557.png)

# %% [markdown]
# ![image.png](attachment:cdf9ea34-204c-43cc-9ebd-7a8246299451.png)

# %% [markdown]
# ![image.png](attachment:f39e347a-8e19-43ea-a031-a826b61458f2.png)

# %%
Burada x verdiğim değerler karşısında y nın alabileceği değerleri kesin olarak bilirim. Buna Deterministik model denir.
Diğeri ise daha çok ML de kullandığımız model olan Stokastik Model vardır.

# %% [markdown]
# ![image.png](attachment:53e6072c-5e64-4bd3-a250-0014eea7f3f9.png)

# %% [markdown]
# ### Model Doğrulama Yöntemleri

# %% [markdown]
# ![image.png](attachment:a4a59d1b-1ce4-4132-92ff-935e6dbcc2df.png)

# %% [markdown]
# ![image.png](attachment:45620ee4-b7ba-4b27-a016-ef935e00aece.png)
