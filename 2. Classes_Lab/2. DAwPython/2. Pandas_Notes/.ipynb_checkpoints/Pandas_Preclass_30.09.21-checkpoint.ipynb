# %%
import pandas as pd
people_dict={"first":["Richard", "Robert", "Jason"],
             "last" :["Stone", "Deepdive", "Seaborn"],
             "email": ["richardstone@email.com", "robertdeepdive@email.com", 
                        "jasonseaborn@email.com"]}
df=pd.DataFrame(people_dict)
df
# Out:
#      first      last                     email
# 0  Richard     Stone    richardstone@email.com
# 1   Robert  Deepdive  robertdeepdive@email.com
# 2    Jason   Seaborn    jasonseaborn@email.com

# %%
df.iloc[1,2]
# Out:
# 'robertdeepdive@email.com'

# %%
import numpy as np
import pandas as pd
outside = ['A1','A1','A1','A2','A2','A2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)
np.random.seed(101)
data = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['X','Y'])
data
# Out:
#              X         Y
# A1 1  2.706850  0.628133
#    2  0.907969  0.503826
#    3  0.651118 -0.319318
# A2 1 -0.848077  0.605965
#    2 -2.018168  0.740122
#    3  0.528813 -0.589001

# %%
data.loc['A1']
# Out:
#           X         Y
# 1  2.706850  0.628133
# 2  0.907969  0.503826
# 3  0.651118 -0.319318

# %%
import pandas as pd
people_dict={"first":["Richard", "Robert", "Jason"],
             "last" :["Stone", "Deepdive", "Seaborn"],
             "email": ["richardstone@email.com", "robertdeepdive@email.com", 
                        "jasonseaborn@email.com"]}
df=pd.DataFrame(people_dict)
df
# Out:
#      first      last                     email
# 0  Richard     Stone    richardstone@email.com
# 1   Robert  Deepdive  robertdeepdive@email.com
# 2    Jason   Seaborn    jasonseaborn@email.com

# %%
df["last"]
# Out:
# 0       Stone
# 1    Deepdive
# 2     Seaborn
# Name: last, dtype: object

# %%
import pandas as pd
import numpy as np

data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'B', 'B', 'A', 'A'],
    'city' :    [ 'Gurgaon', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', 'blue', 'yellow', 'pink', 'black', 'green', 'red']
})

data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F            blue
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M            pink
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   17       A   Mumbai      F             red

# %%
data[['city','age']]
# Out:
#       city  age
# 0  Gurgaon   10
# 1    Delhi   22
# 2   Mumbai   13
# 3    Delhi   21
# 4   Mumbai   12
# 5    Delhi   11
# 6   Mumbai   17

# %%
data.loc[1]   # loc ile location yani satır isimleri ne ise onunla çağırıyoruz.
            # iloc ise index location yani hangi index te ise onun numarası ile çagırıyoruz.
# Out:
# age                   22
# section                B
# city               Delhi
# gender                 F
# favourite_color     blue
# Name: 1, dtype: object

# %%
df = pd.DataFrame(np.arange(12).reshape(3, 4), columns=['A', 'B', 'C', 'D'])
df
# Out:
#    A  B   C   D
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
df.drop(['B', 'C'], axis=1)
# Out:
#    A   D
# 0  0   3
# 1  4   7
# 2  8  11

# %%
import pandas as pd
people_dict={"first":["Richard", "Robert", "Jason"],
             "last" :["Stone", "Deepdive", "Seaborn"],
             "email": ["richardstone@email.com", "robertdeepdive@email.com", 
                        "jasonseaborn@email.com"]}
df=pd.DataFrame(people_dict)
df
# Out:
#      first      last                     email
# 0  Richard     Stone    richardstone@email.com
# 1   Robert  Deepdive  robertdeepdive@email.com
# 2    Jason   Seaborn    jasonseaborn@email.com

# %%
df[(df['first']=="Richard") | (df['last'] == 'Deepdive')]
# Out:
#      first      last                     email
# 0  Richard     Stone    richardstone@email.com
# 1   Robert  Deepdive  robertdeepdive@email.com

# %%
import pandas as pd
import numpy as np

data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'B', 'B', 'A', 'A'],
    'city' :    [ 'Gurgaon', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', 'blue', 'yellow', 'pink', 'black', 'green', 'red']
})

data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F            blue
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M            pink
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   17       A   Mumbai      F             red

# %%
data[data["age"]>=21]
# Out:
#    age section   city gender favourite_color
# 1   22       B  Delhi      F            blue
# 3   21       B  Delhi      M            pink

# %%
data['new'] = data['city'].str[:2]

# %%
data
# Out:
#    age section     city gender favourite_color new
# 0   10       A  Gurgaon      M             red  Gu
# 1   22       B    Delhi      F            blue  De
# 2   13       C   Mumbai      F          yellow  Mu
# 3   21       B    Delhi      M            pink  De
# 4   12       B   Mumbai      M           black  Mu
# 5   11       A    Delhi      M           green  De
# 6   17       A   Mumbai      F             red  Mu

# %%
data.set_index('section', inplace=True)

# %%
data
# Out:
#          age     city gender favourite_color new
# section
# A         10  Gurgaon      M             red  Gu
# B         22    Delhi      F            blue  De
# C         13   Mumbai      F          yellow  Mu
# B         21    Delhi      M            pink  De
# B         12   Mumbai      M           black  Mu
# A         11    Delhi      M           green  De
# A         17   Mumbai      F             red  Mu

# %%
data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'B', 'B', 'A', 'A'],
    'city' :    [ 'Gurgaon', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', 'blue', 'yellow', 'pink', 'black', 'green', 'red']
})

data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F            blue
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M            pink
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   17       A   Mumbai      F             red

# %%
data.drop('city', axis=1, inplace=True)

# %%
data
# Out:
#    age section gender favourite_color
# 0   10       A      M             red
# 1   22       B      F            blue
# 2   13       C      F          yellow
# 3   21       B      M            pink
# 4   12       B      M           black
# 5   11       A      M           green
# 6   17       A      F             red

# %%
data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'B', 'B', 'A', 'A'],
    'city' :    [ 'Gurgaon', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', 'blue', 'yellow', 'pink', 'black', 'green', 'red']
})

data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F            blue
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M            pink
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   17       A   Mumbai      F             red

# %%
data["city"]
# Out:
# 0    Gurgaon
# 1      Delhi
# 2     Mumbai
# 3      Delhi
# 4     Mumbai
# 5      Delhi
# 6     Mumbai
# Name: city, dtype: object

# %%
data.drop(6, axis=0, inplace=True)

# %%
data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F            blue
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M            pink
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      M           green

# %%
data.iloc[1]
# Out:
# age                   22
# section                B
# city               Delhi
# gender                 F
# favourite_color     blue
# Name: 1, dtype: object

# %%
data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'B', 'B', 'A', 'A'],
    'city' :    [ 'Gurgaon', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', 'blue', 'yellow', 'pink', 'black', 'green', 'red']
})

data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F            blue
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M            pink
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   17       A   Mumbai      F             red

# %%
#data.set_index('section', inplace=True)

# %%
#data
# Out:
#          age     city gender favourite_color
# section
# A         10  Gurgaon      M             red
# B         22    Delhi      F            blue
# C         13   Mumbai      F          yellow
# B         21    Delhi      M            pink
# B         12   Mumbai      M           black
# A         11    Delhi      M           green
# A         17   Mumbai      F             red

# %%
data.set_index([pd.Index(["A","B","C","D","E","F","G"]),"section"])
# Out:
#            age     city gender favourite_color
#   section
# A A         10  Gurgaon      M             red
# B B         22    Delhi      F            blue
# C C         13   Mumbai      F          yellow
# D B         21    Delhi      M            pink
# E B         12   Mumbai      M           black
# F A         11    Delhi      M           green
# G A         17   Mumbai      F             red

# %%
data.loc[["D","E"],['city','gender']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-a70c574b02ee> in <module>
# ----> 1 data.loc[["D","E"],['city','gender']]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1065         # ugly hack for GH #836
#    1066         if self._multi_take_opportunity(tup):
# -> 1067             return self._multi_take(tup)
#    1068
#    1069         return self._getitem_tuple_same_dim(tup)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _multi_take(self, tup)
#    1017         """
#    1018         # GH 836
# -> 1019         d = {
#    1020             axis: self._get_listlike_indexer(key, axis)
#    1021             for (key, axis) in zip(tup, self.obj._AXIS_ORDERS)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in <dictcomp>(.0)
#    1018         # GH 836
#    1019         d = {
# -> 1020             axis: self._get_listlike_indexer(key, axis)
#    1021             for (key, axis) in zip(tup, self.obj._AXIS_ORDERS)
#    1022         }
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Index(['D', 'E'], dtype='object')] are in the [index]"

# %%
data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'D', 'E', 'F', 'G'],
    'country' : [ 'USA', 'GBR', 'TUR', 'NLD', 'BEL', 'DEU', 'FRA'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', 'blue', 'yellow', 'pink', 'black', 'green', 'red']
})
data.set_index('section', inplace=True)
data
# Out:
#          age country gender favourite_color
# section
# A         10     USA      M             red
# B         22     GBR      F            blue
# C         13     TUR      F          yellow
# D         21     NLD      M            pink
# E         12     BEL      M           black
# F         11     DEU      M           green
# G         17     FRA      F             red

# %%
data[data["age"]>15]
# Out:
#          age country gender favourite_color
# section
# B         22     GBR      F            blue
# D         21     NLD      M            pink
# G         17     FRA      F             red

# %%
data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'D', 'E', 'F', 'G'],
    'country' : [ 'USA', 'GBR', 'TUR', 'NLD', 'BEL', 'DEU', 'FRA'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', 'blue', 'yellow', 'pink', 'black', 'green', 'red']
})
data.set_index('section', inplace=True)
data
# Out:
#          age country gender favourite_color
# section
# A         10     USA      M             red
# B         22     GBR      F            blue
# C         13     TUR      F          yellow
# D         21     NLD      M            pink
# E         12     BEL      M           black
# F         11     DEU      M           green
# G         17     FRA      F             red

# %%
data[data["age"]>15]["country"]
# Out:
# section
# B    GBR
# D    NLD
# G    FRA
# Name: country, dtype: object

# %%
data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'D', 'E', 'F', 'G'],
    'country' : [ 'USA', 'GBR', 'TUR', 'NLD', 'BEL', 'DEU', 'FRA'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', 'blue', 'yellow', 'pink', 'black', 'green', 'red']
})
data.set_index('section', inplace=True)
data

# %%
data[(data["age"]>15)&(data["favourite_color"]=="red")]
# Out:
#          age country gender favourite_color
# section
# G         17     FRA      F             red

# %%
data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'D', 'E', 'F', 'G'],
    'country' : [ 'USA', 'GBR', 'TUR', 'NLD', 'BEL', 'DEU', 'FRA'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', 'blue', 'yellow', 'pink', 'black', 'green', 'red']
})
data.set_index('section', inplace=True)
data
# Out:
#          age country gender favourite_color
# section
# A         10     USA      M             red
# B         22     GBR      F            blue
# C         13     TUR      F          yellow
# D         21     NLD      M            pink
# E         12     BEL      M           black
# F         11     DEU      M           green
# G         17     FRA      F             red

# %%
data[(data['age']>20) | (data['favourite_color'] == 'red')]
# Out:
#          age country gender favourite_color
# section
# A         10     USA      M             red
# B         22     GBR      F            blue
# D         21     NLD      M            pink
# G         17     FRA      F             red

# %%
outside = ['A1','A1','A1','A2','A2','A2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)
np.random.seed(101)
data = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['X','Y'])
data
# Out:
#              X         Y
# A1 1  2.706850  0.628133
#    2  0.907969  0.503826
#    3  0.651118 -0.319318
# A2 1 -0.848077  0.605965
#    2 -2.018168  0.740122
#    3  0.528813 -0.589001

# %%
data['Y']['A2']
# Out:
# 1    0.605965
# 2    0.740122
# 3   -0.589001
# Name: Y, dtype: float64

# %%
outside = ['A1','A1','A1','A2','A2','A2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)
np.random.seed(101)
data = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['X','Y'])
data
# Out:
#              X         Y
# A1 1  2.706850  0.628133
#    2  0.907969  0.503826
#    3  0.651118 -0.319318
# A2 1 -0.848077  0.605965
#    2 -2.018168  0.740122
#    3  0.528813 -0.589001

# %%
data.loc['A1','X']
# Out:
# 1    2.706850
# 2    0.907969
# 3    0.651118
# Name: X, dtype: float64

# %%
data['X']['A1']
# Out:
# 1    2.706850
# 2    0.907969
# 3    0.651118
# Name: X, dtype: float64

# %%
np.random.randn(6,2)
# Out:
# array([[ 0.18869531, -0.75887206],
#        [-0.93323722,  0.95505651],
#        [ 0.19079432,  1.97875732],
#        [ 2.60596728,  0.68350889],
#        [ 0.30266545,  1.69372293],
#        [-1.70608593, -1.15911942]])

# %%
data['X']['A1']

# %%
outside = ['A1','A1','A1','A2','A2','A2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)
np.random.seed(101)
data = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['X','Y'])
data
# Out:
#              X         Y
# A1 1  2.706850  0.628133
#    2  0.907969  0.503826
#    3  0.651118 -0.319318
# A2 1 -0.848077  0.605965
#    2 -2.018168  0.740122
#    3  0.528813 -0.589001

# %%
data.loc['A2'].loc[1, 'Y']
# Out:
# 0.6059653494949336

# %%
import pandas as pd

# %%
people = { "first": ["Tony","Jack"],
          "last": ["Stark","Rogers"],
        "email":["Ironman@gmail.com", "Cap@avenge.com"]}
df2= pd.DataFrame(people)
df2
# Out:
#   first    last              email
# 0  Tony   Stark  Ironman@gmail.com
# 1  Jack  Rogers     Cap@avenge.com

# %%
df2.append(df2,ignore_index=True)
# Out:
#   first    last              email
# 0  Tony   Stark  Ironman@gmail.com
# 1  Jack  Rogers     Cap@avenge.com
# 2  Tony   Stark  Ironman@gmail.com
# 3  Jack  Rogers     Cap@avenge.com

# %%
df= df2.append(df2,ignore_index=True,sort=True)
df
# Out:
#                email first    last
# 0  Ironman@gmail.com  Tony   Stark
# 1     Cap@avenge.com  Jack  Rogers
# 2  Ironman@gmail.com  Tony   Stark
# 3     Cap@avenge.com  Jack  Rogers

# %%
df.drop(index=3)
# Out:
#   first    last              email
# 0  Tony   Stark  Ironman@gmail.com
# 1  Jack  Rogers     Cap@avenge.com
# 2  Tony   Stark  Ironman@gmail.com

# %%
df.drop(index=df[df["last"]=="Rogers"].index)
# Out:
#                email first   last
# 0  Ironman@gmail.com  Tony  Stark
# 2  Ironman@gmail.com  Tony  Stark

# %%
people = { "first": ["Corey","John","Stephen"],
          "last": ["Stark","Rogers","Ericson"],
        "email":["Ironman@gmail.com", "Cap@avenge.com", "stephen@gmail.com"]}
df= pd.DataFrame(people)
df
# Out:
#      first     last              email
# 0    Corey    Stark  Ironman@gmail.com
# 1     John   Rogers     Cap@avenge.com
# 2  Stephen  Ericson  stephen@gmail.com

# %%
df.sort_values(by="last",ascending=False)
# Out:
#      first     last              email
# 0    Corey    Stark  Ironman@gmail.com
# 1     John   Rogers     Cap@avenge.com
# 2  Stephen  Ericson  stephen@gmail.com

# %%
df.sort_values(by=["last","first"],ascending=False)
# Out:
#      first     last              email
# 0    Corey    Stark  Ironman@gmail.com
# 1     John   Rogers     Cap@avenge.com
# 2  Stephen  Ericson  stephen@gmail.com

# %%
import pandas as pd
import numpy as np
people = {
          "first":["Richard", "Robert", "Jason", "Andrex", np.nan, None, "NA"],
          "last" :["Stone", "Deepdive", "Seaborn"," Alix", np.nan, np.nan,"Missing"],
          "email":["richardstone@email.com", "robertdeepdive@email.com", 
                "jasonseaborn@email.com", None, np.nan, "ananymous@email.com", "NA"], 
          "age": ["33","55","63","36", None, None,"Missing"]
       }
df=pd.DataFrame(people)
df
# Out:
#      first      last                     email      age
# 0  Richard     Stone    richardstone@email.com       33
# 1   Robert  Deepdive  robertdeepdive@email.com       55
# 2    Jason   Seaborn    jasonseaborn@email.com       63
# 3   Andrex      Alix                      None       36
# 4      NaN       NaN                       NaN     None
# 5     None       NaN       ananymous@email.com     None
# 6       NA   Missing                        NA  Missing

# %%
df.dropna()   # missing value olmadığından dolayı 6.satırıda aldı.
# Out:
#      first      last                     email      age
# 0  Richard     Stone    richardstone@email.com       33
# 1   Robert  Deepdive  robertdeepdive@email.com       55
# 2    Jason   Seaborn    jasonseaborn@email.com       63
# 6       NA   Missing                        NA  Missing

# %%
df.dropna(axis = "index", how = "any")
# Out:
#      first      last                     email      age
# 0  Richard     Stone    richardstone@email.com       33
# 1   Robert  Deepdive  robertdeepdive@email.com       55
# 2    Jason   Seaborn    jasonseaborn@email.com       63
# 6       NA   Missing                        NA  Missing

# %%
df.dropna(axis = "index",how = "all")
# Out:
#      first      last                     email      age
# 0  Richard     Stone    richardstone@email.com       33
# 1   Robert  Deepdive  robertdeepdive@email.com       55
# 2    Jason   Seaborn    jasonseaborn@email.com       63
# 3   Andrex      Alix                      None       36
# 5     None       NaN       ananymous@email.com     None
# 6       NA   Missing                        NA  Missing

# %%
df.dropna(axis = "index", how = "any", subset=["email"])  # email deki missing value ları getirmedi.
# Out:
#      first      last                     email      age
# 0  Richard     Stone    richardstone@email.com       33
# 1   Robert  Deepdive  robertdeepdive@email.com       55
# 2    Jason   Seaborn    jasonseaborn@email.com       63
# 5     None       NaN       ananymous@email.com     None
# 6       NA   Missing                        NA  Missing

# %%
df=pd.DataFrame(people)
df.replace("NA",np.nan,inplace=True)
df.replace("Missing",np.nan,inplace=True)

# %%
df
# Out:
#      first      last                     email   age
# 0  Richard     Stone    richardstone@email.com    33
# 1   Robert  Deepdive  robertdeepdive@email.com    55
# 2    Jason   Seaborn    jasonseaborn@email.com    63
# 3   Andrex      Alix                      None    36
# 4      NaN       NaN                       NaN  None
# 5     None       NaN       ananymous@email.com  None
# 6      NaN       NaN                       NaN   NaN

# %%
df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df.fillna("MISSING")
# Out:
#      first      last                     email      age
# 0  Richard     Stone    richardstone@email.com       33
# 1   Robert  Deepdive  robertdeepdive@email.com       55
# 2    Jason   Seaborn    jasonseaborn@email.com       63
# 3   Andrex      Alix                   MISSING       36
# 4  MISSING   MISSING                   MISSING  MISSING
# 5  MISSING   MISSING       ananymous@email.com  MISSING
# 6  MISSING   MISSING                   MISSING  MISSING

# %%
df.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
type(np.nan)
# Out:
# float

# %%
df["age"].mean()   # int ile float concanate yapamadı. np.nan değerleri float tır.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-661ef25eca6e> in <module>
# ----> 1 df["age"].mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11116         )
#   11117         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 11118             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11119
#   11120         # pandas\core\generic.py:10924: error: Cannot assign to a method
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10724
#   10725     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10726         return self._stat_function(
#   10727             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10728         )
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10709         if level is not None:
#   10710             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 10711         return self._reduce(
#   10712             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10713         )
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4180                 )
#    4181             with np.errstate(all="ignore"):
# -> 4182                 return op(delegate, skipna=skipna, **kwds)
#    4183
#    4184     def _reindex_indexer(self, new_index, indexer, copy):
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      71             try:
#      72                 with np.errstate(invalid="ignore"):
# ---> 73                     return f(*args, **kwargs)
#      74             except ValueError as e:
#      75                 # we want to transform an object array
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     133                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     134             else:
# --> 135                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     136
#     137             return result
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     392             mask = isna(values)
#     393
# --> 394         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     395
#     396         if datetimelike:
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     631
#     632     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 633     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     634
#     635     if axis is not None and getattr(the_sum, "ndim", False):
#
# ~\anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      46          initial=_NoValue, where=True):
# ---> 47     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      48
#      49 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: can only concatenate str (not "int") to str

# %%
df["age"] = df["age"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-8424cae59cf4> in <module>
# ----> 1 df["age"] = df["age"].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     671             vals1d = values.ravel()
#     672             try:
# --> 673                 values = astype_nansafe(vals1d, dtype, copy=True)
#     674             except (ValueError, TypeError):
#     675                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1072         # work around NumPy brokenness, #1987
#    1073         if np.issubdtype(dtype.type, np.integer):
# -> 1074             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#    1075
#    1076         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'

# %%
df["age"] = df["age"].astype(float)

# %%
df.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
df["age"].mean()
# Out:
# 46.75
