# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %matplotlib inline
# %matplotlib notebook

plt.rcParams["figure.figsize"] = (10,6)
# plt.rcParams['figure.dpi'] = 100

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %%
import datetime

# %%
df_1 = pd.read_excel("KGUP-01012021-01032022.xls")
df_1
# Out:
#             Tarih   Saat Toplam (MWh) Doğal Gaz    Rüzgar    Linyit Taş Kömür  \
# 0      01.01.2021  00:00    26.465,84  5.886,20  5.061,41  4.620,00    284,00
# 1      01.01.2021  01:00    24.844,67  5.024,60  4.955,46  4.514,00    262,00
# 2      01.01.2021  02:00    23.274,45  4.041,00  4.825,60  4.564,00    262,00
# 3      01.01.2021  03:00    22.453,18  3.638,00  4.667,55  4.460,00    262,00
# 4      01.01.2021  04:00    21.981,51  3.538,00  4.479,05  4.462,00    262,00
# ...           ...    ...          ...       ...       ...       ...       ...
# 10195  01.03.2022  19:00    38.940,64  9.757,19  4.006,90  5.376,30    260,00
# 10196  01.03.2022  20:00    37.780,44  8.824,48  4.159,18  5.384,39    260,00
# 10197  01.03.2022  21:00    36.446,01  7.596,58  4.180,42  5.386,33    260,00
# 10198  01.03.2022  22:00    35.978,74  6.666,52  4.116,31  5.388,26    260,00
# 10199  01.03.2022  23:00    34.447,46  5.898,18  4.060,83  5.382,36    260,00
#
# ...

# %%
df_2 = pd.read_excel("lisanssizUretimMiktari-01032022-01032022.xls")
df_2
# Out:
#            Tarih   Saat  Toplam (MWh)
# 0     01.01.2021  00:00        60.680
# 1     01.01.2021  01:00        58.770
# 2     01.01.2021  02:00        58.080
# 3     01.01.2021  03:00        56.770
# 4     01.01.2021  04:00        56.390
# ...          ...    ...           ...
# 9499  31.01.2022  19:00        31.840
# 9500  31.01.2022  20:00        32.980
# 9501  31.01.2022  21:00        34.920
# 9502  31.01.2022  22:00        37.510
# 9503  31.01.2022  23:00        38.300
#
# [9504 rows x 3 columns]

# %%
df_3 = pd.read_excel("YukTahminPlani-01012021-01032022.xls")
df_3
# Out:
#             Tarih   Saat Yük Tahmin Planı (MWh)
# 0      01/01/2021  00:00              28.125,00
# 1      01/01/2021  01:00              26.548,00
# 2      01/01/2021  02:00              25.288,00
# 3      01/01/2021  03:00              24.312,00
# 4      01/01/2021  04:00              23.730,00
# ...           ...    ...                    ...
# 10195  01/03/2022  19:00              42.341,00
# 10196  01/03/2022  20:00              41.511,00
# 10197  01/03/2022  21:00              40.192,00
# 10198  01/03/2022  22:00              39.217,00
# 10199  01/03/2022  23:00              37.532,00
#
# [10200 rows x 3 columns]

# %%
df_4 = pd.read_excel("PTF-01012021-01032022.xls")
df_4
# Out:
#             Tarih   Saat PTF (TL/MWh) PTF (USD/MWh) PTF (EUR/MWh)
# 0      01/01/2021  00:00       263,99         35,96         29,31
# 1      01/01/2021  01:00       236,99         32,29         26,31
# 2      01/01/2021  02:00       216,70         29,52         24,06
# 3      01/01/2021  03:00       218,07         29,71         24,21
# 4      01/01/2021  04:00       208,99         28,47         23,20
# ...           ...    ...          ...           ...           ...
# 10195  01/03/2022  19:00     1.500,00        106,84         95,48
# 10196  01/03/2022  20:00     1.550,00        110,40         98,67
# 10197  01/03/2022  21:00     1.500,01        106,84         95,48
# 10198  01/03/2022  22:00     1.500,00        106,84         95,48
# 10199  01/03/2022  23:00     1.325,01         94,38         84,34
#
# [10200 rows x 5 columns]

# %%
df = df_1.drop(columns="Toplam (MWh)")
df
# Out:
#             Tarih   Saat Doğal Gaz    Rüzgar    Linyit Taş Kömür İthal Kömür  \
# 0      01.01.2021  00:00  5.886,20  5.061,41  4.620,00    284,00    6.445,90
# 1      01.01.2021  01:00  5.024,60  4.955,46  4.514,00    262,00    6.252,90
# 2      01.01.2021  02:00  4.041,00  4.825,60  4.564,00    262,00    5.820,60
# 3      01.01.2021  03:00  3.638,00  4.667,55  4.460,00    262,00    5.447,60
# 4      01.01.2021  04:00  3.538,00  4.479,05  4.462,00    262,00    5.242,40
# ...           ...    ...       ...       ...       ...       ...         ...
# 10195  01.03.2022  19:00  9.757,19  4.006,90  5.376,30    260,00    7.329,50
# 10196  01.03.2022  20:00  8.824,48  4.159,18  5.384,39    260,00    7.328,50
# 10197  01.03.2022  21:00  7.596,58  4.180,42  5.386,33    260,00    7.326,50
# 10198  01.03.2022  22:00  6.666,52  4.116,31  5.388,26    260,00    7.328,50
# 10199  01.03.2022  23:00  5.898,18  4.060,83  5.382,36    260,00    6.965,50
#
# ...

# %%
df["Yuk"] = df_3["Yük Tahmin Planı (MWh)"]
df
# Out:
#             Tarih   Saat Doğal Gaz    Rüzgar    Linyit Taş Kömür İthal Kömür  \
# 0      01.01.2021  00:00  5.886,20  5.061,41  4.620,00    284,00    6.445,90
# 1      01.01.2021  01:00  5.024,60  4.955,46  4.514,00    262,00    6.252,90
# 2      01.01.2021  02:00  4.041,00  4.825,60  4.564,00    262,00    5.820,60
# 3      01.01.2021  03:00  3.638,00  4.667,55  4.460,00    262,00    5.447,60
# 4      01.01.2021  04:00  3.538,00  4.479,05  4.462,00    262,00    5.242,40
# ...           ...    ...       ...       ...       ...       ...         ...
# 10195  01.03.2022  19:00  9.757,19  4.006,90  5.376,30    260,00    7.329,50
# 10196  01.03.2022  20:00  8.824,48  4.159,18  5.384,39    260,00    7.328,50
# 10197  01.03.2022  21:00  7.596,58  4.180,42  5.386,33    260,00    7.326,50
# 10198  01.03.2022  22:00  6.666,52  4.116,31  5.388,26    260,00    7.328,50
# 10199  01.03.2022  23:00  5.898,18  4.060,83  5.382,36    260,00    6.965,50
#
# ...

# %%
df["Toplam"] = df_1["Toplam (MWh)"]

# %%
df["PTF"] = df_4["PTF (TL/MWh)"]
df
# Out:
#             Tarih   Saat Doğal Gaz    Rüzgar    Linyit Taş Kömür İthal Kömür  \
# 0      01.01.2021  00:00  5.886,20  5.061,41  4.620,00    284,00    6.445,90
# 1      01.01.2021  01:00  5.024,60  4.955,46  4.514,00    262,00    6.252,90
# 2      01.01.2021  02:00  4.041,00  4.825,60  4.564,00    262,00    5.820,60
# 3      01.01.2021  03:00  3.638,00  4.667,55  4.460,00    262,00    5.447,60
# 4      01.01.2021  04:00  3.538,00  4.479,05  4.462,00    262,00    5.242,40
# ...           ...    ...       ...       ...       ...       ...         ...
# 10195  01.03.2022  19:00  9.757,19  4.006,90  5.376,30    260,00    7.329,50
# 10196  01.03.2022  20:00  8.824,48  4.159,18  5.384,39    260,00    7.328,50
# 10197  01.03.2022  21:00  7.596,58  4.180,42  5.386,33    260,00    7.326,50
# 10198  01.03.2022  22:00  6.666,52  4.116,31  5.388,26    260,00    7.328,50
# 10199  01.03.2022  23:00  5.898,18  4.060,83  5.382,36    260,00    6.965,50
#
# ...

# %%
df
# Out:
#             Tarih   Saat Doğal Gaz    Rüzgar    Linyit Taş Kömür İthal Kömür  \
# 0      01.01.2021  00:00  5.886,20  5.061,41  4.620,00    284,00    6.445,90
# 1      01.01.2021  01:00  5.024,60  4.955,46  4.514,00    262,00    6.252,90
# 2      01.01.2021  02:00  4.041,00  4.825,60  4.564,00    262,00    5.820,60
# 3      01.01.2021  03:00  3.638,00  4.667,55  4.460,00    262,00    5.447,60
# 4      01.01.2021  04:00  3.538,00  4.479,05  4.462,00    262,00    5.242,40
# ...           ...    ...       ...       ...       ...       ...         ...
# 10195  01.03.2022  19:00  9.757,19  4.006,90  5.376,30    260,00    7.329,50
# 10196  01.03.2022  20:00  8.824,48  4.159,18  5.384,39    260,00    7.328,50
# 10197  01.03.2022  21:00  7.596,58  4.180,42  5.386,33    260,00    7.326,50
# 10198  01.03.2022  22:00  6.666,52  4.116,31  5.388,26    260,00    7.328,50
# 10199  01.03.2022  23:00  5.898,18  4.060,83  5.382,36    260,00    6.965,50
#
# ...

# %%
df.columns
# Out:
# Index(['Tarih', 'Saat', 'Doğal Gaz', 'Rüzgar', 'Linyit', 'Taş Kömür',
#        'İthal Kömür', 'Fuel Oil', 'Jeotermal', 'Barajlı', 'Nafta', 'Biyokütle',
#        'Akarsu', 'Diğer', 'Yuk', 'Toplam', 'PTF'],
#       dtype='object')

# %%
df.Tarih = pd.to_datetime(df.Tarih , infer_datetime_format=True)
df
# Out:
#            Tarih   Saat Doğal Gaz    Rüzgar    Linyit Taş Kömür İthal Kömür  \
# 0     2021-01-01  00:00  5.886,20  5.061,41  4.620,00    284,00    6.445,90
# 1     2021-01-01  01:00  5.024,60  4.955,46  4.514,00    262,00    6.252,90
# 2     2021-01-01  02:00  4.041,00  4.825,60  4.564,00    262,00    5.820,60
# 3     2021-01-01  03:00  3.638,00  4.667,55  4.460,00    262,00    5.447,60
# 4     2021-01-01  04:00  3.538,00  4.479,05  4.462,00    262,00    5.242,40
# ...          ...    ...       ...       ...       ...       ...         ...
# 10195 2022-01-03  19:00  9.757,19  4.006,90  5.376,30    260,00    7.329,50
# 10196 2022-01-03  20:00  8.824,48  4.159,18  5.384,39    260,00    7.328,50
# 10197 2022-01-03  21:00  7.596,58  4.180,42  5.386,33    260,00    7.326,50
# 10198 2022-01-03  22:00  6.666,52  4.116,31  5.388,26    260,00    7.328,50
# 10199 2022-01-03  23:00  5.898,18  4.060,83  5.382,36    260,00    6.965,50
#
# ...

# %%
colist = ['Doğal Gaz', 'Rüzgar', 'Linyit', 'Taş Kömür',
       'İthal Kömür', 'Fuel Oil', 'Jeotermal', 'Barajlı', 'Nafta', 'Biyokütle',
       'Akarsu', 'Diğer', 'Yuk', 'Toplam', 'PTF']

# %%
for i in colist:
    df[i] = df[i].apply(lambda row: row.replace(",",""))
    df[i] = df[i].apply(lambda row: row.replace(".",""))
    df[i] = df[i].astype(float)/100

df
# Out:
#            Tarih   Saat  Doğal Gaz   Rüzgar   Linyit  Taş Kömür  İthal Kömür  \
# 0     2021-01-01  00:00   5886.200 5061.410 4620.000    284.000     6445.900
# 1     2021-01-01  01:00   5024.600 4955.460 4514.000    262.000     6252.900
# 2     2021-01-01  02:00   4041.000 4825.600 4564.000    262.000     5820.600
# 3     2021-01-01  03:00   3638.000 4667.550 4460.000    262.000     5447.600
# 4     2021-01-01  04:00   3538.000 4479.050 4462.000    262.000     5242.400
# ...          ...    ...        ...      ...      ...        ...          ...
# 10195 2022-01-03  19:00   9757.190 4006.900 5376.300    260.000     7329.500
# 10196 2022-01-03  20:00   8824.480 4159.180 5384.390    260.000     7328.500
# 10197 2022-01-03  21:00   7596.580 4180.420 5386.330    260.000     7326.500
# 10198 2022-01-03  22:00   6666.520 4116.310 5388.260    260.000     7328.500
# 10199 2022-01-03  23:00   5898.180 4060.830 5382.360    260.000     6965.500
#
# ...

# %%
df_total = df[['Tarih', 'Saat', 'Yuk', 'Toplam', 'PTF']]

# %%
df_total
# Out:
#            Tarih   Saat       Yuk    Toplam      PTF
# 0     2021-01-01  00:00 28125.000 26465.840  263.990
# 1     2021-01-01  01:00 26548.000 24844.670  236.990
# 2     2021-01-01  02:00 25288.000 23274.450  216.700
# 3     2021-01-01  03:00 24312.000 22453.180  218.070
# 4     2021-01-01  04:00 23730.000 21981.510  208.990
# ...          ...    ...       ...       ...      ...
# 10195 2022-01-03  19:00 42341.000 38940.640 1500.000
# 10196 2022-01-03  20:00 41511.000 37780.440 1550.000
# 10197 2022-01-03  21:00 40192.000 36446.010 1500.010
# 10198 2022-01-03  22:00 39217.000 35978.740 1500.000
# 10199 2022-01-03  23:00 37532.000 34447.460 1325.010
#
# [10200 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10200 entries, 0 to 10199
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Tarih        10200 non-null  datetime64[ns]
#  1   Saat         10200 non-null  object
#  2   Doğal Gaz    10200 non-null  float64
#  3   Rüzgar       10200 non-null  float64
#  4   Linyit       10200 non-null  float64
#  5   Taş Kömür    10200 non-null  float64
#  6   İthal Kömür  10200 non-null  float64
#  7   Fuel Oil     10200 non-null  float64
#  8   Jeotermal    10200 non-null  float64
#  9   Barajlı      10200 non-null  float64
#  10  Nafta        10200 non-null  float64
#  11  Biyokütle    10200 non-null  float64
#  12  Akarsu       10200 non-null  float64
#  13  Diğer        10200 non-null  float64
#  14  Yuk          10200 non-null  float64
#  15  Toplam       10200 non-null  float64
#  16  PTF          10200 non-null  float64
# ...

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10200 entries, 0 to 10199
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tarih   10200 non-null  datetime64[ns]
#  1   Saat    10200 non-null  object
#  2   Yuk     10200 non-null  float64
#  3   Toplam  10200 non-null  float64
#  4   PTF     10200 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 398.6+ KB

# %%
df.isnull().sum()
# Out:
# Tarih          0
# Saat           0
# Doğal Gaz      0
# Rüzgar         0
# Linyit         0
# Taş Kömür      0
# İthal Kömür    0
# Fuel Oil       0
# Jeotermal      0
# Barajlı        0
# Nafta          0
# Biyokütle      0
# Akarsu         0
# Diğer          0
# Yuk            0
# Toplam         0
# PTF            0
# dtype: int64

# %%
df.describe().T
# Out:
#                 count      mean      std       min       25%       50%  \
# Doğal Gaz   10200.000 10959.710 3361.737  1267.430  8648.775 11022.850
# Rüzgar      10200.000  3534.279 1877.387   246.270  1956.267  3243.650
# Linyit      10200.000  4439.420  432.760  3263.100  4131.000  4421.660
# Taş Kömür   10200.000   133.130   45.801     0.000   122.000   132.400
# İthal Kömür 10200.000  5819.176 1549.799  1364.500  4560.100  6036.750
# Fuel Oil    10200.000     5.605    3.832     0.000     0.700     7.000
# Jeotermal   10200.000  1030.142  112.497   658.700   953.200  1061.070
# Barajlı     10200.000  4007.358 2186.679   225.970  2343.588  3847.000
# Nafta       10200.000     0.083    0.621     0.000     0.000     0.000
# Biyokütle   10200.000   661.703   74.981   481.470   604.575   647.395
# Akarsu      10200.000  1653.840  953.148   335.520  1014.977  1363.880
# Diğer       10200.000   459.933  243.314    19.200   281.125   368.000
# ...

# %%
df.groupby("Saat")[["Toplam","Yuk"]].mean().plot(kind="bar");

# %%
df_total.groupby("Days")[["Toplam","Yuk"]].mean().plot(kind="bar");
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\yasir\Desktop\emresa\Emre_2.ipynb Cell 23' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/yasir/Desktop/emresa/Emre_2.ipynb#ch0000022?line=0'>1</a> df_total.groupby("Days")[["Toplam","Yuk"]].mean().plot(kind="bar")
#
# File c:\Users\yasir\Desktop\streamlit\senv\lib\site-packages\pandas\core\frame.py:6714, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    <a href='file:///c%3A/Users/yasir/Desktop/streamlit/senv/lib/site-packages/pandas/core/frame.py?line=6710'>6711</a>     raise TypeError("You have to supply one of 'by' and 'level'")
#    <a href='file:///c%3A/Users/yasir/Desktop/streamlit/senv/lib/site-packages/pandas/core/frame.py?line=6711'>6712</a> axis = self._get_axis_number(axis)
# ...

# %%
sns.scatterplot(x="Yuk", y="Toplam", data=df, hue="PTF");

# %%
sns.pairplot(df,hue="PTF")

# %%
plt.figure(figsize=(15,10))
plt.subplot(141)
plt.hist(df.Toplam, bins = 50)

plt.subplot(142)
plt.boxplot(df.Toplam)

plt.subplot(143)
plt.boxplot(df.Toplam, whis = 2.5)

plt.subplot(144)
plt.boxplot(np.log(df.Toplam), whis = 2.5)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.subplot(141)
plt.hist(df.PTF, bins = 50)

plt.subplot(142)
plt.boxplot(df.PTF)

plt.subplot(143)
plt.boxplot(df.PTF, whis = 2.5)

plt.subplot(144)
plt.boxplot(np.log(df.PTF), whis = 2.5)
plt.show()

# %%
sns.heatmap(df.corr(), annot =True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df_total.corr(), annot =True)
# Out:
# <AxesSubplot:>

# %%
sns.histplot(df.PTF, bins=50, kde=True)
# Out:
# <AxesSubplot:xlabel='PTF', ylabel='Count'>

# %%
sns.boxplot(df.PTF)
# Out:
# <AxesSubplot:xlabel='PTF'>

# %%
df_total['Month'] = pd. DatetimeIndex(df['Tarih']). month
df_total
# Out:
#            Tarih   Saat       Yuk    Toplam      PTF  Year  Month
# 0     2021-01-01  00:00 28125.000 26465.840  263.990  2021      1
# 1     2021-01-01  01:00 26548.000 24844.670  236.990  2021      1
# 2     2021-01-01  02:00 25288.000 23274.450  216.700  2021      1
# 3     2021-01-01  03:00 24312.000 22453.180  218.070  2021      1
# 4     2021-01-01  04:00 23730.000 21981.510  208.990  2021      1
# ...          ...    ...       ...       ...      ...   ...    ...
# 10195 2022-01-03  19:00 42341.000 38940.640 1500.000  2022      1
# 10196 2022-01-03  20:00 41511.000 37780.440 1550.000  2022      1
# 10197 2022-01-03  21:00 40192.000 36446.010 1500.010  2022      1
# 10198 2022-01-03  22:00 39217.000 35978.740 1500.000  2022      1
# 10199 2022-01-03  23:00 37532.000 34447.460 1325.010  2022      1
#
# [10200 rows x 7 columns]

# %%
import datetime as dt

# %%
df_total["Days"] = pd. DatetimeIndex(df['Tarih']).dayofweek

# %%
df_total["Days"]
# Out:
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
#         ..
# 10195    0
# 10196    0
# 10197    0
# 10198    0
# 10199    0
# Name: Days, Length: 10200, dtype: int64

# %%
df_total['Year'] = pd. DatetimeIndex(df['Tarih']). year
df_total
# Out:
#            Tarih   Saat       Yuk    Toplam      PTF  Year  Month
# 0     2021-01-01  00:00 28125.000 26465.840  263.990  2021      1
# 1     2021-01-01  01:00 26548.000 24844.670  236.990  2021      1
# 2     2021-01-01  02:00 25288.000 23274.450  216.700  2021      1
# 3     2021-01-01  03:00 24312.000 22453.180  218.070  2021      1
# 4     2021-01-01  04:00 23730.000 21981.510  208.990  2021      1
# ...          ...    ...       ...       ...      ...   ...    ...
# 10195 2022-01-03  19:00 42341.000 38940.640 1500.000  2022      1
# 10196 2022-01-03  20:00 41511.000 37780.440 1550.000  2022      1
# 10197 2022-01-03  21:00 40192.000 36446.010 1500.010  2022      1
# 10198 2022-01-03  22:00 39217.000 35978.740 1500.000  2022      1
# 10199 2022-01-03  23:00 37532.000 34447.460 1325.010  2022      1
#
# [10200 rows x 7 columns]

# %%
from datetime import datetime, timedelta
  
# initializing dates ranges
test_date1, test_date2 = datetime(2021, 1, 1), datetime(2022, 1, 3)
  
# printing dates
print("The original range : " + str(test_date1) + " " + str(test_date2))
  
# generating dates
dates = (test_date1 + timedelta(idx + 1)
         for idx in range((test_date2 - test_date1).days))
  
# summing all weekdays
res = sum(1 for day in dates if day.weekday() < 5)
  
# printing
print("Total business days in range : " + str(res))
# Out:
# The original range : 2021-01-01 00:00:00 2022-01-03 00:00:00
# Total business days in range : 261

# %%
df_total.groupby("Month")[["Toplam","Yuk"]].mean().plot(kind="bar");

# %%
df_total.groupby("Month")[["PTF"]].mean().plot(kind="bar");

# %%
import plotly.express as px

# %%
fig = px.scatter(df_total, x="Toplam", y="PTF", color="Yuk", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
fig.show()

# %%
fig = px.sunburst(df_total, path=['Year','Month','Saat'], values='PTF',
                  color='PTF',
                  color_continuous_scale='RdBu')
fig.update_layout(title='Click various dates to view power PTF')
fig.update_layout( width=1600,height=1200)
fig.show()

# %%
fig = px.sunburst(df_total, path=['Year','Month','Saat'], values='Toplam',
                  color='Toplam',
                  color_continuous_scale='RdBu')
fig.update_layout(title="Click various dates an hours to view power 'Toplam MW'")
fig.update_layout( width=1600,height=1200)
fig.show()

# %%
fig = px.bar(df_total, x="Days", y="Yuk", barmode="group")
fig.show()

# %%
fig = px.bar(df_total, x="Saat", y="Yuk", barmode="group")
fig.show()

# %%
corr_by_PTF = df.corr()["PTF"].sort_values()[:-1]
corr_by_PTF
# Out:
# Fuel Oil      -0.188
# Barajlı       -0.109
# Akarsu        -0.107
# Diğer          0.001
# Doğal Gaz      0.060
# Rüzgar         0.080
# Nafta          0.122
# Taş Kömür      0.189
# Toplam         0.239
# Yuk            0.296
# Jeotermal      0.332
# İthal Kömür    0.453
# Linyit         0.584
# Biyokütle      0.841
# Name: PTF, dtype: float64

# %%
plt.figure(figsize = (20,10))
sns.barplot(x = corr_by_PTF.index, y = corr_by_PTF)
plt.xticks(rotation=90)
plt.tight_layout();

# %% [markdown]
# #Regressors

# %%
import scipy.stats as stats
import numpy as np

# %%
for i in df.drop(columns =["PTF","Tarih",'Saat']):
    print(f"corr between PTF and {i:<12}:  {df.PTF.corr(df[i])}")
# Out:
# corr between PTF and Doğal Gaz   :  0.05981585332208602
# corr between PTF and Rüzgar      :  0.0802381349030545
# corr between PTF and Linyit      :  0.583607753303034
# corr between PTF and Taş Kömür   :  0.18903008071175093
# corr between PTF and İthal Kömür :  0.4532329024347552
# corr between PTF and Fuel Oil    :  -0.18784967017977336
# corr between PTF and Jeotermal   :  0.3321268808097677
# corr between PTF and Barajlı     :  -0.10928186050836175
# corr between PTF and Nafta       :  0.12219708965280272
# corr between PTF and Biyokütle   :  0.841464006853912
# corr between PTF and Akarsu      :  -0.10651553624077736
# corr between PTF and Diğer       :  0.000568826537946972
# corr between PTF and Yuk         :  0.2955020507622273
# corr between PTF and Toplam      :  0.23887972775998012

# %%
sns.scatterplot(x="Toplam", y= "PTF",data=df)
# Out:
# <AxesSubplot:xlabel='Toplam', ylabel='PTF'>

# %%
corr = df['Toplam'].corr(df['PTF'])
corr
# Out:
# 0.23887972775998012

# %%
R2_score = corr**2
R2_score
# Out:
# 0.05706352433468222

# %%
sns.regplot(x="Toplam", y="PTF", data=df, ci=None)
# Out:
# <AxesSubplot:xlabel='Toplam', ylabel='PTF'>

# %%
# y_pred = b1X + b0

# %%
X= df["Toplam"]
y= df["PTF"]

# %%
np.polyfit(X, y, deg=1)
# Out:
# array([ 1.95199986e-02, -1.98814790e+01])

# %%
slope, intercept = np.polyfit(X, y, deg=1)

# %%
print("slope    :", slope)
print("intercept:", intercept)
# Out:
# slope    : 0.019519998625965814
# intercept: -19.88147902447599

# %%
b1, b0 = np.polyfit(X, y, deg=1)

# %%
print("b1 :", b1)
print("b0 :", b0)
# Out:
# b1 : 0.019519998625965814
# b0 : -19.88147902447599

# %%
y_pred = b1*X + b0   # b2*X2 + b1*X + b0

# %%
values = {"actual": y, "predicted": y_pred, "residual":y-y_pred, "LSE": (y-y_pred)**2}
df_2 = pd.DataFrame(values)
df_2
# Out:
#         actual  predicted  residual        LSE
# 0      263.990    496.732  -232.742  54168.690
# 1      236.990    465.086  -228.096  52027.988
# 2      216.700    434.436  -217.736  47408.858
# 3      218.070    418.405  -200.335  40133.937
# 4      208.990    409.198  -200.208  40083.069
# ...        ...        ...       ...        ...
# 10195 1500.000    740.240   759.760 577235.622
# 10196 1550.000    717.593   832.407 692901.983
# 10197 1500.010    691.545   808.465 653616.325
# 10198 1500.000    682.423   817.577 668431.372
# 10199 1325.010    652.533   672.477 452225.460
#
# [10200 rows x 4 columns]

# %%
df_2.LSE.sum()
# Out:
# 1300043863.2069793

# %%
potential_PTF = np.linspace(0, 500, 100)
potential_PTF
# Out:
# array([  0.        ,   5.05050505,  10.1010101 ,  15.15151515,
#         20.2020202 ,  25.25252525,  30.3030303 ,  35.35353535,
#         40.4040404 ,  45.45454545,  50.50505051,  55.55555556,
#         60.60606061,  65.65656566,  70.70707071,  75.75757576,
#         80.80808081,  85.85858586,  90.90909091,  95.95959596,
#        101.01010101, 106.06060606, 111.11111111, 116.16161616,
#        121.21212121, 126.26262626, 131.31313131, 136.36363636,
#        141.41414141, 146.46464646, 151.51515152, 156.56565657,
#        161.61616162, 166.66666667, 171.71717172, 176.76767677,
#        181.81818182, 186.86868687, 191.91919192, 196.96969697,
#        202.02020202, 207.07070707, 212.12121212, 217.17171717,
#        222.22222222, 227.27272727, 232.32323232, 237.37373737,
#        242.42424242, 247.47474747, 252.52525253, 257.57575758,
#        262.62626263, 267.67676768, 272.72727273, 277.77777778,
#        282.82828283, 287.87878788, 292.92929293, 297.97979798,
# ...

# %%
predicted_PTF_lin = b1* potential_PTF + b0
predicted_PTF_lin
# Out:
# array([-19.88147902, -19.78289317, -19.68430732, -19.58572147,
#        -19.48713562, -19.38854977, -19.28996391, -19.19137806,
#        -19.09279221, -18.99420636, -18.89562051, -18.79703466,
#        -18.6984488 , -18.59986295, -18.5012771 , -18.40269125,
#        -18.3041054 , -18.20551955, -18.10693369, -18.00834784,
#        -17.90976199, -17.81117614, -17.71259029, -17.61400444,
#        -17.51541858, -17.41683273, -17.31824688, -17.21966103,
#        -17.12107518, -17.02248933, -16.92390348, -16.82531762,
#        -16.72673177, -16.62814592, -16.52956007, -16.43097422,
#        -16.33238837, -16.23380251, -16.13521666, -16.03663081,
#        -15.93804496, -15.83945911, -15.74087326, -15.6422874 ,
#        -15.54370155, -15.4451157 , -15.34652985, -15.247944  ,
#        -15.14935815, -15.05077229, -14.95218644, -14.85360059,
#        -14.75501474, -14.65642889, -14.55784304, -14.45925718,
#        -14.36067133, -14.26208548, -14.16349963, -14.06491378,
# ...

# %%
plt.plot(potential_PTF, predicted_PTF_lin)
sns.scatterplot(x='Toplam',y='PTF',data=df)
# Out:
# <AxesSubplot:xlabel='Toplam', ylabel='PTF'>

# %% [markdown]
# SKLEARN

# %%
X = df.drop(columns =["PTF","Tarih",'Saat']) 
y = df["PTF"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state =42)

# %%
df.sample(15)
# Out:
#           Tarih   Saat  Doğal Gaz   Rüzgar   Linyit  Taş Kömür  İthal Kömür  \
# 7773 2021-11-20  21:00  11339.230 4271.710 4348.200    130.000     7806.200
# 8493 2021-12-20  21:00  14649.670 2253.680 4618.100    118.000     7846.500
# 3204 2021-05-14  12:00   2590.800 3167.650 4041.100    144.000     2203.000
# 8423 2021-12-17  23:00  14440.920 1878.800 4811.100    118.000     8000.500
# 5649 2021-08-24  09:00  17098.650 3577.060 4077.000    141.000     7149.000
# 1977 2021-03-24  09:00  11645.880 4218.470 4330.470    138.000     4993.600
# 7784 2021-11-21  08:00   8468.140 2929.480 4568.400    130.000     6385.500
# 7460 2021-07-11  20:00   9751.840 1979.690 4328.100    122.000     6794.950
# 3436 2021-05-24  04:00   8032.960 2626.890 4176.650    144.000     4482.000
# 8953 2022-09-01  01:00   8837.300 3239.830 4904.100    108.000     7511.300
# 4603 2021-11-07  19:00  13538.530 5049.920 4504.200    117.000     6705.500
# ...

# %%
print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (7140, 14)
# Train target shape   :  (7140,)
# Test features shape  :  (3060, 14)
# Test target shape    :  (3060,)

# %%
X_train
# Out:
#       Doğal Gaz   Rüzgar   Linyit  Taş Kömür  İthal Kömür  Fuel Oil  \
# 9173   9803.350 3366.500 5076.100     98.000     7794.500     0.600
# 8542  14196.600 1358.090 4276.950    210.000     7988.500     7.600
# 2868   8591.490 1331.560 4172.070    142.000     4135.700     5.800
# 2718   6449.080 2150.880 3827.150    142.000     2513.700     5.700
# 8829  12131.090 4225.220 5094.000    120.500     7087.250     7.600
# ...         ...      ...      ...        ...          ...       ...
# 5734  17426.850 1213.570 4660.230    141.000     7748.200     0.000
# 5191  16552.490 2325.770 4964.000    134.500     6158.500     0.400
# 5390  16220.090 6124.600 4243.000    136.000     7327.900     7.400
# 860   11544.250 1056.190 4426.050    142.000     7888.600     5.800
# 7270  12536.190 3756.440 4615.000    122.000     3014.800     7.600
#
#       Jeotermal  Barajlı  Nafta  Biyokütle   Akarsu   Diğer       Yuk  \
# 9173   1201.900  414.320  0.000    799.840  853.190 354.100 32277.000
# ...

# %%
y_train
# Out:
# 9173    825.000
# 8542   1217.000
# 2868    353.030
# 2718    300.010
# 8829   1195.500
#          ...
# 5734    636.000
# 5191    636.000
# 5390    636.000
# 860     320.070
# 7270    560.090
# Name: PTF, Length: 7140, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([1206.764838  ,  693.40020708, 1209.83313787, ..., 1178.29761825,
#         715.90592752,  407.43479774])

# %%
model.coef_
# Out:
# array([-1.72861952e+00, -1.74066024e+00, -1.66217534e+00, -1.16817080e+00,
#        -1.69798420e+00, -1.75484858e+00, -1.15117543e+00, -1.73562137e+00,
#         1.63256229e+01,  1.57407316e+00, -1.71201993e+00, -1.81340884e+00,
#         1.08693070e-02,  1.73501179e+00])

# %%
model.intercept_
# Out:
# -3240.75993671985

# %%
X_test
# Out:
#        Doğal Gaz   Rüzgar   Linyit  Taş Kömür  İthal Kömür  Fuel Oil  \
# 10078   6841.110 7905.790 4700.400    244.000     6347.200     0.300
# 3742   10106.200 3437.120 4204.020    138.000     4526.000     7.600
# 10068   9325.520 7457.160 4334.400    260.000     6619.200     0.300
# 5723   17081.820  399.310 4636.150    141.000     7742.200     0.000
# 8987   13073.140 3903.740 4914.400    216.000     7882.300     0.600
# ...          ...      ...      ...        ...          ...       ...
# 7529    8484.380 7869.940 4472.120    122.000     7761.200     7.600
# 9047    7383.100 7230.290 5226.120     95.000     7145.300     0.600
# 10051  11275.520 4553.290 4529.400    260.000     6703.200     7.000
# 6424   12674.950 2068.460 5097.000    120.000     4547.700     7.700
# 4984   15150.020 6090.810 4754.000    117.000     6585.000     7.300
#
#        Jeotermal  Barajlı  Nafta  Biyokütle   Akarsu    Diğer       Yuk  \
# ...

# %%
sum(X_test.loc[10078] * model.coef_) + model.intercept_
# Out:
# 1206.7648380012024

# %%
my_dict = {"Actual": y_test, "Pred": y_pred, "Residual":y_test-y_pred}

# %%
comparing = pd.DataFrame(my_dict)
comparing
# Out:
#         Actual     Pred  Residual
# 10078 1199.990 1206.765    -6.775
# 3742   371.090  693.400  -322.310
# 10068 1234.000 1209.833    24.167
# 5723   636.000  791.270  -155.270
# 8987  1345.000 1196.749   148.251
# ...        ...      ...       ...
# 7529   979.990 1067.438   -87.448
# 9047   864.790 1179.707  -314.917
# 10051 1504.260 1178.298   325.962
# 6424   453.630  715.906  -262.276
# 4984   617.000  407.435   209.565
#
# [3060 rows x 3 columns]

# %%
result_sample = comparing.head(25)
result_sample
# Out:
#         Actual     Pred  Residual
# 10078 1199.990 1206.765    -6.775
# 3742   371.090  693.400  -322.310
# 10068 1234.000 1209.833    24.167
# 5723   636.000  791.270  -155.270
# 8987  1345.000 1196.749   148.251
# 6522   589.990  736.382  -146.392
# 3149   351.360  404.674   -53.314
# 2876   372.170  410.435   -38.265
# 5914   538.990  740.620  -201.630
# 7744  1119.990 1014.853   105.137
# 5700   636.000  729.945   -93.945
# 4689   385.000  379.613     5.387
# 1780   241.110  304.801   -63.691
# 8904  1023.930 1122.550   -98.620
# 4359   617.000  521.771    95.229
# 7732   669.980  861.179  -191.199
# 3794   355.030  455.494  -100.464
# 3370   370.460  303.670    66.790
# 6013   449.990  644.413  -194.423
# 5803   636.000  689.615   -53.615
# 8778  1345.000 1273.276    71.724
# 9077   800.010 1048.625  -248.615
# 3053   349.570  362.883   -13.313
# 3288   356.830  313.123    43.707
# 2589   325.860  342.485   -16.625

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
R2_score = r2_score(y_test, y_pred)
R2_score
# Out:
# 0.8033412234269874

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 129.75338098348035

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 26616.024630130058

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
rmse
# Out:
# 163.14418356205672

# %%
PTF_mean = df["PTF"].mean()
PTF_mean
# Out:
# 618.5079637254902

# %%
mae / PTF_mean
# Out:
# 0.20978449525844464

# %%
rmse / PTF_mean
# Out:
# 0.26377054642818526

# %% [markdown]
# Adjusted R2 score

# %%
def adj_r2(y_test, y_pred, df):
    r2 = r2_score(y_test, y_pred)
    n = df.shape[0]   # number of observations
    p = df.shape[1]-1 # number of independent variables 
    adj_r2 = 1 - (1-r2)*(n-1)/(n-p-1)
    return adj_r2

# %%
adj_r2(y_test, y_pred, df)
# Out:
# 0.8030322240726548

# %% [markdown]
# Evaluation Model

# %%
def eval_metric(actual, pred):
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    rmse = np.sqrt(mean_squared_error(actual, pred))
    R2_score = r2_score(actual, pred)
    print("Model testing performance:")
    print("--------------------------")
    print(f"R2_score \t\t: {R2_score}")
    print(f"MAE \t\t: {mae}")
    print(f"MSE \t\t: {mse}")
    print(f"RMSE \t\t: {rmse}")

# %%
eval_metric(y_test, y_pred)
# Out:
# Model testing performance:
# --------------------------
# R2_score 		: 0.8033412234269874
# MAE 		: 129.75338098348035
# MSE 		: 26616.024630130058
# RMSE 		: 163.14418356205672

# %%
y_train_pred = model.predict(X_train)

# %%
eval_metric(y_train, y_train_pred)
# Out:
# Model testing performance:
# --------------------------
# R2_score 		: 0.8075157845405685
# MAE 		: 128.28143197996695
# MSE 		: 26002.873819501063
# RMSE 		: 161.25406605571553

# %% [markdown]
# CV ihtiyac yok gibi

# %% [markdown]
# Is data suitable for linear regression?
# https://stats.stackexchange.com/questions/12262/what-if-residuals-are-normally-distributed-but-y-is-not

# %%
residuals = y_test-y_pred

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x = y_test, y = residuals) #-residuals
plt.axhline(y = 0, color ="r", linestyle = "--")
plt.ylabel("residuals")
plt.show()

# %%
sns.kdeplot(residuals)
# Out:
# <AxesSubplot:xlabel='PTF', ylabel='Density'>

# %%
stats.probplot(residuals, dist ="norm", plot =plt);

# %%
from scipy.stats import skew
skew(residuals)
# Out:
# 0.3605105933358722

# %%
from yellowbrick.regressor import ResidualsPlot

# Instantiate the linear model and visualizer
model = LinearRegression()
visualizer = ResidualsPlot(model)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show();        # Finalize and render the figure

# %%
from yellowbrick.regressor import PredictionError
# Instantiate the linear model and visualizer
model = LinearRegression()
visualizer = PredictionError(model)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show();

# %%
final_model = LinearRegression()

# %%
final_model.fit(X, y)
# Out:
# LinearRegression()

# %%
final_model.coef_
# Out:
# array([-1.91443035e+00, -1.92685867e+00, -1.84989254e+00, -1.37248825e+00,
#        -1.88387144e+00, -2.09536832e+00, -1.35695033e+00, -1.92169498e+00,
#         1.87415163e+01,  1.39626706e+00, -1.89804444e+00, -1.99761941e+00,
#         1.09421665e-02,  1.92056461e+00])

# %%
final_model.intercept_
# Out:
# -3204.545295595176

# %%
coeff_df = pd.DataFrame(final_model.coef_, index = X.columns, columns = ["Coefficient"] )

# %%
coeff_df
# Out:
#              Coefficient
# Doğal Gaz         -1.914
# Rüzgar            -1.927
# Linyit            -1.850
# Taş Kömür         -1.372
# İthal Kömür       -1.884
# Fuel Oil          -2.095
# Jeotermal         -1.357
# Barajlı           -1.922
# Nafta             18.742
# Biyokütle          1.396
# Akarsu            -1.898
# Diğer             -1.998
# Yuk                0.011
# Toplam             1.921
