# %%
import pyforest
import plotly
import cufflinks as cf
#Enabling the offline mode for interactive plotting locally
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
#To display the plots
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
from sklearn.metrics import make_scorer
from sklearn.metrics import classification_report,confusion_matrix,plot_confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve, auc
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
# ...

# %% [markdown]
# ### Read Dataset

# %%
df_train = pd.read_csv("health_train.csv")
df_train
# Out:
#             age     sex        bmi smoker     region  children       charges
# 0     21.000000    male  25.745000     no  northeast         2   3279.868550
# 1     36.976978  female  25.744165    yes  southeast         3  21454.494239
# 2     18.000000    male  30.030000     no  southeast         1   1720.353700
# 3     37.000000    male  30.676891     no  northeast         3   6801.437542
# 4     58.000000    male  32.010000     no  southeast         1  11946.625900
# ...         ...     ...        ...    ...        ...       ...           ...
# 2495  31.058051    male  27.555148     no  southeast         4   5889.103901
# 2496  36.833818    male  30.322446     no  northeast         3   6788.534095
# 2497  56.000000  female  36.179587     no  northwest         2  12401.746575
# 2498  49.000000    male  36.429614     no  northwest         3  10376.294629
# 2499  33.000000    male  36.640579     no  southwest         5   6658.237404
#
# [2500 rows x 7 columns]

# %%
df_test = pd.read_csv("health_test.csv")
df_test
# Out:
#            age     sex        bmi smoker     region  children
# 0    39.296556    male  29.978109     no  northwest         4
# 1    40.367560  female  27.927669     no  southeast         5
# 2    32.881563    male  41.576865     no  southwest         5
# 3    62.000000  female  30.495000     no  northwest         2
# 4    32.476173    male  30.322774    yes  northeast         4
# 5    22.317659    male  32.305187     no  northeast         5
# 6    46.160394    male  34.097296     no  northwest         3
# 7    39.474347    male  25.238490     no  southeast         5
# 8    41.551239    male  31.214778     no  southeast         5
# 9    19.000000    male  25.555000     no  northwest         0
# 10   44.044943  female  27.301484     no  southeast         5
# 11   26.000000  female  30.221437     no  southeast         1
# 12   52.037272    male  33.203793     no  northeast         1
# 13   39.457543  female  23.060800     no  northeast         3
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       2500 non-null   float64
#  1   sex       2500 non-null   object
#  2   bmi       2500 non-null   float64
#  3   smoker    2500 non-null   object
#  4   region    2500 non-null   object
#  5   children  2500 non-null   int64
#  6   charges   2500 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 136.8+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       451 non-null    float64
#  1   sex       451 non-null    object
#  2   bmi       451 non-null    float64
#  3   smoker    451 non-null    object
#  4   region    451 non-null    object
#  5   children  451 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 21.3+ KB

# %%
df_train.describe().T
# Out:
#            count          mean           std        min          25%          50%           75%          max
# age       2500.0     39.003033     12.264536    18.0000    28.845667    39.350208     48.688741     64.00000
# bmi       2500.0     30.575497      5.390169    15.9600    26.717647    30.200000     34.046166     53.13000
# children  2500.0      2.488400      1.707346     0.0000     1.000000     2.000000      4.000000      5.00000
# charges   2500.0  12679.311518  10593.270485  1121.8739  5612.780878  9455.047274  14440.628060  63770.42801

# %%
df_test.describe().T
# Out:
#           count       mean        std   min        25%        50%        75%    max
# age       451.0  38.806482  11.789015  18.0  30.000000  39.000000  48.000000  64.00
# bmi       451.0  30.833082   5.538067  17.8  26.733148  30.322774  34.181785  47.74
# children  451.0   2.556541   1.738012   0.0   1.000000   3.000000   4.000000   5.00

# %%
df_train.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# smoker      0
# region      0
# children    0
# charges     0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# smoker      0
# region      0
# children    0
# dtype: int64

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_train = df_train.round({"age": 0, "bmi": 2})
df_train
# Out:
#        age     sex    bmi smoker     region  children       charges
# 0     21.0    male  25.74     no  northeast         2   3279.868550
# 1     37.0  female  25.74    yes  southeast         3  21454.494239
# 2     18.0    male  30.03     no  southeast         1   1720.353700
# 3     37.0    male  30.68     no  northeast         3   6801.437542
# 4     58.0    male  32.01     no  southeast         1  11946.625900
# ...    ...     ...    ...    ...        ...       ...           ...
# 2495  31.0    male  27.56     no  southeast         4   5889.103901
# 2496  37.0    male  30.32     no  northeast         3   6788.534095
# 2497  56.0  female  36.18     no  northwest         2  12401.746575
# 2498  49.0    male  36.43     no  northwest         3  10376.294629
# 2499  33.0    male  36.64     no  southwest         5   6658.237404
#
# [2500 rows x 7 columns]

# %%
df_test = df_test.round({"age": 0, "bmi": 2})
df_test
# Out:
#       age     sex    bmi smoker     region  children
# 0    39.0    male  29.98     no  northwest         4
# 1    40.0  female  27.93     no  southeast         5
# 2    33.0    male  41.58     no  southwest         5
# 3    62.0  female  30.50     no  northwest         2
# 4    32.0    male  30.32    yes  northeast         4
# 5    22.0    male  32.31     no  northeast         5
# 6    46.0    male  34.10     no  northwest         3
# 7    39.0    male  25.24     no  southeast         5
# 8    42.0    male  31.21     no  southeast         5
# 9    19.0    male  25.56     no  northwest         0
# 10   44.0  female  27.30     no  southeast         5
# 11   26.0  female  30.22     no  southeast         1
# 12   52.0    male  33.20     no  northeast         1
# 13   39.0  female  23.06     no  northeast         3
# 14   49.0    male  28.69     no  northwest         3
# 15   23.0    male  32.90     no  northeast         5
# 16   35.0    male  29.15     no  southeast         4
# ...

# %%
for col in df_train.select_dtypes('object').columns:
    print(f"{col:<20}:", df_train[col].nunique())
# Out:
# sex                 : 2
# smoker              : 2
# region              : 4

# %%
for col in df_test.select_dtypes('object').columns:
    print(f"{col:<20}:", df_test[col].nunique())
# Out:
# sex                 : 2
# smoker              : 2
# region              : 4

# %%
sns.heatmap(df_train.corr(), annot =True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (10,5))
sns.barplot(x = df_train.corr()["charges"].index, y = df_train.corr()["charges"])
plt.xticks(rotation=90)
plt.tight_layout();

# %%
sns.boxplot(df_train.age)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.boxplot(df_train.bmi)
# Out:
# <AxesSubplot:xlabel='bmi'>

# %%
sns.boxplot(df_train.children)
# Out:
# <AxesSubplot:xlabel='children'>

# %% [raw]
# index = 0
# plt.figure(figsize=(20,20))
# for feature in df_train.columns:
#     if feature != "charges":
#         index += 1
#         plt.subplot(5, 3, index)
#         sns.boxplot(x='charges', y = feature, data=df_train)

# %% [raw]
# index = 0
# for feature in df_train.columns:
#         index += 1
#         print(df_train[feature].name)
#         print("***********")
#         print(df_train[feature].value_counts())

# %%
# df_train.corr()["charges"].drop("charges").sort_values().plot.barh()

# %%
# sns.pairplot(df_train, hue = "charges")

# %% [markdown]
# # DATA Preprocessing

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
X=df_train.drop("charges", axis=1)
y=df_train.charges

# %%
cat1=df_test.select_dtypes("object").columns

# %%
cat = X.select_dtypes("object").columns
cat
# Out:
# Index(['sex', 'smoker', 'region'], dtype='object')

# %%
enc = OrdinalEncoder()
X[cat] = enc.fit_transform(X[cat])
X.head()
# Out:
#     age  sex    bmi  smoker  region  children
# 0  21.0  1.0  25.74     0.0     0.0         2
# 1  37.0  0.0  25.74     1.0     2.0         3
# 2  18.0  1.0  30.03     0.0     2.0         1
# 3  37.0  1.0  30.68     0.0     0.0         3
# 4  58.0  1.0  32.01     0.0     2.0         1

# %%
enc = OrdinalEncoder()
df_test[cat] = enc.fit_transform(df_test[cat])
df_test.head()
# Out:
#     age  sex    bmi  smoker  region  children
# 0  39.0  1.0  29.98     0.0     1.0         4
# 1  40.0  0.0  27.93     0.0     2.0         5
# 2  33.0  1.0  41.58     0.0     3.0         5
# 3  62.0  0.0  30.50     0.0     1.0         2
# 4  32.0  1.0  30.32     1.0     0.0         4

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2, random_state=5)

print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (2000, 6)
# Train target shape   :  (2000,)
# Test features shape  :  (500, 6)
# Test target shape    :  (500,)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
def train_val(model, X_train, y_train, X_test, y_test, i):
    
    y_pred = model.predict(X_test)
    y_train_pred = model.predict(X_train)
    
    scores = {i+"_train": {"R2" : r2_score(y_train, y_train_pred),
    "mae" : mean_absolute_error(y_train, y_train_pred),
    "mse" : mean_squared_error(y_train, y_train_pred),                          
    "rmse" : np.sqrt(mean_squared_error(y_train, y_train_pred))},
    
     i+"_test": {"R2" : r2_score(y_test, y_pred),
    "mae" : mean_absolute_error(y_test, y_pred),
    "mse" : mean_squared_error(y_test, y_pred),
    "rmse" : np.sqrt(mean_squared_error(y_test, y_pred))}}
    
    return pd.DataFrame(scores)

# %% [markdown]
# ## 1. DecisionTree

# %% [raw]
# classification da criterion olarak gini vardı ancak regresyonda criterion parametresinde meansquarederror üzerinden işlemlerimizi yapıyoruz. mse bizim variance gösterir. Classf. birbirine yakın olan sınıflara göre ayrım yaparken regresyonda fiyatları birbirine yakın olan arabalara göre ayrım yapar. bunun yaparken mse düşecek.

# %%
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor

# %%
DT_model = DecisionTreeRegressor(random_state=101)
DT_model.fit(X_train, y_train)
train_val(DT_model, X_train, y_train, X_test, y_test, "dt")
# Out:
#           dt_train       dt_test
# R2        0.999171  8.216505e-01
# mae       9.651313  1.835662e+03
# mse   91600.322364  2.111507e+07
# rmse    302.655452  4.595114e+03

# %% [markdown]
# ### CV

# %%
from sklearn.model_selection import cross_validate, cross_val_score
model = DecisionTreeRegressor(random_state=101)
scores = cross_validate(model, X_train, y_train, scoring=['r2', 
            'neg_mean_absolute_error','neg_mean_squared_error','neg_root_mean_squared_error'], cv =10)
df_scores = pd.DataFrame(scores)
df_scores.mean()[2:]
# Out:
# test_r2                             7.550087e-01
# test_neg_mean_absolute_error       -1.988574e+03
# test_neg_mean_squared_error        -2.707117e+07
# test_neg_root_mean_squared_error   -5.166418e+03
# dtype: float64

# %% [raw]
# CV ile aldığımız scoreların dahada kötü olduğunu gördük ve burada bir overfitting olduğuna karar kıldık.

# %% [markdown]
# ### GridSearch for DT

# %%
param_grid = {"splitter":["best", "random"],
            "max_depth": [None, 4, 5, 6, 7, 8],
              "min_samples_leaf": [1, 2, 3, 4, 5, 6],
             "min_samples_split": [2, 3, 5, 6, 7]}

# %%
model = DecisionTreeRegressor(random_state=101)
dt_model = GridSearchCV(estimator=model,
                          param_grid=param_grid,
                          scoring='neg_root_mean_squared_error',
                          cv=10,
                          n_jobs = -1)

# %%
dt_model.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeRegressor(random_state=101),
#              n_jobs=-1,
#              param_grid={'max_depth': [None, 4, 5, 6, 7, 8],
#                          'min_samples_leaf': [1, 2, 3, 4, 5, 6],
#                          'min_samples_split': [2, 3, 5, 6, 7],
#                          'splitter': ['best', 'random']},
#              scoring='neg_root_mean_squared_error')

# %%
dt_model.best_estimator_
# Out:
# DecisionTreeRegressor(max_depth=8, min_samples_leaf=6, random_state=101)

# %%
dt_model.best_params_
# Out:
# {'max_depth': 8,
#  'min_samples_leaf': 6,
#  'min_samples_split': 2,
#  'splitter': 'best'}

# %%
dt_model.best_score_
# Out:
# -4209.482116565105

# %%
dt = train_val(dt_model, X_train, y_train, X_test, y_test, "dt")
dt
# Out:
#           dt_train       dt_test
# R2    9.035324e-01  8.873450e-01
# mae   1.620833e+03  1.880511e+03
# mse   1.066013e+07  1.333740e+07
# rmse  3.264985e+03  3.652041e+03

# %% [markdown]
# ### Feature İmportance

# %%
model = DecisionTreeRegressor(random_state=101, max_depth=8, min_samples_leaf=6, min_samples_split=2, splitter="best")
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=8, min_samples_leaf=6, random_state=101)

# %%
model.feature_importances_
# Out:
# array([1.06120636e-01, 2.81881204e-04, 1.64448912e-01, 6.32892469e-01,
#        4.35869689e-02, 5.26691315e-02])

# %%
imp_feats = pd.DataFrame(index=X.columns, data=model.feature_importances_,columns=['dt_Importance'])
dt_imp_feats = imp_feats.sort_values('dt_Importance')
dt_imp_feats
# Out:
#           dt_Importance
# sex            0.000282
# region         0.043587
# children       0.052669
# age            0.106121
# bmi            0.164449
# smoker         0.632892

# %% [markdown]
# ## 2. RF

# %% [raw]
# n_estimator(ağaç sayısı) ve feature sayısını bootstrap ile alması. bir diğer husus ise max_feature da her zaman en iyi feature almak için feature ların karekökünü alarak her ağaç için belirliyor bunu. rassallık oluşsun diye.
#
# regresyonda bunu default değerde bırakırsak her zaman en iyi feature secer bunu engellemek için parametreler iyi oynamamız gerekir. gridsearch ile müdahale etmek gerekir.
#
# regresyonda maxfeature için 2/3, classification da maxfeature için karekökünü kullanıyoruz (burada default olarak karekökünü kullandığından dolayı ilave birşey yapmaya gerek yok.)
#
# RF, baggingin özel bir kullanım methodudur. bagging sadece subbamples ile ilgilenir. classifier ve featurelar üzerinden bir etkisi olmaz. RF hem subsamples üzerinde 2/3 ile uğraşıp hem de featureları değiştererek farklı ağaçlar elde etmiştir.
#
# classificationda  maxfeature auto karekök alıp int olarak aşağı çeviriyordu. regresyonda ise  max_features default değer auto yani treebased modelin yaptığı gibi benim feature import. en önemli hangisi ise onu veriyor. yani benim tüm featurelarımı kullanıyor. ancak bunlar içerisinde treebased modelin yaptığı gibi en güçlü feature seçiyor. tek farkı boostrap yapıyor. kullandığı gözlemler farklı her ağaçta 2/3 kullanıyor.  gridsearch yaparken max_feature mutlaka bulundurmakta fayda var.

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(random_state=101)
rf_model.fit(X_train,y_train)
train_val(rf_model, X_train, y_train, X_test, y_test, "rf")
# Out:
#           rf_train       rf_test
# R2    9.801281e-01  9.098598e-01
# mae   6.762029e+02  1.602785e+03
# mse   2.195944e+06  1.067184e+07
# rmse  1.481872e+03  3.266779e+03

# %% [markdown]
# ### CV

# %%
from sklearn.model_selection import cross_validate, cross_val_score
model = RandomForestRegressor(random_state=101)
scores = cross_validate(model, X_train, y_train, scoring=['r2', 
            'neg_mean_absolute_error','neg_mean_squared_error','neg_root_mean_squared_error'], cv =10)
df_scores = pd.DataFrame(scores)
df_scores.mean()[2:]
# Out:
# test_r2                             8.590850e-01
# test_neg_mean_absolute_error       -1.857897e+03
# test_neg_mean_squared_error        -1.556523e+07
# test_neg_root_mean_squared_error   -3.902274e+03
# dtype: float64

# %% [markdown]
# ### GridSearch for RF

# %%
param_grid = {"n_estimators":[200, 500],
              "max_depth": [None, 4, 5],
              "min_samples_leaf": [1, 2],
              "min_samples_split": [2, 3],
              "max_features":['auto', len(df_train.columns)/3]}

# %%
model = RandomForestRegressor(random_state=101)
rf_model = GridSearchCV(estimator=model,
                          param_grid=param_grid,
                          scoring='neg_root_mean_squared_error',
                          cv=5,
                          n_jobs = -1)

# %%
rf_model.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=101), n_jobs=-1,
#              param_grid={'max_depth': [None, 4, 5],
#                          'max_features': ['auto', 2.3333333333333335],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 3],
#                          'n_estimators': [200, 500]},
#              scoring='neg_root_mean_squared_error')

# %%
rf_model.best_params_
# Out:
# {'max_depth': None,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'min_samples_split': 3,
#  'n_estimators': 200}

# %%
rf_model.best_score_
# Out:
# -3934.0449622336664

# %%
rf = train_val(rf_model, X_train, y_train, X_test, y_test, "rf")
rf
# Out:
#           rf_train       rf_test
# R2    9.743921e-01  9.105760e-01
# mae   7.800764e+02  1.627609e+03
# mse   2.829789e+06  1.058705e+07
# rmse  1.682198e+03  3.253774e+03

# %% [markdown]
# ### Feature İmportance

# %%
model = RandomForestRegressor(random_state=101, max_depth=None, max_features= "auto", min_samples_leaf = 1, min_samples_split=3, n_estimators= 200)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(min_samples_split=3, n_estimators=200, random_state=101)

# %%
model.feature_importances_
# Out:
# array([0.1197762 , 0.00682705, 0.19101453, 0.57603913, 0.04298248,
#        0.06336062])

# %%
imp_feats = pd.DataFrame(index=X.columns, data=model.feature_importances_,columns=['rf_Importance'])
rf_imp_feats = imp_feats.sort_values('rf_Importance')
rf_imp_feats
# Out:
#           rf_Importance
# sex            0.006827
# region         0.042982
# children       0.063361
# age            0.119776
# bmi            0.191015
# smoker         0.576039

# %% [markdown]
# ## 3. Adaboost

# %% [raw]
# Adaboost her bir gözlem için her ağaca bir ağırlık verir ve bunun değerini alır. regresyonda variance göre atadığından dolayı fiyatı birbirine daha yakın olan arabaların arasına atadı.

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor

# %% [raw]
# treebased modellerde daha iyi score verdiğinden dolayı base_estimator kullandım. regresyon modellerinde ağaçlanma class. göre daha fazla olduğundan dolayi tek derinlik yani max_depth=1 düşük olduğundan dolayı max_depth=3 aldım.

# %%
ada_model = AdaBoostRegressor(random_state=101, n_estimators=50, base_estimator=DecisionTreeRegressor(max_depth=3))

# %%
ada_model.fit(X_train, y_train)
# Out:
# AdaBoostRegressor(base_estimator=DecisionTreeRegressor(max_depth=3),
#                   random_state=101)

# %%
train_val(ada_model, X_train, y_train, X_test, y_test, "ada")
# Out:
#          ada_train      ada_test
# R2    5.272671e-01  5.771362e-01
# mae   6.785113e+03  6.588787e+03
# mse   5.223922e+07  5.006351e+07
# rmse  7.227670e+03  7.075557e+03

# %% [markdown]
# ### CV

# %%
from sklearn.model_selection import cross_validate, cross_val_score
model = AdaBoostRegressor(random_state=101, n_estimators=50, base_estimator=DecisionTreeRegressor(max_depth=3))
scores = cross_validate(model, X_train, y_train, scoring=['r2', 
            'neg_mean_absolute_error','neg_mean_squared_error','neg_root_mean_squared_error'], cv =10)
pd.DataFrame(scores)
pd.DataFrame(scores).mean()[2:]
# Out:
# test_r2                             5.859225e-01
# test_neg_mean_absolute_error       -6.095433e+03
# test_neg_mean_squared_error        -4.531957e+07
# test_neg_root_mean_squared_error   -6.702439e+03
# dtype: float64

# %% [raw]
# score lara bakınca train ve test seti scoreları arasında ciddi bir fark yok ve bir overfitting yokmuş gibi gözüküyor. CV ile aldığımız scoreları bakınca rmse değerlerinin daha da düştüğünü gördüm.

# %% [markdown]
# ### GridSearchCV for Adaboost

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {"n_estimators":[50, 100, 200, 300, 500],
              "learning_rate":[0.1, 0.5, 0.8, 1],
              "loss": ["linear", "square"]  
            }

# %%
model = AdaBoostRegressor(random_state=101, n_estimators=50, base_estimator=DecisionTreeRegressor(max_depth=3))
grid_model = GridSearchCV(estimator=model,
                          param_grid=param_grid,
                          scoring='neg_root_mean_squared_error',
                          cv=10,
                          n_jobs = -1)

# %%
grid_model.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(max_depth=3),
#                                          random_state=101),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.1, 0.5, 0.8, 1],
#                          'loss': ['linear', 'square'],
#                          'n_estimators': [50, 100, 200, 300, 500]},
#              scoring='neg_root_mean_squared_error')

# %%
grid_model.best_params_
# Out:
# {'learning_rate': 0.1, 'loss': 'linear', 'n_estimators': 50}

# %% [raw]
# learning rate oranını azaltırsam bir sonraki ağaçta ağırlıklandırmayı ne kadar agresif yapıp yapmayacağına karar veriyor. bunu artırınca hatayı 2-3 ağaç sonra düzeltmeye çalışıyor. bu durum ise bizde overfittinge sebep oluyor. ben bu sorunu hemen değil daha fazla ağaçta çözmeye çalışmasını istiyorum.

# %%
grid_model.best_score_
# Out:
# -5124.961734568571

# %%
ada = train_val(grid_model, X_train, y_train, X_test, y_test,"ada")
ada
# Out:
#          ada_train      ada_test
# R2    7.700176e-01  8.260771e-01
# mae   3.662932e+03  3.418625e+03
# mse   2.541415e+07  2.059100e+07
# rmse  5.041245e+03  4.537731e+03

# %% [raw]
# görüldüğü gibi GridSearch ile aldığım parametrelere göre rmse değerleri daha iyi scorelar verdi.

# %% [markdown]
# ### Feature İmportance

# %%
model = AdaBoostRegressor(random_state=101, n_estimators=50, loss = "linear", learning_rate=0.1)
model.fit(X_train, y_train)
# Out:
# AdaBoostRegressor(learning_rate=0.1, random_state=101)

# %%
model.feature_importances_
# Out:
# array([0.09776767, 0.        , 0.15972299, 0.68430695, 0.0372476 ,
#        0.02095479])

# %%
imp_feats = pd.DataFrame(index=X.columns, data=model.feature_importances_,columns=['ada_Importance'])
ada_imp_feats = imp_feats.sort_values('ada_Importance')
ada_imp_feats
# Out:
#           ada_Importance
# sex             0.000000
# children        0.020955
# region          0.037248
# age             0.097768
# bmi             0.159723
# smoker          0.684307

# %% [markdown]
# ## 4. GradientBoosting

# %% [raw]
# linear modellerde ypred değerlerini ytest değerlerine yaklaştırmaya çalışıyorduk.Ancak gradientboosting biz bunlar arasındaki farkı minimize etmeye yani 0 yaklaştırmaya çalışıyoruz.
#
# Bu modellerde ilk önce kendisine bir başlanğıç değeri alıyor. Bu değere göre alınan değerleri ya büyütecek veya küçültecek şekilde hareket ediyor. ilk başlanğıç değeri olarak datam daki target sütunun değerlerinin toplamının ortalaması yani mean değeri olacak.
#
# her ağaç sonucunda bulduğumuz değerleri learning rate ile çarparak bunları ilk başlangıç olasılık değeri ile toplayıp bunları ilk başlangıç değerine doğru azaltmaya, diğerini ise artırmaya çalışıyor.
#
# burada subsample alabiliyoruz. subsample ise bir alt örneklem oluşturarak daha hızlı çalışmama imkan sağlıyor.
#
# max_depth çok yükseltmemek gerekir.

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
grad_model = GradientBoostingRegressor(random_state=101)

# %%
grad_model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=101)

# %%
train_val(grad_model, X_train, y_train, X_test, y_test, "gb")
# Out:
#           gb_train       gb_test
# R2    8.787534e-01  9.021180e-01
# mae   1.971879e+03  1.989505e+03
# mse   1.339832e+07  1.158841e+07
# rmse  3.660372e+03  3.404175e+03

# %% [markdown]
# ### CV

# %%
model = GradientBoostingRegressor(random_state=101)
scores = cross_validate(model, X_train, y_train, scoring=['r2', 
            'neg_mean_absolute_error','neg_mean_squared_error','neg_root_mean_squared_error'], cv =10)
pd.DataFrame(scores)
pd.DataFrame(scores).mean()[2:]
# Out:
# test_r2                             8.481844e-01
# test_neg_mean_absolute_error       -2.203124e+03
# test_neg_mean_squared_error        -1.685562e+07
# test_neg_root_mean_squared_error   -4.057681e+03
# dtype: float64

# %% [raw]
# scoreların iyileştiğini ve overfitting kısmen ortadan kaldırıldığını görüyoruzb

# %% [markdown]
# ### GridSearchCV for GradientBoosting

# %%
param_grid = {"n_estimators":[100,300], "subsample":[0.8, 1], "max_features" : [None, 2, 3, 4],
            "learning_rate": [0.01, 0.1, 1], 'max_depth':[2,3]}

# %%
model = GradientBoostingRegressor(random_state=101)
grid_model = GridSearchCV(estimator=model,
                          param_grid=param_grid,
                          scoring='neg_root_mean_squared_error',
                          cv=10,
                          n_jobs = -1)

# %%
grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=GradientBoostingRegressor(random_state=101),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.1, 1], 'max_depth': [2, 3],
#                          'max_features': [None, 2, 3, 4],
#                          'n_estimators': [100, 300], 'subsample': [0.8, 1]},
#              scoring='neg_root_mean_squared_error')

# %%
grid_model.best_params_
# Out:
# {'learning_rate': 0.1,
#  'max_depth': 3,
#  'max_features': 2,
#  'n_estimators': 300,
#  'subsample': 0.8}

# %%
grid_model.best_score_
# Out:
# -4055.254227466453

# %%
gb = train_val(grid_model, X_train, y_train, X_test, y_test, "gb")
gb
# Out:
#           gb_train       gb_test
# R2    8.985083e-01  9.027258e-01
# mae   1.794335e+03  1.947514e+03
# mse   1.121531e+07  1.151645e+07
# rmse  3.348927e+03  3.393589e+03

# %% [raw]
# !!! önemli:
#
# gridsearch ilk başta rmse değerinin test seti scorenu train seti için alınan scora çekmeye çalışır. ancak bu olmuyorsa belli bir noktadan sonra kendi ona gitmeye başlar.
#
# bizim için regresyon modellerinde rmse bakmamız öncelik olmalıdır. aldığım scorelardaki outlier değerleride dikkate alıyor. datamın ne kadar iyi tahmin yaptığını bana gösteriyor.

# %% [markdown]
# ### Feature İmportance

# %%
model = GradientBoostingRegressor(random_state=101, max_depth=3, learning_rate = 0.1, max_features=2, n_estimators=300, subsample=0.8)
model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(max_features=2, n_estimators=300, random_state=101,
#                           subsample=0.8)

# %%
model.feature_importances_
# Out:
# array([0.13496751, 0.01199635, 0.14167639, 0.6170262 , 0.03760354,
#        0.05673001])

# %%
imp_feats = pd.DataFrame(index=X.columns,data=model.feature_importances_,columns=['grad_Importance'])
grad_imp_feats = imp_feats.sort_values('grad_Importance')
grad_imp_feats
# Out:
#           grad_Importance
# sex              0.011996
# region           0.037604
# children         0.056730
# age              0.134968
# bmi              0.141676
# smoker           0.617026

# %% [markdown]
# ### 3. XGBRegressor

# %% [raw]
# min_child_weight büyüterek overfitting ile mücadele edebiliyoruz.
# gamma 0 ile sonsuz arasında bir değer alabiliyor.
# subsample ile oynanıyorsa bylevel ile çok fazla oynamak tercih edilmiyor.
# colsamplebynode ile oynamak maxdepth e göre çok zahmetlidir.
# reg_alpha 1 dersek Lasso gibi, default 0 yani Riched gibi davranır.
# reg_lambda 1 riched gibi davranır. 0 yaparsak Lasso gibi davranır.

# %%
from xgboost import XGBRegressor

# %%
xgb_model = XGBRegressor(random_state=101, objective="reg:squarederror")

# %%
xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=101,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
train_val(xgb_model, X_train, y_train, X_test, y_test, "xgb")
# Out:
#          xgb_train      xgb_test
# R2    9.898948e-01  8.876778e-01
# mae   5.980710e+02  2.031458e+03
# mse   1.116667e+06  1.329801e+07
# rmse  1.056725e+03  3.646643e+03

# %% [markdown]
# ### CV

# %%
model = XGBRegressor(random_state=101, objective="reg:squarederror")
scores = cross_validate(model, X_train, y_train, scoring=['r2', 
            'neg_mean_absolute_error','neg_mean_squared_error','neg_root_mean_squared_error'], cv =10)
pd.DataFrame(scores).iloc[:, 2:].mean()
# Out:
# test_r2                             8.336039e-01
# test_neg_mean_absolute_error       -2.238283e+03
# test_neg_mean_squared_error        -1.833649e+07
# test_neg_root_mean_squared_error   -4.245324e+03
# dtype: float64

# %% [markdown]
# ### GridSearch for XGBRegressor

# %%
param_grid = {"n_estimators":[100,500],'max_depth':[3,5,6], "learning_rate": [0.05, 0.1, 0.3],
             "subsample":[0.8, 1], "colsample_bytree":[0.5, 1]}

# %%
model = XGBRegressor(random_state=101, objective="reg:squarederror")
grid_model = GridSearchCV(estimator=model,
                          param_grid=param_grid,
                          scoring='neg_root_mean_squared_error',
                          cv=10,
                          n_jobs = -1)

# %%
grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     enable_categorical=False, gamma=None,
#                                     gpu_id=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=None,
#                                     missing=nan, monotone_constraints=None,...
#                                     num_parallel_tree=None, predictor=None,
#                                     random_state=101, reg_alpha=None,
#                                     reg_lambda=None, scale_pos_weight=None,
# ...

# %%
grid_model.best_params_
# Out:
# {'colsample_bytree': 1,
#  'learning_rate': 0.05,
#  'max_depth': 6,
#  'n_estimators': 100,
#  'subsample': 1}

# %%
grid_model.best_score_
# Out:
# -3902.9266630424086

# %%
xgb = train_val(grid_model, X_train, y_train, X_test, y_test, "xgb")
xgb
# Out:
#          xgb_train      xgb_test
# R2    9.261482e-01  9.130991e-01
# mae   1.401861e+03  1.731551e+03
# mse   8.160977e+06  1.028834e+07
# rmse  2.856742e+03  3.207544e+03

# %% [raw]
# XGBoost bu data için regresyonda diğerlerine göre daha iyi sonuç vermiş diyebiliriz. boosting modellerde bunun feature importance dikkate alıyoruz.

# %% [markdown]
# ### Feature İmportance

# %%
model = XGBRegressor(random_state=101, objective="reg:squarederror", learning_rate=0.05, colsample_bytree= 1, max_depth=6, subsample=1, n_estimators=100)
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.05, max_delta_step=0,
#              max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=101,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
model.feature_importances_
# Out:
# array([0.01168166, 0.00433548, 0.01499114, 0.94157857, 0.01485796,
#        0.01255524], dtype=float32)

# %%
imp_feats = pd.DataFrame(index=X.columns,data=model.feature_importances_,columns=['xgb_Importance'])
xgb_imp_feats = imp_feats.sort_values('xgb_Importance')
xgb_imp_feats
# Out:
#           xgb_Importance
# sex             0.004335
# age             0.011682
# children        0.012555
# region          0.014858
# bmi             0.014991
# smoker          0.941579

# %%
pd.concat([dt, rf, ada, gb, xgb], axis=1)
# Out:
#           dt_train       dt_test      rf_train       rf_test     ada_train      ada_test      gb_train       gb_test     xgb_train      xgb_test
# R2    9.035324e-01  8.873450e-01  9.743921e-01  9.105760e-01  7.700176e-01  8.260771e-01  8.985083e-01  9.027258e-01  9.261482e-01  9.130991e-01
# mae   1.620833e+03  1.880511e+03  7.800764e+02  1.627609e+03  3.662932e+03  3.418625e+03  1.794335e+03  1.947514e+03  1.401861e+03  1.731551e+03
# mse   1.066013e+07  1.333740e+07  2.829789e+06  1.058705e+07  2.541415e+07  2.059100e+07  1.121531e+07  1.151645e+07  8.160977e+06  1.028834e+07
# rmse  3.264985e+03  3.652041e+03  1.682198e+03  3.253774e+03  5.041245e+03  4.537731e+03  3.348927e+03  3.393589e+03  2.856742e+03  3.207544e+03

# %%
pd.concat([dt_imp_feats, rf_imp_feats, ada_imp_feats, grad_imp_feats, xgb_imp_feats], axis=1)
# Out:
#           dt_Importance  rf_Importance  ada_Importance  grad_Importance  xgb_Importance
# sex            0.000282       0.006827        0.000000         0.011996        0.004335
# region         0.043587       0.042982        0.037248         0.037604        0.014858
# children       0.052669       0.063361        0.020955         0.056730        0.012555
# age            0.106121       0.119776        0.097768         0.134968        0.011682
# bmi            0.164449       0.191015        0.159723         0.141676        0.014991
# smoker         0.632892       0.576039        0.684307         0.617026        0.941579

# %% [markdown]
# ### Final Model

# %%
X=df_train.drop("charges", axis=1)
y=df_train.charges

cat1=df_test.select_dtypes("object").columns

cat = X.select_dtypes("object").columns
cat

enc = OrdinalEncoder()
X[cat] = enc.fit_transform(X[cat])
X.head()
# Out:
#     age  sex    bmi  smoker  region  children
# 0  21.0  1.0  25.74     0.0     0.0         2
# 1  37.0  0.0  25.74     1.0     2.0         3
# 2  18.0  1.0  30.03     0.0     2.0         1
# 3  37.0  1.0  30.68     0.0     0.0         3
# 4  58.0  1.0  32.01     0.0     2.0         1

# %%
final_model = XGBRegressor(random_state=101, objective="reg:squarederror", learning_rate=0.05, colsample_bytree= 1, max_depth=6, subsample=1, n_estimators=100)

# %%
final_model.fit(X, y)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.05, max_delta_step=0,
#              max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=101,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
predictions = final_model.predict(df_test)
predictions = pd.DataFrame(predictions)

# %%
predictions.to_csv("C9307.csv", index=False)
