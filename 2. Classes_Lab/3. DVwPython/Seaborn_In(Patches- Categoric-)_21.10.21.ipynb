# %%
# Basic Libraries
import pandas as pd
import numpy as np
# Libraries for visualizaton
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
#print(sns.get_dataset_names())

# %%
tips = sns.load_dataset("tips")

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ## Countplot

# %%
##### Burada kategorik değişkenin değerlerini count yapıyor. Sadece x eksenini yazıyoruz.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ## <span style=" color:Purple"> Countplot
# A simple plot, it merely shows the total count of rows per category.
#
# - seaborn.countplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, dodge=True, ax=None, **kwargs)</span>

# %%
tips.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sns.countplot(x="day", data=tips)
# günleri unique olarak sayarak y eksenine yazdırdı.
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x='day', data=tips)

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.3, p.get_height()+0.5));
    # matplotlib.pyplot.annotate(text, xy, *args, **kwargs)
    # [https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.annotate.html]

# %%
print(ax.patches)
# Out:
# [<matplotlib.patches.Rectangle object at 0x0000011F417714F0>, <matplotlib.patches.Rectangle object at 0x0000011F41771880>, <matplotlib.patches.Rectangle object at 0x0000011F41746610>, <matplotlib.patches.Rectangle object at 0x0000011F41771BB0>]

# %%
for p in ax.patches:
    print(p)
# Out:
# Rectangle(xy=(-0.4, 0), width=0.8, height=62, angle=0)
# Rectangle(xy=(0.6, 0), width=0.8, height=19, angle=0)
# Rectangle(xy=(1.6, 0), width=0.8, height=87, angle=0)
# Rectangle(xy=(2.6, 0), width=0.8, height=76, angle=0)

# %%
print(p.get_height)
# Out:
# <bound method Rectangle.get_height of <matplotlib.patches.Rectangle object at 0x0000011F41771BB0>>

# %%
sns.countplot(x="day", data=tips, hue="sex")
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x="day", data=tips, hue="sex")


for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.1, p.get_height()+0.6))
    ax.text(p.get_x()+0.05, p.get_height()-p.get_height()/2,str(round(p.get_height()/tips.day.count(),2)) )

# %%
mpg = sns.load_dataset("mpg")

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.countplot(x="cylinders", data=mpg)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='count'>

# %%
sns.countplot(x="model_year", data=mpg)
# Out:
# <AxesSubplot:xlabel='model_year', ylabel='count'>

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x="model_year", data=mpg)


for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.1, p.get_height()+0.6))
    ax.text(p.get_x()+0.05, p.get_height()-p.get_height()/2,str(round(p.get_height()/tips.day.count(),2)) )

# %%
sns.countplot(x="origin", data=mpg)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='count'>

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x="origin", data=mpg)


for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.35, p.get_height()+0.9))
    ax.text(p.get_x()+0.35, p.get_height()-p.get_height()/2,str(round(p.get_height()/tips.day.count(),2)) )

# %%
sns.countplot(x="model_year", hue="origin", data=mpg)
# Out:
# <AxesSubplot:xlabel='model_year', ylabel='count'>

# %% [markdown]
# ## Barplot

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ## <span style=" color:Purple"> Barplot
# So far we've seen the y axis default to a count (similar to a .groupby(x_axis).count() call in pandas). We can expand our visualizations by specifying a specific continuous feature for the y-axis. Keep in mind, you should be careful with these plots, as they may imply a relationship continuity along the y axis where there is none
#
#
# - seaborn.barplot( x=None, y=None, hue=None, data=None, order=None, hue_order=None,  ci=95, n_boot=1000, units=None, seed=None, orient=None, color=None, palette=None, saturation=0.75, errcolor='.26', errwidth=None, capsize=None, dodge=True, ax=None, **kwargs)</span>

# %% [markdown]
# ##### kategorik değişkene karşılık bir numerik değişkenin değişimini veriyoruz. Bu numerik değişkene göre bir güven aralığı belirleyerek bunun dağılımını veriyor.

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.barplot(x="sex", y="total_bill", data=tips, ci=100)
# matplotlib barplot ttan farklı olarak confidence interval veriyor bizede. Burada bunları değiştirebiliyoruz.
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x="day", y="total_bill", data=tips, hue="sex")

# tips.groupby([‘sex’, ‘day’]).total_bill.describe()
# burada day kategorik değişkenine göre total bill leri, sex değişkenine confidence interval kapsamında bir hesaplama yapıyor.
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x="day", y="total_bill", data=tips, hue="sex", estimator=np.sum)   
# default olarak mean kullanır.
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
tips.groupby(["day","sex"]).sum()  # estimator yukarıda np.sum olduğundan dolayı sum alıp baktık.
# Out:
#              total_bill     tip  size
# day  sex
# Thur Male        561.44   89.41    73
#      Female      534.89   82.42    79
# Fri  Male        198.57   26.93    21
#      Female      127.31   25.03    19
# Sat  Male       1227.35  181.95   156
#      Female      551.05   78.45    63
# Sun  Male       1269.46  186.78   163
#      Female      357.70   60.61    53

# %%
sns.barplot(x="day", y="total_bill", data=tips, hue="sex", estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
fig,ax=plt.subplots(1,2,figsize=(12,4))
sns.barplot(x="day", y="total_bill", data=tips, ax=ax[0], estimator=np.count_nonzero)
# estimator count olursa bunun count değerler bir olacağından dolayı confidence interval çıkmadı.
sns.countplot(x="day", data=tips, ax=ax[1])
plt.tight_layout()

# %%
fig,ax=plt.subplots(1,2,figsize=(12,4))
sns.barplot(x="day", y="total_bill", data=tips, ax=ax[0], estimator=np.std)
# estimator count olursa bunun count değerler bir olacağından dolayı confidence interval çıkmadı.

sns.countplot(x="day", data=tips, ax=ax[1])
# countplot ta kategorik değişkene göre numerik değerleri unique olarak count yapıyor. Sonucu y eksenine yazıyor.
plt.tight_layout()

# %% [markdown]
# #### Boxplot

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ## <span style=" color:Purple"> Boxplot
# As described in the video, a boxplot display distribution through the use of quartiles and an IQR for outliers.
#
# - seaborn.boxplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None, **kwargs)</span>

# %%
sns.boxplot(x="day", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day", y="total_bill", data=tips, hue="sex")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day", y="total_bill", data=tips, hue="sex")

# yukarıda legend outlier üzerine geldiğinden bundan kurtulmak için aşağıdaki kodu kullanıyorum.

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.10)  

# borderaxespad ise border ile axes arasındaki farkı verir.

# %%
# veya aşağıdaki gibi legend içine en iyi konuma koyduruyoruz.

sns.boxplot(x="day", y="total_bill", data=tips, hue="sex")

plt.legend(loc="best")

# %%
# veya bu şekilde size büyüterek legend fig içinde en iyi konuma gitmesini sağladık.

plt.figure(figsize=(10,5))

sns.boxplot(x="day", y="total_bill", data=tips, hue="sex", width=0.3)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(10,5))

sns.boxplot(y="day", x="total_bill", data=tips, hue="sex") # x ve y eksenlerindeki değişkenleri değiştererek yatay bir grafik elde ettik.
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
df = pd.read_csv("StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
sns.boxplot(x="parental level of education", y="math score", data=df)
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='math score'>

# %%
# yukarıdaki gibi x ekseni değerleri birbirine girmiş bunları düzeltmek için ya size büyütüyoruz veya rotation ile yaparız.
plt.figure(figsize=(10,5))

sns.boxplot(x="parental level of education", y="math score", data=df)
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='math score'>

# %%
# Bu şekilde de çözebiliriz.

sns.boxplot(x="parental level of education", y="math score", data=df, hue="gender")
ploe = df["parental level of education"].value_counts()

ploe_pos = range(len(ploe.index))
plt.xticks(ploe_pos, ploe.index, rotation=45)
# Out:
# ([<matplotlib.axis.XTick at 0x11f44f0ac40>,
#   <matplotlib.axis.XTick at 0x11f44f0ac10>,
#   <matplotlib.axis.XTick at 0x11f44f3b0d0>,
#   <matplotlib.axis.XTick at 0x11f45012cd0>,
#   <matplotlib.axis.XTick at 0x11f4501d460>,
#   <matplotlib.axis.XTick at 0x11f4501dbb0>],
#  [Text(0, 0, 'some college'),
#   Text(1, 0, "associate's degree"),
#   Text(2, 0, 'high school'),
#   Text(3, 0, 'some high school'),
#   Text(4, 0, "bachelor's degree"),
#   Text(5, 0, "master's degree")])

# %%
# bir diğer yöntem olarak bunuda kullanabiliriz.

plt.figure(figsize=(12,6))
sns.boxplot(x='parental level of education', y='math score', data=df, hue='gender')

# Optional move the legend outside
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#plt.xticks(rotation = 'vertical');

# %% [markdown]
# #### ViolinPlot

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ## <span style=" color:Purple">  Violinplot
# A violin plot plays a similar role as a box and whisker plot. It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared. Unlike a box plot, in which all of the plot components correspond to actual datapoints, the violin plot features a kernel density estimation of the underlying distribution.
#
# - seaborn.violinplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, bw='scott', cut=2, scale='area', scale_hue=True, gridsize=100, width=0.8, inner='box', split=False, dodge=True, orient=None, linewidth=None, color=None, palette=None, saturation=0.75, ax=None, **kwargs)</span>

# %%
# boxplot ile kde nin birleşimi gibi düşünebiliriz.

sns.violinplot(x="day", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(12,6))

sns.violinplot(x="day", y="total_bill", data=tips, hue="sex")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(12,6))

sns.violinplot(x="day", y="total_bill", data=tips, hue="sex", split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(12,6))

sns.violinplot(x="day", y="total_bill", data=tips, hue="sex", inner="quartile")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(12,6))

sns.violinplot(y="day", x="total_bill", data=tips, hue="sex")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
plt.figure(figsize=(12,6))

sns.violinplot(x="day", y="total_bill", data=tips, hue="sex", bw=0.5, split=True, inner="quartile")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ####  Swarmplot

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ## <span style=" color:Purple"> Swarmplot
# Draw a categorical scatterplot with non-overlapping points.
# - seaborn.swarmplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, dodge=False, orient=None, color=None, palette=None, size=5, edgecolor='gray', linewidth=0, ax=None, **kwargs)</span>

# %%
sns.swarmplot(x="day", y="total_bill", data=tips);

# %%
sns.swarmplot(x="total_bill", data=tips);

# %%
sns.swarmplot(x="total_bill", y="smoker", data=tips, size=7);

# %%
sns.swarmplot(x="total_bill", y="smoker", data=tips, hue="sex", size=7);

# %%
sns.swarmplot(x="total_bill", y="smoker", data=tips, dodge=True,hue="sex", size=7)

# dodge ile ayırabiliyoruz.
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.swarmplot(x="math score", data=df, size=3); 

# size default olarak 5 tir.

# %%
sns.swarmplot(x="math score", y="race/ethnicity", data=df, size=5);
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 21.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 39.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 30.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(y="math score", x="race/ethnicity", data=df, size=5);
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 36.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 32.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(y="math score", x="race/ethnicity", data=df, hue="gender", size=5);
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 36.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 32.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Boxenplot
# #### Büyük veri setlerinde kullanılır.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ## <span style=" color:Purple"> Boxenplot (letter-value plot)
# Official Paper on this plot: https://vita.had.co.nz/papers/letter-value-plot.html
#
# This style of plot was originally named a “letter value” plot because it shows a large number of quantiles that are defined as “letter values”. It is similar to a box plot in plotting a nonparametric representation of a distribution in which all features correspond to actual observations. By plotting more quantiles, it provides more information about the shape of the distribution, particularly in the tails.</span>

# %%
sns.boxenplot(x="math score", y="race/ethnicity", data=df)
# Out:
# <AxesSubplot:xlabel='math score', ylabel='race/ethnicity'>

# %%
sns.boxenplot(y="math score", x="race/ethnicity", data=df, hue="gender")
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='math score'>

# %% [markdown]
# ## Lineplot

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ## <span style=" color:Blue"> Line plot
# https://seaborn.pydata.org/generated/seaborn.lineplot.html</span>

# %%
# print(sns.get_dataset_names())

flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x="year", y="passengers", data=flights)
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
f_sum = flights.groupby(["year","month"]).sum()
f_sum
# Out:
#             passengers
# year month
# 1949 Jan           112
#      Feb           118
#      Mar           132
#      Apr           129
#      May           121
# ...                ...
# 1960 Aug           606
#      Sep           508
#      Oct           461
#      Nov           390
#      Dec           432
#
# [144 rows x 1 columns]

# %%
f_sum.reset_index()  
# yapınca indeksleri resetleyip aşağıdaki gibi bir df verdi.
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.lineplot(y=f_sum.passengers, x=f_sum.reset_index().index)
# Out:
# <AxesSubplot:ylabel='passengers'>

# %%
flights[flights.month=="May"]
# Out:
#      year month  passengers
# 4    1949   May         121
# 16   1950   May         125
# 28   1951   May         172
# 40   1952   May         183
# 52   1953   May         229
# 64   1954   May         234
# 76   1955   May         270
# 88   1956   May         318
# 100  1957   May         355
# 112  1958   May         363
# 124  1959   May         420
# 136  1960   May         472

# %%
sns.lineplot(x="year", y="passengers", data=flights[flights.month=="May"])
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
flights_wide = flights.pivot(index = "year", columns = "month", values = "passengers")
flights_wide
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.lineplot(data = flights_wide)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# yukarıdaki ile aynı sonuca ulaşıyoruz.

sns.lineplot(x="year", y="passengers", data=flights, hue="month")
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data = flights_wide.T)
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ## <span style=" color:Purple"> Thanks for Attending!</span>

# %% [markdown]
# <div class="alert alert-primary" role="alert">
#   Thanks for Attending!
# </div>

# %% [markdown]
# <div class="alert alert-primary" role="alert">
#   This is a primary alert with <a href="#" class="alert-link">an example link</a>. Give it a click if you like.
# </div>

# %% [markdown]
# <h1>Example heading <span class="badge badge-secondary">New</span></h1>

# %% [markdown]
# <nav aria-label="breadcrumb">
#   <ol class="breadcrumb">
#     <li class="breadcrumb-item"><a href="#">Home</a></li>
#     <li class="breadcrumb-item"><a href="#">Library</a></li>
#     <li class="breadcrumb-item active" aria-current="page">Data</li>
#   </ol>
# </nav>

# %% [markdown]
# <button type="button" class="btn btn-outline-primary">Primary</button>
# <button type="button" class="btn btn-outline-secondary">Secondary</button>
# <button type="button" class="btn btn-outline-success">Success</button>
# <button type="button" class="btn btn-outline-danger">Danger</button>
# <button type="button" class="btn btn-outline-warning">Warning</button>
# <button type="button" class="btn btn-outline-info">Info</button>
# <button type="button" class="btn btn-outline-light">Light</button>
# <button type="button" class="btn btn-outline-dark">Dark</button>

# %% [markdown]
# <div class="card" style="width: 18rem;">
#   <img class="card-img-top" src="..." alt="Card image cap">
#   <div class="card-body">
#     <h5 class="card-title">Card title</h5>
#     <p class="card-text">Some quick example text to build on the card title and make up the bulk of the card's content.</p>
#     <a href="#" class="btn btn-primary">Go somewhere</a>
#   </div>
# </div>

# %% [markdown]
# <ul class="list-group">
#   <li class="list-group-item">Cras justo odio</li>
#   <li class="list-group-item">Dapibus ac facilisis in</li>
#   <li class="list-group-item">Morbi leo risus</li>
#   <li class="list-group-item">Porta ac consectetur ac</li>
#   <li class="list-group-item">Vestibulum at eros</li>
# </ul>
