# %%
import pandas as pd
import numpy as np
import scipy
import seaborn as sns
from  matplotlib import pyplot as plt

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
tips.shape
# Out:
# (244, 7)

# %%
sns.scatterplot(x='total_bill', y='tip',  data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
tips['tip_as_pct']= tips['tip']/tips['total_bill']
tips.groupby(['sex']).mean()
# Out:
#         total_bill       tip      size  tip_as_pct
# sex
# Male     20.744076  3.089618  2.630573    0.157651
# Female   18.056897  2.833448  2.459770    0.166491

# %%
tips.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_as_pct
# 0       16.99  1.01  Female     No  Sun  Dinner     2    0.059447

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='sex')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, style='sex')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, size='sex')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, size='sex', hue='sex')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
tips.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_as_pct
# 0       16.99  1.01  Female     No  Sun  Dinner     2    0.059447

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='day')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
help(sns.scatterplot)
# Out:
# Help on function scatterplot in module seaborn.relational:
#
# scatterplot(*, x=None, y=None, hue=None, style=None, size=None, data=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=True, style_order=None, x_bins=None, y_bins=None, units=None, estimator=None, ci=95, n_boot=1000, alpha=None, x_jitter=None, y_jitter=None, legend='auto', ax=None, **kwargs)
#     Draw a scatter plot with possibility of several semantic groupings.
#
#     The relationship between ``x`` and ``y`` can be shown for different subsets
#     of the data using the ``hue``, ``size``, and ``style`` parameters. These
#     parameters control what visual semantics are used to identify the different
#     subsets. It is possible to show up to three dimensions independently by
#     using all three semantic types, but this style of plot can be hard to
#     interpret and is often ineffective. Using redundant semantics (i.e. both
# ...

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, size='sex', hue='sex')
sns.scatterplot(x='total_bill', y='tip', data=tips, s=200, color='green', marker='o')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',
                y='tip',
                data=tips [ (tips['day']=='Sun') | (tips['day']=='Sat'   ) ],
                hue='day', 
                size='day'
               )
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
#pairplot()   RBG   RBGA
sns.scatterplot(x='total_bill', y='tip', data=tips, s=150, alpha=0.2)  #alpha 0-->1
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plt.figure.figsize=(4, 4)
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plt.savefig('some_figure_name.jpg')   #.png

# %%
yyyy = sns.scatterplot(x='total_bill', y='tip', data=tips, s=150, alpha=0.2) 
yyyy.figure.figsize=(2,2)

fig, ax = plt.subplots(figsize=(2,2))
sns.scatterplot(x='total_bill', y='tip', data=tips, s=150, alpha=0.2) #plt.plot()
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.rugplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.rugplot(tips['total_bill'], height=.5 )
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
help(sns.rugplot)

# %%
sns.displot(x='total_bill', data=tips)

# %%
sns.displot(x='total_bill', data=tips, kde=True)

# %%
sns.histplot(x='total_bill', data=tips, kde=True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x='total_bill', data=tips, bins=5)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x='total_bill', data=tips, bins=50)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.set(style='darkgrid')
sns.histplot(data=tips, x='total_bill', bins=20)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.set(style='whitegrid')
sns.histplot(data=tips, x='total_bill', bins=20)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(data=tips,
           x='total_bill',
           bins=20, 
           kde=False,  #default
           color='red', 
           edgecolor='black',
           lw=4, 
           ls='--')

# %%
sns.kdeplot(x='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(x='total_bill', data=tips, clip=[10, 30])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(x='total_bill', data=tips, bw_adjust=1)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.histplot(data=tips, x='total_bill', bins=20)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
data = pd.DataFrame(np.random.normal(0,1,size=(100,2)),columns=['x','y'])
data.head(5)
# Out:
#           x         y
# 0  0.591874  0.020249
# 1 -0.271013 -0.371647
# 2 -1.040107 -1.423100
# 3 -2.580916 -0.835987
# 4  0.228214 -0.655485

# %% [markdown]
# ![fuji_side1.PNG](attachment:fuji_side1.PNG)

# %% [markdown]
# ![fuji_topo-2.PNG](attachment:fuji_topo-2.PNG)

# %%
sns.kdeplot(data=data, x='x', y='y' )
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
![fuji_topo-2.PNG](attachment:fuji_topo-2.PNG)

![fuji_side1.PNG](attachment:fuji_side1.PNG)
