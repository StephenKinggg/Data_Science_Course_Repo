# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sns.set()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
rest = sns.load_dataset("tips")
rest
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.plot(rest.total_bill, rest.tip)

# %%
sns.set_style("white")

# %%
plt.plot(rest.total_bill, rest.tip);

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.4.3'

# %%
sns.__version__
# Out:
# '0.11.2'

# %%
cars = sns.load_dataset("mpg")

# %%
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
cars.shape
# Out:
# (398, 9)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
cars.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars.dropna(inplace=True)

# %%
sns.relplot(x="model_year", y="mpg", col="origin", hue="cylinders", data=cars)

# %%
diamonds = sns.load_dataset("diamonds")

# %%
diamonds.shape
# Out:
# (53940, 10)

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
diamond = diamonds[diamonds.cut.isin(["Premium", "Good"]) & diamonds.color.isin(["D","F","J"])].sample(n=100, random_state=22)

# %%
diamond.cut.value_counts()
# Out:
# Premium      69
# Good         31
# Ideal         0
# Very Good     0
# Fair          0
# Name: cut, dtype: int64

# %%
diamond.shape
# Out:
# (100, 10)

# %%
sns.scatterplot(diamond.carat, diamond.price)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x=diamond.carat, y=diamond.price)  # yukarıdaki hatayı x ve y eksen isimlerini ekleyerek giderebiliyoruz.
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x="carat", y="price", data=diamond); # eksenlere isim verdik.

# %%
sns.scatterplot(x="carat", y="price", hue= "cut", data=diamond);

# %%
sns.scatterplot(x="carat", y="price", hue= "cut", data=diamond,
               palette=["purple","#55CCCC"]);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-3d28c061d889> in <module>
# ----> 1 sns.scatterplot(x="carat", y="price", hue= "cut", data=diamond,
#       2                palette=["purple","#55CCCC"]);
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     813     )
#     814
# --> 815     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
# ...

# %%
sns.scatterplot(x="carat", y="price", hue= "depth", data=diamond, 
               s=100);

# %%
sns.scatterplot(x="carat", y="price", style="cut", data=diamond, 
               s=100);

# %%
sns.scatterplot(x="carat", y="price", size="cut", data=diamond, 
               s=100);

# %%
sns.scatterplot(x="carat", y="price", size="cut", data=diamond, 
               sizes=[150,50,25,10,5]);  # cut ta yukarıda seçtiğimiz iki değerin dışında başka değerler de geldiğinden dolay sizes içine 5 eleman yazdık.

# %%
sns.scatterplot(x="carat", y="price", hue="cut", data=diamond,
                style = "cut",
               s= 100);

# %%
sns.scatterplot(x="carat", y="price", data=diamond,
                s=100,
                alpha = 0.6);

# %%
sns.scatterplot(x="carat", y="price", data=diamond,
                s=400,
                marker = "*");

# %%
sns.scatterplot(x="carat", y="price", data=diamond,
                s=400,
                marker = "*",
               edgecolor = "black");

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
penguins.dropna(inplace=True)

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.8+ KB

# %%
sns.set_style("darkgrid")

# %%
sns.histplot(penguins.flipper_length_mm);

# %%
sns.histplot(x="flipper_length_mm", data=penguins,
            kde=True);

# %%
sns.histplot(x="flipper_length_mm", data=penguins, bins=20,
            kde=True);

# %%
sns.histplot(x="flipper_length_mm", data=penguins, bins=[180,195,210,225,230],
            kde=True);

# bins ile x eksenini gruplandırdık.

# %%
sns.histplot(x="flipper_length_mm", data=penguins, 
             binwidth=10, binrange=(180,230),
            kde=True);
# binrange ile verilen aralıkta binwidth yazan değer kadar aralıklara böldük.

# %%
sns.histplot(x="flipper_length_mm", data=penguins, 
             stat="count");

#stat: Aggregate statistic to compute in each bin.

# %%
sns.histplot(x="flipper_length_mm", data=penguins, 
             stat="density");

# %%
sns.histplot(x="flipper_length_mm", data=penguins, 
             stat="probability");

# %%
sns.histplot(x="flipper_length_mm", data=penguins, 
             stat="probability", fill=False, element="step",
            cumulative=True);
# fill false olunca içini doldurmadık ve element ile basamaklandırdık.
# cumulative, If True, plot the cumulative counts as bins increase.

# %%
sns.histplot(x="flipper_length_mm", data=penguins, 
             hue="species");

# %%
sns.histplot(x="flipper_length_mm", data=penguins, 
             hue="species", element="poly");

#element : {"bars", "step", "poly"}
#Visual representation of the histogram statistic. Only relevant with univariate data.

# %%
sns.histplot(x="flipper_length_mm", data=penguins, 
             hue="species", multiple="stack");

# multiple : {"layer", "dodge", "stack", "fill"}
# Approach to resolving multiple elements when semantic mapping creates subsets.
# Only relevant with univariate data.

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
sns.set_style("white")
sns.histplot(x = "flipper_length_mm", y = "body_mass_g", data=penguins, cbar=True)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.set_style("white")
sns.histplot(x = "flipper_length_mm", y = "body_mass_g", hue="species", data=penguins, cbar=True)

# hue ile yeni bir kategorik değişken ilave etmiş olduk. Yani groupby yapmış olduk.
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.set_style("white")
sns.histplot(x = "flipper_length_mm", y = "species", hue="species", data=penguins, cbar=True)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='species'>

# %%
sns.histplot(x = "species", hue="sex", multiple= "dodge", data=penguins, cbar=True)
# Out:
# <AxesSubplot:xlabel='species', ylabel='Count'>

# %%
sns.histplot(x = "species", hue="sex", multiple= "dodge", data=penguins, shrink=0.8, cbar=True)
# Out:
# <AxesSubplot:xlabel='species', ylabel='Count'>

# %%
sns.histplot(x = "flipper_length_mm", data=penguins, color= "blue", cbar=True)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(x = "species", hue="sex", multiple= "dodge", data=penguins, shrink=0.8, palette="bone", cbar=True)

# palette : string, list, dict, or :class:`matplotlib.colors.Colormap` 
# Method for choosing the colors to use when mapping the ``hue``
# Out:
# <AxesSubplot:xlabel='species', ylabel='Count'>

# %%
cars = sns.load_dataset("mpg").dropna()  # başlangıçta 6 tana missing value düştük.

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    object
#  8   name          392 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 30.6+ KB

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.set_style("white")

# %% [markdown]
# ***
# kind : {"hist", "kde", "ecdf"}
#
# kde = kernel density estimation
#
# ecdf = empirical distribution functional plot
#
# Approach for visualizing the data. Selects the underlying plotting function and determines the additional set of valid parameters.
# ***

# %%
sns.displot(x = "weight", data = cars, kind="ecdf")

# %%
sns.displot(x = "weight", data = cars, kind="kde", rug= True)

# rug : bool
# If True, show each observation with marginal ticks (as in :func:`rugplot`).
# alt taraftaki yukarı doğru olan çizgiler.

# %%
sns.displot(x = "weight", data = cars, hue="origin")

# hue : categorical variables.
# hue : vector or key in ``data``
# Semantic variable that is mapped to determine the color of plot elements.

# %%
# Bivariate 2nd Options:

# %%
sns.displot(x = "weight", y="horsepower", data = cars, cbar=True)

# %%
sns.displot(x = "weight", y="horsepower", data = cars, kind="kde", rug = True, cbar = True)

# %%
# Small Multiplies(FacetGrid)

# %%
sns.displot(x = "weight", data = cars, hue="origin", col="origin")

# %%
sns.displot(x = "weight", data = cars, col="origin", kind="kde", rug = True)

# %%
sns.displot(x ="weight", data = cars[cars.cylinders.isin([4,6,8])],
           col = "origin",
           row = "cylinders",
           hue = "cylinders")

# %%
# Styling
## Palette

# %% [markdown]
# ***
# palette : string, list, dict, or :class:`matplotlib.colors.Colormap`
#
# Method for choosing the colors to use when mapping the ``hue`` semantic.String values are passed to :func:`color_palette`. List or dict values imply categorical mapping, while a colormap object implies numeric mapping.
# ***

# %%
sns.displot(x ="weight", data = cars,
           col = "origin", hue = "origin",
           palette = "crest")

# %%
# height, aspect

# %% [markdown]
# ***
# height : scalar
#     Height (in inches) of each facet. See also: ``aspect``.
# aspect : scalar
#     Aspect ratio of each facet, so that ``aspect * height`` gives the width
# ***

# %%
sns.displot(x ="weight", data = cars,
           col = "origin", height = 5, aspect=0.5)

# aspect width/height olduğundan dolayı aspect artarsa height küçülür.

# %%
sns.displot(x ="weight", data = cars,
           bins=10)

# bins büyüdükçe kutucukların genişlik küçülür ve grafiği daha iyi okumamızı sağlar.

# %%
sns.displot(x ="weight", data = cars,
           kind = "kde", fill =True, lw=3)

# fill ile grafiğin alt tarafını tarıyoruz. 
# lw ise grafiğin dış cephesini kalınlaştırıyor.

# %%
sns.displot(x ="weight", data = cars,
           kind = "kde", rug =True, rug_kws = {"height" : 0.15})

# rug_kws ile grafiğin altındaki rugların yüksekliğini belirliyoruz. 0.025 default olarak atanıyor.

# %%
# Facet Grid Styling

# %%
sns.displot(x ="weight", data = cars,
           col = "origin", facet_kws = {"despine" : False})

# %%
a = sns.displot(x ="weight", data = cars, col = "origin")
type(a)
# Out:
# seaborn.axisgrid.FacetGrid

# %%
a.axes_dict.items()
# Out:
# dict_items([('usa', <AxesSubplot:title={'center':'origin = usa'}, xlabel='weight', ylabel='Count'>), ('japan', <AxesSubplot:title={'center':'origin = japan'}, xlabel='weight'>), ('europe', <AxesSubplot:title={'center':'origin = europe'}, xlabel='weight'>)])

# %%
a = sns.displot(x ="weight", data = cars, col = "origin")

for col_val, ax in a.axes_dict.items():
    if col_val == "europa":
        ax.set_facecolor("#E2F2FF")

# %%
sns.kdeplot(cars.horsepower, shade=True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(cars.horsepower, bw=5)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(cars.horsepower, cumulative=True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(cars.horsepower, cars.mpg , shade=True,shade_lowest= True, cbar=True)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:1718: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0`, but please update your code.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
sns.kdeplot(cars.horsepower, cars.mpg , shade=True, cbar=True)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>
