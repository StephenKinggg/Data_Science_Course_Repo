# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.shape
# Out:
# (344, 7)

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
sns.set_style("darkgrid")

# %% [markdown]
# # Barplot

# %%
sns.barplot(x="species", y="body_mass_g", data=penguins)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
penguins.groupby("species").body_mass_g.mean()
# Out:
# species
# Adelie       3700.662252
# Chinstrap    3733.088235
# Gentoo       5076.016260
# Name: body_mass_g, dtype: float64

# %%
sns.barplot(x="body_mass_g",y="species", data=penguins)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='species'>

# %% [markdown]
# ***
# Interval Estimates
# ***

# %%
sns.barplot(x="species", y="body_mass_g", 
            data=penguins,
           ci=None)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x="species", y="body_mass_g", 
            data=penguins,
           ci=68)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x="species", y="body_mass_g", 
            data=penguins,
           ci=95)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x="species", y="body_mass_g", 
            data=penguins,
           estimator=np.std)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
penguins.groupby("species").body_mass_g.describe()
# Out:
#            count         mean         std     min     25%     50%     75%  \
# species
# Adelie     151.0  3700.662252  458.566126  2850.0  3350.0  3700.0  4000.0
# Chinstrap   68.0  3733.088235  384.335081  2700.0  3487.5  3700.0  3950.0
# Gentoo     123.0  5076.016260  504.116237  3950.0  4700.0  5000.0  5500.0
#
#               max
# species
# Adelie     4775.0
# Chinstrap  4800.0
# Gentoo     6300.0

# %%
sns.barplot(x="species", y="body_mass_g", 
            data=penguins,
           estimator=np.max)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# ***
# Categorical Variables
# ***

# %%
sns.barplot(x="species", y="body_mass_g", 
            data=penguins,
           hue="sex")
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x="species", y="body_mass_g", 
            data=penguins,
            order=["Gentoo","Chinstrap","Adelie"]
           )
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x="species", y="body_mass_g", 
            data=penguins,
            hue="sex",
            hue_order=["Female","Male"],
            order=["Gentoo","Chinstrap","Adelie"]
           )
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# ***
# Styling Color
# ***

# %%
sns.barplot(x="species", y="body_mass_g", 
            data=penguins,
            color="c",
            errcolor="darkslateblue",
            errwidth=8
           )
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x="species", y="body_mass_g", 
            data=penguins,
            palette="hot",
            errcolor="darkslateblue",
            errwidth=8
           )
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# ***
# edgecolor and linewidth
# ***

# %%
sns.barplot(x="species", y="body_mass_g", 
            data=penguins,
            ci=None,
            edgecolor="mediumblue",
            lw=3)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# ## CountPlot
#
# #### Barplottan farkı bootstrapping yok.

# %%
diamonds=sns.load_dataset("diamonds")

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# diamonds=diamonds[diamonds.clarity.isin(["SI1","SI2"])]

# %%
diamonds.shape
# Out:
# (53940, 10)

# %%
sns.set_style("darkgrid")

# %%
sns.countplot(x="color", data=diamonds)
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
diamonds.color.value_counts(sort=True)
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %%
diamonds.color.cat.categories  
# diamonds.color.value_counts().index
# Out:
# Index(['D', 'E', 'F', 'G', 'H', 'I', 'J'], dtype='object')

# %%
diamonds.cut.cat.categories
# Out:
# Index(['Ideal', 'Premium', 'Very Good', 'Good', 'Fair'], dtype='object')

# %%
diamonds.color.value_counts(sort=True)
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %%
sns.countplot(x="color", data=diamonds,
              order=diamonds.color.value_counts().index
             )
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
sns.countplot(x="color", data=diamonds,
              order=diamonds.color.value_counts().index[::-1]
             )
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %% [markdown]
# ***
# hue, hue_order
# ***

# %%
sns.countplot(x="color", data=diamonds,
              hue="clarity",
             )
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
sns.countplot(x="color", data=diamonds,
              hue="clarity",
              hue_order=["SI1","VS2"]
             )
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %% [markdown]
# ***
# STYLING
#
# color and palette
# ***

# %%
sns.countplot(x="color", data=diamonds,
              palette="twilight"
             )
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %% [markdown]
# ***
# Other Matplotlib Properties
# ***

# %%
sns.countplot(x="color", data=diamonds,
              lw=4, ec="black", hatch="/*"
             )
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %% [markdown]
# ## BoxPlot

# %%
cars = sns.load_dataset("mpg").dropna()

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars.shape
# Out:
# (392, 9)

# %%
cars.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    392.000000  392.000000
# mean      15.541327   75.979592
# std        2.758864    3.683737
# min        8.000000   70.000000
# 25%       13.775000   73.000000
# 50%       15.500000   76.000000
# 75%       17.025000   79.000000
# max       24.800000   82.000000

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    object
#  8   name          392 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 30.6+ KB

# %%
sns.set_style("ticks")   # style must be one of white, dark, whitegrid, darkgrid, ticks

# %%
cars.cylinders.value_counts()
# Out:
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
cars = cars[cars.cylinders.isin([4,6,8])]

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.boxplot(cars.mpg)
# Out:
# <AxesSubplot:xlabel='mpg'>

# %%
cars.mpg.describe()
# Out:
# count    385.000000
# mean      23.445455
# std        7.836911
# min        9.000000
# 25%       17.000000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
sns.boxplot(x=cars.origin, y=cars.mpg)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x="origin", y="mpg", data=cars)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %% [markdown]
# ***
# Hue
# ***

# %%
sns.boxplot(x="origin", y="mpg", hue="cylinders", data=cars)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %% [markdown]
# ***
# By Model Year
# ***

# %%
cars.model_year.describe()
# Out:
# count    385.000000
# mean      75.961039
# std        3.692058
# min       70.000000
# 25%       73.000000
# 50%       76.000000
# 75%       79.000000
# max       82.000000
# Name: model_year, dtype: float64

# %%
cars["new_model"] = cars.model_year > 76

# %%
sns.boxplot(x="origin", y="mpg", hue="cylinders", data=cars)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x="origin", y="mpg", hue="new_model", data=cars)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %% [markdown]
# ***
# Styling Options
# ***

# %%
sns.boxplot(x="mpg", y="origin", data=cars)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(x="mpg", y="origin", 
            data=cars,
            order= ["japan","europe","usa"]
           )
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(x="mpg", y="origin", 
            data=cars, hue="new_model",
            order= ["japan","europe","usa"],
            hue_order=[True, False]
           )
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %% [markdown]
# ***
# color
# ***

# %%
sns.boxplot(x="mpg", y="origin", 
            data=cars, 
            color="g"
           )
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(x="mpg", y="origin", 
            data=cars, hue="new_model",
            color="g"
           )
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %% [markdown]
# ***
# width-linewidth
# ***

# %%
sns.boxplot(x="mpg", y="origin", 
            data=cars, hue="new_model",
            width=0.5, linewidth=2.5
           )
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %% [markdown]
# ***
# whisker
# ***

# %%
sns.boxplot(x="mpg", y="origin", 
            data=cars, 
            whis=1
           )
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %% [markdown]
# ***
# fliersize
# ***

# %%
sns.boxplot(x="mpg", y="origin", 
            data=cars, 
            fliersize=10               #outlier ların ölçülerini büyütüyoruz.
           )
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %% [markdown]
# ***
# showcaps
# ***

# %%
sns.boxplot(x="mpg", y="origin", 
            data=cars, 
            showcaps=False,          # max ve min değerlerin ucundaki çubukları kaldırıyor.
           )
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %% [markdown]
# ## Violin Plot

# %%
cars = sns.load_dataset("mpg").dropna()

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    392.000000  392.000000
# mean      15.541327   75.979592
# std        2.758864    3.683737
# min        8.000000   70.000000
# 25%       13.775000   73.000000
# 50%       15.500000   76.000000
# 75%       17.025000   79.000000
# max       24.800000   82.000000

# %%
sns.set_style("whitegrid")

# %%
cars.cylinders.value_counts()
# Out:
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
cars = cars[cars.cylinders.isin([4,6,8])]

# %%
sns.violinplot(cars.displacement)
# Out:
# <AxesSubplot:xlabel='displacement'>

# %%
sns.violinplot(x="cylinders", y="displacement", 
               data=cars)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='displacement'>

# %%
sns.violinplot(x="cylinders", y="displacement", 
               data=cars, hue="origin"
               )
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='displacement'>

# %%
sns.violinplot(x="cylinders", y="displacement", 
               data=cars[cars.origin.isin(["japan","europe"])], hue="origin"
               )
plt.legend(loc=2)

# %%
sns.violinplot(x="cylinders", y="displacement", 
               data=cars[cars.origin.isin(["japan","europe"])], hue="origin",
               split=True
               )

plt.legend(loc=2)   
# legend location belirliyor. 2(üst sol)  1(üst sağ)/4(alt sol) 3(alt sol) köşelere göre.

# %%
sns.violinplot(x="cylinders", y="displacement", 
               data=cars[cars.origin.isin(["japan","europe"])], hue="origin",
               split=True,
               inner="quartiles"
               )

plt.legend(loc=2)

# %%
sns.violinplot(x="cylinders", y="displacement", 
               data=cars[cars.origin.isin(["japan","europe"])], hue="origin",
               split=True,
               scale="count"
               )
# scale : {"area", "count", "width"}, optional
# The method used to scale the width of each violin. If ``area``, each violin will have the same area. If ``count``, the width of th
plt.legend(loc=2)

# %%
sns.violinplot(x="cylinders", y="displacement", 
               data=cars[cars.origin.isin(["japan","europe"])], hue="origin",
               split=True,
               scale="count",
               scale_hue=False
               )
# scale : {"area", "count", "width"}, optional
# The method used to scale the width of each violin. If ``area``, each violin will have the same area. If ``count``, the width of th
plt.legend(loc=2)

# %%
sns.violinplot(x=cars.origin, y=cars.displacement,
              order=(["japan","europe","usa"])
              )
# Out:
# <AxesSubplot:xlabel='origin', ylabel='displacement'>

# %%
sns.violinplot(x=cars.origin, y=cars.displacement,
              order=(["japan","europe","usa"]),
               linewidth=4   # çerçeve çizginin kalınlığı.
              )
# Out:
# <AxesSubplot:xlabel='origin', ylabel='displacement'>

# %% [markdown]
# ***
# kde options
# ***

# %%
sns.violinplot(x=cars.origin, y=cars.displacement,
              order=(["japan","europe","usa"]),
              bw=0.4  # çerçeve çizginin kalınlığı.
              )
# bw : {'scott', 'silverman', float}, optional
# Either the name of a reference rule or the scale factor to use when computing the kernel bandwidth. The actual kernel size will be
# determined by multiplying the scale factor by the standard deviation of the data within each bin.
# Out:
# <AxesSubplot:xlabel='origin', ylabel='displacement'>

# %% [markdown]
# ## Comparison Plots

# %%
cars = sns.load_dataset("mpg").dropna()

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars = cars[cars.cylinders.isin([4,6,8])]

# %%
cars["type"]=["old" if x <=76 else "new" for x in cars.model_year]

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name type
# 0          70    usa  chevrolet chevelle malibu  old
# 1          70    usa          buick skylark 320  old
# 2          70    usa         plymouth satellite  old
# 3          70    usa              amc rebel sst  old
# 4          70    usa                ford torino  old

# %%
sns.set_style("white")

# %%
sns.catplot(x="horsepower", data=cars)

# %%
sns.catplot(y="horsepower", data=cars)

# %%
sns.catplot(x="horsepower", data=cars, kind="violin")
