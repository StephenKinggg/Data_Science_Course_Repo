# %% [markdown]
# ![image.png](attachment:520f431f-a7e0-4724-b78c-7fc8e4500300.png)

# %% [markdown]
# ***
# Scatter plot , değişkenler arasındaki ilişkiyi ifade etmek için,
#
# Barplot; nominal ve ordinal yani kategorik değişkenler içeren veri setlerinin analizinde,
#
# Piecharts; nominal ve ordinal yani kategorik değişkenler içeren veri setlerinin analizinde,
#
# Histogram; intervel ve ratio yani numerik değişkenler içeren veri setlerinin analizinde,
#
# Boxplot; intervel ve ratio yani numerik değişkenler içeren veri setlerinin analizinde kullanılır.
# ***

# %%
# Basic Library
import numpy as np
import pandas as pd

# Libraries for Visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings;
warnings.filterwarnings('ignore')

# %%
age = [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]
salary = [38496, 42000, 46752, 49320, 53200,
         56000, 62316, 64928, 67317, 68748, 73752]
salary_2 = [45372, 48876, 53850, 57287, 63016,
            65998, 70003, 70000, 71496, 75370, 83640]

# %% [markdown]
# ![image.png](attachment:0de9b2dc-04a9-4de9-a302-7f5614b566a9.png)

# %%
for i in range(1, 7):
    
    plt.subplot(2, 3, i)   # row ve column sayısı
    plt.text(0.5, 0.5, str((2, 3, i)),fontsize=18, ha='center') # x ve y ekseninde 0.5 olarak str yazan değeri yazıyor. 
    plt.title(i)
    
plt.suptitle("with for loop")
plt.tight_layout()
plt.show()

# %% [markdown]
# ![image.png](attachment:658da8cd-a9de-4f31-977f-778fe087c411.png)

# %%
x= np.array([15,17,18,17,12,17,12,19,14,11,12,19,16,13])
y= np.array([99,86,87,88,81,86,93,87,94,78,77,85,86,85])

plt.scatter(x,y)
plt.show()

# %%
y= np.random.randint(10,100,50)
x= np.random.randint(10,100,50)

plt.scatter(x,y)
plt.show()

# %%
sns.get_dataset_names()

# %%
tips = sns.load_dataset("tips")
tips.head()

# %%
plt.scatter(tips.tip, tips.total_bill, )
plt.show()

# tip ile total_bill arasında pozitif bir ilişki olduğunu görüyoruz.

# %%
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]

fig, ax = plt.subplots()

ax.bar(langs, students)
plt.show()

# %%
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]

fig, ax = plt.subplots()

ax.barh(langs, students)   # bar yanına h koyarsak horizontal olarak çizer.

plt.show()

# %%
tips.head(3)

# %%
tips.groupby("day").sum()  # nümerik sütunları toplayıp günlere göre gruplandırdı.

# %%
tips.groupby("day").sum().index

# %%
day = tips.day.unique()
day

# %%
tips.groupby("day")["total_bill"].sum()

# %%
day_of_total_bill= list(tips.groupby("day")["total_bill"].sum())
day_of_total_bill

# %%
fig, ax = plt.subplots(figsize = (12,7))  # figsize ile ölçülerini genişlettik.

ax.barh(day, day_of_total_bill)
plt.show()

# %%
day_of_tip= list(tips.groupby("day")["tip"].sum())
day_of_tip

# %%
fig, ax = plt.subplots(figsize = (8,6))  # figsize ile ölçülerini genişlettik.

ax.bar(day, day_of_tip)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (8,6))  # figsize ile ölçülerini genişlettik.


ax.bar(day, day_of_total_bill, label="total_bil")
ax.bar(day, day_of_tip, label="tip")

plt.legend()

plt.show()

# %%
# Optional hard to coding
fig, ax = plt.subplots(figsize=(10,5))

p = np.arange(len(day))  # gün uzunluğu kadar bir array oluşturdum.
width = 0.4  # bir barın genişliği olarak atadığımız değer.

ax.bar(p - width/2, day_of_total_bill, width, label="total_bill")  # p-width/2 dersek merkezden bunu bu kadar sola kaydır.
ax.bar(p + width/2, day_of_tip,        width, label="tip")      # p+width/2 dersek merkezden bunu bu kadar sola kaydır.

ax.set_xticks(p)
ax.set_xticklabels(day)

plt.legend()
plt.show()

# %%
x = np.random.normal(170,10,250)

plt.hist(x)
plt.show()

# %%
x = np.random.randn(259)

plt.hist(x, bins=30)  # bins parametresi ile grafiği daha okunaklı hale getirdik.
plt.show()

# %%
tips.head()

# %%
plt.hist(tips.total_bill, bins=40)
plt.show()

# %%
plt.hist(tips.tip, bins=40)
plt.show()

# %%
X = np.random.normal(170,10,250)

plt.boxplot(X)
plt.show()

# %%
X = np.random.normal(170,10,250)

plt.boxplot(X, vert=False)  # default True olur, false yazarsak vertical yapar.
plt.show()

# %%
box = np.array(np.random.randn(10,4))
print(box)

plt.boxplot(box, labels=['A', 'B', 'C', 'D'])
plt.show()

# %%
tips.head(2)

# %%
plt.boxplot(tips.tip)
plt.show()
# grafiğe baktığımızda max üzerinde outlierların olduklarını görüyoruz.

# %%
plt.boxplot([tips.tip, tips.total_bill])
plt.show()

# %%
plt.boxplot([tips.total_bill,tips.tip])
plt.show()

# %%
fig, ax = plt.subplots(2,1)

ax[0].boxplot(tips.tip)
ax[1].boxplot(tips.total_bill)

plt.show()

# %%
tips.head()

# %%
tips.iloc[:,0:2]

# %%
plt.boxplot(tips.iloc[:,0:2], labels=["total_bill","tip"])

plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

# %%
plt.figure(figsize=(10,8))
plt.pie(y, labels = mylabels, labeldistance = 0.7, autopct= "%.2f")

plt.show()

# %%
plt.figure(figsize=(10,8))
plt.pie(y, labels = mylabels, labeldistance = 0.7, autopct="%.2f")
plt.show()

# %%
plt.figure(figsize=(10,8))

y = np.array([35, 25, 25, 15])

mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

myexplode = [0.1, 0, 0, 0]

# %%
plt.figure(figsize=(10,8))
plt.pie(y, labels = mylabels, explode = myexplode, labeldistance = 0.7, autopct="%.2f")
plt.show()

# %%
plt.figure(figsize=(10,8))

colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explode_list = [0, 0, 0.1, 0.1] # ratio for each continent with which to offset each wedge.

y = np.array([25, 35, 25, 15])
mylabels = ["Bananas", "Apples", "Cherries", "Dates"]
myexplode = [0.1, 0.1, 0, 0]

plt.pie(y, labels = mylabels, labeldistance=0.5, autopct="%.1f", startangle=90, shadow=True, pctdistance=1.1, colors=colors_list, explode=explode_list)
plt.legend()
plt.show()

# startangle ilk olan Bananyı 90 derece olarak önce onu yerleştiriyor sonra diğerlerini de ona göre yerleştiriyor.
# autopct bunları float olarak nokta sonrasına koyduğumuz kadar basamak koyar. 
# labeldistance labelları içeri ve dışarı doğru

# %% [markdown]
# ***
# autopct = sayıların .dan sonraki sayısı(float basamak)
#
# startangle = kaç derece döndürüleceği
#
# pctdistance= sayıların ne kadar mesafeye yazılacağı
#
# explode = merkezden uzaklaşan pasta dilimleri
#
# labeldistance = birimlerin merkezden uzaklığı, "0" merkez, 1 çember
# ***

# %%
# fig.savefig("output.pdf")  ile çalıştığımız dosyayı kaydediyoruz.

# %% [markdown]
# ![image.png](attachment:b0b56735-0a07-4334-b682-187506131b6a.png)

# %%
# yukarıda va bottom yazarsak bin üzerine yazıyı üste yazar.

# %%
fig, ax = plt.subplots()
for i in range(len(kill_agecat.index)):
  plt.annotate(str(kill_agecat[i]), xy = (kill_agecat.index[i], kill_agecat[i]), ha = "center", va = "bottom")
ax.bar(kill_agecat.index, kill_agecat)
plt.show()

# %% [markdown]
# ![image.png](attachment:7ce63ce9-911a-4346-b9df-d14cd074042c.png)
