# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('currency_rates_082020_EUR.csv')

# %%
df.head()
# Out:
#   currency      date  rate
# 0      EUR  8/1/2020   1.0
# 1      EUR  8/2/2020   1.0
# 2      EUR  8/3/2020   1.0
# 3      EUR  8/4/2020   1.0
# 4      EUR  8/5/2020   1.0

# %%
df.currency.unique()
# Out:
# array(['EUR', 'GBP', 'USD', 'AUD', 'CAD', 'NZD', 'HKD', 'CHF', 'SEK',
#        'DKK', 'ILS', 'PLN', 'THB', 'MXN', 'JPY', 'NOK', 'SGD', 'MYR',
#        'TWD', 'HUF', 'CZK', 'BRL'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   currency  220 non-null    object
#  1   date      220 non-null    object
#  2   rate      220 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 5.3+ KB

# %%
# sales = pd.read_csv(‘sales_082020.csv’, parse_dates=[‘date’])

# %%
df["date"]=pd.to_datetime(df["date"],format='%d/%m/%Y')

# %%
df
# Out:
#     currency       date    rate
# 0        EUR 2020-01-08  1.0000
# 1        EUR 2020-02-08  1.0000
# 2        EUR 2020-03-08  1.0000
# 3        EUR 2020-04-08  1.0000
# 4        EUR 2020-05-08  1.0000
# ..       ...        ...     ...
# 215      BRL 2020-06-08  6.3324
# 216      BRL 2020-07-08  6.4111
# 217      BRL 2020-08-08  6.4111
# 218      BRL 2020-09-08  6.4111
# 219      BRL 2020-10-08  6.4351
#
# [220 rows x 3 columns]

# %%
df.groupby('currency').rate

# %%
df1 = pd.read_csv('sales_082020.csv')

# %%
df1
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 0       qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1       o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2       sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3       o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4       o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
# ...            ...           ...       ...            ...           ...
# 237666  p7ibf7soot            GB  ss7jy9ks             GB  hzc7pmjxmsb6
# 237667  2hg8zirueq            US  bk6apusi             US  fskn84lfyrvz
# 237668  k5hmcfxcs6            GB  n2ez0xph             GB  5afe7yhdpcmz
# 237669  ca8nc8qv1x            GB  j1s4nqxb             GB  ktdrjbrq0fo2
# 237670  z09h7w9zcd            US  0au7baxi             US  0r1qni2g1zi4
#
#                 category             brand currency   price        date
# ...

# %%
df2 = df1.groupby("category").get_group("Jewellery")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237671 entries, 0 to 237670
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   buyer_id        237671 non-null  object
#  1   buyer_country   237671 non-null  object
#  2   seller_id       237671 non-null  object
#  3   seller_country  237671 non-null  object
#  4   product_code    237671 non-null  object
#  5   category        237655 non-null  object
#  6   brand           119330 non-null  object
#  7   currency        237671 non-null  object
#  8   price           237671 non-null  float64
#  9   date            237671 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 18.1+ MB

# %%
df1["date"]=pd.to_datetime(df1["date"],format='%Y-%m-%d')

# %%
df1.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price       date
# 0           Dresses               NaN      GBP  19.11 2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92 2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37 2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27 2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90 2020-08-09

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237671 entries, 0 to 237670
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   buyer_id        237671 non-null  object
#  1   buyer_country   237671 non-null  object
#  2   seller_id       237671 non-null  object
#  3   seller_country  237671 non-null  object
#  4   product_code    237671 non-null  object
#  5   category        237655 non-null  object
#  6   brand           119330 non-null  object
#  7   currency        237671 non-null  object
#  8   price           237671 non-null  float64
#  9   date            237671 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 18.1+ MB

# %%
df1.duplicated().value_counts()
# Out:
# False    237631
# True         40
# dtype: int64

# %%
df1.groupby("seller_id").sum()
# Out:
#             price
# seller_id
# 00026zrn   104.52
# 000aaqnz    28.04
# 0011guej    14.85
# 00185ns7    16.75
# 001r1gvf    24.34
# ...           ...
# zzy962vt    38.82
# zzy993vl    38.37
# zzythjtn     5.57
# zzzqa0ik    25.62
# zzzzlrla    13.59
#
# [114227 rows x 1 columns]

# %%
df1.groupby("currency").sum()
# Out:
#                price
# currency
# AUD        325563.44
# BRL            34.92
# CAD         65101.80
# CHF          5974.74
# CZK          3923.18
# DKK          4853.44
# EUR        275837.69
# GBP       3449449.49
# HKD           108.13
# HUF         36919.18
# ILS            33.80
# JPY         39722.66
# MXN           389.47
# MYR           263.30
# NOK          3168.34
# NZD         10532.85
# PLN           693.36
# SEK         10903.22
# SGD           443.37
# THB          1223.72
# TWD            42.81
# USD       2504544.82

# %%
df1.groupby("brand")["price"].sum().sort_values()
# Out:
# brand
# 36572                      1.12
# 360 Cashmere               3.36
# Popular Sports             5.26
# 3LAB                       5.57
# Ann Demeulemeester         6.19
#                         ...
# Dr. Martens            84418.65
# Brandy Melville       100055.63
# American Vintage      105227.77
# Adidas                110351.33
# Nike                  373559.23
# Name: price, Length: 1134, dtype: float64

# %%
df2 = df1.groupby("category").get_group("Jewellery")

# %%
df2.brand.value_counts(dropna=False).product_code.nunique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-c06f020f6d94> in <module>
# ----> 1 df2.brand.value_counts(dropna=False).product_code.nunique()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'product_code'

# %%
df2.brand.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-0a877d80d5fc> in <module>
# ----> 1 df2.brand.isnull().sum()
#
# AttributeError: 'int' object has no attribute 'brand'

# %%
df1.groupby("brand")["price"].sum().sort_values()
# Out:
# brand
# 36572                      1.12
# 360 Cashmere               3.36
# Popular Sports             5.26
# 3LAB                       5.57
# Ann Demeulemeester         6.19
#                         ...
# Dr. Martens            84418.65
# Brandy Melville       100055.63
# American Vintage      105227.77
# Adidas                110351.33
# Nike                  373559.23
# Name: price, Length: 1134, dtype: float64

# %%
df3 = df1.merge(df, how='left', on=["date","currency"])

# %%
df3.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price       date  rate
# 0           Dresses               NaN      GBP  19.11 2020-08-03   NaN
# 1         Outerwear  Adidas Originals      GBP  15.92 2020-08-09   NaN
# 2       Tops - Mens               NaN      GBP   6.37 2020-08-07   NaN
# 3       Tops - Mens          Berghaus      GBP  25.27 2020-08-09   NaN
# 4  Bottoms - Womens               NaN      GBP   8.90 2020-08-09   NaN

# %%
df3["price_euro"] = (1/df3.rate)+df3.price

# %%
df3.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price       date  rate  \
# 0           Dresses               NaN      GBP  19.11 2020-08-03   NaN
# 1         Outerwear  Adidas Originals      GBP  15.92 2020-08-09   NaN
# 2       Tops - Mens               NaN      GBP   6.37 2020-08-07   NaN
# 3       Tops - Mens          Berghaus      GBP  25.27 2020-08-09   NaN
# 4  Bottoms - Womens               NaN      GBP   8.90 2020-08-09   NaN
#
#    price_euro
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df3.price_euro.sum()
# Out:
# 1065294.642434167

# %%
sales = pd.read_csv("sales_082020.csv", parse_dates=["date"])
sales.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price       date
# 0           Dresses               NaN      GBP  19.11 2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92 2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37 2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27 2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90 2020-08-09

# %%
currency_rates = pd.read_csv("currency_rates_082020_EUR.csv", parse_dates=["date"])
currency_rates.head()
# Out:
#   currency       date  rate
# 0      EUR 2020-08-01   1.0
# 1      EUR 2020-08-02   1.0
# 2      EUR 2020-08-03   1.0
# 3      EUR 2020-08-04   1.0
# 4      EUR 2020-08-05   1.0

# %%
currency_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   currency  220 non-null    object
#  1   date      220 non-null    datetime64[ns]
#  2   rate      220 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 5.3+ KB

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237671 entries, 0 to 237670
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   buyer_id        237671 non-null  object
#  1   buyer_country   237671 non-null  object
#  2   seller_id       237671 non-null  object
#  3   seller_country  237671 non-null  object
#  4   product_code    237671 non-null  object
#  5   category        237655 non-null  object
#  6   brand           119330 non-null  object
#  7   currency        237671 non-null  object
#  8   price           237671 non-null  float64
#  9   date            237671 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 18.1+ MB

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-d05ef12b182f> in <module>
# ----> 1 sales_and_currency[(sales_and_currency["category"] == "Jewellery")\
#       2                     & (sales_and_currency["brand"].isnull())]\
#       3                     ["product_code"].nunique()
#
# NameError: name 'sales_and_currency' is not defined

# %%
sales_and_currency["product_code"].unique()

# %%
sales_and_currency[(sales_and_currency["category"] == "Jewellery")\
                    & (sales_and_currency["brand"].isnull())]\
                    ["product_code"].nunique()

# %%
currency_rates.info()
